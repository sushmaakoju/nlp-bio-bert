# %% [markdown]
# ### Named Entity Recognition over medical journal corpus

# %% [markdown]
# ##### Homework 3, Fall, 2021
# ##### Prof. James H. Martin
# ###### author: Sushma Akoju

# %% [markdown]
# Notebook to train/fine-tune a BioBERT model to perform named entity recognition (NER).
#
# Required features:
#   - Sentence id
#   - Word
#   - Tag
#
# ### This notebook includes
# - Viterbi Dynamic programming approach with Trellis and back pointer approach.
# - HMM aproach with Start, Transition, Emission probabilities for observations using Bigram approach. This is adaptable for trigram approach, which is not explored in this notebook in the interest of time as well as scope of homework
# - Replacing RARE words with a RARE keyword to account for out-of-vocabulary and/or rare words in Test dataset.
#
# ### About the Dataset split;
# - the dataset split is 80/20

# %% [markdown]
# #### References
# - [Sequence Labeling for Parts of Speech and Named Entities:  ](https://web.stanford.edu/~jurafsky/slp3/8.pdf)
# - [Hidden Markov Models:  ](https://web.stanford.edu/~jurafsky/slp3/A.pdf)
# - [Viterbi algorithm: ](https://en.wikipedia.org/wiki/Viterbi_algorithm#Pseudocode)

# %% [markdown]
# #### Analysis:
# - From above results, it is not recommended to continue using HMM and Viterbi approach for Named Entity Recognition, since the very pitfall of HMM model is that it is not flexible enough to unknown words as well as any new vocabulary words. It is possible to consider the previous word is a B tag, then next tag as an O tag, then the likelihood of having an I tag or O tag more than a B tag. However this consideration is not sufficient to generalize and improve HMM with Viterbi.
# - We could use additional features such as the first letter is a capital letter, all letters are capital letters, the previous word is a hyphen, or next word is a number, previous word + next word is an alphanumeric, all of which can act as better features for working with HMM. The idea is frequencies for each of these new features and their likelihood of being assigned a tag under a 5-gram approach, may work and seems like a reasonable approach to explore, but will be limiting to this approach alone.

# %%
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/nlp-hw3'
# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/nlp-hw3
# /content/drive/MyDrive/Colab Notebooks/nlp-hw3

# %% [markdown]
# Preprocess the Data and analyze.

# %%
all_lines = {}
ent_tags = {}
tokens = []
with open("S21-gene-train.txt", "r", encoding="utf8", newline="\n") as file:
  lines = file.readlines()

new_line_counter = 0
all_raw_lines = []
sentences = []
sentence = []
word_tags = {}
this_sentence_tag_pairs = []
for i,line in enumerate(lines):
  if line != "\n":
    this_line = line.split("\t")
    sentence.append(this_line[1])
    #print(this_line)
    ent_tags[this_line[1].strip()] = this_line[2].strip()
    this_pair = this_line[1].strip(), this_line[2].strip()
    this_sentence_tag_pairs.append(this_pair)
    tokens.append(this_line[1].strip())
    if this_line[1].strip() not in word_tags.keys():
      word_tags[this_line[1].strip()] = {"O": 0, "I":0, "B":0 }
    word_tags[this_line[1].strip()][this_line[2].strip()] += 1
    all_raw_lines.append({"Sentence #":new_line_counter,"Line":int(this_line[0].strip()),"Word":this_line[1].strip(), "Tag":this_line[2].strip()})
  else:
    new_line_counter += 1
    all_lines[i] = this_sentence_tag_pairs
    this_sentence_tag_pairs = []
    sentences.append(" ".join(sentence))
    sentence = []

# %%
all_lines
# Out:
# {9: [('Comparison', 'O'),
#   ('with', 'O'),
#   ('alkaline', 'B'),
#   ('phosphatases', 'I'),
#   ('and', 'O'),
#   ('5', 'B'),
#   ('-', 'I'),
#   ('nucleotidase', 'I'),
#   ('.', 'O')],
#  16: [('Pharmacologic', 'O'),
#   ('aspects', 'O'),
#   ('of', 'O'),
#   ('neonatal', 'O'),
#   ('hyperbilirubinemia', 'O'),
#   ('.', 'O')],
#  62: [('When', 'O'),
#   ('CSF', 'O'),
#   ('[', 'O'),
#   ('HCO3', 'O'),
#   ('-]', 'O'),
#   ('is', 'O'),
#   ('shown', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('function', 'O'),
#   ('of', 'O'),
#   ('CSF', 'O'),
#   ('PCO2', 'O'),
#   ('the', 'O'),
#   ('data', 'O'),
#   ('of', 'O'),
#   ('K', 'O'),
#   ('-', 'O'),
#   ('depleted', 'O'),
#   ('rats', 'O'),
#   ('are', 'O'),
#   ('no', 'O'),
#   ('longer', 'O'),
#   ('displaced', 'O'),
#   ('when', 'O'),
#   ('compared', 'O'),
#   ('to', 'O'),
#   ('controls', 'O'),
#   ('but', 'O'),
#   ('still', 'O'),
#   ('have', 'O'),
#   ('a', 'O'),
#   ('significantly', 'O'),
#   ('greater', 'O'),
#   ('slope', 'O'),
#   ('(', 'O'),
#   ('1', 'O'),
#   ('.', 'O'),
#   ('21', 'O'),
#   ('+/-', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('23', 'O'),
#   ('vs', 'O'),
#   ('.', 'O')],
#  87: [('Flurazepam', 'O'),
#   ('thus', 'O'),
#   ('appears', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('an', 'O'),
#   ('effective', 'O'),
#   ('hypnotic', 'O'),
#   ('drug', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('optimum', 'O'),
#   ('dose', 'O'),
#   ('for', 'O'),
#   ('use', 'O'),
#   ('in', 'O'),
#   ('general', 'O'),
#   ('practice', 'O'),
#   ('being', 'O'),
#   ('15', 'O'),
#   ('mg', 'O'),
#   ('at', 'O'),
#   ('night', 'O'),
#   ('.', 'O')],
#  92: [('Beta', 'O'), ('blocking', 'O'), ('agents', 'O'), ('.', 'O')],
#  108: [('When', 'O'),
#   ('extracorporeal', 'O'),
#   ('CO2', 'O'),
#   ('removal', 'O'),
#   ('approximated', 'O'),
#   ('CO2', 'O'),
#   ('production', 'O'),
#   ('(', 'O'),
#   ('VCO2', 'O'),
#   ('),', 'O'),
#   ('alveolar', 'O'),
#   ('ventilation', 'O'),
#   ('almost', 'O'),
#   ('ceased', 'O'),
#   ('.', 'O')],
#  160: [('Intravenous', 'O'),
#   ('administration', 'O'),
#   ('(', 'O'),
#   ('25', 'O'),
#   ('mg', 'O'),
#   ('/', 'O'),
#   ('kg', 'O'),
#   (')', 'O'),
#   ('of', 'O'),
#   ('carbonic', 'B'),
#   ('anhydrase', 'I'),
#   ('inhibitors', 'O'),
#   ('(', 'O'),
#   ('acetazolamide', 'O'),
#   (',', 'O'),
#   ('methazolamide', 'O'),
#   (',', 'O'),
#   ('dichlorphenamide', 'O'),
#   (',', 'O'),
#   ('sulthiame', 'O'),
#   (')', 'O'),
#   ('induced', 'O'),
#   ('an', 'O'),
#   ('early', 'O'),
#   ('important', 'O'),
#   ('rise', 'O'),
#   ('of', 'O'),
#   ('cortical', 'O'),
#   ('p', 'O'),
#   ('O2', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('is', 'O'),
#   ('not', 'O'),
#   ('dependent', 'O'),
#   ('on', 'O'),
#   ('increase', 'O'),
#   ('of', 'O'),
#   ('p', 'O'),
#   ('O2', 'O'),
#   ('and', 'O'),
#   ('p', 'O'),
#   ('CO2', 'O'),
#   ('and', 'O'),
#   ('decrease', 'O'),
#   ('of', 'O'),
#   ('pH', 'O'),
#   ('in', 'O'),
#   ('arterial', 'O'),
#   ('blood', 'O'),
#   ('.', 'O')],
#  171: [('Teratological', 'O'),
#   ('study', 'O'),
#   ('of', 'O'),
#   ('etoperidone', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('rat', 'O'),
#   ('and', 'O'),
#   ('rabbit', 'O'),
#   ('.', 'O')],
#  181: [('Colorectal', 'O'),
#   ('polyps', 'O'),
#   ('should', 'O'),
#   ('be', 'O'),
#   ('removed', 'O'),
#   ('endoscopically', 'O'),
#   ('whenever', 'O'),
#   ('possible', 'O'),
#   ('.', 'O')],
#  202: [('The', 'O'),
#   ('variable', 'O'),
#   ('HMG', 'B'),
#   ('dosage', 'O'),
#   ('regimen', 'O'),
#   ('was', 'O'),
#   ('found', 'O'),
#   ('to', 'O'),
#   ('offer', 'O'),
#   ('no', 'O'),
#   ('advantages', 'O'),
#   ('when', 'O'),
#   ('compared', 'O'),
#   ('with', 'O'),
#   ('our', 'O'),
#   ('standard', 'O'),
#   ('daily', 'O'),
#   ('dosage', 'O'),
#   ('regimen', 'O'),
#   ('.', 'O')],
#  220: [('When', 'O'),
#   ('the', 'O'),
#   ('CO2', 'O'),
#   ('content', 'O'),
#   ('reached', 'O'),
#   ('9', 'O'),
#   ('Vol', 'O'),
#   ('%', 'O'),
#   ('the', 'O'),
#   ('animals', 'O'),
#   ('became', 'O'),
#   ('apathic', 'O'),
#   ('and', 'O'),
#   ('lost', 'O'),
#   ('body', 'O'),
#   ('weight', 'O'),
#   ('.', 'O')],
#  233: [('Serum', 'B'),
#   ('gamma', 'I'),
#   ('glutamyltransferase', 'I'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('diagnosis', 'O'),
#   ('of', 'O'),
#   ('liver', 'O'),
#   ('disease', 'O'),
#   ('in', 'O'),
#   ('cattle', 'O'),
#   ('.', 'O')],
#  273: [('By', 'O'),
#   ('contrast', 'O'),
#   (',', 'O'),
#   ('secretory', 'B'),
#   ('HI', 'I'),
#   ('antibodies', 'I'),
#   ('were', 'O'),
#   ('not', 'O'),
#   ('demonstrated', 'O'),
#   ('at', 'O'),
#   ('the', 'O'),
#   ('onset', 'O'),
#   ('of', 'O'),
#   ('illness', 'O'),
#   ('in', 'O'),
#   ('any', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('patients', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('their', 'O'),
#   ('formation', 'O'),
#   ('started', 'O'),
#   ('early', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('antibodies', 'O'),
#   ('reached', 'O'),
#   ('maximal', 'O'),
#   ('levels', 'O'),
#   ('about', 'O'),
#   ('10', 'O'),
#   ('days', 'O'),
#   ('after', 'O'),
#   ('onset', 'O'),
#   ('of', 'O'),
#   ('illness', 'O'),
#   ('.', 'O')],
#  299: [('With', 'O'),
#   ('the', 'O'),
#   ('exception', 'O'),
#   ('of', 'O'),
#   ('virus', 'O'),
#   ('assay', 'O'),
#   ('and', 'O'),
#   ('quantitation', 'O'),
#   (',', 'O'),
#   ('these', 'O'),
#   ('methods', 'O'),
#   ('are', 'O'),
#   ('simple', 'O'),
#   ('and', 'O'),
#   ('inexpensive', 'O'),
#   ('enough', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('done', 'O'),
#   ('in', 'O'),
#   ('typical', 'O'),
#   ('shellfish', 'O'),
#   ('microbiology', 'O'),
#   ('laboratories', 'O'),
#   ('.', 'O')],
#  305: [('Characteristics', 'O'),
#   ('of', 'O'),
#   ('lipase', 'B'),
#   ('activity', 'O'),
#   ('.', 'O')],
#  317: [('Takayasu', 'O'),
#   ("'", 'O'),
#   ('s', 'O'),
#   ('disease', 'O'),
#   (':', 'O'),
#   ('association', 'O'),
#   ('with', 'O'),
#   ('HLA', 'B'),
#   ('-', 'I'),
#   ('B5', 'I'),
#   ('.', 'O')],
#  333: [('SGPT', 'B'),
#   (',', 'O'),
#   ('SGOT', 'B'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('alkaline', 'B'),
#   ('phosphatase', 'I'),
#   ('concentrations', 'O'),
#   ('were', 'O'),
#   ('essentially', 'O'),
#   ('normal', 'O'),
#   ('in', 'O'),
#   ('all', 'O'),
#   ('subjects', 'O'),
#   ('.', 'O')],
#  345: [('Gamma', 'B'),
#   ('glutamyl', 'I'),
#   ('transpeptidase', 'I'),
#   ('(', 'O'),
#   ('GGTP', 'B'),
#   (')', 'O'),
#   ('activity', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('seminal', 'O'),
#   ('fluid', 'O')],
#  367: [('Patients', 'O'),
#   ('with', 'O'),
#   ('Parkinson', 'O'),
#   ("'", 'O'),
#   ('s', 'O'),
#   ('disease', 'O'),
#   ('showed', 'O'),
#   ('a', 'O'),
#   ('relatively', 'O'),
#   ('high', 'O'),
#   ('incidence', 'O'),
#   ('to', 'O'),
#   ('psychoses', 'O'),
#   ('during', 'O'),
#   ('drug', 'O'),
#   ('treatment', 'O'),
#   ('(', 'O'),
#   ('51', 'O'),
#   ('.', 'O'),
#   ('47', 'O'),
#   ('%).', 'O')],
#  385: [('Selective', 'O'),
#   ('stimulation', 'O'),
#   ('of', 'O'),
#   ('central', 'O'),
#   ('alpha', 'B'),
#   ('-', 'I'),
#   ('autoreceptors', 'I'),
#   ('following', 'O'),
#   ('treatment', 'O'),
#   ('with', 'O'),
#   ('alpha', 'O'),
#   ('-', 'O'),
#   ('methyldopa', 'O'),
#   ('and', 'O'),
#   ('FLA', 'O'),
#   ('136', 'O'),
#   ('.', 'O')],
#  401: [('Anti', 'O'),
#   ('-', 'O'),
#   ('anxiety', 'O'),
#   ('action', 'O'),
#   ('of', 'O'),
#   ('diazepam', 'O'),
#   ('after', 'O'),
#   ('intra', 'O'),
#   ('-', 'O'),
#   ('amygdaloid', 'O'),
#   ('application', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('rat', 'O'),
#   ('.', 'O')],
#  404: [('Abstracts', 'O'), ('.', 'O')],
#  422: [('Removal', 'O'),
#   ('of', 'O'),
#   ('thick', 'O'),
#   (',', 'O'),
#   ('permanently', 'O'),
#   ('altered', 'O'),
#   ('mucoas', 'O'),
#   ('is', 'O'),
#   ('recommended', 'O'),
#   ('even', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('absence', 'O'),
#   ('of', 'O'),
#   ('squamous', 'O'),
#   ('epithelium', 'O'),
#   ('.', 'O')],
#  446: [('An', 'O'),
#   ('IgG', 'B'),
#   ('monoclonal', 'O'),
#   ('gammopathy', 'O'),
#   ('was', 'O'),
#   ('present', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('serum', 'O'),
#   ('of', 'O'),
#   ('4', 'O'),
#   ('patients', 'O'),
#   ('and', 'O'),
#   ('Bence', 'O'),
#   ('-', 'O'),
#   ('Joanes', 'O'),
#   ('proteinuria', 'O'),
#   ('was', 'O'),
#   ('found', 'O'),
#   ('in', 'O'),
#   ('1', 'O'),
#   ('patient', 'O'),
#   ('.', 'O')],
#  462: [('Studies', 'O'),
#   ('on', 'O'),
#   ('immunoglobulin', 'B'),
#   ('E', 'I'),
#   (':', 'O'),
#   ('the', 'O'),
#   ('impact', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('sojourn', 'O'),
#   ('with', 'O'),
#   ('Professor', 'O'),
#   ('Dan', 'O'),
#   ('H', 'O'),
#   ('.', 'O')],
#  475: [('Peroxydase', 'B'),
#   ('reaction', 'O'),
#   ('stains', 'O'),
#   ('were', 'O'),
#   ('negative', 'O'),
#   (',', 'O'),
#   ('chloroacetate', 'B'),
#   ('esterase', 'I'),
#   ('were', 'O'),
#   ('strongly', 'O'),
#   ('positive', 'O'),
#   ('.', 'O')],
#  533: [('Ten', 'O'),
#   ('out', 'O'),
#   ('-', 'O'),
#   ('patients', 'O'),
#   ('with', 'O'),
#   ('pustulosis', 'O'),
#   ('palmaris', 'O'),
#   ('et', 'O'),
#   ('plantaris', 'O'),
#   ('were', 'O'),
#   ('examined', 'O'),
#   ('with', 'O'),
#   ('direct', 'O'),
#   ('immunofluorescence', 'O'),
#   ('(', 'O'),
#   ('IF', 'O'),
#   (')', 'O'),
#   ('technique', 'O'),
#   ('for', 'O'),
#   ('deposition', 'O'),
#   ('of', 'O'),
#   ('fibrinogen', 'B'),
#   (',', 'O'),
#   ('fibrin', 'B'),
#   ('or', 'O'),
#   ('its', 'O'),
#   ('degradation', 'O'),
#   ('products', 'O'),
#   ('(', 'O'),
#   ('FR', 'B'),
#   ('-', 'I'),
#   ('antigen', 'I'),
#   (')', 'O'),
#   ('in', 'O'),
#   ('affected', 'O'),
#   ('and', 'O'),
#   ('unaffected', 'O'),
#   ('skin', 'O'),
#   (',', 'O'),
#   ('together', 'O'),
#   ('with', 'O'),
#   ('heparin', 'O'),
#   ('-', 'O'),
#   ('precipitable', 'O'),
#   ('fraction', 'O'),
#   ('(', 'O'),
#   ('HPF', 'O'),
#   ('),', 'O'),
#   ('cryoglobulin', 'B'),
#   ('and', 'O'),
#   ('total', 'O'),
#   ('plasma', 'O'),
#   ('fibrinogen', 'B'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('blood', 'O'),
#   ('.', 'O')],
#  556: [('Of', 'O'),
#   ('600', 'O'),
#   ('mediastinoscopies', 'O'),
#   ('carried', 'O'),
#   ('out', 'O'),
#   ('from', 'O'),
#   ('1966', 'O'),
#   ('to', 'O'),
#   ('1973', 'O'),
#   (',', 'O'),
#   ('479', 'O'),
#   ('were', 'O'),
#   ('performed', 'O'),
#   ('to', 'O'),
#   ('assess', 'O'),
#   ('the', 'O'),
#   ('operability', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('pulmonary', 'O'),
#   ('carcinoma', 'O'),
#   ('.', 'O')],
#  578: [('A', 'O'),
#   ('mixture', 'O'),
#   ('of', 'O'),
#   ('human', 'B'),
#   ('albumin', 'I'),
#   ('5', 'O'),
#   ('%', 'O'),
#   ('and', 'O'),
#   ('hydroxy', 'O'),
#   ('-', 'O'),
#   ('ethyl', 'O'),
#   ('-', 'O'),
#   ('starch', 'O'),
#   ('was', 'O'),
#   ('used', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('solution', 'O'),
#   ('for', 'O'),
#   ('dilution', 'O'),
#   ('.', 'O')],
#  625: [('In', 'O'),
#   ('the', 'O'),
#   ('matched', 'O'),
#   ('control', 'O'),
#   ('group', 'O'),
#   ('the', 'O'),
#   ('acquisition', 'O'),
#   ('-', 'O'),
#   ('rate', 'O'),
#   ('of', 'O'),
#   ('both', 'O'),
#   ('symptomatic', 'O'),
#   ('and', 'O'),
#   ('asymptomatic', 'O'),
#   ('0acteriuria', 'O'),
#   ('was', 'O'),
#   ('over', 'O'),
#   ('12', 'O'),
#   ('%,', 'O'),
#   ('a', 'O'),
#   ('figure', 'O'),
#   ('similar', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('percentage', 'O'),
#   ('of', 'O'),
#   ('women', 'O'),
#   ('present', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('practice', 'O'),
#   ('population', 'O'),
#   ('during', 'O'),
#   ('one', 'O'),
#   ('year', 'O'),
#   ('with', 'O'),
#   ('transient', 'O'),
#   (',', 'O'),
#   ('symptomatic', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('persistent', 'O'),
#   ('A', 'O'),
#   ('.', 'O'),
#   ('B', 'O'),
#   ('.', 'O')],
#  634: [('Late', 'O'),
#   ('complications', 'O'),
#   ('of', 'O'),
#   ('catheterisation', 'O'),
#   ('for', 'O'),
#   ('intravenous', 'O'),
#   ('nutrition', 'O'),
#   ('.', 'O')],
#  640: [('Prenatal', 'O'),
#   ('diagnosis', 'O'),
#   ('of', 'O'),
#   ('galactosaemia', 'O'),
#   ('.', 'O')],
#  651: [('Sings', 'O'),
#   ('which', 'O'),
#   ('are', 'O'),
#   ('indicative', 'O'),
#   ('of', 'O'),
#   ('metaplastic', 'O'),
#   ('erythropoiesis', 'O'),
#   ('are', 'O'),
#   ('absent', 'O'),
#   ('.', 'O')],
#  671: [('False', 'O'),
#   ('positive', 'O'),
#   ('amniotic', 'B'),
#   ('fluid', 'I'),
#   ('alpha', 'I'),
#   ('fetoprotein', 'I'),
#   ('levels', 'O'),
#   ('resulting', 'O'),
#   ('from', 'O'),
#   ('contamination', 'O'),
#   ('with', 'O'),
#   ('fetal', 'O'),
#   ('blood', 'O'),
#   (':', 'O'),
#   ('results', 'O'),
#   ('of', 'O'),
#   ('an', 'O'),
#   ('experiment', 'O'),
#   ('.', 'O')],
#  680: [('Serum', 'O'),
#   ('-', 'O'),
#   ('ferritin', 'B'),
#   ('in', 'O'),
#   ('diagnosis', 'O'),
#   ('of', 'O'),
#   ('haemochromatosis', 'O'),
#   ('.', 'O')],
#  695: [('In', 'O'),
#   ('2', 'O'),
#   ('subjects', 'O'),
#   ('the', 'O'),
#   ('phytomitogen', 'O'),
#   ('reactivity', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('lymphocytes', 'O'),
#   ('was', 'O'),
#   ('improved', 'O'),
#   ('after', 'O'),
#   ('treatment', 'O'),
#   ('.', 'O')],
#  702: [('Patients', 'O'),
#   ('at', 'O'),
#   ('risk', 'O'),
#   ('of', 'O'),
#   ('hypothyroidism', 'O'),
#   ('.', 'O')],
#  714: [('Albumin', 'B'),
#   ('and', 'O'),
#   ('cyclic', 'O'),
#   ('AMP', 'O'),
#   ('levels', 'O'),
#   ('in', 'O'),
#   ('peritoneal', 'O'),
#   ('fluids', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('child', 'O')],
#  717: [('Preface', 'O'), ('.', 'O')],
#  748: [('Thirty', 'O'),
#   ('-', 'O'),
#   ('five', 'O'),
#   ('strains', 'O'),
#   ('of', 'O'),
#   ('Legionnaires', 'O'),
#   ("'", 'O'),
#   ('disease', 'O'),
#   ('bacteria', 'O'),
#   ('were', 'O'),
#   ('shown', 'O'),
#   ('to', 'O'),
#   ('belong', 'O'),
#   ('in', 'O'),
#   ('four', 'O'),
#   ('distinct', 'O'),
#   ('serologic', 'O'),
#   ('groups', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('basis', 'O'),
#   ('of', 'O'),
#   ('findings', 'O'),
#   ('obtained', 'O'),
#   ('with', 'O'),
#   ('direct', 'O'),
#   ('fluorescent', 'O'),
#   ('antibody', 'O'),
#   ('testing', 'O'),
#   ('.', 'O')],
#  768: [('On', 'O'),
#   ('the', 'O'),
#   ('other', 'O'),
#   ('hand', 'O'),
#   ('factor', 'B'),
#   ('IX', 'I'),
#   ('activity', 'O'),
#   ('is', 'O'),
#   ('decreased', 'O'),
#   ('in', 'O'),
#   ('coumarin', 'O'),
#   ('treatment', 'O'),
#   ('with', 'O'),
#   ('factor', 'B'),
#   ('IX', 'I'),
#   ('antigen', 'O'),
#   ('remaining', 'O'),
#   ('normal', 'O'),
#   ('.', 'O')],
#  831: [('The', 'O'),
#   ('concentration', 'O'),
#   ('of', 'O'),
#   ('alpha', 'B'),
#   ('2', 'I'),
#   ('-', 'I'),
#   ('macroglobulin', 'I'),
#   (',', 'O'),
#   ('alpha', 'B'),
#   ('1', 'I'),
#   ('-', 'I'),
#   ('antitrypsin', 'I'),
#   (',', 'O'),
#   ('plasminogen', 'B'),
#   (',', 'O'),
#   ('C3', 'B'),
#   ('-', 'I'),
#   ('complement', 'I'),
#   (',', 'O'),
#   ('fibrinogen', 'B'),
#   ('degradation', 'I'),
#   ('products', 'I'),
#   ('(', 'O'),
#   ('FDP', 'B'),
#   (')', 'O'),
#   ('and', 'O'),
#   ('fibrinolytic', 'O'),
#   ('activity', 'O'),
#   (',', 'O'),
#   ('were', 'O'),
#   ('studied', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('aqueous', 'O'),
#   ('humour', 'O'),
#   ('and', 'O'),
#   ('serum', 'O'),
#   ('from', 'O'),
#   ('nine', 'O'),
#   ('patients', 'O'),
#   ('with', 'O'),
#   ('Fuchs', 'O'),
#   ("'", 'O'),
#   ('endothelial', 'O'),
#   ('dystrophy', 'O'),
#   (',', 'O'),
#   ('17', 'O'),
#   ('patients', 'O'),
#   ('with', 'O'),
#   ('uncomplicated', 'O'),
#   ('senile', 'O'),
#   ('cataract', 'O'),
#   ('and', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('secondary', 'O'),
#   ('aqueous', 'O'),
#   ('from', 'O'),
#   ('six', 'O'),
#   ('cataract', 'O'),
#   ('patients', 'O'),
#   ('.', 'O')],
#  844: [('Only', 'O'),
#   ('17', 'O'),
#   ('%', 'O'),
#   ('of', 'O'),
#   ('all', 'O'),
#   ('patients', 'O'),
#   ('admitted', 'O'),
#   ('it', 'O'),
#   ('at', 'O'),
#   ('all', 'O'),
#   ('times', 'O'),
#   ('.', 'O')],
#  865: [('Prazosin', 'O'),
#   ('alone', 'O'),
#   ('was', 'O'),
#   ('effective', 'O'),
#   ('in', 'O'),
#   ('volume', 'O'),
#   ('responsive', 'O'),
#   ('patients', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('dose', 'O'),
#   ('of', 'O'),
#   ('5', 'O'),
#   ('+/-', 'O'),
#   ('1', 'O'),
#   ('.', 'O'),
#   ('0', 'O'),
#   ('mg', 'O'),
#   ('daily', 'O'),
#   ('.', 'O')],
#  909: [('T4', 'O'),
#   ('and', 'O'),
#   ('FT4I', 'O'),
#   ('followed', 'O'),
#   ('parallel', 'O'),
#   ('courses', 'O'),
#   ('in', 'O'),
#   ('both', 'O'),
#   ('groups', 'O'),
#   (';', 'O'),
#   ('during', 'O'),
#   ('the', 'O'),
#   ('first', 'O'),
#   ('45', 'O'),
#   ('days', 'O'),
#   (',', 'O'),
#   ('however', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('values', 'O'),
#   ('were', 'O'),
#   ('significantly', 'O'),
#   ('lower', 'O'),
#   ('in', 'O'),
#   ('premature', 'O'),
#   ('infants', 'O'),
#   ('under', 'O'),
#   ('34', 'O'),
#   ('weeks', 'O'),
#   ("'", 'O'),
#   ('EGA', 'O'),
#   ('than', 'O'),
#   ('in', 'O'),
#   ('term', 'O'),
#   ('infants', 'O'),
#   ('(', 'O'),
#   ('P', 'O'),
#   ('less', 'O'),
#   ('than', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('001', 'O'),
#   (').', 'O')],
#  924: [('A', 'O'),
#   ('three', 'O'),
#   ('-', 'O'),
#   ('phased', 'O'),
#   ('analysis', 'O'),
#   ('of', 'O'),
#   ('treatment', 'O'),
#   ('plans', 'O'),
#   ('for', 'O'),
#   ('45', 'O'),
#   ('patients', 'O'),
#   ('was', 'O'),
#   ('undertaken', 'O'),
#   ('.', 'O')],
#  942: [('Aspirin', 'O'),
#   ('intolerance', 'O'),
#   (':', 'O'),
#   ('unaltered', 'O'),
#   ('susceptibility', 'O'),
#   ('of', 'O'),
#   ('platelet', 'B'),
#   ('cyclo', 'I'),
#   ('-', 'I'),
#   ('oxygenase', 'I'),
#   ('to', 'O'),
#   ('inhibition', 'O'),
#   ('by', 'O'),
#   ('aspirin', 'O'),
#   ('in', 'O'),
#   ('vitro', 'O'),
#   ('.', 'O')],
#  968: [('These', 'O'),
#   ('results', 'O'),
#   ('indicate', 'O'),
#   ('that', 'O'),
#   ('cynomolgus', 'O'),
#   ('monkeys', 'O'),
#   ('are', 'O'),
#   ('either', 'O'),
#   ('less', 'O'),
#   ('sensitive', 'O'),
#   ('or', 'O'),
#   ('respond', 'O'),
#   ('differently', 'O'),
#   ('than', 'O'),
#   ('rhesus', 'O'),
#   ('monkeys', 'O'),
#   ('to', 'O'),
#   ('some', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('pharmacological', 'O'),
#   ('effects', 'O'),
#   ('of', 'O'),
#   ('norcocaine', 'O'),
#   ('.', 'O')],
#  1001: [('59', 'O'),
#   ('cases', 'O'),
#   ('of', 'O'),
#   ('surgically', 'O'),
#   ('resectable', 'O'),
#   ('cancers', 'O'),
#   ('(', 'O'),
#   ('T1', 'O'),
#   (',', 'O'),
#   ('T2', 'O'),
#   (',', 'O'),
#   ('T3', 'O'),
#   (',', 'O'),
#   ('N0', 'O'),
#   (',', 'O'),
#   ('N1', 'O'),
#   (')', 'O'),
#   ('had', 'O'),
#   ('a', 'O'),
#   ('minimum', 'O'),
#   ('followup', 'O'),
#   ('of', 'O'),
#   ('two', 'O'),
#   ('years', 'O'),
#   ('(', 'O'),
#   ('average', 'O'),
#   ('4', 'O'),
#   ('years', 'O'),
#   ('+/-', 'O'),
#   ('3', 'O'),
#   ('months', 'O'),
#   (').', 'O')],
#  1042: [('The', 'O'),
#   ('effect', 'O'),
#   ('of', 'O'),
#   ('CBZ', 'O'),
#   ('and', 'O'),
#   ('DPH', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('explained', 'O'),
#   ('by', 'O'),
#   ('interference', 'O'),
#   ('with', 'O'),
#   ('thyroid', 'O'),
#   ('hormone', 'O'),
#   ('binding', 'O'),
#   ('to', 'O'),
#   ('TBG', 'B'),
#   ('combined', 'O'),
#   ('with', 'O'),
#   ('enzyme', 'O'),
#   ('-', 'O'),
#   ('induced', 'O'),
#   ('increased', 'O'),
#   ('metabolic', 'O'),
#   ('clearance', 'O'),
#   ('rate', 'O'),
#   ('of', 'O'),
#   ('thyroid', 'O'),
#   ('hormones', 'O'),
#   ('without', 'O'),
#   ('homeostatic', 'O'),
#   ('maintenance', 'O'),
#   ('of', 'O'),
#   ('premedication', 'O'),
#   ('levels', 'O'),
#   ('of', 'O'),
#   ('FT4', 'O'),
#   ('and', 'O'),
#   ('FT3', 'O'),
#   ('.', 'O')],
#  1066: [('The', 'O'),
#   ('present', 'O'),
#   ('research', 'O'),
#   ('evaluated', 'O'),
#   ('the', 'O'),
#   ('possibility', 'O'),
#   ('that', 'O'),
#   ('polyethylene', 'O'),
#   ('glycol', 'O'),
#   ('400', 'O'),
#   ('(', 'O'),
#   ('PEG', 'O'),
#   ('400', 'O'),
#   (')', 'O'),
#   ('might', 'O'),
#   ('be', 'O'),
#   ('efficacious', 'O'),
#   (',', 'O'),
#   ('toxic', 'O'),
#   (',', 'O'),
#   ('or', 'O'),
#   ('both', 'O'),
#   ('.', 'O')],
#  1109: [('According', 'O'),
#   ('to', 'O'),
#   ('their', 'O'),
#   ('functional', 'O'),
#   ('properties', 'O'),
#   ('the', 'O'),
#   ('latter', 'O'),
#   ('neurons', 'O'),
#   ('were', 'O'),
#   ('subdivided', 'O'),
#   ('into', 'O'),
#   (':', 'O'),
#   ('(', 'O'),
#   ('a', 'O'),
#   (')', 'O'),
#   ('neurons', 'O'),
#   ('responding', 'O'),
#   ('to', 'O'),
#   ('stimuli', 'O'),
#   ('near', 'O'),
#   ('the', 'O'),
#   ('eyes', 'O'),
#   (';', 'O'),
#   ('(', 'O'),
#   ('b', 'O'),
#   (')', 'O'),
#   ('neurons', 'O'),
#   ('triggered', 'O'),
#   ('by', 'O'),
#   ('complex', 'O'),
#   ('visual', 'O'),
#   ('stimuli', 'O'),
#   (';', 'O'),
#   ('(', 'O'),
#   ('c', 'O'),
#   (')', 'O'),
#   ('neurons', 'O'),
#   ('inhibited', 'O'),
#   ('by', 'O'),
#   ('visual', 'O'),
#   ('stimuli', 'O'),
#   ('.', 'O')],
#  1170: [('Pentobarbital', 'O'),
#   ('(', 'O'),
#   ('1', 'O'),
#   (',', 'O'),
#   ('3', 'O'),
#   (',', 'O'),
#   ('10', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('17', 'O'),
#   ('.', 'O'),
#   ('5', 'O'),
#   ('mg', 'O'),
#   ('/', 'O'),
#   ('kg', 'O'),
#   (')', 'O'),
#   ('was', 'O'),
#   ('also', 'O'),
#   ('tested', 'O'),
#   ('in', 'O'),
#   ('combination', 'O'),
#   ('with', 'O'),
#   ('rate', 'O'),
#   ('-', 'O'),
#   ('decreasing', 'O'),
#   ('doses', 'O'),
#   ('of', 'O'),
#   ('normeperidine', 'O'),
#   ('(', 'O'),
#   ('17', 'O'),
#   ('.', 'O'),
#   ('5', 'O'),
#   ('mg', 'O'),
#   ('/', 'O'),
#   ('kg', 'O'),
#   ('),', 'O'),
#   ('anileridine', 'O'),
#   ('(', 'O'),
#   ('10', 'O'),
#   ('mg', 'O'),
#   ('/', 'O'),
#   ('kg', 'O'),
#   ('),', 'O'),
#   ('alphaprodine', 'O'),
#   ('(', 'O'),
#   ('10', 'O'),
#   ('mg', 'O'),
#   ('/', 'O'),
#   ('kg', 'O'),
#   ('),', 'O'),
#   ('and', 'O'),
#   ('fentanyl', 'O'),
#   ('(', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('3', 'O'),
#   ('mg', 'O'),
#   ('/', 'O'),
#   ('kg', 'O'),
#   (').', 'O')],
#  1187: [('Pb', 'O'),
#   ('foil', 'O'),
#   ('(', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('55', 'O'),
#   ('gcm', 'O'),
#   ('-', 'O'),
#   ('2', 'O'),
#   (')', 'O'),
#   ('provided', 'O'),
#   ('the', 'O'),
#   ('best', 'O'),
#   ('overall', 'O'),
#   ('improvement', 'O'),
#   ('.', 'O')],
#  1235: [('An', 'O'),
#   ('anatomical', 'O'),
#   ('and', 'O'),
#   ('histochemical', 'O'),
#   ('study', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('undertaken', 'O'),
#   ('and', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('result', 'O'),
#   ('emphasis', 'O'),
#   ('is', 'O'),
#   ('given', 'O'),
#   ('to', 'O'),
#   ('recent', 'O'),
#   ('hypotheses', 'O'),
#   ('that', 'O'),
#   ('suggest', 'O'),
#   ('there', 'O'),
#   ('are', 'O'),
#   ('similarities', 'O'),
#   ('with', 'O'),
#   ('Type', 'O'),
#   ('IV', 'O'),
#   ('glycogen', 'O'),
#   ('storage', 'O'),
#   ('disease', 'O'),
#   ('(', 'O'),
#   ('Andersen', 'O'),
#   ("'", 'O'),
#   ('s', 'O'),
#   ('disease', 'O'),
#   (')', 'O'),
#   ('which', 'O'),
#   (',', 'O'),
#   ('although', 'O'),
#   ('clinically', 'O'),
#   ('distinct', 'O'),
#   (',', 'O'),
#   ('has', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('enzyme', 'O'),
#   ('defect', 'O'),
#   ('.', 'O')],
#  1254: [('All', 'O'),
#   ('groups', 'O'),
#   ('were', 'O'),
#   ('tested', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('Hebb', 'O'),
#   ('-', 'O'),
#   ('Williams', 'O'),
#   ('maze', 'O'),
#   ('at', 'O'),
#   ('100', 'O'),
#   ('approximately', 'O'),
#   ('10', 'O'),
#   ('days', 'O'),
#   ('of', 'O'),
#   ('age', 'O'),
#   ('.', 'O')],
#  1266: [('Erythromycin', 'O'),
#   ('and', 'O'),
#   ('clindamycin', 'O'),
#   ('resistance', 'O'),
#   ('in', 'O'),
#   ('Corynebacterium', 'O'),
#   ('diphtheriae', 'O'),
#   ('from', 'O'),
#   ('skin', 'O'),
#   ('lesions', 'O'),
#   ('.', 'O')],
#  1302: [('Imposed', 'O'),
#   ('angular', 'O'),
#   ('displacements', 'O'),
#   ('of', 'O'),
#   ('monkey', 'O'),
#   ("'", 'O'),
#   ('s', 'O'),
#   ('wrist', 'O'),
#   ('produce', 'O'),
#   ('three', 'O'),
#   ('major', 'O'),
#   ('peaks', 'O'),
#   ('of', 'O'),
#   ('activity', 'O'),
#   ('(', 'O'),
#   ('terms', 'O'),
#   ('M1', 'O'),
#   (',', 'O'),
#   ('M2', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('M3', 'O'),
#   ('peaks', 'O'),
#   (')', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('averaged', 'O'),
#   ('gross', 'O'),
#   ('EMG', 'O'),
#   ('activity', 'O'),
#   ('ot', 'O'),
#   ('the', 'O'),
#   ('stretched', 'O'),
#   ('muscles', 'O'),
#   ('.', 'O')],
#  1309: [('Hemolytic', 'O'),
#   ('disease', 'O'),
#   ('of', 'O'),
#   ('African', 'O'),
#   ('newborn', 'O'),
#   ('.', 'O')],
#  1352: [('In', 'O'),
#   ('this', 'O'),
#   ('animal', 'O'),
#   (',', 'O'),
#   ('infected', 'O'),
#   ('with', 'O'),
#   ('what', 'O'),
#   ('was', 'O'),
#   ('judged', 'O'),
#   ('previously', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('the', 'O'),
#   ('less', 'O'),
#   ('virulent', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('two', 'O'),
#   ('T', 'O'),
#   ('.', 'O'),
#   ('cruzi', 'O'),
#   ('stocks', 'O'),
#   ('used', 'O'),
#   ("('", 'O'),
#   ('strain', 'O'),
#   ('7', 'O'),
#   ("'),", 'O'),
#   ('there', 'O'),
#   ('was', 'O'),
#   ('severe', 'O'),
#   ('myocarditis', 'O'),
#   (',', 'O'),
#   ('with', 'O'),
#   ('myofibre', 'O'),
#   ('degeneration', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('lesions', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('oesophagus', 'O'),
#   ('.', 'O')],
#  1379: [('The', 'O'),
#   ('majority', 'O'),
#   ('of', 'O'),
#   ('MRF', 'O'),
#   ('units', 'O'),
#   ('were', 'O'),
#   ('behaviorally', 'O'),
#   ('incongruent', 'O'),
#   (';', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('most', 'O'),
#   ('frequently', 'O'),
#   ('observed', 'O'),
#   ('case', 'O'),
#   (',', 'O'),
#   ('their', 'O'),
#   ('activity', 'O'),
#   ('failed', 'O'),
#   ('to', 'O'),
#   ('change', 'O'),
#   ('reliably', 'O'),
#   ('when', 'O'),
#   ('behavior', 'O'),
#   ('habituated', 'O'),
#   ('.', 'O')],
#  1398: [('Variability', 'O'),
#   ('within', 'O'),
#   ('Down', 'O'),
#   ("'", 'O'),
#   ('s', 'O'),
#   ('syndrome', 'O'),
#   ('(', 'O'),
#   ('trisomy', 'O'),
#   ('-', 'O'),
#   ('21', 'O'),
#   ('):', 'O'),
#   ('empirically', 'O'),
#   ('observed', 'O'),
#   ('sex', 'O'),
#   ('differences', 'O'),
#   ('in', 'O'),
#   ('IQs', 'O'),
#   ('.', 'O')],
#  1401: [('VII', 'O'), ('.', 'O')],
#  1410: [('Several', 'O'),
#   ('demographic', 'O'),
#   ('indices', 'O'),
#   ('of', 'O'),
#   ('isolated', 'O'),
#   ('populations', 'O'),
#   ('in', 'O'),
#   ('Uzbekistan', 'O')],
#  1422: [('2', 'O'),
#   ('.--', 'O'),
#   ('concepts', 'O'),
#   ('of', 'O'),
#   ('higher', 'O'),
#   ('nervous', 'O'),
#   ('function', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('USSR', 'O'),
#   ('.', 'O')],
#  1457: [('The', 'O'),
#   ('maintenance', 'O'),
#   ('of', 'O'),
#   ('increased', 'O'),
#   ('myocardial', 'O'),
#   ('capillary', 'O'),
#   ('density', 'O'),
#   ('required', 'O'),
#   ('a', 'O'),
#   ('similar', 'O'),
#   ('amount', 'O'),
#   ('of', 'O'),
#   ('exercise', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('1', 'O'),
#   ('h', 'O'),
#   ('of', 'O'),
#   ('exercise', 'O'),
#   ('once', 'O'),
#   ('a', 'O'),
#   ('week', 'O'),
#   ('was', 'O'),
#   ('necessary', 'O'),
#   ('to', 'O'),
#   ('maintain', 'O'),
#   ('the', 'O'),
#   ('enlargement', 'O'),
#   ('of', 'O'),
#   ('ECA', 'O'),
#   ('.', 'O'),
#   ('20', 'O')],
#  1480: [('These', 'O'),
#   ('observations', 'O'),
#   ('have', 'O'),
#   ('led', 'O'),
#   ('us', 'O'),
#   ('to', 'O'),
#   ('conclude', 'O'),
#   ('that', 'O'),
#   ('an', 'O'),
#   ('elevated', 'O'),
#   ('VIII', 'O'),
#   ('-', 'O'),
#   ('ratio', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('very', 'O'),
#   ('sensitive', 'O'),
#   ('indicator', 'O'),
#   ('of', 'O'),
#   ('intravascular', 'O'),
#   ('coagulation', 'O'),
#   ('.', 'O')],
#  1507: [('Eight', 'O'),
#   ('hours', 'O'),
#   ('after', 'O'),
#   ('the', 'O'),
#   ('administration', 'O'),
#   ('of', 'O'),
#   ('colchicine', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('serum', 'B'),
#   ('ceruloplasmin', 'I'),
#   ('level', 'O'),
#   ('began', 'O'),
#   ('to', 'O'),
#   ('rise', 'O'),
#   ('again', 'O'),
#   ('in', 'O'),
#   ('female', 'O'),
#   ('rats', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('not', 'O'),
#   ('in', 'O'),
#   ('male', 'O'),
#   ('rats', 'O'),
#   ('.', 'O')],
#  1553: [('Radioimmunoassays', 'O'),
#   ('of', 'O'),
#   ('pregnenolone', 'O'),
#   (',', 'O'),
#   ('progesterone', 'O'),
#   (',', 'O'),
#   ('dehydroepiandrosterone', 'O'),
#   ('(', 'O'),
#   ('DHA', 'O'),
#   (')', 'O'),
#   ('16', 'O'),
#   ('alpha', 'O'),
#   ('-', 'O'),
#   ('hydroxy', 'O'),
#   ('-', 'O'),
#   ('DHA', 'O'),
#   (',', 'O'),
#   ('estriol', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('cortisol', 'O'),
#   ('were', 'O'),
#   ('performed', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('total', 'O'),
#   ('of', 'O'),
#   ('0', 'O'),
#   (';', 'O'),
#   ('1', 'O'),
#   ('ml', 'O'),
#   (';', 'O'),
#   ('of', 'O'),
#   ('fetal', 'O'),
#   ('plasma', 'O'),
#   (',', 'O'),
#   ('collected', 'O'),
#   ('during', 'O'),
#   ('the', 'O'),
#   ('course', 'O'),
#   ('of', 'O'),
#   ('normal', 'O'),
#   ('vaginal', 'O'),
#   ('delivery', 'O'),
#   ('.', 'O')],
#  1587: [('In', 'O'),
#   ('only', 'O'),
#   ('two', 'O'),
#   ('patients', 'O'),
#   ('were', 'O'),
#   ('we', 'O'),
#   ('able', 'O'),
#   ('to', 'O'),
#   ('demonstrate', 'O'),
#   ('changes', 'O'),
#   ('suggestive', 'O'),
#   ('of', 'O'),
#   ('pulmonary', 'O'),
#   ('metastases', 'O'),
#   ('any', 'O'),
#   ('earlier', 'O'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('99mTc', 'O'),
#   ('-', 'O'),
#   ('EHDP', 'O'),
#   ('scan', 'O'),
#   ('than', 'O'),
#   ('with', 'O'),
#   ('chest', 'O'),
#   ('radiographs', 'O'),
#   ('and', 'O'),
#   ('one', 'O'),
#   ('of', 'O'),
#   ('these', 'O'),
#   ('resolved', 'O'),
#   ('spontaneously', 'O'),
#   ('.', 'O')],
#  1613: [('The', 'O'),
#   ('majority', 'O'),
#   ('of', 'O'),
#   ('tumors', 'O'),
#   ('occurred', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('nasal', 'O'),
#   ('cavities', 'O'),
#   (',', 'O'),
#   ('although', 'O'),
#   ('significant', 'O'),
#   ('incidences', 'O'),
#   ('were', 'O'),
#   ('also', 'O'),
#   ('found', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('larynx', 'O'),
#   (',', 'O'),
#   ('trachea', 'O'),
#   ('and', 'O'),
#   ('stem', 'O'),
#   ('bronchi', 'O'),
#   ('.', 'O')],
#  1621: [('Prediction', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('times', 'O'),
#   ('of', 'O'),
#   ('sandfly', 'O'),
#   ('development', 'O')],
#  1633: [('Native', 'O'),
#   ('human', 'B'),
#   ('fibrinogen', 'I'),
#   ('was', 'O'),
#   ('brought', 'O'),
#   ('to', 'O'),
#   ('coagulation', 'O'),
#   ('by', 'O'),
#   ('adding', 'O'),
#   ('thrombin', 'B'),
#   ('.', 'O')],
#  1645: [('No', 'O'),
#   ('post', 'O'),
#   ('-', 'O'),
#   ('operative', 'O'),
#   ('haemorrhages', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('prostheses', 'O'),
#   ('were', 'O'),
#   ('observed', 'O'),
#   ('.', 'O')],
#  1671: [('The', 'O'),
#   ('Southern', 'O'),
#   ('technique', 'O'),
#   ('allowed', 'O'),
#   ('a', 'O'),
#   ('further', 'O'),
#   ('localization', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('region', 'O'),
#   ('of', 'O'),
#   ('most', 'O'),
#   ('extensive', 'O'),
#   ('transcription', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('1', 'O'),
#   ('.', 'O'),
#   ('8', 'O'),
#   ('kb', 'O'),
#   ('HindIII', 'B'),
#   ('-', 'O'),
#   ('EcoRI', 'B'),
#   ('fragment', 'O'),
#   ('.', 'O')],
#  1743: [('Accepting', 'O'),
#   ('arbitrarily', 'O'),
#   ('chosen', 'O'),
#   ('limits', 'O'),
#   ('of', 'O'),
#   ('maximized', 'O'),
#   ('errors', 'O'),
#   ('of', 'O'),
#   ('+/-', 'O'),
#   ('10', 'O'),
#   ('%,', 'O'),
#   ('it', 'O'),
#   ('could', 'O'),
#   ('be', 'O'),
#   ('shown', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('system', 'O'),
#   ('did', 'O'),
#   ('not', 'O'),
#   ('work', 'O'),
#   ('acceptably', 'O'),
#   ('when', 'O'),
#   ('the', 'O'),
#   ('mean', 'O'),
#   ('carbon', 'O'),
#   ('dioxide', 'O'),
#   ('concentration', 'O'),
#   ('was', 'O'),
#   ('below', 'O'),
#   ('1', 'O'),
#   ('.', 'O'),
#   ('5', 'O'),
#   ('vol', 'O'),
#   ('.%', 'O'),
#   ('within', 'O'),
#   ('the', 'O'),
#   ('fresh', 'O'),
#   ('gas', 'O'),
#   ('flow', 'O'),
#   ('rates', 'O'),
#   ('(', 'O'),
#   ('2', 'O'),
#   ('.', 'O'),
#   ('2', 'O'),
#   ('--', 'O'),
#   ('7', 'O'),
#   ('.', 'O'),
#   ('7', 'O'),
#   ('1', 'O'),
#   ('min', 'O'),
#   ('-', 'O'),
#   ('1', 'O'),
#   (')', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('range', 'O'),
#   ('of', 'O'),
#   ('minute', 'O'),
#   ('ventilation', 'O'),
#   ('(', 'O'),
#   ('4', 'O'),
#   ('--', 'O'),
#   ('10', 'O'),
#   ('1', 'O'),
#   ('min', 'O'),
#   ('-', 'O'),
#   ('1', 'O'),
#   (')', 'O'),
#   ('employed', 'O'),
#   ('.', 'O')],
#  1774: [('SV', 'O'),
#   ('increased', 'O'),
#   ('less', 'O'),
#   ('in', 'O'),
#   ('SHR', 'O'),
#   (',', 'O'),
#   ('mainly', 'O'),
#   ('reflecting', 'O'),
#   ('the', 'O'),
#   ('reduced', 'O'),
#   ('diastolic', 'O'),
#   ('compliance', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('hypertrophied', 'O'),
#   ('SHR', 'O'),
#   ('left', 'O'),
#   ('ventricle', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('consequent', 'O'),
#   ('rightward', 'O'),
#   ('shift', 'O'),
#   ('of', 'O'),
#   ('its', 'O'),
#   ('Frank', 'O'),
#   ('-', 'O'),
#   ('Starling', 'O'),
#   ('curve', 'O'),
#   ('.', 'O')],
#  1800: [('The', 'O'),
#   ('carcass', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('great', 'O'),
#   ('horned', 'O'),
#   ('owl', 'O'),
#   ('(', 'O'),
#   ('Bubo', 'O'),
#   ('virginianus', 'O'),
#   ('),', 'O'),
#   ('which', 'O'),
#   ('had', 'O'),
#   ('been', 'O'),
#   ('found', 'O'),
#   ('moribund', 'O'),
#   ('in', 'O'),
#   ('southern', 'O'),
#   ('Ontario', 'O'),
#   (',', 'O'),
#   ('was', 'O'),
#   ('presented', 'O'),
#   ('for', 'O'),
#   ('necropsy', 'O'),
#   ('.', 'O')],
#  1835: [('The', 'O'),
#   ('inner', 'O'),
#   ('ears', 'O'),
#   ('were', 'O'),
#   ('exposed', 'O'),
#   ('by', 'O'),
#   ('microdissection', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('vestibular', 'O'),
#   ('sensory', 'O'),
#   ('regions', 'O'),
#   ('were', 'O'),
#   ('either', 'O'),
#   ('sectioned', 'O'),
#   ('and', 'O'),
#   ('studied', 'O'),
#   ('with', 'O'),
#   ('light', 'O'),
#   ('or', 'O'),
#   ('electron', 'O'),
#   ('microscopy', 'O'),
#   (',', 'O'),
#   ('or', 'O'),
#   ('prepared', 'O'),
#   ('and', 'O'),
#   ('studied', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('surface', 'O'),
#   ('specimen', 'O'),
#   ('technique', 'O'),
#   ('.', 'O')],
#  1872: [('Patulin', 'O'),
#   ('is', 'O'),
#   ('extracted', 'O'),
#   ('from', 'O'),
#   ('apple', 'O'),
#   ('butter', 'O'),
#   ('samples', 'O'),
#   ('with', 'O'),
#   ('ethyl', 'O'),
#   ('acetate', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('extract', 'O'),
#   ('is', 'O'),
#   ('cleaned', 'O'),
#   ('up', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('silica', 'O'),
#   ('gel', 'O'),
#   ('column', 'O'),
#   (',', 'O'),
#   ('using', 'O'),
#   ('benzene', 'O'),
#   ('-', 'O'),
#   ('ethyl', 'O'),
#   ('acetate', 'O'),
#   ('(', 'O'),
#   ('75', 'O'),
#   ('+', 'O'),
#   ('25', 'O'),
#   (')', 'O'),
#   ('as', 'O'),
#   ('the', 'O'),
#   ('eluant', 'O'),
#   ('.', 'O')],
#  1881: [('Steroid', 'O'),
#   ('glucuronides', 'O'),
#   ('in', 'O'),
#   ('amniotic', 'O'),
#   ('fluid', 'O'),
#   ('at', 'O'),
#   ('term', 'O'),
#   ('.', 'O')],
#  1911: [('The', 'O'),
#   ('matrix', 'O'),
#   ('surrounding', 'O'),
#   ('the', 'O'),
#   ('clusters', 'O'),
#   ('either', 'O'),
#   ('showed', 'O'),
#   ('a', 'O'),
#   ('normal', 'O'),
#   ('morphology', 'O'),
#   ('or', 'O'),
#   ('a', 'O'),
#   ('homogeneous', 'O'),
#   ('appearance', 'O'),
#   (',', 'O'),
#   ('within', 'O'),
#   ('which', 'O'),
#   ('faint', 'O'),
#   ('cross', 'O'),
#   ('striations', 'O'),
#   ('but', 'O'),
#   ('no', 'O'),
#   ('distinctly', 'O'),
#   ('fibrillar', 'O'),
#   ('outlines', 'O'),
#   ('could', 'O'),
#   ('be', 'O'),
#   ('identified', 'O'),
#   ('.', 'O')],
#  1945: [('Riboflavin', 'O'),
#   ('did', 'O'),
#   ('not', 'O'),
#   ('affect', 'O'),
#   ('the', 'O'),
#   ('percentage', 'O'),
#   ('of', 'O'),
#   ('aflatoxin', 'O'),
#   ('-', 'O'),
#   ('treated', 'O'),
#   ('animals', 'O'),
#   ('with', 'O'),
#   ('abnormal', 'O'),
#   ('urinary', 'O'),
#   ('excretion', 'O'),
#   ('patterns', 'O'),
#   (',', 'O'),
#   ('but', 'O'),
#   ('did', 'O'),
#   ('increase', 'O'),
#   ('the', 'O'),
#   ('magnitude', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('disturbances', 'O'),
#   ('in', 'O'),
#   ('elimination', 'O'),
#   ('of', 'O'),
#   ('kynurenic', 'O'),
#   ('and', 'O'),
#   ('xanthurenic', 'O'),
#   ('acids', 'O'),
#   ('.', 'O')],
#  1957: [('Polyglactin', 'O'),
#   ('910', 'O'),
#   ('suture', 'O'),
#   ('absorption', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('role', 'O'),
#   ('of', 'O'),
#   ('cellular', 'O'),
#   ('enzymes', 'O'),
#   ('.', 'O')],
#  2003: [('The', 'O'),
#   ('incidence', 'O'),
#   ('of', 'O'),
#   ('DNCB', 'O'),
#   ('reactions', 'O'),
#   ('was', 'O'),
#   ('78', 'O'),
#   ('per', 'O'),
#   ('cent', 'O'),
#   ('for', 'O'),
#   ('Stage', 'O'),
#   ('I', 'O'),
#   ('and', 'O'),
#   ('II', 'O'),
#   ('cancers', 'O'),
#   ('(', 'O'),
#   ('37', 'O'),
#   ('patinets', 'O'),
#   ('),', 'O'),
#   ('73', 'O'),
#   ('per', 'O'),
#   ('cent', 'O'),
#   ('for', 'O'),
#   ('resectable', 'O'),
#   ('Stage', 'O'),
#   ('III', 'O'),
#   ('cancer', 'O'),
#   ('(', 'O'),
#   ('22', 'O'),
#   ('patients', 'O'),
#   ('),', 'O'),
#   ('and', 'O'),
#   ('66', 'O'),
#   ('per', 'O'),
#   ('cent', 'O'),
#   ('in', 'O'),
#   ('patients', 'O'),
#   ('with', 'O'),
#   ('unresectable', 'O'),
#   ('or', 'O'),
#   ('inoperable', 'O'),
#   ('Stage', 'O'),
#   ('III', 'O'),
#   ('cancer', 'O'),
#   ('.', 'O')],
#  2027: [('Studies', 'O'),
#   ('of', 'O'),
#   ('lipoproteins', 'O'),
#   ('should', 'O'),
#   (',', 'O'),
#   ('however', 'O'),
#   (',', 'O'),
#   ('be', 'O'),
#   ('made', 'O'),
#   ('in', 'O'),
#   ('children', 'O'),
#   ('from', 'O'),
#   ('families', 'O'),
#   ('known', 'O'),
#   ('to', 'O'),
#   ('have', 'O'),
#   ('FH', 'O'),
#   ('or', 'O'),
#   ('early', 'O'),
#   ('coronary', 'O'),
#   ('heart', 'O'),
#   ('disease', 'O'),
#   ('.', 'O')],
#  2041: [('Sixteen', 'O'),
#   ('other', 'O'),
#   ('normal', 'O'),
#   ('subjects', 'O'),
#   ('with', 'O'),
#   ('2', 'O'),
#   ('g', 'O'),
#   ('of', 'O'),
#   ('Metyrapone', 'O'),
#   ('are', 'O'),
#   ('best', 'O'),
#   ('responses', 'O'),
#   ('.', 'O')],
#  2054: [('EEG', 'O'),
#   ('theta', 'O'),
#   ('waves', 'O'),
#   ('and', 'O'),
#   ('psychological', 'O'),
#   ('phenomena', 'O'),
#   (':', 'O'),
#   ('a', 'O'),
#   ('review', 'O'),
#   ('and', 'O'),
#   ('analysis', 'O'),
#   ('.', 'O')],
#  2097: [('REM', 'O'),
#   ('dream', 'O'),
#   ('content', 'O'),
#   ('was', 'O'),
#   ('scored', 'O'),
#   ('for', 'O'),
#   ('categories', 'O'),
#   ('suggesting', 'O'),
#   ('the', 'O'),
#   ('predominant', 'O'),
#   ('influence', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('left', 'O'),
#   ('hemisphere', 'O'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('.', 'O'),
#   ('g', 'O'),
#   ('.,', 'O'),
#   ('good', 'O'),
#   ('ego', 'O'),
#   ('functioning', 'O'),
#   (',', 'O'),
#   ('verbalization', 'O'),
#   (',', 'O'),
#   ('or', 'O'),
#   ('the', 'O'),
#   ('right', 'O'),
#   ('hemisphere', 'O'),
#   (',', 'O'),
#   ('e', 'O'),
#   ('.', 'O'),
#   ('g', 'O'),
#   ('.,', 'O'),
#   ('music', 'O'),
#   (',', 'O'),
#   ('spatial', 'O'),
#   ('salience', 'O'),
#   (',', 'O'),
#   ('bizarreness', 'O'),
#   ('.', 'O')],
#  2110: [('Innervation', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('ventral', 'O'),
#   ('diaphragm', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('locust', 'O'),
#   ('(', 'O'),
#   ('Locusta', 'O'),
#   ('migratoria', 'O'),
#   (').', 'O')],
#  2119: [('Ectopic', 'O'),
#   ('ACTH', 'B'),
#   ('syndrome', 'O'),
#   ('and', 'O'),
#   ('medullary', 'O'),
#   ('thyroid', 'O'),
#   ('carcinoma', 'O'),
#   ('.', 'O')],
#  2139: [('A', 'O'),
#   ('striking', 'O'),
#   ('finding', 'O'),
#   ('in', 'O'),
#   ('all', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('studies', 'O'),
#   ('was', 'O'),
#   ('a', 'O'),
#   ('positive', 'O'),
#   ('correlation', 'O'),
#   ('between', 'O'),
#   ('PI', 'O'),
#   ('ACTH', 'B'),
#   ('and', 'O'),
#   ('MSH', 'B'),
#   ('contents', 'O'),
#   ('.', 'O')],
#  2153: [('Chronic', 'O'),
#   ('hypophosphatemia', 'O'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('most', 'O'),
#   ('common', 'O'),
#   ('type', 'O'),
#   ('of', 'O'),
#   ('"', 'O'),
#   ('resistant', 'O'),
#   ('"', 'O'),
#   ('rickets', 'O'),
#   ('.', 'O')],
#  2187: [('There', 'O'),
#   ('was', 'O'),
#   ('no', 'O'),
#   ('correlation', 'O'),
#   ('between', 'O'),
#   ('serum', 'B'),
#   ('LH', 'I'),
#   ('and', 'O'),
#   ('chronological', 'O'),
#   ('or', 'O'),
#   ('bone', 'O'),
#   ('age', 'O'),
#   ('in', 'O'),
#   ('this', 'O'),
#   ('age', 'O'),
#   ('group', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('suggests', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('correlation', 'O'),
#   ('found', 'O'),
#   ('is', 'O'),
#   ('not', 'O'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('age', 'O'),
#   ('-', 'O'),
#   ('related', 'O'),
#   ('parallel', 'O'),
#   ('phenomena', 'O'),
#   ('.', 'O')],
#  2194: [('Molecular', 'O'),
#   ('neurochemistry', 'O'),
#   ('of', 'O'),
#   ('addictive', 'O'),
#   ('drugs', 'O'),
#   ('.', 'O')],
#  2225: [('Efforts', 'O'),
#   ('were', 'O'),
#   ('made', 'O'),
#   ('to', 'O'),
#   ('determine', 'O'),
#   ('the', 'O'),
#   ('amount', 'O'),
#   ('of', 'O'),
#   ('time', 'O'),
#   ('required', 'O'),
#   ('for', 'O'),
#   ('kidney', 'O'),
#   ('lesions', 'O'),
#   ('to', 'O'),
#   ('develop', 'O'),
#   ('and', 'O'),
#   (',', 'O'),
#   ('if', 'O'),
#   ('possible', 'O'),
#   (',', 'O'),
#   ('to', 'O'),
#   ('delineate', 'O'),
#   ('the', 'O'),
#   ('potential', 'O'),
#   ('site', 'O'),
#   ('of', 'O'),
#   ('action', 'O'),
#   ('of', 'O'),
#   ('PBB', 'O'),
#   ('.', 'O')],
#  2246: [('Effect', 'O'),
#   ('of', 'O'),
#   ('succimer', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('intensity', 'O'),
#   ('of', 'O'),
#   ('tricarboxylic', 'B'),
#   ('acid', 'I'),
#   ('dehydrogenase', 'I'),
#   ('reactions', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('brain', 'O'),
#   ('of', 'O'),
#   ('rats', 'O'),
#   ('poisoned', 'O'),
#   ('with', 'O'),
#   ('mercuric', 'O'),
#   ('chloride', 'O')],
#  2270: [('Distribution', 'O'),
#   ('and', 'O'),
#   ('correlations', 'O'),
#   ('of', 'O'),
#   ('serum', 'O'),
#   ('uric', 'O'),
#   ('-', 'O'),
#   ('acid', 'O'),
#   ('in', 'O'),
#   ('two', 'O'),
#   ('French', 'O'),
#   ('adult', 'O'),
#   ('populations', 'O'),
#   (':', 'O'),
#   ('13', 'O'),
#   (',', 'O'),
#   ('885', 'O'),
#   ('men', 'O'),
#   ('and', 'O'),
#   ('6', 'O'),
#   (',', 'O'),
#   ('861', 'O'),
#   ('women', 'O')],
#  2287: [('The', 'O'),
#   ('incidence', 'O'),
#   ('of', 'O'),
#   ('hepatitis', 'B'),
#   ('B', 'I'),
#   ('antigen', 'I'),
#   ('following', 'O'),
#   ('transfusion', 'O'),
#   ('was', 'O'),
#   ('about', 'O'),
#   ('2', 'O'),
#   ('.', 'O'),
#   ('8', 'O'),
#   ('per', 'O'),
#   ('cent', 'O'),
#   ('.', 'O')],
#  2321: [('Technetium', 'O'),
#   ('-', 'O'),
#   ('99m', 'O'),
#   ('stannous', 'O'),
#   ('pyrophosphate', 'O'),
#   ('myocardial', 'O'),
#   ('scintigrams', 'O'),
#   ('were', 'O'),
#   ('obtained', 'O'),
#   ('in', 'O'),
#   ('138', 'O'),
#   ('clinically', 'O'),
#   ('stable', 'O'),
#   ('patients', 'O'),
#   ('32', 'O'),
#   ('.', 'O'),
#   ('7', 'O'),
#   ('+/-', 'O'),
#   ('47', 'O'),
#   ('.', 'O'),
#   ('3', 'O'),
#   ('weeks', 'O'),
#   ('(', 'O'),
#   ('range', 'O'),
#   ('6', 'O'),
#   ('to', 'O'),
#   ('260', 'O'),
#   (')', 'O'),
#   ('after', 'O'),
#   ('acute', 'O'),
#   ('myocardial', 'O'),
#   ('infarction', 'O'),
#   ('.', 'O')],
#  2333: [('A', 'O'),
#   ('similar', 'O'),
#   ('phenomenon', 'O'),
#   ('has', 'O'),
#   ('been', 'O'),
#   ('reported', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('few', 'O'),
#   ('humans', 'O'),
#   ('.', 'O')],
#  2362: [('The', 'O'),
#   ('decline', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('activity', 'O'),
#   ('of', 'O'),
#   ('cytochrome', 'B'),
#   ('oxidase', 'I'),
#   (',', 'O'),
#   ('peroxidase', 'B'),
#   ('and', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('lipid', 'O'),
#   ('content', 'O'),
#   ('of', 'O'),
#   ('peripheral', 'O'),
#   ('neutrophils', 'O'),
#   ('was', 'O'),
#   ('followed', 'O'),
#   ('by', 'O'),
#   ('a', 'O'),
#   ('decrease', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('phagocytic', 'O'),
#   ('activity', 'O'),
#   ('.', 'O')],
#  2398: [('Treatment', 'O'),
#   ('of', 'O'),
#   ('2', 'O'),
#   ('patients', 'O'),
#   ('with', 'O'),
#   ('pseudohypoparathyroidism', 'O'),
#   ('type', 'O'),
#   ('I', 'O'),
#   ('with', 'O'),
#   ('vitamin', 'O'),
#   ('-', 'O'),
#   ('D', 'O'),
#   ('-', 'O'),
#   ('3', 'O'),
#   ('and', 'O'),
#   ('1', 'O'),
#   ('alpha', 'O'),
#   ('-', 'O'),
#   ('Hydroxycholecalciferol', 'O'),
#   ('consecutively', 'O'),
#   ('resulted', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('nonuniform', 'O'),
#   ('response', 'O'),
#   ('with', 'O'),
#   ('regard', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('normalisation', 'O'),
#   ('of', 'O'),
#   ('serum', 'O'),
#   ('-', 'O'),
#   ('calcium', 'O'),
#   ('.', 'O')],
#  2423: [('Workers', 'O'),
#   ('with', 'O'),
#   ('"', 'O'),
#   ('sensitivity', 'O'),
#   ('"', 'O'),
#   ('to', 'O'),
#   ('toluene', 'O'),
#   ('diisocyanate', 'O'),
#   ('(', 'O'),
#   ('TDI', 'O'),
#   (')', 'O'),
#   ('studied', 'O'),
#   ('in', 'O'),
#   ('depth', 'O'),
#   ('in', 'O'),
#   ('an', 'O'),
#   ('attempt', 'O'),
#   ('to', 'O'),
#   ('determine', 'O'),
#   ('mechanisms', 'O'),
#   ('of', 'O'),
#   ('bronchial', 'O'),
#   ('hyperreactivity', 'O'),
#   ('.', 'O')],
#  2513: [('Total', 'O'),
#   ('VO2', 'O'),
#   ('was', 'O'),
#   ('decreased', 'O'),
#   ('in', 'O'),
#   ('both', 'O'),
#   ('groups', 'O'),
#   ('during', 'O'),
#   ('severe', 'O'),
#   ('hypoxia', 'O'),
#   ('but', 'O'),
#   ('limb', 'O'),
#   ('VO2', 'O'),
#   ('was', 'O'),
#   ('maintained', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('beta', 'O'),
#   ('-', 'O'),
#   ('block', 'O'),
#   ('group', 'O'),
#   ('.', 'O'),
#   ('beta', 'O'),
#   ('-', 'O'),
#   ('Block', 'O'),
#   ('prevented', 'O'),
#   ('the', 'O'),
#   ('fall', 'O'),
#   ('in', 'O'),
#   ('total', 'O'),
#   ('and', 'O'),
#   ('limb', 'O'),
#   ('peripheral', 'O'),
#   ('resistance', 'O'),
#   ('seen', 'O'),
#   ('in', 'O'),
#   ('severe', 'O'),
#   ('hypoxia', 'O'),
#   ('but', 'O'),
#   ('did', 'O'),
#   ('not', 'O'),
#   ('alter', 'O'),
#   ('the', 'O'),
#   ('consistently', 'O'),
#   ('more', 'O'),
#   ('efficient', 'O'),
#   ('utilization', 'O'),
#   ('of', 'O'),
#   ('total', 'O'),
#   ('O2', 'O'),
#   ('delivery', 'O'),
#   ('shown', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('limb', 'O'),
#   ('in', 'O'),
#   ('comparison', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('whole', 'O'),
#   ('body', 'O'),
#   ('by', 'O'),
#   ('higher', 'O'),
#   ('O2', 'O'),
#   ('extraction', 'O'),
#   ('ratios', 'O'),
#   ('and', 'O'),
#   ('lower', 'O'),
#   ('venous', 'O'),
#   ('O2', 'O'),
#   ('pressure', 'O'),
#   ('.', 'O'),
#   ('beta', 'B'),
#   ('-', 'I'),
#   ('Vasodilator', 'I'),
#   ('receptors', 'I'),
#   ('evidently', 'O'),
#   ('played', 'O'),
#   ('an', 'O'),
#   ('active', 'O'),
#   ('part', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('vasodilatation', 'O'),
#   ('seen', 'O'),
#   ('during', 'O'),
#   ('severe', 'O'),
#   ('hypoxia', 'O'),
#   ('.', 'O')],
#  2536: [('Phenobarbital', 'O'),
#   ('-', 'O'),
#   ('induced', 'O'),
#   ('alterations', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('metabolism', 'O'),
#   ('of', 'O'),
#   ('[', 'O'),
#   ('3H', 'O'),
#   (']', 'O'),
#   ('vitamin', 'O'),
#   ('D3', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('perfused', 'O'),
#   ('rachitic', 'O'),
#   ('rat', 'O'),
#   ('liver', 'O'),
#   ('in', 'O'),
#   ('vitro', 'O'),
#   ('.', 'O')],
#  2558: [('Modulation', 'O'),
#   ('of', 'O'),
#   ('25', 'B'),
#   ('-', 'I'),
#   ('hydroxyvitamin', 'I'),
#   ('D3', 'I'),
#   ('-', 'I'),
#   ('24', 'I'),
#   ('-', 'I'),
#   ('hydroxylase', 'I'),
#   ('by', 'O'),
#   ('aminophylline', 'O'),
#   (':', 'O'),
#   ('a', 'O'),
#   ('cytochrome', 'B'),
#   ('P', 'I'),
#   ('-', 'I'),
#   ('450', 'I'),
#   ('monooxygenase', 'I'),
#   ('system', 'O'),
#   ('.', 'O')],
#  2579: [('In', 'O'),
#   ('both', 'O'),
#   ('these', 'O'),
#   ('respects', 'O'),
#   (',', 'O'),
#   ('however', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('DBP', 'B'),
#   ('mRNA', 'I'),
#   ('resembles', 'O'),
#   ('the', 'O'),
#   ('late', 'O'),
#   ('messengers', 'O'),
#   ('of', 'O'),
#   ('SV40', 'O'),
#   ('and', 'O'),
#   ('polyoma', 'O'),
#   ('viruses', 'O'),
#   ('.', 'O')],
#  2595: [('Effect', 'O'),
#   ('of', 'O'),
#   ('corticosteroid', 'O'),
#   ('-', 'O'),
#   ('containing', 'O'),
#   ('antirheumatic', 'O'),
#   ('combination', 'O'),
#   ('drugs', 'O'),
#   ('on', 'O'),
#   ('endogenous', 'O'),
#   ('ACTH', 'B'),
#   ('and', 'O'),
#   ('cortisol', 'O'),
#   ('production', 'O'),
#   ('.', 'O')],
#  2606: [('Serum', 'B'),
#   ('ACTH', 'I'),
#   ('did', 'O'),
#   ('not', 'O'),
#   ('respond', 'O'),
#   ('to', 'O'),
#   ('insulin', 'B'),
#   ('and', 'O'),
#   ('metyrapone', 'O'),
#   ('.', 'O')],
#  2639: [('Anatomy', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('RNA', 'O'),
#   ('and', 'O'),
#   ('gene', 'O'),
#   ('products', 'O'),
#   ('of', 'O'),
#   ('MC29', 'O'),
#   ('and', 'O'),
#   ('MH2', 'O'),
#   (',', 'O'),
#   ('two', 'O'),
#   ('defective', 'O'),
#   ('avian', 'O'),
#   ('tumor', 'O'),
#   ('viruses', 'O'),
#   ('causing', 'O'),
#   ('acute', 'O'),
#   ('leukemia', 'O'),
#   ('and', 'O'),
#   ('carcinoma', 'O'),
#   (':', 'O'),
#   ('evidence', 'O'),
#   ('for', 'O'),
#   ('a', 'O'),
#   ('new', 'O'),
#   ('class', 'O'),
#   ('of', 'O'),
#   ('transforming', 'O'),
#   ('genes', 'O'),
#   ('.', 'O')],
#  2661: [('Bertioga', 'O'),
#   ('(', 'O'),
#   ('Guama', 'O'),
#   ('group', 'O'),
#   (')', 'O'),
#   ('and', 'O'),
#   ('Anhembi', 'O'),
#   ('(', 'O'),
#   ('Bunyamwera', 'O'),
#   ('group', 'O'),
#   ('),', 'O'),
#   ('two', 'O'),
#   ('new', 'O'),
#   ('arboviruses', 'O'),
#   ('isolated', 'O'),
#   ('in', 'O'),
#   ('Sao', 'O'),
#   ('Paulo', 'O'),
#   (',', 'O'),
#   ('Brazil', 'O'),
#   ('.', 'O')],
#  2689: [('Gamma', 'B'),
#   ('glutamyl', 'I'),
#   ('transpeptidase', 'I'),
#   ('activity', 'O'),
#   ('was', 'O'),
#   ('increased', 'O'),
#   ('up', 'O'),
#   ('to', 'O'),
#   ('15', 'O'),
#   ('times', 'O'),
#   ('above', 'O'),
#   ('the', 'O'),
#   ('upper', 'O'),
#   ('normal', 'O'),
#   ('limit', 'O'),
#   ('in', 'O'),
#   ('children', 'O'),
#   (',', 'O'),
#   ('who', 'O'),
#   ('received', 'O'),
#   ('aminopyrine', 'O'),
#   ('for', 'O'),
#   ('two', 'O'),
#   ('weeks', 'O'),
#   ('or', 'O'),
#   ('longer', 'O'),
#   ('.', 'O')],
#  2692: [('XXI', 'O'), ('.', 'O')],
#  2716: [('A', 'O'),
#   ('gas', 'O'),
#   ('-', 'O'),
#   ('liquid', 'O'),
#   ('chromatographic', 'O'),
#   ('method', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('determination', 'O'),
#   ('of', 'O'),
#   ('p', 'O'),
#   ('-', 'O'),
#   ('chlorophenoxyisobutyric', 'O'),
#   ('(', 'O'),
#   ('CPIB', 'O'),
#   (')', 'O'),
#   ('acid', 'O'),
#   ('in', 'O'),
#   ('blood', 'O'),
#   ('plasma', 'O'),
#   ('is', 'O'),
#   ('described', 'O'),
#   ('.', 'O')],
#  2728: [('Dopamine', 'B'),
#   ('receptor', 'I'),
#   ('blockade', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('neuroleptics', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('crystallographic', 'O'),
#   ('study', 'O'),
#   ('.', 'O')],
#  2731: [('V', 'O'), ('.', 'O')],
#  2750: [('A', 'O'),
#   ('rapid', 'O'),
#   ('fluorimetric', 'O'),
#   ('procedure', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('determination', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('fungicide', 'O'),
#   ('5', 'O'),
#   ('-', 'O'),
#   ('fluorocytosine', 'O'),
#   ('in', 'O'),
#   ('serum', 'O'),
#   ('is', 'O'),
#   ('described', 'O'),
#   ('.', 'O')],
#  2761: [('The', 'O'),
#   ("'", 'O'),
#   ('field', 'O'),
#   ('of', 'O'),
#   ('stress', 'O'),
#   ("'", 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('supervisory', 'O'),
#   ('nurse', 'O')],
#  2775: [('How', 'O'),
#   ('do', 'O'),
#   ('graduates', 'O'),
#   ('of', 'O'),
#   ('different', 'O'),
#   ('types', 'O'),
#   ('of', 'O'),
#   ('programs', 'O'),
#   ('perform', 'O'),
#   ('on', 'O'),
#   ('state', 'O'),
#   ('boards', 'O'),
#   ('?', 'O')],
#  2791: [('Similarly', 'O'),
#   (',', 'O'),
#   ('maternal', 'B'),
#   ('serum', 'I'),
# ...
#   ('.', 'O')],
#  25001: [('To', 'O'),
#   ('study', 'O'),
#   ('the', 'O'),
#   ('significance', 'O'),
#   ('of', 'O'),
#   ('these', 'O'),
#   ('domains', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('overall', 'O'),
#   ('evolutionary', 'O'),
#   ('conservation', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('gene', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('homolog', 'O'),
#   ('from', 'O'),
#   ('Drosophila', 'O'),
#   ('melanogaster', 'O'),
#   ('was', 'O'),
#   ('isolated', 'O'),
#   ('by', 'O'),
#   ('low', 'O'),
#   ('stringency', 'O'),
#   ('hybridizations', 'O'),
#   ('using', 'O'),
#   ('two', 'O'),
#   ('flanking', 'O'),
#   ('probes', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('human', 'B'),
#   ('ERCC3', 'I'),
#   ('cDNA', 'I'),
#   ('.', 'O')],
#  25057: [('Mono', 'O'),
#   ('-', 'O'),
#   ('ADP', 'O'),
#   ('-', 'O'),
#   ('ribosylation', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('reversible', 'O'),
#   ('modification', 'O'),
#   ('of', 'O'),
#   ('proteins', 'O'),
#   (',', 'O'),
#   ('with', 'O'),
#   ('NAD', 'O'),
#   (':', 'O'),
#   ('arginine', 'B'),
#   ('ADP', 'I'),
#   ('-', 'I'),
#   ('ribosyltransferases', 'I'),
#   ('(', 'O'),
#   ('EC', 'B'),
#   ('2', 'I'),
#   ('.', 'I'),
#   ('4', 'I'),
#   ('.', 'I'),
#   ('2', 'I'),
#   ('.', 'I'),
#   ('31', 'I'),
#   (')', 'O'),
#   ('and', 'O'),
#   ('ADP', 'B'),
#   ('-', 'I'),
#   ('ribosylarginine', 'I'),
#   ('hydrolases', 'I'),
#   ('(', 'O'),
#   ('EC', 'B'),
#   ('3', 'I'),
#   ('.', 'I'),
#   ('2', 'I'),
#   ('.', 'I'),
#   ('2', 'I'),
#   ('.', 'I'),
#   ('19', 'I'),
#   (')', 'O'),
#   ('catalyzing', 'O'),
#   ('the', 'O'),
#   ('opposing', 'O'),
#   ('reactions', 'O'),
#   ('in', 'O'),
#   ('an', 'O'),
#   ('ADP', 'O'),
#   ('-', 'O'),
#   ('ribosylation', 'O'),
#   ('cycle', 'O'),
#   ('.', 'O')],
#  25116: [('For', 'O'),
#   ('this', 'O'),
#   ('reason', 'O'),
#   (',', 'O'),
#   ('the', 'O'),
#   ('particle', 'O'),
#   ('forming', 'O'),
#   ('capacity', 'O'),
#   ('of', 'O'),
#   ('derivatives', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('HIV', 'B'),
#   ('-', 'I'),
#   ('1', 'I'),
#   ('group', 'I'),
#   ('specific', 'I'),
#   ('core', 'I'),
#   ('antigen', 'I'),
#   ('p55', 'I'),
#   ('gag', 'I'),
#   ('was', 'O'),
#   ('assayed', 'O'),
#   ('and', 'O'),
#   ('compared', 'O'),
#   ('dependent', 'O'),
#   ('on', 'O'),
#   ('various', 'O'),
#   ('expression', 'O'),
#   ('systems', 'O'),
#   (':', 'O'),
#   ('recombinant', 'O'),
#   ('bacteria', 'O'),
#   (',', 'O'),
#   ('vaccinia', 'O'),
#   ('-', 'O'),
#   ('and', 'O'),
#   ('baculoviruses', 'O'),
#   ('were', 'O'),
#   ('established', 'O'),
#   ('encoding', 'O'),
#   ('the', 'O'),
#   ('entire', 'O'),
#   ('core', 'B'),
#   ('protein', 'I'),
#   ('p55', 'I'),
#   ('either', 'O'),
#   ('in', 'O'),
#   ('its', 'O'),
#   ('authentic', 'O'),
#   ('sequence', 'O'),
#   ('or', 'O'),
#   ('lacking', 'O'),
#   ('the', 'O'),
#   ('myristylation', 'O'),
#   ('consensus', 'O'),
#   ('signal', 'O'),
#   ('.', 'O')],
#  25143: [('The', 'O'),
#   ('tramtrack', 'B'),
#   ('(', 'O'),
#   ('ttk', 'B'),
#   (')', 'O'),
#   ('gene', 'O'),
#   ('of', 'O'),
#   ('Drosophila', 'O'),
#   ('encodes', 'O'),
#   ('69', 'O'),
#   ('-', 'O'),
#   ('kDa', 'O'),
#   ('and', 'O'),
#   ('88', 'O'),
#   ('-', 'O'),
#   ('kDa', 'O'),
#   ('proteins', 'O'),
#   ('through', 'O'),
#   ('alternative', 'O'),
#   ('splicing', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('primary', 'O'),
#   ('ttk', 'B'),
#   ('transcript', 'I'),
#   ('.', 'O')],
#  25161: [('Removal', 'O'),
#   ('of', 'O'),
#   ('beta', 'B'),
#   ('2', 'I'),
#   ('-', 'I'),
#   ('microglobulin', 'I'),
#   ('by', 'O'),
#   ('hemodialysis', 'O'),
#   ('and', 'O'),
#   ('hemofiltration', 'O'),
#   (':', 'O'),
#   ('a', 'O'),
#   ('four', 'O'),
#   ('year', 'O'),
#   ('follow', 'O'),
#   ('up', 'O'),
#   ('.', 'O')],
#  25179: [('Removal', 'O'),
#   ('of', 'O'),
#   ('beta', 'B'),
#   ('2', 'I'),
#   ('-', 'I'),
#   ('microglobulin', 'I'),
#   ('by', 'O'),
#   ('hemodialysis', 'O'),
#   ('and', 'O'),
#   ('hemofiltration', 'O'),
#   (':', 'O'),
#   ('a', 'O'),
#   ('four', 'O'),
#   ('year', 'O'),
#   ('follow', 'O'),
#   ('up', 'O'),
#   ('.', 'O')],
#  25230: [('Adapromine', 'O'),
#   ('was', 'O'),
#   ('established', 'O'),
#   ('to', 'O'),
#   ('evoke', 'O'),
#   ('a', 'O'),
#   ('decrease', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('amplitude', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('dominant', 'O'),
#   ('peak', 'O'),
#   ('and', 'O'),
#   ('dominant', 'O'),
#   ('theta', 'O'),
#   ('-', 'O'),
#   ('activity', 'O'),
#   ('in', 'O'),
#   ('power', 'O'),
#   ('spectra', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('EEG', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('cortex', 'O'),
#   ('and', 'O'),
#   ('hippocamp', 'O'),
#   (',', 'O'),
#   ('with', 'O'),
#   ('an', 'O'),
#   ('increase', 'O'),
#   ('of', 'O'),
#   ('rapid', 'O'),
#   ('wave', 'O'),
#   ('activity', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('beta', 'O'),
#   ('2', 'O'),
#   ('range', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('right', 'O'),
#   ('cortex', 'O'),
#   ('and', 'O'),
#   ('hippocamp', 'O'),
#   ('.', 'O')],
#  25249: [('These', 'O'),
#   ('sequences', 'O'),
#   ('were', 'O'),
#   ('then', 'O'),
#   ('used', 'O'),
#   ('to', 'O'),
#   ('clone', 'O'),
#   ('the', 'O'),
#   ('full', 'O'),
#   ('-', 'O'),
#   ('length', 'O'),
#   ('genes', 'O'),
#   ('from', 'O'),
#   ('a', 'O'),
#   ('yeast', 'O'),
#   ('genomic', 'O'),
#   ('library', 'O'),
#   ('.', 'O')],
#  25276: [('GAL4', 'B'),
#   ('-', 'O'),
#   ('VP16', 'B'),
#   ('-', 'O'),
#   ('mediated', 'O'),
#   ('antirepression', 'O'),
#   ('required', 'O'),
#   ('an', 'O'),
#   ('auxiliary', 'O'),
#   ('factor', 'O'),
#   (',', 'O'),
#   ('denoted', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('co', 'O'),
#   ('-', 'O'),
#   ('antirepressor', 'O'),
#   (',', 'O'),
#   ('which', 'O'),
#   ('was', 'O'),
#   ('partially', 'O'),
#   ('purified', 'O'),
#   ('from', 'O'),
#   ('Drosophila', 'O'),
#   ('embryos', 'O'),
#   ('.', 'O')],
#  25306: [('After', 'O'),
#   ('28', 'O'),
#   ('days', 'O'),
#   ('of', 'O'),
#   ('haloperidol', 'O'),
#   ('treatment', 'O'),
#   (',', 'O'),
#   ('similar', 'O'),
#   ('changes', 'O'),
#   ('were', 'O'),
#   ('observed', 'O'),
#   ('for', 'O'),
#   ('delta', 'O'),
#   (',', 'O'),
#   ('together', 'O'),
#   ('with', 'O'),
#   ('an', 'O'),
#   ('increase', 'O'),
#   ('of', 'O'),
#   ('alpha', 'O'),
#   ('1', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('a', 'O'),
#   ('decrease', 'O'),
#   ('of', 'O'),
#   ('fast', 'O'),
#   ('beta', 'O'),
#   ('.', 'O')],
#  25350: [('Four', 'O'),
#   ('ruminally', 'O'),
#   ('and', 'O'),
#   ('duodenally', 'O'),
#   ('cannulated', 'O'),
#   ('Hampshire', 'O'),
#   ('wethers', 'O'),
#   ('were', 'O'),
#   ('used', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('4', 'O'),
#   ('x', 'O'),
#   ('4', 'O'),
#   ('Latin', 'O'),
#   ('square', 'O'),
#   ('experiment', 'O'),
#   ('to', 'O'),
#   ('determine', 'O'),
#   ('whether', 'O'),
#   ('linoleoyl', 'O'),
#   ('methionine', 'O'),
#   ('and', 'O'),
#   ('calcium', 'O'),
#   ('linoleate', 'O'),
#   ('would', 'O'),
#   ('increase', 'O'),
#   ('duodenal', 'O'),
#   ('flow', 'O'),
#   ('of', 'O'),
#   ('unsaturated', 'O'),
#   ('fatty', 'O'),
#   ('acids', 'O'),
#   ('(', 'O'),
#   ('C18', 'O'),
#   (':', 'O'),
#   ('2', 'O'),
#   ('+', 'O'),
#   ('cis', 'O'),
#   ('C18', 'O'),
#   (':', 'O'),
#   ('1', 'O'),
#   (').', 'O')],
#  25388: [('Truncated', 'B'),
#   ('ICSBP', 'I'),
#   ('lacking', 'O'),
#   ('the', 'O'),
#   ('first', 'O'),
#   ('33', 'O'),
#   ('amino', 'O'),
#   ('-', 'O'),
#   ('terminal', 'O'),
#   ('amino', 'O'),
#   ('acids', 'O'),
#   ('fails', 'O'),
#   ('to', 'O'),
#   ('bind', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('ICS', 'B'),
#   (',', 'O'),
#   ('indicating', 'O'),
#   ('that', 'O'),
#   ('at', 'O'),
#   ('least', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('DNA', 'O'),
#   ('binding', 'O'),
#   ('domain', 'O'),
#   ('is', 'O'),
#   ('located', 'O'),
#   ('within', 'O'),
#   ('the', 'O'),
#   ('well', 'O'),
#   ('conserved', 'O'),
#   ('amino', 'O'),
#   ('terminus', 'O'),
#   ('.', 'O')],
#  25409: [('Therefore', 'O'),
#   (',', 'O'),
#   ('ICSBP', 'B'),
#   ('may', 'O'),
#   ('be', 'O'),
#   ('involved', 'O'),
#   ('in', 'O'),
#   ('maintaining', 'O'),
#   ('submaximal', 'O'),
#   ('transcriptional', 'O'),
#   ('activity', 'O'),
#   ('of', 'O'),
#   ('IFN', 'B'),
#   ('-', 'O'),
#   ('inducible', 'O'),
#   ('genes', 'O'),
#   ('in', 'O'),
#   ('hematopoietic', 'O'),
#   ('cells', 'O'),
#   ('.', 'O')],
#  25423: [('A', 'O'),
#   ('case', 'O'),
#   ('of', 'O'),
#   ('chronic', 'O'),
#   ('hepatitis', 'O'),
#   ('C', 'O'),
#   ('with', 'O'),
#   ('primary', 'O'),
#   ('hypothyroidism', 'O'),
#   ('manifested', 'O'),
#   ('during', 'O'),
#   ('interferon', 'B'),
#   ('treatment', 'O')],
#  25434: [('Dynamic', 'O'),
#   ('decision', 'O'),
#   ('making', 'O'),
#   (':', 'O'),
#   ('human', 'O'),
#   ('control', 'O'),
#   ('of', 'O'),
#   ('complex', 'O'),
#   ('systems', 'O'),
#   ('.', 'O')],
#  25450: [('A', 'O'),
#   ('coiled', 'B'),
#   ('-', 'I'),
#   ('coil', 'I'),
#   ('related', 'I'),
#   ('protein', 'I'),
#   ('specific', 'O'),
#   ('for', 'O'),
#   ('synapsed', 'O'),
#   ('regions', 'O'),
#   ('of', 'O'),
#   ('meiotic', 'O'),
#   ('prophase', 'O'),
#   ('chromosomes', 'O'),
#   ('.', 'O')],
#  25483: [('Comparable', 'O'),
#   ('amounts', 'O'),
#   ('of', 'O'),
#   ('alpha', 'B'),
#   ('5', 'I'),
#   ('beta', 'I'),
#   ('1', 'I'),
#   ('integrin', 'I'),
#   ('were', 'O'),
#   ('isolated', 'O'),
#   ('from', 'O'),
#   ('these', 'O'),
#   ('cells', 'O'),
#   ('by', 'O'),
#   ('chromatography', 'O'),
#   ('of', 'O'),
#   ('detergent', 'O'),
#   ('extracts', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('fibronectin', 'B'),
#   ('cell', 'O'),
#   ('-', 'O'),
#   ('binding', 'O'),
#   ('fragment', 'O'),
#   ('affinity', 'O'),
#   ('column', 'O'),
#   ('and', 'O'),
#   ('elution', 'O'),
#   ('with', 'O'),
#   ('EDTA', 'O'),
#   ('.', 'O')],
#  25486: [('Abstracts', 'O'), ('.', 'O')],
#  25516: [('These', 'O'),
#   ('results', 'O'),
#   ('indicate', 'O'),
#   ('a', 'O'),
#   ('possible', 'O'),
#   ('involvement', 'O'),
#   ('of', 'O'),
#   ('endogenous', 'O'),
#   ('opioid', 'O'),
#   ('peptides', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('cardiac', 'O'),
#   ('effects', 'O'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('myocardial', 'O'),
#   ('ischaemia', 'O'),
#   ('and', 'O'),
#   ('reperfusion', 'O'),
#   (',', 'O'),
#   ('mediated', 'O'),
#   ('by', 'O'),
#   ('opiate', 'B'),
#   ('receptors', 'I'),
#   ('through', 'O'),
#   ('opiate', 'O'),
#   ('antagonism', 'O'),
#   ('.', 'O')],
#  25555: [('From', 'O'),
#   ('this', 'O'),
#   ('library', 'O'),
#   (',', 'O'),
#   ('LEU2', 'B'),
#   ('and', 'O'),
#   ('HIS3', 'B'),
#   ('cDNAs', 'O'),
#   ('were', 'O'),
#   ('recovered', 'O'),
#   ('at', 'O'),
#   ('a', 'O'),
#   ('frequency', 'O'),
#   ('of', 'O'),
#   ('about', 'O'),
#   ('1', 'O'),
#   ('in', 'O'),
#   ('10', 'O'),
#   ('(', 'O'),
#   ('4', 'O'),
#   (')', 'O'),
#   ('and', 'O'),
#   ('in', 'O'),
#   ('12', 'O'),
#   ('out', 'O'),
#   ('of', 'O'),
#   ('13', 'O'),
#   ('cases', 'O'),
#   ('these', 'O'),
#   ('were', 'O'),
#   ('expressed', 'O'),
#   ('in', 'O'),
#   ('a', 'O'),
#   ('galactose', 'O'),
#   ('-', 'O'),
#   ('dependent', 'O'),
#   ('manner', 'O'),
#   ('.', 'O')],
#  25570: [('Among', 'O'),
#   ('these', 'O'),
#   (',', 'O'),
#   ('ACT1', 'B'),
#   ('was', 'O'),
#   ('isolated', 'O'),
#   ('four', 'O'),
#   ('times', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('NSR1', 'B'),
#   ('three', 'O'),
#   ('times', 'O'),
#   ('.', 'O')],
#  25617: [('Since', 'O'),
#   ('CENP', 'B'),
#   ('-', 'I'),
#   ('B', 'I'),
#   ('gene', 'I'),
#   ('is', 'O'),
#   ('conserved', 'O'),
#   ('in', 'O'),
#   ('mammalian', 'O'),
#   ('species', 'O'),
#   ('and', 'O'),
#   ('CENP', 'B'),
#   ('-', 'I'),
#   ('B', 'I'),
#   ('boxes', 'I'),
#   ('are', 'O'),
#   ('found', 'O'),
#   ('also', 'O'),
#   ('in', 'O'),
#   ('mouse', 'O'),
#   ('centromere', 'O'),
#   ('satellite', 'O'),
#   ('DNA', 'O'),
#   ('(', 'O'),
#   ('minor', 'O'),
#   ('satellite', 'O'),
#   ('),', 'O'),
#   ('this', 'O'),
#   ('sequence', 'O'),
#   ('-', 'O'),
#   ('specific', 'O'),
#   ('DNA', 'O'),
#   ('-', 'O'),
#   ('protein', 'O'),
#   ('interaction', 'O'),
#   ('may', 'O'),
#   ('be', 'O'),
#   ('important', 'O'),
#   ('for', 'O'),
#   ('some', 'O'),
#   ('kind', 'O'),
#   ('of', 'O'),
#   ('common', 'O'),
#   ('centromere', 'O'),
#   ('function', 'O'),
#   ('.', 'O')],
#  25661: [('Interestingly', 'O'),
#   (',', 'O'),
#   ('a', 'O'),
#   ('portion', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('tail', 'O'),
#   ('domain', 'O'),
#   ('(', 'O'),
#   ('aa', 'O'),
#   (',', 'O'),
#   ('1', 'O'),
#   (',', 'O'),
#   ('094', 'O'),
#   ('-', 'O'),
#   ('1', 'O'),
#   (',', 'O'),
#   ('830', 'O'),
#   (')', 'O'),
#   ('shares', 'O'),
#   ('58', 'O'),
#   ('%', 'O'),
#   ('amino', 'O'),
#   ('acid', 'O'),
#   ('sequence', 'O'),
#   ('identity', 'O'),
#   ('with', 'O'),
#   ('a', 'O'),
#   ('723', 'O'),
#   ('-', 'O'),
#   ('aa', 'O'),
#   ('protein', 'O'),
#   ('from', 'O'),
#   ('mouse', 'O'),
#   ('brain', 'O'),
#   ('reported', 'O'),
#   ('to', 'O'),
#   ('be', 'O'),
#   ('a', 'O'),
#   ('glutamic', 'B'),
#   ('acid', 'I'),
#   ('decarboxylase', 'I'),
#   ('.', 'O')],
#  25746: [('However', 'O'),
#   (',', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('subgroup', 'O'),
#   ('with', 'O'),
#   ('normal', 'O'),
#   ('Ht', 'O'),
#   ('(<', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('45', 'O'),
#   ('l', 'O'),
#   ('/', 'O'),
#   ('l', 'O'),
#   (';', 'O'),
#   ('n', 'O'),
#   ('=', 'O'),
#   ('201', 'O'),
#   (')', 'O'),
#   ('there', 'O'),
#   ('was', 'O'),
#   ('a', 'O'),
#   ('significant', 'O'),
#   ('reduction', 'O'),
#   ('(', 'O'),
#   ('p', 'O'),
#   ('<', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('05', 'O'),
#   (')', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('mortality', 'O'),
#   ('after', 'O'),
#   ('3', 'O'),
#   ('months', 'O'),
#   ('(', 'O'),
#   ('27', 'O'),
#   ('%', 'O'),
#   ('and', 'O'),
#   ('16', 'O'),
#   ('%,', 'O'),
#   ('respectively', 'O'),
#   (')', 'O'),
#   ('and', 'O'),
#   ('an', 'O'),
#   ('increase', 'O'),
#   ('of', 'O'),
#   ('independence', 'O'),
#   ('at', 'O'),
#   ('home', 'O'),
#   ('(', 'O'),
#   ('35', 'O'),
#   ('%', 'O'),
#   ('and', 'O'),
#   ('48', 'O'),
#   ('%,', 'O'),
#   ('respectively', 'O'),
#   (')', 'O'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('a', 'O'),
#   ('reduction', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('viscosity', 'O'),
#   ('by', 'O'),
#   ('means', 'O'),
#   ('of', 'O'),
#   ('haemodilution', 'O'),
#   ('with', 'O'),
#   ('albumin', 'B'),
#   ('(', 'O'),
#   ('a', 'O'),
#   ('specific', 'O'),
#   ('viscosity', 'O'),
#   ('effect', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('normovolaemic', 'O'),
#   ('group', 'O'),
#   (').', 'O')],
#  25752: [('Distribution', 'O'),
#   ('and', 'O'),
#   ('changing', 'O'),
#   ('morphological', 'O'),
#   ('course', 'O')],
#  25805: [('The', 'O'),
#   ('appropriate', 'O'),
#   ('use', 'O'),
#   ('and', 'O'),
#   ('benefits', 'O'),
#   ('of', 'O'),
#   ('bile', 'O'),
#   ('acid', 'O'),
#   ('sequestrants', 'O'),
#   (',', 'O'),
#   ('nicotinic', 'O'),
#   ('acid', 'O'),
#   (',', 'O'),
#   ('fibric', 'O'),
#   ('acids', 'O'),
#   (',', 'O'),
#   ('3', 'B'),
#   ('-', 'I'),
#   ('hydroxy', 'I'),
#   ('-', 'I'),
#   ('3', 'I'),
#   ('-', 'I'),
#   ('methylglutaryl', 'I'),
#   ('coenzyme', 'I'),
#   ('A', 'I'),
#   ('(', 'I'),
#   ('HMG', 'I'),
#   ('-', 'I'),
#   ('CoA', 'I'),
#   (')', 'I'),
#   ('reductase', 'I'),
#   ('inhibitors', 'O'),
#   (',', 'O'),
#   ('and', 'O'),
#   ('probucol', 'O'),
#   ('are', 'O'),
#   ('individually', 'O'),
#   ('discussed', 'O'),
#   (',', 'O'),
#   ('whereas', 'O'),
#   ('nonpharmacologic', 'O'),
#   ('approaches', 'O'),
#   ('used', 'O'),
#   ('in', 'O'),
#   ('conjunction', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('drugs', 'O'),
#   ('are', 'O'),
#   ('recommended', 'O'),
#   ('emphatically', 'O'),
#   ('.', 'O')],
#  25818: [('This', 'O'),
#   ('may', 'O'),
#   ('result', 'O'),
#   ('in', 'O'),
#   ('more', 'O'),
#   ('reabsorption', 'O'),
#   ('and', 'O'),
#   ('hence', 'O'),
#   ('reduced', 'O'),
#   ('renal', 'O'),
#   ('clearance', 'O'),
#   ('.', 'O')],
#  25831: [('The', 'O'),
#   ('major', 'O'),
#   ('pathological', 'O'),
#   ('findings', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('placenta', 'O'),
#   ('were', 'O'),
#   ('prematuration', 'O'),
#   ('and', 'O'),
#   ('hypoplasia', 'O'),
#   ('.', 'O')],
#  25849: [('Green', 'O'),
#   ('pepper', 'O'),
#   ('significantly', 'O'),
#   ('inhibited', 'O'),
#   ('N', 'O'),
#   ('-', 'O'),
#   ('nitrosothiazolidine', 'O'),
#   ('-', 'O'),
#   ('carboxylic', 'O'),
#   ('acid', 'O'),
#   ('formation', 'O'),
#   ('relative', 'O'),
#   ('to', 'O'),
#   ('ascorbic', 'O'),
#   ('acid', 'O'),
#   ('alone', 'O'),
#   ('.', 'O')],
#  25880: [('A', 'O'),
#   ('genomic', 'O'),
#   ('clone', 'O'),
#   (',', 'O'),
#   ('pTt21', 'O'),
#   (',', 'O'),
#   ('containing', 'O'),
#   ('DNA', 'O'),
#   ('apparently', 'O'),
#   ('transcribed', 'O'),
#   ('specifically', 'O'),
#   ('in', 'O'),
#   ('Trypanosoma', 'O'),
#   ('cruzi', 'O'),
#   ('trypomastigotes', 'O'),
#   (',', 'O'),
#   ('was', 'O'),
#   ('obtained', 'O'),
#   ('by', 'O'),
#   ('differentially', 'O'),
#   ('screening', 'O'),
#   ('a', 'O'),
#   ('genomic', 'O'),
#   ('library', 'O'),
#   ('with', 'O'),
#   ('trypomastigote', 'O'),
#   ('and', 'O'),
#   ('epimastigote', 'O'),
#   ('cDNA', 'O'),
#   ('.', 'O')],
#  ...}

# %% [markdown]
# #### About the data
# - Total number of sentences: 13795
# - Total number of words/tokens in dataset: 308229
# - Max number of words in a sentence: ~102
# - Vocabulary size: 27282
# - Total number of B tags: 13304
# - Total number of I tags: 19527
# - Total number of O tags: 276009
# - The most common top 10 words are: “.”, “the”, “of”, “-”, (',','and','in','a','(', 'to'.
# - The least common top 10 words are: 'K713','hypercholesterolemic','lutein','P69','conference','Talk','Tele','cruciform','TE105'

# %%
train, test = train_test_split(list(all_lines.values()), test_size=0.2)
print(len(train), len(test)), train[2]
# Out:
# 11036 2759
# (None,
#  [('Therefore', 'O'),
#   ('the', 'O'),
#   ('prevalences', 'O'),
#   ('of', 'O'),
#   ('total', 'O'),
#   ('diabetes', 'O'),
#   ('and', 'O'),
#   ('GDM', 'O'),
#   ('were', 'O'),
#   ('1', 'O'),
#   ('.', 'O'),
#   ('19', 'O'),
#   ('%', 'O'),
#   ('and', 'O'),
#   ('0', 'O'),
#   ('.', 'O'),
#   ('56', 'O'),
#   ('%,', 'O'),
#   ('respectively', 'O'),
#   ('.', 'O')])

# %%
word_tag_pairs = [this_tuple for sent in train for this_tuple in sent]
all_words = [this_word_tag[0] for this_word_tag in word_tag_pairs]
all_tags = [this_word_tag[1] for this_word_tag in word_tag_pairs]
all_tag_string = ''.join(all_tags)
vocab = list(set(all_words))
unique_tags = set(all_tags)
tag_counter = Counter(all_tags)
word_tag_pair_counts = Counter(word_tag_pairs)

# %%
data = pd.DataFrame.from_records(all_raw_lines, index=range(1,len(all_raw_lines)+1) )
sent_word_count = data.groupby(['Sentence #']).count()['Word']
df = pd.DataFrame.from_dict(word_tags)
df_wt = pd.DataFrame.from_dict(word_tags).T
most_common = Counter(" ".join(data["Word"]).split()).most_common(10)
least_common = Counter(" ".join(data["Word"]).split()).most_common()[:-100-1:-1] 
data.head(5)
# Out:
#    Sentence #  Line          Word Tag
# 1           0     1    Comparison   O
# 2           0     2          with   O
# 3           0     3      alkaline   B
# 4           0     4  phosphatases   I
# 5           0     5           and   O

# %%
word_tag_pairs
# Out:
# [('In', 'O'),
#  ('conclusion', 'O'),
#  (',', 'O'),
#  ('these', 'O'),
#  ('studies', 'O'),
#  ('indicate', 'O'),
#  ('that', 'O'),
#  ('LiCl', 'O'),
#  ('(', 'O'),
#  ('1', 'O'),
#  (')', 'O'),
#  ('decreases', 'O'),
#  ('histamine', 'O'),
#  ('-', 'O'),
#  ('stimulated', 'O'),
#  ('gastric', 'O'),
#  ('acid', 'O'),
#  ('secretion', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('(', 'O'),
#  ('2', 'O'),
#  (')', 'O'),
#  ('diminishes', 'O'),
#  ('bile', 'O'),
#  ('-', 'O'),
#  ('induced', 'O'),
#  ('disruption', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('gastric', 'O'),
#  ('mucosal', 'O'),
#  ('barrier', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('canine', 'O'),
#  ('Heidenhain', 'O'),
#  ('pouch', 'O'),
#  ('.', 'O'),
#  ('Two', 'O'),
#  ('new', 'O'),
#  ('glucosidase', 'B'),
#  ('inhibitors', 'O'),
#  ('(', 'O'),
#  ('BAY', 'O'),
#  ('m', 'O'),
#  ('1099', 'O'),
#  ('and', 'O'),
#  ('BAY', 'O'),
#  ('o', 'O'),
#  ('1248', 'O'),
#  (')', 'O'),
#  ('were', 'O'),
#  ('studied', 'O'),
#  ('in', 'O'),
#  ('volunteers', 'O'),
#  ('and', 'O'),
#  ('type', 'O'),
#  ('II', 'O'),
#  ('diabetics', 'O'),
#  ('under', 'O'),
#  ('various', 'O'),
#  ('conditions', 'O'),
#  ('.', 'O'),
#  ('Therefore', 'O'),
#  ('the', 'O'),
#  ('prevalences', 'O'),
#  ('of', 'O'),
#  ('total', 'O'),
#  ('diabetes', 'O'),
#  ('and', 'O'),
#  ('GDM', 'O'),
#  ('were', 'O'),
#  ('1', 'O'),
#  ('.', 'O'),
#  ('19', 'O'),
#  ('%', 'O'),
#  ('and', 'O'),
#  ('0', 'O'),
#  ('.', 'O'),
#  ('56', 'O'),
#  ('%,', 'O'),
#  ('respectively', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('relative', 'O'),
#  ('toxicity', 'O'),
#  ('of', 'O'),
#  ('nickel', 'O'),
#  ('oxide', 'O'),
#  ('(', 'O'),
#  ('NiO', 'O'),
#  ('),', 'O'),
#  ('nickel', 'O'),
#  ('sulfate', 'O'),
#  ('hexahydrate', 'O'),
#  ('(', 'O'),
#  ('NiSO4', 'O'),
#  ('.', 'O'),
#  ('6H2O', 'O'),
#  ('),', 'O'),
#  ('and', 'O'),
#  ('nickel', 'O'),
#  ('subsulfide', 'O'),
#  ('(', 'O'),
#  ('Ni3S2', 'O'),
#  (')', 'O'),
#  ('was', 'O'),
#  ('studied', 'O'),
#  ('in', 'O'),
#  ('F344', 'O'),
#  ('/', 'O'),
#  ('N', 'O'),
#  ('rats', 'O'),
#  ('and', 'O'),
#  ('B6C3F1', 'O'),
#  ('mice', 'O'),
#  ('after', 'O'),
#  ('inhalation', 'O'),
#  ('exposure', 'O'),
#  ('for', 'O'),
#  ('6', 'O'),
#  ('hr', 'O'),
#  ('/', 'O'),
#  ('day', 'O'),
#  (',', 'O'),
#  ('5', 'O'),
#  ('days', 'O'),
#  ('/', 'O'),
#  ('week', 'O'),
#  (',', 'O'),
#  ('for', 'O'),
#  ('13', 'O'),
#  ('weeks', 'O'),
#  ('.', 'O'),
#  ('Each', 'O'),
#  ('patient', 'O'),
#  ('had', 'O'),
#  ('measurable', 'O'),
#  ('LH', 'B'),
#  ('and', 'O'),
#  ('FSH', 'B'),
#  ('levels', 'O'),
#  (',', 'O'),
#  ('with', 'O'),
#  ('pulsed', 'O'),
#  ('nocturnal', 'O'),
#  ('secretion', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('pubertal', 'O'),
#  ('LH', 'B'),
#  ('and', 'O'),
#  ('FSH', 'B'),
#  ('responses', 'O'),
#  ('to', 'O'),
#  ('LRH', 'B'),
#  ('.', 'O'),
#  ('Ophthalmosonographic', 'O'),
#  ('evaluation', 'O'),
#  ('of', 'O'),
#  ('blood', 'O'),
#  ('flow', 'O'),
#  ('velocity', 'O'),
#  ('in', 'O'),
#  ('arteriocavernous', 'O'),
#  ('fistula', 'O'),
#  ('From', 'O'),
#  ('Pap', 'O'),
#  ('to', 'O'),
#  ('ApUp', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('control', 'O'),
#  ('patients', 'O'),
#  (',', 'O'),
#  ('baseline', 'O'),
#  ('images', 'O'),
#  ('presented', 'O'),
#  ('Type', 'O'),
#  ('I', 'O'),
#  ('in', 'O'),
#  ('25', 'O'),
#  (',', 'O'),
#  ('Type', 'O'),
#  ('II', 'O'),
#  ('in', 'O'),
#  ('7', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Type', 'O'),
#  ('III', 'O'),
#  ('&', 'O'),
#  ('IV', 'O'),
#  ('in', 'O'),
#  ('0', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('Type', 'O'),
#  ('after', 'O'),
#  ('loading', 'O'),
#  ('was', 'O'),
#  ('the', 'O'),
#  ('same', 'O'),
#  ('as', 'O'),
#  ('the', 'O'),
#  ('Type', 'O'),
#  ('at', 'O'),
#  ('baseline', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('major', 'O'),
#  ('findings', 'O'),
#  ('of', 'O'),
#  ('our', 'O'),
#  ('studies', 'O'),
#  ('are', 'O'),
#  ('as', 'O'),
#  ('follows', 'O'),
#  (':', 'O'),
#  ('1', 'O'),
#  (')', 'O'),
#  ('There', 'O'),
#  ('are', 'O'),
#  ('no', 'O'),
#  ('detectable', 'O'),
#  ('signals', 'O'),
#  ('around', 'O'),
#  ('GDF', 'B'),
#  ('-', 'I'),
#  ('9', 'I'),
#  ('-', 'O'),
#  ('deficient', 'O'),
#  ('follicles', 'O'),
#  ('for', 'O'),
#  ('several', 'O'),
#  ('theca', 'O'),
#  ('cell', 'O'),
#  ('layer', 'O'),
#  ('markers', 'O'),
#  ('[', 'O'),
#  ('i', 'O'),
#  ('.', 'O'),
#  ('e', 'O'),
#  ('.', 'O'),
#  ('Keck', 'O'),
#  (',', 'O'),
#  ('C', 'O'),
#  ('.', 'O'),
#  ('J', 'O'),
#  ('.', 'O'),
#  ('Therefore', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('rbcL', 'B'),
#  ('-', 'O'),
#  ('rbcS', 'B'),
#  ('locus', 'O'),
#  ('seems', 'O'),
#  ('to', 'O'),
#  ('be', 'O'),
#  ('barely', 'O'),
#  ('expressed', 'O'),
#  ('under', 'O'),
#  ('a', 'O'),
#  ('standard', 'O'),
#  ('condition', 'O'),
#  ('for', 'O'),
#  ('photoautotrophic', 'O'),
#  ('growth', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('properties', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('phi', 'O'),
#  ('29', 'O'),
#  ('SSB', 'B'),
#  ('-', 'I'),
#  ('ssDNA', 'I'),
#  ('complex', 'O'),
#  ('are', 'O'),
#  ('described', 'O'),
#  ('.', 'O'),
#  ('Internal', 'O'),
#  ('modes', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('soliton', 'O'),
#  ('.', 'O'),
#  ('A', 'O'),
#  ('total', 'O'),
#  ('of', 'O'),
#  ('281', 'O'),
#  ('patients', 'O'),
#  ('were', 'O'),
#  ('divided', 'O'),
#  ('into', 'O'),
#  ('groups', 'O'),
#  ('according', 'O'),
#  ('to', 'O'),
#  ('their', 'O'),
#  ('clinical', 'O'),
#  ('diagnosis', 'O'),
#  ('and', 'O'),
#  ('were', 'O'),
#  ('examined', 'O'),
#  ('using', 'O'),
#  ('capnography', 'O'),
#  (',', 'O'),
#  ('spirometry', 'O'),
#  ('and', 'O'),
#  ('blood', 'O'),
#  ('-', 'O'),
#  ('gas', 'O'),
#  ('analysis', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('addition', 'O'),
#  ('to', 'O'),
#  ('its', 'O'),
#  ('effect', 'O'),
#  ('in', 'O'),
#  ('augmenting', 'O'),
#  ('the', 'O'),
#  ('neutrophil', 'O'),
#  ('response', 'O'),
#  ('to', 'O'),
#  ('eccentric', 'O'),
#  ('exercise', 'O'),
#  (',', 'O'),
#  ('vitamin', 'O'),
#  ('E', 'O'),
#  ('causes', 'O'),
#  ('a', 'O'),
#  ('greater', 'O'),
#  ('increase', 'O'),
#  ('in', 'O'),
#  ('circulating', 'O'),
#  ('creatine', 'B'),
#  ('kinase', 'I'),
#  ('activity', 'O'),
#  (',', 'O'),
#  ('perhaps', 'O'),
#  ('indicating', 'O'),
#  ('increased', 'O'),
#  ('skeletal', 'O'),
#  ('muscle', 'O'),
#  ('repair', 'O'),
#  ('.', 'O'),
#  ('Methods', 'O'),
#  ('included', 'O'),
#  ('24', 'O'),
#  ('-', 'O'),
#  ('hour', 'O'),
#  ('dietary', 'O'),
#  ('recall', 'O'),
#  (',', 'O'),
#  ('menu', 'O'),
#  ('weights', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('recipe', 'O'),
#  ('analysis', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('this', 'O'),
#  ('method', 'O'),
#  (',', 'O'),
#  ('PLP', 'O'),
#  ('in', 'O'),
#  ('plasma', 'O'),
#  ('can', 'O'),
#  ('be', 'O'),
#  ('determined', 'O'),
#  ('with', 'O'),
#  ('high', 'O'),
#  ('sensitivity', 'O'),
#  ('using', 'O'),
#  ('derivatization', 'O'),
#  ('with', 'O'),
#  ('sodium', 'O'),
#  ('bisulfite', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('mobile', 'O'),
#  ('phase', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('general', 'O'),
#  ('recombination', 'O'),
#  ('at', 'O'),
#  ('a', 'O'),
#  ('polarizing', 'O'),
#  ('voltage', 'O'),
#  ('of', 'O'),
#  ('300', 'O'),
#  ('V', 'O'),
#  ('is', 'O'),
#  ('less', 'O'),
#  ('than', 'O'),
#  ('2', 'O'),
#  ('%', 'O'),
#  ('for', 'O'),
#  ('dose', 'O'),
#  ('-', 'O'),
#  ('rates', 'O'),
#  ('up', 'O'),
#  ('to', 'O'),
#  ('about', 'O'),
#  ('100', 'O'),
#  ('mGy', 'O'),
#  ('min', 'O'),
#  ('-', 'O'),
#  ('1', 'O'),
#  ('.', 'O'),
#  ('Use', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('vena', 'O'),
#  ('cava', 'O'),
#  ('to', 'O'),
#  ('extend', 'O'),
#  ('the', 'O'),
#  ('right', 'O'),
#  ('renal', 'O'),
#  ('vein', 'O'),
#  ('for', 'O'),
#  ('cadaver', 'O'),
#  ('transplantation', 'O'),
#  ('is', 'O'),
#  ('controversial', 'O'),
#  ('.', 'O'),
#  ('(', 'O'),
#  ('1992', 'O'),
#  (')', 'O'),
#  ('Genomics', 'O'),
#  ('12', 'O'),
#  (',', 'O'),
#  ('58', 'O'),
#  ('-', 'O'),
#  ('62', 'O'),
#  (').', 'O'),
#  ('Spinal', 'O'),
#  ('cord', 'O'),
#  ('representation', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('micturition', 'O'),
#  ('reflex', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('two', 'O'),
#  ('-', 'O'),
#  ('hybrid', 'O'),
#  ('assay', 'O'),
#  ('was', 'O'),
#  ('then', 'O'),
#  ('performed', 'O'),
#  ('using', 'O'),
#  ('full', 'O'),
#  ('-', 'O'),
#  ('length', 'O'),
#  ('genes', 'O'),
#  ('of', 'O'),
#  ('CI', 'B'),
#  (',', 'O'),
#  ('HC', 'B'),
#  ('-', 'I'),
#  ('Pro', 'I'),
#  (',', 'O'),
#  ('P1', 'B'),
#  (',', 'O'),
#  ('P3', 'B'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('CP', 'B'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('no', 'O'),
#  ('heterologous', 'O'),
#  ('interactions', 'O'),
#  ('were', 'O'),
#  ('detected', 'O'),
#  ('.', 'O'),
#  ('High', 'O'),
#  ('plasma', 'O'),
#  ('concentrations', 'O'),
#  ('of', 'O'),
#  ('soluble', 'O'),
#  ('E', 'B'),
#  ('-', 'I'),
#  ('selectin', 'I'),
#  ('were', 'O'),
#  ('closely', 'O'),
#  ('associated', 'O'),
#  ('with', 'O'),
#  ('multiple', 'O'),
#  ('-', 'O'),
#  ('organ', 'O'),
#  ('dysfunction', 'O'),
#  ('and', 'O'),
#  ('death', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('patients', 'O'),
#  ('with', 'O'),
#  ('limited', 'O'),
#  ('disease', 'O'),
#  (',', 'O'),
#  ('the', 'O'),
#  ('survival', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('alternating', 'O'),
#  ('arm', 'O'),
#  ('was', 'O'),
#  ('significantly', 'O'),
#  ('superior', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('survival', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('CAV', 'O'),
#  ('arm', 'O'),
#  ('(', 'O'),
#  ('P', 'O'),
#  ('=', 'O'),
#  ('.', 'O'),
#  ('014', 'O'),
#  (')', 'O'),
#  ('or', 'O'),
#  ('the', 'O'),
#  ('survival', 'O'),
#  ('in', 'O'),
#  ('the', 'O'),
#  ('PE', 'O'),
#  ('arm', 'O'),
#  ('(', 'O'),
#  ('P', 'O'),
#  ('=', 'O'),
#  ('.', 'O'),
#  ('023', 'O'),
#  (').', 'O'),
#  ('Mg', 'B'),
#  ('-', 'I'),
#  ('chelatase', 'I'),
#  ('of', 'O'),
#  ('tobacco', 'O'),
#  (':', 'O'),
#  ('identification', 'O'),
#  ('of', 'O'),
#  ('a', 'O'),
#  ('Chl', 'B'),
#  ('D', 'I'),
#  ('cDNA', 'I'),
#  ('sequence', 'I'),
#  ('encoding', 'O'),
#  ('a', 'O'),
#  ('third', 'O'),
#  ('subunit', 'O'),
#  (',', 'O'),
#  ('analysis', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('interaction', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('three', 'O'),
#  ('subunits', 'O'),
#  ('with', 'O'),
#  ('the', 'O'),
#  ('yeast', 'O'),
#  ('two', 'O'),
#  ('-', 'O'),
#  ('hybrid', 'O'),
#  ('system', 'O'),
#  (',', 'O'),
#  ('and', 'O'),
#  ('reconstitution', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('enzyme', 'O'),
#  ('activity', 'O'),
#  ('by', 'O'),
#  ('co', 'O'),
#  ('-', 'O'),
#  ('expression', 'O'),
#  ('of', 'O'),
#  ('recombinant', 'B'),
#  ('CHL', 'I'),
#  ('D', 'I'),
#  (',', 'O'),
#  ('CHL', 'B'),
#  ('H', 'I'),
#  ('and', 'O'),
#  ('CHL', 'B'),
#  ('I', 'I'),
#  ('.', 'O'),
#  ('This', 'O'),
#  ('suggested', 'O'),
#  ('that', 'O'),
#  ('delta', 'O'),
#  ('6', 'O'),
#  ('and', 'O'),
#  ('delta', 'O'),
#  ('5', 'O'),
#  ('desaturation', 'O'),
#  ('activities', 'O'),
#  ('are', 'O'),
#  ('normal', 'O'),
#  ('in', 'O'),
#  ('these', 'O'),
#  ('conditions', 'O'),
#  ('with', 'O'),
#  ('this', 'O'),
#  ('C18', 'O'),
#  (':', 'O'),
#  ('2w6', 'O'),
#  ('supply', 'O'),
#  ('.', 'O'),
#  ('Gel', 'O'),
#  ('shift', 'O'),
#  ('analysis', 'O'),
#  ('indicates', 'O'),
#  ('that', 'O'),
#  ('the', 'O'),
#  ('full', 'B'),
#  ('-', 'I'),
#  ('length', 'I'),
#  ('ERM', 'I'),
#  ('protein', 'I'),
#  ('is', 'O'),
#  ('able', 'O'),
#  ('to', 'O'),
#  ('bind', 'O'),
#  ('specifically', 'O'),
#  ('to', 'O'),
#  ('an', 'O'),
#  ('oligonucleotide', 'O'),
#  ('containing', 'O'),
#  ('the', 'O'),
#  ('consensus', 'O'),
#  ('nucleotide', 'O'),
#  ('core', 'O'),
#  ('sequence', 'O'),
#  ('GGAA', 'O'),
#  ('recognized', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('Ets', 'B'),
#  ('proteins', 'O'),
#  ('.', 'O'),
#  ('This', 'O'),
#  ('test', 'O'),
#  ('should', 'O'),
#  ('provide', 'O'),
#  ('another', 'O'),
#  ('practical', 'O'),
#  ('means', 'O'),
#  ('to', 'O'),
#  ('study', 'O'),
#  ('leprosy', 'O'),
#  ('.', 'O'),
#  ('CONCLUSIONS', 'O'),
#  (':', 'O'),
#  ('EBCT', 'O'),
#  ('technology', 'O'),
#  ('allows', 'O'),
#  ('minimally', 'O'),
#  ('invasive', 'O'),
#  ('evaluation', 'O'),
#  ('of', 'O'),
#  ('intramyocardial', 'O'),
#  ('microcirculatory', 'O'),
#  ('function', 'O'),
#  ('and', 'O'),
#  ('permits', 'O'),
#  ('assessment', 'O'),
#  ('of', 'O'),
#  ('microvascular', 'O'),
#  ('BV', 'O'),
#  ('distribution', 'O'),
#  ('in', 'O'),
#  ('different', 'O'),
#  ('functional', 'O'),
#  ('components', 'O'),
#  ('.', 'O'),
#  ('RT', 'O'),
#  ('-', 'O'),
#  ('PCR', 'O'),
#  ('was', 'O'),
#  ('performed', 'O'),
#  ('using', 'O'),
#  ('previously', 'O'),
#  ('reported', 'O'),
#  ('degenerate', 'O'),
#  ('oligonucleotide', 'O'),
#  ('primers', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('ligand', 'O'),
#  ('binding', 'O'),
#  ('domain', 'O'),
#  ('(', 'O'),
#  ('LBD', 'O'),
#  (')', 'O'),
#  ('of', 'O'),
#  ('known', 'O'),
#  ('beta', 'B'),
#  ('integrin', 'I'),
#  ('subunits', 'I'),
#  ('and', 'O'),
#  ('Bge', 'B'),
#  ('cDNA', 'I'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('effective', 'O'),
#  ('and', 'O'),
#  ('low', 'O'),
#  ('toxic', 'O'),
#  ('dose', 'O'),
#  ('schedules', 'O'),
#  ('of', 'O'),
#  ('KW', 'O'),
#  ('-', 'O'),
#  ('2083', 'O'),
#  ('should', 'O'),
#  ('be', 'O'),
#  ('investigated', 'O'),
#  ('further', 'O'),
#  ('.', 'O'),
#  ('These', 'O'),
#  ('results', 'O'),
#  ('suggest', 'O'),
#  ('that', 'O'),
#  ('the', 'O'),
#  ('phenotype', 'O'),
#  ('of', 'O'),
#  ('XLP', 'O'),
#  ('may', 'O'),
#  ('result', 'O'),
#  ('from', 'O'),
#  ('perturbed', 'O'),
#  ('signaling', 'O'),
#  ('not', 'O'),
#  ('only', 'O'),
#  ('through', 'O'),
#  ('SLAM', 'B'),
#  (',', 'O'),
#  ('but', 'O'),
#  ('also', 'O'),
#  ('other', 'O'),
#  ('cell', 'O'),
#  ('surface', 'O'),
#  ('molecules', 'O'),
#  ('that', 'O'),
#  ('utilize', 'O'),
#  ('SAP', 'B'),
#  ('as', 'O'),
#  ('a', 'O'),
#  ('signaling', 'O'),
#  ('adaptor', 'O'),
#  ('protein', 'O'),
#  ('.', 'O'),
#  ('A', 'O'),
#  ('randomized', 'O'),
#  (',', 'O'),
#  ('prospective', 'O'),
#  ('study', 'O'),
#  ('was', 'O'),
#  ('conducted', 'O'),
#  ('to', 'O'),
#  ('compare', 'O'),
#  ('ovarian', 'O'),
#  ('stimulation', 'O'),
#  ('with', 'O'),
#  ('human', 'B'),
#  ('menopausal', 'I'),
#  ('gonadotropin', 'I'),
#  ('(', 'O'),
#  ('hMG', 'B'),
#  (')', 'O'),
#  ('and', 'O'),
#  ('human', 'B'),
#  ('follicle', 'I'),
#  ('-', 'I'),
#  ('stimulating', 'I'),
#  ('hormone', 'I'),
#  ('(', 'O'),
#  ('hFSH', 'B'),
#  (')', 'O'),
#  ('in', 'O'),
#  ('an', 'O'),
#  ('in', 'O'),
#  ('vitro', 'O'),
#  ('fertilization', 'O'),
#  ('and', 'O'),
#  ('embryo', 'O'),
#  ('transfer', 'O'),
#  ('(', 'O'),
#  ('IVF', 'O'),
#  ('-', 'O'),
#  ('ET', 'O'),
#  (')', 'O'),
#  ('program', 'O'),
#  ('.', 'O'),
#  ('Tl', 'O'),
#  ('-', 'O'),
#  ('201', 'O'),
#  ('uptake', 'O'),
#  ('ratio', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('right', 'O'),
#  ('ventricle', 'O'),
#  (',', 'O'),
#  ('which', 'O'),
#  ('represents', 'O'),
#  ('the', 'O'),
#  ('ratio', 'O'),
#  ('of', 'O'),
#  ('total', 'O'),
#  ('counts', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('right', 'O'),
#  ('ventricle', 'O'),
#  ('to', 'O'),
#  ('counts', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('administered', 'O'),
#  ('dose', 'O'),
#  ('of', 'O'),
#  ('Tl', 'O'),
#  ('-', 'O'),
#  ('201', 'O'),
#  (',', 'O'),
#  ('was', 'O'),
#  ('higher', 'O'),
#  ('in', 'O'),
#  ('COPD', 'O'),
#  (',', 'O'),
#  ('especially', 'O'),
#  ('in', 'O'),
#  ('pulmonary', 'O'),
#  ('emphysema', 'O'),
#  ('and', 'O'),
#  ('B', 'O'),
#  ('type', 'O'),
#  ('COPD', 'O'),
#  ('by', 'O'),
#  ('Burrows', 'O'),
#  ('classification', 'O'),
#  ('than', 'O'),
#  ('in', 'O'),
#  ('controls', 'O'),
#  ('.', 'O'),
#  ('The', 'O'),
#  ('yeast', 'B'),
#  ('SSS1', 'I'),
#  ('gene', 'I'),
#  ('is', 'O'),
#  ('essential', 'O'),
#  ('for', 'O'),
#  ('secretory', 'O'),
#  ('protein', 'O'),
#  ('translocation', 'O'),
#  ('and', 'O'),
#  ('encodes', 'O'),
#  ('a', 'O'),
#  ('conserved', 'O'),
#  ('protein', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('endoplasmic', 'O'),
#  ('reticulum', 'O'),
#  ('.', 'O'),
#  ('In', 'O'),
#  ('some', 'O'),
#  ('instances', 'O'),
#  (',', 'O'),
#  ('this', 'O'),
#  ('is', 'O'),
#  ('partly', 'O'),
#  ('mediated', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('expression', 'O'),
#  ('of', 'O'),
#  ('virally', 'O'),
#  ('encoded', 'O'),
#  ('proteases', 'O'),
#  ('which', 'O'),
#  ('lead', 'O'),
#  ('to', 'O'),
#  ('the', 'O'),
#  ('cleavage', 'O'),
#  ('of', 'O'),
#  ('initiation', 'B'),
#  ('factor', 'I'),
#  ('eIF4G', 'I'),
#  ('.', 'O'),
#  ('Structural', 'O'),
#  ('characteristics', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('erythrocyte', 'O'),
#  ('membrane', 'O'),
#  (',', 'O'),
#  ('peroxidation', 'O'),
#  ('processes', 'O'),
#  ('and', 'O'),
#  ('antioxidant', 'O'),
#  ('function', 'O'),
#  ('in', 'O'),
#  ('children', 'O'),
#  ('with', 'O'),
#  ('diffuse', 'O'),
#  ('glomerulonephritis', 'O'),
#  ('RPA190', 'B'),
#  ('encodes', 'O'),
#  ('a', 'O'),
#  ('polypeptide', 'O'),
#  ('chain', 'O'),
#  ('of', 'O'),
#  ('186', 'O'),
#  (',', 'O'),
#  ('270', 'O'),
#  ('daltons', 'O'),
#  ('in', 'O'),
#  ('a', 'O'),
#  ('large', 'O'),
#  ('uninterrupted', 'O'),
#  ('reading', 'O'),
#  ('frame', 'O'),
#  ('.', 'O'),
#  ('This', 'O'),
#  ('paper', 'O'),
#  ('reviews', 'O'),
#  ('the', 'O'),
#  ('middleware', 'O'),
#  ('-', 'O'),
#  ('based', 'O'),
#  ('approach', 'O'),
#  ('adopted', 'O'),
#  ('by', 'O'),
#  ('CEN', 'O'),
#  ('ENV', 'O'),
#  ('12967', 'O'),
#  ('-', 'O'),
#  ('1', 'O'),
#  ('and', 'O'),
#  ('the', 'O'),
#  ('specialisation', 'O'),
#  ('necessary', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('healthcare', 'O'),
#  ('record', 'O'),
#  ('based', 'O'),
#  ('on', 'O'),
#  ('CEN', 'O'),
#  ('ENV', 'O'),
#  ('12265', 'O'),
#  ("'", 'O'),
#  ('Electronic', 'O'),
#  ('Healthcare', 'O'),
#  ('Record', 'O'),
#  ('Architecture', 'O'),
#  ("'.", 'O'),
#  ('The', 'O'),
#  ('sequence', 'O'),
#  ('upstream', 'O'),
#  ('of', 'O'),
#  ('the', 'O'),
#  ('rhlA', 'B'),
#  ('promoter', 'I'),
#  ('contains', 'O'),
#  ('two', 'O'),
#  ('inverted', 'O'),
#  ('repeats', 'O'),
#  ('which', 'O'),
#  ('define', 'O'),
#  ('putative', 'O'),
#  ('binding', 'O'),
#  ('sites', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('RhlR', 'B'),
#  ('regulator', 'I'),
#  ('.', 'O'),
#  ('Ongoing', 'O'),
#  ('and', 'O'),
#  ('future', 'O'),
#  ('investigations', 'O'),
#  ...]

# %%
print(len(word_tags.keys()), len(word_tags.values()))
# Out:
# 31328 31328

# %%
print("Summary of this Dataset:")
print("Total number of sentences: %d"%(len(all_lines)))
print("Total number of words/tokens in dataset: %d" %len(tokens))
print("Max number of words in a sentence: %d"%(max(sent_word_count)))
print("Vocabulary size: %d"% (len(vocab)))
print("Total number of B tags:", tag_counter['B'])
print("Total number of I tags:", tag_counter['I'])
print("Total number of O tags:", tag_counter['O'])
print("The most common top 10 words are: ",most_common)
print("The least common top 10 words are: ",least_common)
# Out:
# Summary of this Dataset:
# Total number of sentences: 13795
# Total number of words/tokens in dataset: 386201
# Max number of words in a sentence: 255
# Vocabulary size: 27523
# Total number of B tags: 13276
# Total number of I tags: 19696
# Total number of O tags: 276997
# The most common top 10 words are:  [('.', 15510), ('the', 15508), ('of', 14771), ('-', 13150), (',', 12190), ('and', 9980), ('in', 8065), ('a', 5498), ('(', 5375), ('to', 5177)]
# The least common top 10 words are:  [('K713', 1), ('hypercholesterolemic', 1), ('lutein', 1), ('P69', 1), ('conference', 1), ('Talk', 1), ('Tele', 1), ('cruciform', 1), ('TE105', 1), ('probing', 1), ('nonoverlapping', 1), ('monochannel', 1), ('Termination', 1), ('SMemb', 1), ('Tie2', 1), ('Ang1', 1), ('accumulations', 1), ('Ang2', 1), ('INCENP', 1), ('dictating', 1), ('satMa', 1), ('SAF', 1), ('FBT', 1), ('fluorobenzyltrozamicol', 1), ('](+)-', 1), ('Closeup', 1), ('USH1', 1), ('5G', 1), ('IVS51', 1), ('M1281', 1), ('domoic', 1), ('sardine', 1), ('managing', 1), ('TV', 1), ('IIDR', 1), ('Toshiba', 1), ('RLM', 1), ('accelerations', 1), ('AtHD1', 1), ('antagonizes', 1), ('int6Delta', 1), ('int6', 1), ('eIF3e', 1), ('kappaE3', 1), ('Engagement', 1), ('NiCl', 1), ('overestimates', 1), ('subtests', 1), ('nonlinearity', 1), ('Volterra', 1), ('Y8', 1), ('homidum', 1), ('Yankasa', 1), ('Ze', 1), ('castus', 1), ('agnus', 1), ('Vitex', 1), ('crevicular', 1), ('FD2', 1), ('fractal', 1), ('radius', 1), ('nonfracture', 1), ('Adjuvant', 1), ('Bihar', 1), ('Bupropion', 1), ('sequelae', 1), ('3y', 1), ('73401', 1), ('inguinal', 1), ('peeping', 1), ('vanished', 1), ('wilt', 1), ('mealybug', 1), ('pineapple', 1), ('supercoils', 1), ('supercoiling', 1), ('vasculitides', 1), ('Paraneoplastic', 1), ('Percentage', 1), ('betac', 1), ('GADD153', 1), ('HR12', 1), ('Rat1', 1), ('PDE11A', 1), ('GAF', 1), ('Presently', 1), ('inducers', 1), ('BMPs', 1), ('believers', 1), ('LANA2', 1), ('ORFK10', 1), ('jeopardize', 1), ('TAg', 1), ('HDAC1', 1), ('mSin3', 1), ('juglone', 1), ('MdPin1', 1), ('predisposes', 1), ('impeded', 1), ('HMA', 1)]

# %% [markdown]
# Function to find transition probabilities a_ij : p(tag2|tag1)
# ##### Steps
#   - Input: tag2, tag1 and all train_word_tag_pairs
#   - Get all tags for the train_word_tag_pairs
#   - count tag1 = count of tag1 in train_word_tag_pairs
#   - sequence_counts = 0
#   - for all word_tag pairs:
#   - - for all tag1, tag2 sequence
#     - sequence_counts += 1
#   - return sequence_counts, count_tag1
# #### Create Transition probabilities matrix for sequences
#
# ###### Steps:
#   - Create a tag matrix tag_count * tag_count
#   - Fill in each tag matrix with transition probability for the two tags in the

# %% [markdown]
# #### Create Emission Probabilities
# ###### Steps
#   - Get count of tags that match the tag in word_tag_pairs
#   - Get all word_tag_pairs that match the tag
#   - Get count of words that match the word in word_tag_pairs that match the tag
#   - return word_count_for_matched_tag, tag_count

# %%
def get_emission_prob(tag, word, word_tag_pair_counts, tag_counter:Counter):
  #print(tag, word, word_tag_pair_counts)
  tag_count = tag_counter[tag]
  word_count_for_this_tag = word_tag_pair_counts[(word, tag)]
  return (word_count_for_this_tag, tag_count)

# %%
num, denom = get_emission_prob("B", "VirD2",word_tag_pair_counts, tag_counter)
num/denom
# Out:
# 0.00022597167821633023

# %%
def get_transition_prob( tag2, tag1, all_tags_string, tag_counter):
  count1 = tag_counter[tag1]
  sequence_count = all_tag_string.count(tag1+tag2)
  #print(tag1+tag2, sequence_count, all_tag_string)
  return sequence_count, count1

# %%
def create_tag_transition_matrix(unique_tags:list,all_tags_string:str, tag_coutner:Counter):
  tag_matrix = np.zeros((len(unique_tags), len(unique_tags)), dtype="float32")
  for i,tag1 in enumerate(list(unique_tags)):
    for j,tag2 in enumerate(list(unique_tags)):
      seq_count, count1 = get_transition_prob( tag2, tag1, all_tags_string, tag_counter)
      tag_matrix[i, j] = seq_count/count1
  return tag_matrix

# %%
bigram_trans_prob_matrix = create_tag_transition_matrix(unique_tags, all_tag_string, tag_counter)
utags = list(unique_tags)
transition_df = pd.DataFrame(bigram_trans_prob_matrix, columns = utags, index=utags)
transition_df
# Out:
#           I         B         O
# I  0.393684  0.000000  0.394293
# B  0.584965  0.000000  0.415035
# O  0.000000  0.047928  0.486283

# %% [markdown]
# Impement Viterbi with numpy and DP table (Trellis)
# #### Viterbi Algorithm
# - Inputs: Transition probabilities, emission probabilities, start probabilities, result_probabilities
# ###### Inputs/Variables
#   - K is number of unique tags K = 3 (B,I,O)
#   - Bigram case: number of states are BI, BB, BO, IO, II, IB, OI, OO, OB
#   - Trigram case: number of states are
#     - BIB IIO OBO IBO BOO OBB BBO IOO IOI
#     - OOO IBI OBI IOB BBI OOB BII BOI IBB
#     - BOB BBB IIB OIB BIO OII OIO III OOI
#   - Number of Tokens N = 31328 for this Dataset
#   - Start probabalities are set of Initial probabilities and has size K * 1
#   - Transition Probabilities Matrix T with a size K * K
#   - Emission Matrix with a size N * K
#   - End transition scores with a size of K * 1
#
# ###### Most Likely Hidden state Sequence
#   - a hidden state sequence K * 1
#
# ###### Return value
#   - Score of best sequence
#   - Array of size N with integers (best sequence)

# %%
K = len(unique_tags) #total unique tags : 3
N = len(word_tags.keys()) # total number of tokens : 32328
start_p = np.zeros((K)) # 3x1
trans_p = np.zeros((K,K)) # 3 x 3
end_scores =  np.zeros((K))
emission_p = np.zeros((N,K)) # 31328 x 3
tag_order = ['B', 'O', 'I']
tot_tags = len(all_tags)

# %%
tag_counter, utags, tag_order,tot_tags,
# Out:
# (Counter({'B': 13276, 'I': 19696, 'O': 276997}),
#  ['I', 'B', 'O'],
#  ['B', 'O', 'I'],
#  309969)

# %%
start_p.shape
# Out:
# (3,)

# %%
count = 0
start_tags = []
for sent in train:
  tuples = [t[1] for t in sent[:1]]
  tag_seq = "".join(tuples)
  start_tags.append(tag_seq)
start_tag_counter = Counter(start_tags)
start_tag_counter['I'] = 0
tot_start_tags = sum(start_tag_counter.values())
start_tag_counter
# Out:
# Counter({'B': 575, 'I': 0, 'O': 10461})

# %%
for i,tag in enumerate(utags):
    start_p[i] = np.round(start_tag_counter[tag]/tot_tags, 3)

# %%
trans_p = np.asarray(bigram_trans_prob_matrix)
print(transition_df.head())
# Out:
#           I         B         O
# I  0.393684  0.000000  0.394293
# B  0.584965  0.000000  0.415035
# O  0.000000  0.047928  0.486283

# %%
for i,word in enumerate(vocab):
  for j,tag in enumerate(utags):
    word_count_for_this_tag, tag_count = get_emission_prob(tag,word, word_tag_pair_counts, tag_counter)
    if tag_count != 0:
      emission_p[i][j] = word_count_for_this_tag / tag_count
    else:
      emission_p[i][j] = 0.0

# %%
e =  (emission_p - emission_p.min()) / (np.ptp(emission_p))
np.linalg.norm(emission_p/np.linalg.norm(emission_p)), e
# Out:
# (0.9999999999999994, array([[0.00000000e+00, 0.00000000e+00, 2.00466488e-05],
#         [0.00000000e+00, 0.00000000e+00, 6.01399464e-05],
#         [0.00000000e+00, 0.00000000e+00, 2.00466488e-05],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]))

# %%
for i, tag in enumerate(utags):
  num, denom = get_emission_prob(tag, ".", word_tag_pair_counts, tag_counter)
  end_scores[i] = num/denom

# %%
end_scores
# Out:
# array([0.00690496, 0.        , 0.04436149])

# %%
from past.builtins import xrange
def viterbi_dp(start_p, trans_p, emission_p, end_scores):
  pred = []
  trellis = np.array([[0.0 for j in range(N)] for i in range(K)])
  backpointer = np.array([[-1 for j in range(N)] for i in range(K)])

  for i in xrange(N):
      if i == 0:
          trellis[:,0] = np.add(start_p, end_scores)
          print(trellis[:,0])
      else:
          for j in xrange(K):
              trellis[j,i] = np.max(np.add(trans_p[:,j], trellis[:,i-1] )) + emission_p[i,j]
              backpointer[j,i] = np.argmax(np.add(trans_p[:,j], trellis[:,i-1]))
  
  final_score = np.max(np.add(trellis[:, i], end_scores ))
  index = np.argmax(np.add(trellis[:, i], end_scores ))
  print(trellis)
  while index != -1:
      pred.append(index)
      index = argmax_trellis[index, i]
      i -= 1
  
  pred.reverse()
  return (final_score, pred)

# %%
score, pred = viterbi_dp(start_p, trans_p, emission_p, end_scores)
# Out:
# [0.00690496 0.002      0.07836149]
# [[6.90495532e-03 5.86965348e-01 9.80649348e-01 ... 1.52335613e+04
#   1.52340475e+04 1.52345338e+04]
#  [2.00000000e-03 1.26289810e-01 6.12583883e-01 ... 1.52334626e+04
#   1.52339489e+04 1.52344351e+04]
#  [7.83614913e-02 5.64655564e-01 1.05094242e+00 ... 1.52339009e+04
#   1.52343872e+04 1.52348735e+04]]

# %%
score
# Out:
# 15234.917863516936

# %%
sum(pred) == len(word_tags.keys())
# Out:
# False

# %%
preds = np.asarray(pred)
preds[preds==1],preds[preds==2], utags, len(test),len(preds)
# Out:
# (array([], dtype=int64),
#  array([2, 2, 2, ..., 2, 2, 2]),
#  ['I', 'B', 'O'],
#  2759,
#  31328)

# %%
len(sentences[:len(train)]) ==len(train)
# Out:
# True

# %%
ngrams = None
def get_ngrams(train, n):
  for sent in train:
    #print(sent)
    word_boundary = (n-1) * [(None, "*")]
    word_boundary.extend(sent)
    word_boundary.append((None, "STOP"))
    ngrams = (tuple(word_boundary[i:i+n]) for i in xrange(len(word_boundary)-n+1))
    #print(ngrams)
    for ngram in ngrams:
      yield ngram

# %%
from collections import defaultdict

def train_hmm(train, n):
  emission_counts = defaultdict(int)
  ngram_counts = [defaultdict(int) for i in xrange(n)]
  for ngram in get_ngrams(train, n):
      
      assert len(ngram) == n, "n = %i, expected %i" %(len(ngram), n)
      #sent = [[t] for t in ngram]
      tags = tuple([tag for word, tag in ngram])

      for i in xrange(2, n+1):
        ngram_counts[i-1][tags[-i:]] += 1

      if ngram[-1][0] is not None:
        ngram_counts[0][tags[-1:]] += 1
        emission_counts[ngram[-1]] += 1
      
      if ngram[-(n-1)][0] is None:
        ngram_counts[n-2][tuple((n-1) * ["*"])] += 1
      
  return ngram_counts, emission_counts

# %%
bigram_counts, emit_counts = train_hmm(train, 2)
unigram_counts, uemit_counts = train_hmm(train, 1)

# %%
unigram_counts, tag_counter,bigram_counts, len(word_tag_pair_counts), len(emit_counts), len(uemit_counts)
# Out:
# ([defaultdict(int, {(): 11036, ('B',): 13276, ('I',): 19696, ('O',): 276997})],
#  Counter({'B': 13276, 'I': 19696, 'O': 276997}),
#  [defaultdict(int,
#               {('*',): 11036, ('B',): 13276, ('I',): 19696, ('O',): 276997}),
#   defaultdict(int,
#               {('*', 'B'): 575,
#                ('*', 'O'): 10461,
#                ('B', 'I'): 7766,
#                ('B', 'O'): 5508,
#                ('B', 'STOP'): 2,
#                ('I', 'I'): 11930,
#                ('I', 'O'): 7758,
#                ('I', 'STOP'): 8,
#                ('O', 'B'): 12701,
#                ('O', 'O'): 253270,
#                ('O', 'STOP'): 11026})],
#  30470,
#  30470,
#  30470)

# %%
word_tag_pair_counts[('cancer', 'O')], emit_counts[('cancer', 'O')], uemit_counts[('cancer', 'O')],unigram_counts
# Out:
# (76,
#  76,
#  76,
#  [defaultdict(int, {(): 11036, ('B',): 13276, ('I',): 19696, ('O',): 276997})])

# %%
tag_counter,word_tag_pair_counts
# Out:
# (Counter({'B': 13276, 'I': 19696, 'O': 276997}),
#  Counter({('In', 'O'): 617,
#           ('conclusion', 'O'): 14,
#           (',', 'O'): 9720,
#           ('these', 'O'): 395,
#           ('studies', 'O'): 189,
#           ('indicate', 'O'): 117,
#           ('that', 'O'): 2295,
#           ('LiCl', 'O'): 2,
#           ('(', 'O'): 4120,
#           ('1', 'O'): 945,
#           (')', 'O'): 2579,
#           ('decreases', 'O'): 17,
#           ('histamine', 'O'): 8,
#           ('-', 'O'): 6992,
#           ('stimulated', 'O'): 78,
#           ('gastric', 'O'): 35,
#           ('acid', 'O'): 284,
#           ('secretion', 'O'): 43,
#           ('and', 'O'): 7889,
#           ('2', 'O'): 668,
#           ('diminishes', 'O'): 2,
#           ('bile', 'O'): 11,
#           ('induced', 'O'): 330,
#           ('disruption', 'O'): 13,
#           ('of', 'O'): 11782,
#           ('the', 'O'): 12439,
#           ('mucosal', 'O'): 7,
#           ('barrier', 'O'): 8,
#           ('in', 'O'): 6486,
#           ('canine', 'O'): 9,
#           ('Heidenhain', 'O'): 2,
#           ('pouch', 'O'): 4,
#           ('.', 'O'): 12288,
#           ('Two', 'O'): 65,
#           ('new', 'O'): 133,
#           ('glucosidase', 'B'): 1,
#           ('inhibitors', 'O'): 39,
#           ('BAY', 'O'): 2,
#           ('m', 'O'): 27,
#           ('1099', 'O'): 2,
#           ('o', 'O'): 8,
#           ('1248', 'O'): 1,
#           ('were', 'O'): 1449,
#           ('studied', 'O'): 111,
#           ('volunteers', 'O'): 25,
#           ('type', 'O'): 250,
#           ('II', 'O'): 107,
#           ('diabetics', 'O'): 2,
#           ('under', 'O'): 101,
#           ('various', 'O'): 72,
#           ('conditions', 'O'): 76,
#           ('Therefore', 'O'): 33,
#           ('prevalences', 'O'): 1,
#           ('total', 'O'): 122,
#           ('diabetes', 'O'): 24,
#           ('GDM', 'O'): 1,
#           ('19', 'O'): 62,
#           ('%', 'O'): 502,
#           ('0', 'O'): 767,
#           ('56', 'O'): 27,
#           ('%,', 'O'): 91,
#           ('respectively', 'O'): 180,
#           ('The', 'O'): 2046,
#           ('relative', 'O'): 65,
#           ('toxicity', 'O'): 27,
#           ('nickel', 'O'): 3,
#           ('oxide', 'O'): 9,
#           ('NiO', 'O'): 1,
#           ('),', 'O'): 644,
#           ('sulfate', 'O'): 21,
#           ('hexahydrate', 'O'): 1,
#           ('NiSO4', 'O'): 1,
#           ('6H2O', 'O'): 2,
#           ('subsulfide', 'O'): 1,
#           ('Ni3S2', 'O'): 1,
#           ('was', 'O'): 1934,
#           ('F344', 'O'): 2,
#           ('/', 'O'): 1208,
#           ('N', 'O'): 169,
#           ('rats', 'O'): 137,
#           ('B6C3F1', 'O'): 1,
#           ('mice', 'O'): 93,
#           ('after', 'O'): 383,
#           ('inhalation', 'O'): 12,
#           ('exposure', 'O'): 48,
#           ('for', 'O'): 1948,
#           ('6', 'O'): 316,
#           ('hr', 'O'): 20,
#           ('day', 'O'): 120,
#           ('5', 'O'): 704,
#           ('days', 'O'): 104,
#           ('week', 'O'): 37,
#           ('13', 'O'): 98,
#           ('weeks', 'O'): 69,
#           ('Each', 'O'): 18,
#           ('patient', 'O'): 102,
#           ('had', 'O'): 241,
#           ('measurable', 'O'): 2,
#           ('LH', 'B'): 10,
#           ('FSH', 'B'): 14,
#           ('levels', 'O'): 360,
#           ('with', 'O'): 2686,
#           ('pulsed', 'O'): 5,
#           ('nocturnal', 'O'): 2,
#           ('pubertal', 'O'): 4,
#           ('responses', 'O'): 83,
#           ('to', 'O'): 4119,
#           ('LRH', 'B'): 1,
#           ('Ophthalmosonographic', 'O'): 1,
#           ('evaluation', 'O'): 36,
#           ('blood', 'O'): 251,
#           ('flow', 'O'): 102,
#           ('velocity', 'O'): 9,
#           ('arteriocavernous', 'O'): 1,
#           ('fistula', 'O'): 3,
#           ('From', 'O'): 20,
#           ('Pap', 'O'): 2,
#           ('ApUp', 'O'): 1,
#           ('control', 'O'): 241,
#           ('patients', 'O'): 713,
#           ('baseline', 'O'): 24,
#           ('images', 'O'): 12,
#           ('presented', 'O'): 45,
#           ('Type', 'O'): 32,
#           ('I', 'O'): 135,
#           ('25', 'O'): 69,
#           ('7', 'O'): 259,
#           ('III', 'O'): 49,
#           ('&', 'O'): 15,
#           ('IV', 'O'): 37,
#           ('loading', 'O'): 4,
#           ('same', 'O'): 95,
#           ('as', 'O'): 1010,
#           ('at', 'O'): 812,
#           ('major', 'O'): 87,
#           ('findings', 'O'): 71,
#           ('our', 'O'): 71,
#           ('are', 'O'): 817,
#           ('follows', 'O'): 15,
#           (':', 'O'): 723,
#           ('There', 'O'): 47,
#           ('no', 'O'): 193,
#           ('detectable', 'O'): 24,
#           ('signals', 'O'): 41,
#           ('around', 'O'): 17,
#           ('GDF', 'B'): 1,
#           ('-', 'I'): 3547,
#           ('9', 'I'): 6,
#           ('deficient', 'O'): 37,
#           ('follicles', 'O'): 3,
#           ('several', 'O'): 120,
#           ('theca', 'O'): 1,
#           ('cell', 'O'): 529,
#           ('layer', 'O'): 17,
#           ('markers', 'O'): 23,
#           ('[', 'O'): 110,
#           ('i', 'O'): 107,
#           ('e', 'O'): 67,
#           ('Keck', 'O'): 1,
#           ('C', 'O'): 265,
#           ('J', 'O'): 54,
#           ('rbcL', 'B'): 1,
#           ('rbcS', 'B'): 1,
#           ('locus', 'O'): 38,
#           ('seems', 'O'): 21,
#           ('be', 'O'): 655,
#           ('barely', 'O'): 2,
#           ('expressed', 'O'): 226,
#           ('a', 'O'): 4403,
#           ('standard', 'O'): 38,
#           ('condition', 'O'): 15,
#           ('photoautotrophic', 'O'): 1,
#           ('growth', 'O'): 151,
#           ('properties', 'O'): 57,
#           ('phi', 'O'): 4,
#           ('29', 'O'): 35,
#           ('SSB', 'B'): 4,
#           ('ssDNA', 'I'): 1,
#           ('complex', 'O'): 165,
#           ('described', 'O'): 63,
#           ('Internal', 'O'): 4,
#           ('modes', 'O'): 5,
#           ('soliton', 'O'): 2,
#           ('A', 'O'): 622,
#           ('281', 'O'): 2,
#           ('divided', 'O'): 20,
#           ('into', 'O'): 226,
#           ('groups', 'O'): 100,
#           ('according', 'O'): 26,
#           ('their', 'O'): 212,
#           ('clinical', 'O'): 117,
#           ('diagnosis', 'O'): 72,
#           ('examined', 'O'): 80,
#           ('using', 'O'): 272,
#           ('capnography', 'O'): 1,
#           ('spirometry', 'O'): 4,
#           ('gas', 'O'): 27,
#           ('analysis', 'O'): 340,
#           ('addition', 'O'): 115,
#           ('its', 'O'): 283,
#           ('effect', 'O'): 248,
#           ('augmenting', 'O'): 2,
#           ('neutrophil', 'O'): 12,
#           ('response', 'O'): 224,
#           ('eccentric', 'O'): 2,
#           ('exercise', 'O'): 42,
#           ('vitamin', 'O'): 38,
#           ('E', 'O'): 80,
#           ('causes', 'O'): 38,
#           ('greater', 'O'): 99,
#           ('increase', 'O'): 139,
#           ('circulating', 'O'): 12,
#           ('creatine', 'B'): 8,
#           ('kinase', 'I'): 337,
#           ('activity', 'O'): 642,
#           ('perhaps', 'O'): 8,
#           ('indicating', 'O'): 55,
#           ('increased', 'O'): 213,
#           ('skeletal', 'O'): 19,
#           ('muscle', 'O'): 104,
#           ('repair', 'O'): 29,
#           ('Methods', 'O'): 3,
#           ('included', 'O'): 35,
#           ('24', 'O'): 91,
#           ('hour', 'O'): 16,
#           ('dietary', 'O'): 21,
#           ('recall', 'O'): 3,
#           ('menu', 'O'): 1,
#           ('weights', 'O'): 6,
#           ('recipe', 'O'): 1,
#           ('this', 'O'): 560,
#           ('method', 'O'): 103,
#           ('PLP', 'O'): 1,
#           ('plasma', 'O'): 135,
#           ('can', 'O'): 249,
#           ('determined', 'O'): 121,
#           ('high', 'O'): 254,
#           ('sensitivity', 'O'): 57,
#           ('derivatization', 'O'): 1,
#           ('sodium', 'O'): 39,
#           ('bisulfite', 'O'): 1,
#           ('mobile', 'O'): 7,
#           ('phase', 'O'): 121,
#           ('general', 'O'): 30,
#           ('recombination', 'O'): 32,
#           ('polarizing', 'O'): 1,
#           ('voltage', 'O'): 9,
#           ('300', 'O'): 18,
#           ('V', 'O'): 40,
#           ('is', 'O'): 1868,
#           ('less', 'O'): 204,
#           ('than', 'O'): 473,
#           ('dose', 'O'): 125,
#           ('rates', 'O'): 46,
#           ('up', 'O'): 87,
#           ('about', 'O'): 75,
#           ('100', 'O'): 113,
#           ('mGy', 'O'): 1,
#           ('min', 'O'): 136,
#           ('Use', 'O'): 7,
#           ('vena', 'O'): 3,
#           ('cava', 'O'): 2,
#           ('extend', 'O'): 8,
#           ('right', 'O'): 56,
#           ('renal', 'O'): 72,
#           ('vein', 'O'): 21,
#           ('cadaver', 'O'): 2,
#           ('transplantation', 'O'): 23,
#           ('controversial', 'O'): 3,
#           ('1992', 'O'): 16,
#           ('Genomics', 'O'): 1,
#           ('12', 'O'): 149,
#           ('58', 'O'): 15,
#           ('62', 'O'): 22,
#           (').', 'O'): 620,
#           ('Spinal', 'O'): 1,
#           ('cord', 'O'): 17,
#           ('representation', 'O'): 3,
#           ('micturition', 'O'): 3,
#           ('reflex', 'O'): 12,
#           ('two', 'O'): 519,
#           ('hybrid', 'O'): 34,
#           ('assay', 'O'): 66,
#           ('then', 'O'): 44,
#           ('performed', 'O'): 105,
#           ('full', 'O'): 51,
#           ('length', 'O'): 70,
#           ('genes', 'O'): 240,
#           ('CI', 'B'): 1,
#           ('HC', 'B'): 3,
#           ('Pro', 'I'): 1,
#           ('P1', 'B'): 5,
#           ('P3', 'B'): 1,
#           ('CP', 'B'): 2,
#           ('but', 'O'): 455,
#           ('heterologous', 'O'): 23,
#           ('interactions', 'O'): 56,
#           ('detected', 'O'): 109,
#           ('High', 'O'): 18,
#           ('concentrations', 'O'): 113,
#           ('soluble', 'O'): 19,
#           ('E', 'B'): 18,
#           ('selectin', 'I'): 4,
#           ('closely', 'O'): 37,
#           ('associated', 'O'): 193,
#           ('multiple', 'O'): 115,
#           ('organ', 'O'): 17,
#           ('dysfunction', 'O'): 10,
#           ('death', 'O'): 42,
#           ('limited', 'O'): 23,
#           ('disease', 'O'): 178,
#           ('survival', 'O'): 58,
#           ('alternating', 'O'): 1,
#           ('arm', 'O'): 20,
#           ('significantly', 'O'): 216,
#           ('superior', 'O'): 11,
#           ('CAV', 'O'): 1,
#           ('P', 'O'): 170,
#           ('=', 'O'): 225,
#           ('014', 'O'): 1,
#           ('or', 'O'): 906,
#           ('PE', 'O'): 2,
#           ('023', 'O'): 1,
#           ('Mg', 'B'): 1,
#           ('chelatase', 'I'): 1,
#           ('tobacco', 'O'): 15,
#           ('identification', 'O'): 36,
#           ('Chl', 'B'): 1,
#           ('D', 'I'): 26,
#           ('cDNA', 'I'): 62,
#           ('sequence', 'I'): 70,
#           ('encoding', 'O'): 154,
#           ('third', 'O'): 44,
#           ('subunit', 'O'): 74,
#           ('interaction', 'O'): 127,
#           ('three', 'O'): 215,
#           ('subunits', 'O'): 37,
#           ('yeast', 'O'): 134,
#           ('system', 'O'): 142,
#           ('reconstitution', 'O'): 3,
#           ('enzyme', 'O'): 83,
#           ('by', 'O'): 1883,
#           ('co', 'O'): 44,
#           ('expression', 'O'): 624,
#           ('recombinant', 'B'): 28,
#           ('CHL', 'I'): 1,
#           ('CHL', 'B'): 2,
#           ('H', 'I'): 25,
#           ('I', 'I'): 121,
#           ('This', 'O'): 252,
#           ('suggested', 'O'): 63,
#           ('delta', 'O'): 36,
#           ('desaturation', 'O'): 1,
#           ('activities', 'O'): 68,
#           ('normal', 'O'): 207,
#           ('C18', 'O'): 5,
#           ('2w6', 'O'): 1,
#           ('supply', 'O'): 8,
#           ('Gel', 'O'): 12,
#           ('shift', 'O'): 67,
#           ('indicates', 'O'): 45,
#           ('full', 'B'): 13,
#           ('length', 'I'): 15,
#           ('ERM', 'I'): 1,
#           ('protein', 'I'): 567,
#           ('able', 'O'): 43,
#           ('bind', 'O'): 78,
#           ('specifically', 'O'): 52,
#           ('an', 'O'): 852,
#           ('oligonucleotide', 'O'): 17,
#           ('containing', 'O'): 228,
#           ('consensus', 'O'): 70,
#           ('nucleotide', 'O'): 89,
#           ('core', 'O'): 35,
#           ('sequence', 'O'): 506,
#           ('GGAA', 'O'): 1,
#           ('recognized', 'O'): 20,
#           ('Ets', 'B'): 20,
#           ('proteins', 'O'): 252,
#           ('test', 'O'): 114,
#           ('should', 'O'): 55,
#           ('provide', 'O'): 39,
#           ('another', 'O'): 31,
#           ('practical', 'O'): 4,
#           ('means', 'O'): 32,
#           ('study', 'O'): 301,
#           ('leprosy', 'O'): 3,
#           ('CONCLUSIONS', 'O'): 33,
#           ('EBCT', 'O'): 1,
#           ('technology', 'O'): 6,
#           ('allows', 'O'): 12,
#           ('minimally', 'O'): 4,
#           ('invasive', 'O'): 18,
#           ('intramyocardial', 'O'): 1,
#           ('microcirculatory', 'O'): 2,
#           ('function', 'O'): 235,
#           ('permits', 'O'): 5,
#           ('assessment', 'O'): 22,
#           ('microvascular', 'O'): 4,
#           ('BV', 'O'): 1,
#           ('distribution', 'O'): 46,
#           ('different', 'O'): 187,
#           ('functional', 'O'): 119,
#           ('components', 'O'): 50,
#           ('RT', 'O'): 15,
#           ('PCR', 'O'): 46,
#           ('previously', 'O'): 128,
#           ('reported', 'O'): 74,
#           ('degenerate', 'O'): 4,
#           ('primers', 'O'): 12,
#           ('ligand', 'O'): 40,
#           ('binding', 'O'): 528,
#           ('domain', 'O'): 282,
#           ('LBD', 'O'): 2,
#           ('known', 'O'): 93,
#           ('beta', 'B'): 90,
#           ('integrin', 'I'): 6,
#           ('subunits', 'I'): 18,
#           ('Bge', 'B'): 1,
#           ('effective', 'O'): 61,
#           ('low', 'O'): 114,
#           ('toxic', 'O'): 19,
#           ('schedules', 'O'): 3,
#           ('KW', 'O'): 1,
#           ('2083', 'O'): 1,
#           ('investigated', 'O'): 62,
#           ('further', 'O'): 77,
#           ('These', 'O'): 272,
#           ('results', 'O'): 309,
#           ('suggest', 'O'): 155,
#           ('phenotype', 'O'): 44,
#           ('XLP', 'O'): 1,
#           ('may', 'O'): 304,
#           ('result', 'O'): 63,
#           ('from', 'O'): 1143,
#           ('perturbed', 'O'): 3,
#           ('signaling', 'O'): 78,
#           ('not', 'O'): 692,
#           ('only', 'O'): 228,
#           ('through', 'O'): 105,
#           ('SLAM', 'B'): 1,
#           ('also', 'O'): 399,
#           ('other', 'O'): 281,
#           ('surface', 'O'): 50,
#           ('molecules', 'O'): 30,
#           ('utilize', 'O'): 2,
#           ('SAP', 'B'): 3,
#           ('adaptor', 'O'): 13,
#           ('protein', 'O'): 576,
#           ('randomized', 'O'): 22,
#           ('prospective', 'O'): 14,
#           ('conducted', 'O'): 18,
#           ('compare', 'O'): 15,
#           ('ovarian', 'O'): 19,
#           ('stimulation', 'O'): 76,
#           ('human', 'B'): 226,
#           ('menopausal', 'I'): 1,
#           ('gonadotropin', 'I'): 5,
#           ('hMG', 'B'): 2,
#           ('follicle', 'I'): 1,
#           ('stimulating', 'I'): 17,
#           ('hormone', 'I'): 45,
#           ('hFSH', 'B'): 1,
#           ('vitro', 'O'): 180,
#           ('fertilization', 'O'): 4,
#           ('embryo', 'O'): 21,
#           ('transfer', 'O'): 25,
#           ('IVF', 'O'): 3,
#           ('ET', 'O'): 3,
#           ('program', 'O'): 17,
#           ('Tl', 'O'): 5,
#           ('201', 'O'): 14,
#           ('uptake', 'O'): 34,
#           ('ratio', 'O'): 70,
#           ('ventricle', 'O'): 10,
#           ('which', 'O'): 679,
#           ('represents', 'O'): 30,
#           ('counts', 'O'): 20,
#           ('administered', 'O'): 55,
#           ('higher', 'O'): 140,
#           ('COPD', 'O'): 6,
#           ('especially', 'O'): 27,
#           ('pulmonary', 'O'): 43,
#           ('emphysema', 'O'): 3,
#           ('B', 'O'): 176,
#           ('Burrows', 'O'): 1,
#           ('classification', 'O'): 8,
#           ('controls', 'O'): 69,
#           ('yeast', 'B'): 31,
#           ('SSS1', 'I'): 1,
#           ('gene', 'I'): 709,
#           ('essential', 'O'): 102,
#           ('secretory', 'O'): 11,
#           ('translocation', 'O'): 24,
#           ('encodes', 'O'): 111,
#           ('conserved', 'O'): 141,
#           ('endoplasmic', 'O'): 11,
#           ('reticulum', 'O'): 13,
#           ('some', 'O'): 83,
#           ('instances', 'O'): 4,
#           ('partly', 'O'): 8,
#           ('mediated', 'O'): 128,
#           ('virally', 'O'): 2,
#           ('encoded', 'O'): 86,
#           ('proteases', 'O'): 5,
#           ('lead', 'O'): 24,
#           ('cleavage', 'O'): 35,
#           ('initiation', 'B'): 1,
#           ('factor', 'I'): 268,
#           ('eIF4G', 'I'): 1,
#           ('Structural', 'O'): 9,
#           ('characteristics', 'O'): 34,
#           ('erythrocyte', 'O'): 9,
#           ('membrane', 'O'): 87,
#           ('peroxidation', 'O'): 5,
#           ('processes', 'O'): 23,
#           ('antioxidant', 'O'): 6,
#           ('children', 'O'): 80,
#           ('diffuse', 'O'): 6,
#           ('glomerulonephritis', 'O'): 3,
#           ('RPA190', 'B'): 1,
#           ('polypeptide', 'O'): 32,
#           ('chain', 'O'): 50,
#           ('186', 'O'): 4,
#           ('270', 'O'): 5,
#           ('daltons', 'O'): 2,
#           ('large', 'O'): 70,
#           ('uninterrupted', 'O'): 1,
#           ('reading', 'O'): 80,
#           ('frame', 'O'): 65,
#           ('paper', 'O'): 20,
#           ('reviews', 'O'): 3,
#           ('middleware', 'O'): 1,
#           ('based', 'O'): 78,
#           ('approach', 'O'): 27,
#           ('adopted', 'O'): 5,
#           ('CEN', 'O'): 3,
#           ('ENV', 'O'): 2,
#           ('12967', 'O'): 1,
#           ('specialisation', 'O'): 1,
#           ('necessary', 'O'): 52,
#           ('healthcare', 'O'): 1,
#           ('record', 'O'): 5,
#           ('on', 'O'): 904,
#           ('12265', 'O'): 1,
#           ("'", 'O'): 453,
#           ('Electronic', 'O'): 4,
#           ('Healthcare', 'O'): 1,
#           ('Record', 'O'): 1,
#           ('Architecture', 'O'): 1,
#           ("'.", 'O'): 5,
#           ('upstream', 'O'): 142,
#           ('rhlA', 'B'): 1,
#           ('promoter', 'I'): 259,
#           ('contains', 'O'): 148,
#           ('inverted', 'O'): 13,
#           ('repeats', 'O'): 35,
#           ('define', 'O'): 25,
#           ('putative', 'O'): 97,
#           ('sites', 'O'): 184,
#           ('RhlR', 'B'): 1,
#           ('regulator', 'I'): 7,
#           ('Ongoing', 'O'): 1,
#           ('future', 'O'): 14,
#           ('investigations', 'O'): 9,
#           ('better', 'O'): 29,
#           ('optimal', 'O'): 16,
#           ('local', 'O'): 29,
#           ('duration', 'O'): 23,
#           ('maintenance', 'O'): 19,
#           ('chemotherapy', 'O'): 34,
#           ('possible', 'O'): 79,
#           ('role', 'O'): 184,
#           ('biologic', 'O'): 4,
#           ('modifiers', 'O'): 1,
#           ('factors', 'O'): 180,
#           ('improving', 'O'): 3,
#           ('outcome', 'O'): 15,
#           ('cloned', 'O'): 90,
#           ('alcR', 'B'): 2,
#           ('provided', 'O'): 29,
#           ('trans', 'O'): 44,
#           ('restored', 'O'): 16,
#           ('siderophore', 'O'): 2,
#           ('mutants', 'O'): 65,
#           ('Although', 'O'): 62,
#           ('4E', 'B'): 2,
#           ('BP1', 'I'): 4,
#           ('alone', 'O'): 48,
#           ('has', 'O'): 388,
#           ('yet', 'O'): 23,
#           ('been', 'O'): 353,
#           ('accomplished', 'O'): 1,
#           ('gene', 'O'): 460,
#           ('Escherichia', 'O'): 42,
#           ('coli', 'O'): 65,
#           ('BL21', 'O'): 2,
#           ('DE3', 'O'): 2,
#           (')]', 'O'): 7,
#           ('fusion', 'O'): 76,
#           ('glutathione', 'B'): 16,
#           ('S', 'I'): 39,
#           ('transferase', 'I'): 22,
#           ('GST', 'B'): 18,
#           ('prokaryotic', 'O'): 5,
#           ('vector', 'O'): 40,
#           ('pGEX', 'O'): 3,
#           ('4T', 'O'): 1,
#           ('coding', 'O'): 80,
#           ('site', 'O'): 290,
#           ('specific', 'O'): 332,
#           ('protease', 'O'): 8,
#           ('alpha', 'B'): 82,
#           ('thrombin', 'I'): 1,
#           ('An', 'O'): 81,
#           ('explanation', 'O'): 4,
#           ('explored', 'O'): 4,
#           ('lack', 'O'): 26,
#           ('RAR', 'B'): 13,
#           ('alpha', 'I'): 218,
#           ('PML', 'B'): 3,
#           ('might', 'O'): 28,
#           ('suppress', 'O'): 11,
#           ('APL', 'O'): 1,
#           ('holoenzyme', 'B'): 1,
#           ('RNA', 'I'): 62,
#           ('polymerases', 'I'): 8,
#           ('generated', 'O'): 44,
#           ('upon', 'O'): 41,
#           ('reconstituting', 'O'): 3,
#           ('independently', 'O'): 21,
#           ('core', 'B'): 8,
#           ('polymerase', 'I'): 64,
#           ('alpha2beta', 'O'): 1,
#           ('beta', 'O'): 92,
#           ("')", 'O'): 5,
#           ('have', 'O'): 490,
#           ('shown', 'O'): 139,
#           ('reduced', 'O'): 131,
#           ('transcriptional', 'O'): 190,
#           ('comparison', 'O'): 62,
#           ('wild', 'B'): 36,
#           ('type', 'I'): 87,
#           ('sigma', 'I'): 6,
#           ('PAI', 'B'): 6,
#           ('2', 'I'): 301,
#           ('one', 'O'): 287,
#           ('most', 'O'): 106,
#           ('TNF', 'B'): 30,
#           ('responsive', 'I'): 14,
#           ('genes', 'I'): 152,
#           ('highly', 'O'): 104,
#           ('phorbol', 'O'): 29,
#           ('ester', 'O'): 13,
#           ('myristate', 'O'): 8,
#           ('acetate', 'O'): 26,
#           ('PMA', 'O'): 13,
#           ('phosphatase', 'O'): 7,
#           ('inhibitor', 'O'): 68,
#           ('okadaic', 'O'): 4,
#           ('both', 'O'): 446,
#           ('HT', 'O'): 10,
#           ('1080', 'O'): 1,
#           ('fibrosarcoma', 'O'): 2,
#           ('U', 'O'): 33,
#           ('937', 'O'): 1,
#           ('histiocytic', 'O'): 3,
#           ('cells', 'O'): 715,
#           ('Precipitating', 'O'): 1,
#           ('antibodies', 'O'): 41,
#           ('Thermophilic', 'O'): 1,
#           ('actinomycetes', 'O'): 1,
#           ('M', 'O'): 62,
#           ('f', 'O'): 4,
#           ('negative', 'O'): 105,
#           ('RESULTS', 'O'): 52,
#           ('cardiac', 'O'): 58,
#           ('index', 'O'): 35,
#           ('changed', 'O'): 14,
#           ('varying', 'O'): 9,
#           ('PaCO2', 'O'): 7,
#           ('hypocapnia', 'O'): 2,
#           ('9', 'O'): 179,
#           ('%;', 'O'): 17,
#           ('hypercapnia', 'O'): 3,
#           ('%).', 'O'): 32,
#           ('sulfhydryl', 'O'): 2,
#           ('group', 'O'): 245,
#           ('certain', 'O'): 26,
#           ('angiotensin', 'B'): 9,
#           ('converting', 'I'): 6,
#           ('enzyme', 'I'): 23,
#           ('potentiate', 'O'): 4,
#           ('endogenous', 'O'): 37,
#           ('nitrovasodilator', 'O'): 1,
#           ('EDRF', 'B'): 1,
#           ('PC12', 'O'): 8,
#           ('mutant', 'O'): 109,
#           ('protein', 'B'): 67,
#           ('A', 'I'): 108,
#           ('AB', 'O'): 2,
#           ('11', 'O'): 102,
#           ('all', 'O'): 217,
#           ('differentiating', 'O'): 5,
#           ('agents', 'O'): 51,
#           ('unable', 'O'): 16,
#           ('down', 'O'): 26,
#           ('regulate', 'O'): 38,
#           ('nrg', 'B'): 1,
#           ('1', 'I'): 704,
#           ('mRNA', 'I'): 112,
#           ('Anamnestic', 'O'): 1,
#           ('data', 'O'): 175,
#           ('obtained', 'O'): 110,
#           ('case', 'O'): 60,
#           ('history', 'O'): 29,
#           ('smoking', 'O'): 16,
#           ('habits', 'O'): 2,
#           ('collective', 'O'): 1,
#           ('evident', 'O'): 16,
#           ('inciting', 'O'): 1,
#           ('agent', 'O'): 34,
#           ('Here', 'O'): 62,
#           ('we', 'O'): 383,
#           ('demonstrate', 'O'): 86,
#           ('Hh', 'B'): 1,
#           ('Patched', 'B'): 1,
#           ('Ptc', 'B'): 1,
#           ('act', 'O'): 22,
#           ('those', 'O'): 130,
#           ('Ci', 'B'): 2,
#           ('modulate', 'O'): 15,
#           ('level', 'O'): 170,
#           ('dependent', 'O'): 213,
#           ('activation', 'O'): 329,
#           ('S2', 'O'): 4,
#           ('coexpression', 'O'): 6,
#           ('constructs', 'O'): 40,
#           ('DBP', 'B'): 4,
#           ('hepatic', 'B'): 2,
#           ('leukemia', 'I'): 5,
#           ('resulted', 'O'): 82,
#           ('dramatic', 'O'): 9,
#           ('GAL4', 'B'): 12,
#           ('suggesting', 'O'): 105,
#           ('involvement', 'O'): 25,
#           ('regulated', 'O'): 104,
#           ('coactivator', 'O'): 6,
#           ('process', 'O'): 36,
#           ('Cox', 'O'): 4,
#           ('proportional', 'O'): 2,
#           ('hazards', 'O'): 1,
#           ('model', 'O'): 94,
#           ('applied', 'O'): 13,
#           ('order', 'O'): 55,
#           ('determine', 'O'): 68,
#           ('prognostic', 'O'): 5,
#           ('long', 'O'): 95,
#           ('term', 'O'): 54,
#           ('REM', 'O'): 3,
#           ('sleep', 'O'): 11,
#           ('deprivation', 'O'): 6,
#           ('platform', 'O'): 1,
#           ('technique', 'O'): 56,
#           ('How', 'O'): 4,
#           ('does', 'O'): 73,
#           ('nurse', 'O'): 6,
#           ('go', 'O'): 1,
#           ('maintaining', 'O'): 12,
#           ('her', 'O'): 4,
#           ('competence', 'O'): 3,
#           ('when', 'O'): 200,
#           ('she', 'O'): 3,
#           ('few', 'O'): 14,
#           ('practitioners', 'O'): 1,
#           ('field', 'O'): 39,
#           ('?', 'O'): 21,
#           ('Vancouver', 'O'): 1,
#           ('sex', 'O'): 23,
#           ('therapist', 'O'): 1,
#           ('Bianca', 'O'): 1,
#           ('Rucker', 'O'): 1,
#           ('doing', 'O'): 1,
#           ('it', 'O'): 204,
#           ('cultivating', 'O'): 1,
#           ('network', 'O'): 5,
#           ('colleagues', 'O'): 1,
#           ('mentors', 'O'): 1,
#           ('related', 'O'): 158,
#           ('fields', 'O'): 7,
#           ('home', 'O'): 9,
#           ('across', 'O'): 17,
#           ('continent', 'O'): 1,
#           ('We', 'O'): 394,
#           ('present', 'O'): 158,
#           ('preliminary', 'O'): 7,
#           ('36', 'O'): 19,
#           ('followed', 'O'): 43,
#           ('mean', 'O'): 100,
#           ('period', 'O'): 68,
#           ('months', 'O'): 63,
#           ('Biologically', 'O'): 1,
#           ('significant', 'O'): 198,
#           ('amounts', 'O'): 13,
#           ('platelet', 'B'): 7,
#           ('activating', 'I'): 23,
#           ('eluted', 'O'): 3,
#           ('sorbent', 'O'): 1,
#           ('during', 'O'): 301,
#           ('entire', 'O'): 31,
#           ('treatment', 'O'): 261,
#           ('time', 'O'): 144,
#           ('287', 'O'): 2,
#           ('advanced', 'O'): 19,
#           ('non', 'O'): 125,
#           ('small', 'O'): 81,
#           ('lung', 'O'): 66,
#           ('cancer', 'O'): 76,
#           ('NSCLC', 'O'): 1,
#           ('stage', 'O'): 54,
#           ('IIIb', 'O'): 2,
#           ('ECOG', 'O'): 1,
#           ('performance', 'O'): 42,
#           ('status', 'O'): 40,
#           ('PS', 'O'): 6,
#           ('randomly', 'O'): 10,
#           ('assigned', 'O'): 7,
#           ('receive', 'O'): 8,
#           ('either', 'O'): 129,
#           ('best', 'O'): 17,
#           ('supportive', 'O'): 4,
#           ('care', 'O'): 29,
#           ('BSC', 'O'): 1,
#           ('plus', 'O'): 34,
#           ('combination', 'O'): 68,
#           ('IEP', 'O'): 1,
#           ('regimen', 'O'): 24,
#           ('ifosfamide', 'O'): 2,
#           ('3', 'O'): 627,
#           ('gm', 'O'): 4,
#           ('m2', 'O'): 42,
#           ('mesna', 'O'): 1,
#           ('uroprotection', 'O'): 1,
#           ('epirubicin', 'O'): 1,
#           ('60', 'O'): 70,
#           ('mg', 'O'): 251,
#           ('cisplatin', 'O'): 13,
#           (';', 'O'): 421,
#           ('MVP', 'O'): 1,
#           ('mitomycin', 'O'): 4,
#           ('8', 'O'): 257,
#           ('vinblastine', 'O'): 3,
#           ('4', 'O'): 357,
#           ('15', 'O'): 111,
#           ('Sulphur', 'O'): 1,
#           ('amino', 'O'): 312,
#           ('acids', 'O'): 122,
#           ('g', 'O'): 100,
#           ('16', 'O'): 92,
#           ('isolates', 'O'): 19,
#           ('flours', 'O'): 1,
#           ('Bacteriologic', 'O'): 1,
#           ('culture', 'O'): 19,
#           ('pancreatic', 'O'): 22,
#           ('tissue', 'O'): 114,
#           ('positive', 'O'): 109,
#           ('IB', 'O'): 1,
#           ('17', 'O'): 82,
#           ('NIB', 'O'): 1,
#           ('p', 'O'): 193,
#           ('01', 'O'): 65,
#           ('demonstrated', 'O'): 114,
#           ('reproductive', 'O'): 9,
#           ('neuropeptide', 'O'): 1,
#           ('GnRH', 'B'): 11,
#           ('repressed', 'O'): 18,
#           ('glutamate', 'O'): 3,
#           ('NO', 'O'): 14,
#           ('cyclic', 'O'): 17,
#           ('GMP', 'O'): 3,
#           ('cGMP', 'O'): 2,
#           ('signal', 'O'): 93,
#           ('transduction', 'O'): 32,
#           ('pathway', 'O'): 102,
#           ('cGMP', 'B'): 2,
#           ('dependent', 'I'): 52,
#           ('hypothalamic', 'O'): 3,
#           ('secreting', 'O'): 6,
#           ('neuronal', 'O'): 23,
#           ('line', 'O'): 91,
#           ('GT1', 'O'): 1,
#           ('Total', 'O'): 10,
#           ('cholesterol', 'O'): 25,
#           ('20', 'O'): 135,
#           ('30', 'O'): 121,
#           ('52', 'O'): 19,
#           ('(<', 'O'): 6,
#           ('(>', 'O'): 6,
#           ('Again', 'O'): 1,
#           ('residue', 'O'): 52,
#           ('Glu', 'O'): 4,
#           ('381', 'O'): 1,
#           ('notably', 'O'): 2,
#           ('missing', 'O'): 9,
#           ('epsilon', 'O'): 5,
#           ('peptide', 'O'): 53,
#           ('could', 'O'): 121,
#           ('identified', 'O'): 230,
#           ('choices', 'O'): 1,
#           ('Ser', 'O'): 34,
#           ('106', 'O'): 2,
#           ('107', 'O'): 3,
#           ('108', 'O'): 1,
#           ('4024', 'O'): 1,
#           ('base', 'O'): 79,
#           ('pair', 'O'): 44,
#           ('bp', 'O'): 182,
#           ('segment', 'O'): 48,
#           ('extends', 'O'): 3,
#           ('149', 'O'): 3,
#           ('cap', 'O'): 9,
#           ('207', 'O'): 3,
#           ('psi', 'B'): 3,
#           ('Self', 'O'): 3,
#           ('emasculation', 'O'): 1,
#           ('end', 'O'): 118,
#           ('unusual', 'O'): 13,
#           ('psychiatric', 'O'): 6,
#           ('disorder', 'O'): 23,
#           ('initially', 'O'): 18,
#           ('requires', 'O'): 38,
#           ('surgical', 'O'): 23,
#           ('Doxorubicin', 'O'): 1,
#           ('dacarbazine', 'O'): 1,
#           ('vincristine', 'O'): 4,
#           ('cyclophosphamide', 'O'): 14,
#           ('gastrointestinal', 'O'): 11,
#           ('leiomyosarcoma', 'O'): 1,
#           ('inflation', 'O'): 2,
#           ('hub', 'O'): 1,
#           ('probe', 'O'): 35,
#           ('recreated', 'O'): 1,
#           ('modifying', 'O'): 3,
#           ('USCI', 'O'): 1,
#           ('Tuohy', 'O'): 1,
#           ('Borst', 'O'): 1,
#           ('Y', 'O'): 26,
#           ('attaching', 'O'): 1,
#           ('transected', 'O'): 1,
#           ('hypotube', 'O'): 1,
#           ('indoramin', 'O'): 2,
#           ('Class', 'O'): 14,
#           ('antiarrhythmic', 'O'): 7,
#           ('desipramine', 'O'): 3,
#           ('probably', 'O'): 23,
#           ('inhibition', 'O'): 81,
#           ('amitriptyline', 'O'): 3,
#           ('mianserin', 'O'): 1,
#           ('blockade', 'O'): 14,
#           ('prejunctional', 'O'): 1,
#           ('adrenoreceptors', 'I'): 1,
#           ('Data', 'O'): 5,
#           ('spread', 'O'): 15,
#           ('LSF', 'O'): 1,
#           ('image', 'O'): 12,
#           ('mm', 'O'): 40,
#           ('wide', 'O'): 13,
#           ('slit', 'O'): 1,
#           ('between', 'O'): 383,
#           ('tungsten', 'O'): 1,
#           ('blocks', 'O'): 23,
#           ('positioned', 'O'): 8,
#           ('isocentre', 'O'): 1,
#           ('front', 'O'): 5,
#           ('polystyrene', 'O'): 4,
#           ('phantom', 'O'): 2,
#           ('Using', 'O'): 50,
#           ('series', 'O'): 40,
#           ('mutant', 'B'): 18,
#           ('T', 'I'): 18,
#           ('antigens', 'I'): 5,
#           ('recombinant', 'O'): 48,
#           ('baculoviruses', 'O'): 4,
#           ('Sf9', 'O'): 5,
#           ('find', 'O'): 9,
#           ('origin', 'O'): 37,
#           ('unwinding', 'O'): 2,
#           ('TS677', 'O'): 2,
#           ('-->', 'O'): 11,
#           ('679', 'O'): 1,
#           ('inhibited', 'O'): 59,
#           ('T', 'B'): 30,
#           ('antigen', 'I'): 42,
#           ('Thus', 'O'): 75,
#           ('presence', 'O'): 132,
#           ('active', 'B'): 3,
#           ('CDKs', 'I'): 2,
#           ('Dbf4', 'B'): 1,
#           ('Cdc7', 'B'): 1,
#           ('Mcms', 'B'): 1,
#           ...}))

# %%
d = defaultdict(float)
d_rare = []
for w,c in Counter(all_words).items():
  if c < 5:
    d_rare.append(word)

# %%
Counter(all_words).most_common()[::-1]
# Out:
# [('Bacteriol', 1),
#  ('neoplasia', 1),
#  ('dysregulation', 1),
#  ('morphologically', 1),
#  ('p24', 1),
#  ('DAo', 1),
#  ('conduits', 1),
#  ('valved', 1),
#  ('SMV', 1),
#  ('FY', 1),
#  ('Funding', 1),
#  ('sporting', 1),
#  ('Epidemiological', 1),
#  ('appressoria', 1),
#  ('melanized', 1),
#  ('21q22', 1),
#  ('lividomycin', 1),
#  ('Rv', 1),
#  ('scd1', 1),
#  ('Chc', 1),
#  ('Cytological', 1),
#  ('anyone', 1),
#  ('Ps', 1),
#  ('lettuce', 1),
#  ('Aer', 1),
#  ('predominately', 1),
#  ('click', 1),
#  ('ITDs', 1),
#  ('interaural', 1),
#  ('alkali', 1),
#  ('disappears', 1),
#  ('digestions', 1),
#  ('dm3', 1),
#  ('ichthiomycin', 1),
#  ('carps', 1),
#  ('PACs', 1),
#  ('NPAT', 1),
#  ('2N', 1),
#  ('french', 1),
#  ('prescriptions', 1),
#  ('Rab3', 1),
#  ('Bartter', 1),
#  ('alternation', 1),
#  ('Na3', 1),
#  ('trigonal', 1),
#  ('gal11', 1),
#  ('PYK1', 1),
#  ('menarche', 1),
#  ('Waf1', 1),
#  ('H2O', 1),
#  ('Mucin', 1),
#  ('CD19', 1),
#  ('bronchodilator', 1),
#  ('augments', 1),
#  ('nebulized', 1),
#  ('resumption', 1),
#  ('convulsion', 1),
#  ('fasciculations', 1),
#  ('methohexitone', 1),
#  ('eyelash', 1),
#  ('fasl', 1),
#  ('DdRPs', 1),
#  ('CREST', 1),
#  ('GH4', 1),
#  ('Viskovo', 1),
#  ('FVC', 1),
#  ('pollution', 1),
#  ('CPA', 1),
#  ('hinting', 1),
#  ('impermeable', 1),
#  ('aluminized', 1),
#  ('uniforms', 1),
#  ('fighter', 1),
#  ('wearing', 1),
#  ('firemen', 1),
#  ('humidity', 1),
#  ('Characterisation', 1),
#  ('OF1', 1),
#  ('OFA', 1),
#  ('mMpl', 1),
#  ('Mpl', 1),
#  ('CIATT', 1),
#  ('TrypTect', 1),
#  ('trypanosomiasis', 1),
#  ('p15INK4b', 1),
#  ('Mts2', 1),
#  ('p16INK4a', 1),
#  ('Mts1', 1),
#  ('Candidate', 1),
#  ('nonsuppressors', 1),
#  ('DST', 1),
#  ('schizophrenics', 1),
#  ('Subjects', 1),
#  ('9ORF1', 1),
#  ('harmony', 1),
#  ('954', 1),
#  ('2862', 1),
#  ('submucosal', 1),
#  ('AVLF', 1),
#  ('sixteen', 1),
#  ('manifesting', 1),
#  ('Patel', 1),
#  ('DLL', 1),
#  ('cobA', 1),
#  ('judgements', 1),
#  ('1946', 1),
#  ('Gdansk', 1),
#  ('395', 1),
#  ('disablement', 1),
#  ('chlorthalidone', 1),
#  ('hamartoma', 1),
#  ('lesioning', 1),
#  ('Stereotactic', 1),
#  ('gonorrhoea', 1),
#  ('NSGI', 1),
#  ('Edinburgh', 1),
#  ('Infirmary', 1),
#  ('GUM', 1),
#  ('attending', 1),
#  ('Individuals', 1),
#  ('cotinine', 1),
#  ('S120K', 1),
#  ('pork', 1),
#  ('EAST', 1),
#  ('GH3', 1),
#  ('hyphal', 1),
#  ('Cek1p', 1),
#  ('Roles', 1),
#  ('nontumorigenic', 1),
#  ('McCann', 1),
#  ('sec4', 1),
#  ('synthetically', 1),
#  ('SEC', 1),
#  ('SEC3', 1),
#  ('MSB', 1),
#  ('Batch', 1),
#  ('Rating', 1),
#  ('Menopause', 1),
#  ('starts', 1),
#  ('Hum1p', 1),
#  ('antiport', 1),
#  ('hum1', 1),
#  ('Vacuolar', 1),
#  ('IRS1', 1),
#  ('Tyr497', 1),
#  ('schemes', 1),
#  ('Clin', 1),
#  ('hem2', 1),
#  ('Intraperitoneal', 1),
#  ('EMCV', 1),
#  ('capstructure', 1),
#  ('methylated', 1),
#  ('rad52', 1),
#  ('5kb', 1),
#  ('504bp', 1),
#  ('p41MAPK', 1),
#  ('neuroepithelium', 1),
#  ('Wright', 1),
#  ('eosinophiluria', 1),
#  ('Hansel', 1),
#  ('destabilize', 1),
#  ('Cln2', 1),
#  ('Scott', 1),
#  ('normalised', 1),
#  ('axin', 1),
#  ('urethra', 1),
#  ('dnaA', 1),
#  ('V88A', 1),
#  ('Epileptiform', 1),
#  ('42d', 1),
#  ('destroyed', 1),
#  ('JPEG', 1),
#  ('hematuric', 1),
#  ('arrangements', 1),
#  ('sharing', 1),
#  ('SI', 1),
#  ('innominata', 1),
#  ('neurochemical', 1),
#  ('chCTCF', 1),
#  ('alendronate', 1),
#  ('raloxifene', 1),
#  ('NTS', 1),
#  ('SRK', 1),
#  ('SLG', 1),
#  ('Flap', 1),
#  ('subpathways', 1),
#  ('CD11c', 1),
#  ('fading', 1),
#  ('thyrotoxicosis', 1),
#  ('Thyrotoxicosis', 1),
#  ('SNX', 1),
#  ('neuroprotective', 1),
#  ('confusion', 1),
#  ('Pancreaticoduodenal', 1),
#  ('Lsp', 1),
#  ('EcR', 1),
#  ('neuropsychologic', 1),
#  ('intricately', 1),
#  ('candidemia', 1),
#  ('RXRgamma2', 1),
#  ('CDAI', 1),
#  ('?]', 1),
#  ('isochore', 1),
#  ('DXS52', 1),
#  ('Prophase', 1),
#  ('Spo11', 1),
#  ('SSA3', 1),
#  ('rim15Delta', 1),
#  ('Gis1', 1),
#  ('ionomycin', 1),
#  ('acne', 1),
#  ('HDL3', 1),
#  ('subfractions', 1),
#  ('apoprotein', 1),
#  ('quantify', 1),
#  ('climacteric', 1),
#  ('aminoketones', 1),
#  ('Tpo', 1),
#  ('ddATP', 1),
#  ('araATP', 1),
#  ('dATP', 1),
#  ('carAB', 1),
#  ('CarP', 1),
#  ('server', 1),
#  ('WWW', 1),
#  ('ExPASy', 1),
#  ('emphatically', 1),
#  ('nonpharmacologic', 1),
#  ('probucol', 1),
#  ('fibric', 1),
#  ('sickness', 1),
#  ('kittens', 1),
#  ('numerical', 1),
#  ('learn', 1),
#  ('DPAT', 1),
#  ('electrophilic', 1),
#  ('catalyze', 1),
#  ('GSTs', 1),
#  ('predisposing', 1),
#  ('Free', 1),
#  ('Relations', 1),
#  ('461', 1),
#  ('octanucleotide', 1),
#  ('333', 1),
#  ('12th', 1),
#  ('Calcifications', 1),
#  ('inappropriate', 1),
#  ('Ventricular', 1),
#  ('LRBV', 1),
#  ('LVc', 1),
#  ('EL4', 1),
#  ('Enhancers', 1),
#  ('perinatal', 1),
#  ('ethylenediaminotetracetic', 1),
#  ('microanalysis', 1),
#  ('Spectrophotometric', 1),
#  ('Sam68', 1),
#  ('transcriptosomal', 1),
#  ('YT521', 1),
#  ('FtsN', 1),
#  ('ftsN', 1),
#  ('bH', 1),
#  ('MDF', 1),
#  ('glycyrrhetate', 1),
#  ('GTD', 1),
#  ('Her', 1),
#  ('neurinoma', 1),
#  ('distortions', 1),
#  ('nontetrahedral', 1),
#  ('3T1', 1),
#  ('lariats', 1),
#  ('debranched', 1),
#  ('Norwegian', 1),
#  ('pharmacy', 1),
#  ('Predictors', 1),
#  ('microphthalmos', 1),
#  ('buphthalmos', 1),
#  ('aquosa', 1),
#  ('camera', 1),
#  ('persistence', 1),
#  ('Infant', 1),
#  ('peers', 1),
#  ('conformity', 1),
#  ('inelastic', 1),
#  ('wavefront', 1),
#  ('exit', 1),
#  ('Vk', 1),
#  ('Jk', 1),
#  ('thirtynine', 1),
#  ('aggregate', 1),
#  ('Irradiation', 1),
#  ('SSc', 1),
#  ('concurrently', 1),
#  ('HAL', 1),
#  ('antidopaminergic', 1),
#  ('urban', 1),
#  ('Delhi', 1),
#  ('Cdc31p', 1),
#  ('DSK2', 1),
#  ('TBBMD', 1),
#  ('684', 1),
#  ('rap1t', 1),
#  ('meeting', 1),
#  ('RSNA', 1),
#  ('leukopoiesis', 1),
#  ('valuing', 1),
#  ('carbonate', 1),
#  ('EIN2', 1),
#  ('INSENSITIVE2', 1),
#  ('ETHYLENE', 1),
#  ('drought', 1),
#  ('abiotic', 1),
#  ('AtERF', 1),
#  ('pallidus', 1),
#  ('globus', 1),
#  ('49th', 1),
#  ('DMEA', 1),
#  ('PCr', 1),
#  ('CPEB', 1),
#  ('clam', 1),
#  ('kHz', 1),
#  ('brainstem', 1),
#  ('dates', 1),
#  ('Fifteen', 1),
#  ('Tyr727', 1),
#  ('CNTF', 1),
#  ('Tyr705', 1),
#  ('Tyk', 1),
#  ('unimodal', 1),
#  ('MAN', 1),
#  ('crotoxin', 1),
#  ('nonenlarging', 1),
#  ('nontender', 1),
#  ('PGL', 1),
#  ('adenopathy', 1),
#  ('uncapping', 1),
#  ('liposome', 1),
#  ('miniexon', 1),
#  ('fasciculata', 1),
#  ('Crithidia', 1),
#  ('premedicated', 1),
#  ('neighbors', 1),
#  ('familiar', 1),
#  ('harems', 1),
#  ('nonopiate', 1),
#  ('propyl', 1),
#  ('oxiracetam', 1),
#  ('perceptual', 1),
#  ('ovulatory', 1),
#  ('PLR', 1),
#  ('nonsurvivors', 1),
#  ('ISS', 1),
#  ('Subsets', 1),
#  ('purulenta', 1),
#  ('conductometry', 1),
#  ('cisterns', 1),
#  ('ventriculoscope', 1),
#  ('disagnosis', 1),
#  ('FCN', 1),
#  ('VBP', 1),
#  ('gHoxb', 1),
#  ('sweats', 1),
#  ('Benztropine', 1),
#  ('technologies', 1),
#  ('Papnet', 1),
#  ('AutoPap', 1),
#  ('ThinPrep', 1),
#  ('CONTEXT', 1),
#  ('SB203580', 1),
#  ('claustrum', 1),
#  ('Jack', 1),
#  ('package', 1),
#  ('ADAPT', 1),
#  ('bayesian', 1),
#  ('ATLN', 1),
#  ('enforced', 1),
#  ('Much', 1),
#  ('LANA2', 1),
#  ('ORFK10', 1),
#  ('periimplantation', 1),
#  ('extraembryonic', 1),
#  ('tetraploid', 1),
#  ('vHnf1', 1),
#  ('Aggregation', 1),
#  ('xenografts', 1),
#  ('RF02', 1),
#  ('contrasts', 1),
#  ('TC', 1),
#  ('vasodilatating', 1),
#  ('myorelaxing', 1),
#  ('analgetic', 1),
#  ('MED', 1),
#  ('Pint', 1),
#  ('].(', 1),
#  ('GMV', 1),
#  ('GMBF', 1),
#  ('commencing', 1),
#  ('U74500A', 1),
#  ('NotI', 1),
#  ('Vero', 1),
#  ('B95', 1),
#  ('embedding', 1),
#  ('miscible', 1),
#  ('methacrylate', 1),
#  ('Hydroxypropyl', 1),
#  ('JUN', 1),
#  ('cyclobutane', 1),
#  ('inodilators', 1),
#  ('crystallin', 1),
#  ('delta1', 1),
#  ('alphaA', 1),
#  ('alphaB', 1),
#  ('Cyclic', 1),
#  ('Fregnac', 1),
#  ('rhodanide', 1),
#  ('degradative', 1),
#  ('synthesizing', 1),
#  ('Evaluating', 1),
#  ('Tpl', 1),
#  ('Canada', 1),
#  ('Columbia', 1),
#  ('British', 1),
#  ('coast', 1),
#  ('west', 1),
#  ('coastal', 1),
#  ('marine', 1),
#  ('Lakes', 1),
#  ('Great', 1),
#  ('Huron', 1),
#  ('Tributyltin', 1),
#  ('unsuspected', 1),
#  ('Widening', 1),
#  ('presequences', 1),
#  ('hydroxylating', 1),
#  ('hydrase', 1),
#  ('shag', 1),
#  ('Nmd3', 1),
#  ('polyphosphate', 1),
#  ('synaptojanin', 1),
#  ('INP53', 1),
#  ('LUV1', 1),
#  ('RIC1', 1),
#  ('Polycythemia', 1),
#  ('Epigenetic', 1),
#  ('spg', 1),
#  ('gt10', 1),
#  ('transplantable', 1),
#  ('occasional', 1),
#  ('Phenylephrine', 1),
#  ('QUTA', 1),
#  ('qutA', 1),
#  ('Metyrapone', 1),
#  ('canid', 1),
#  ('Herpesvirinae', 1),
#  ('Varicellovirus', 1),
#  ('PhHV', 1),
#  ('Wildervanck', 1),
#  ('cholelithiasis', 1),
#  ('pkr', 1),
#  ('fundus', 1),
#  ('Ophthalmoscope', 1),
#  ('apropos', 1),
#  ('reflexions', 1),
#  ('Abdominal', 1),
#  ('512', 1),
#  ('487', 1),
#  ('RAD18', 1),
#  ('L17', 1),
#  ('IF1', 1),
#  ('lay', 1),
#  ('logarithmic', 1),
#  ('cstA', 1),
#  ('Suggestive', 1),
#  ('.),', 1),
#  ('Methisergide', 1),
#  ('dialysed', 1),
#  ('methylhippuric', 1),
#  ('hippuric', 1),
#  ('reconstitute', 1),
#  ('y5', 1),
#  ('interrupting', 1),
#  ('proximity', 1),
#  ('epidemica', 1),
#  ('nephropathia', 1),
#  ('nephritis', 1),
#  ('tubulointerstitial', 1),
#  ('Metabolism', 1),
#  ('echographically', 1),
#  ('CUG', 1),
#  ('etr', 1),
#  ('Mis3', 1),
#  ('INCENP', 1),
#  ('dictating', 1),
#  ('EC27', 1),
#  ('E18', 1),
#  ('3002', 1),
#  ('Abp1', 1),
#  ('efficacies', 1),
#  ('taurocholate', 1),
#  ('Adaptation', 1),
#  ('Spliced', 1),
#  ('Panlobular', 1),
#  ('1185', 1),
#  ('1171', 1),
#  ('1074', 1),
#  ('1057', 1),
#  ('coordinates', 1),
#  ('XPG', 1),
#  ('Freezing', 1),
#  ('Transpulmonary', 1),
#  ('IDPN', 1),
#  ('Hiss', 1),
#  ('bilinear', 1),
#  ('pauciflorus', 1),
#  ('Lysionotus', 1),
#  ('aerial', 1),
#  ('glucosyl', 1),
#  ('glucosides', 1),
#  ('flavone', 1),
#  ('81X', 1),
#  ('41X', 1),
#  ('3X', 1),
#  ('repressible', 1),
#  ('ura4', 1),
#  ('leu1', 1),
#  ('LEU', 1),
#  ('pJR', 1),
#  ('Antidepressant', 1),
#  ('friendly', 1),
#  ('generic', 1),
#  ('searches', 1),
#  ('premedication', 1),
#  ('homeostatic', 1),
#  ('TBG', 1),
#  ('DPH', 1),
#  ('CBZ', 1),
#  ('TRAF3', 1),
#  ('TRAF', 1),
#  ('TNFR', 1),
#  ('BCMA', 1),
#  ('Coimmunoprecipitation', 1),
#  ('rs3', 1),
#  ('rs2', 1),
#  ('FGF4', 1),
#  ('xenograft', 1),
#  ('histopathology', 1),
#  ('IEGs', 1),
#  ('You', 1),
#  ('ECP', 1),
#  ('CVS', 1),
#  ('EAF', 1),
#  ('rut', 1),
#  ('boxA', 1),
#  ('tnaC', 1),
#  ('adiposity', 1),
#  ('audit', 1),
#  ('Training', 1),
#  ('Crick', 1),
#  ('Watson', 1),
#  ('resonate', 1),
#  ('alertness', 1),
#  ('nortriptyline', 1),
#  ('fluphenazine', 1),
#  ('Motival', 1),
#  ('organizer', 1),
#  ('Dharma', 1),
#  ('Bozozok', 1),
#  ('NiCl', 1),
#  ('neurotransmitters', 1),
#  ('sclerotization', 1),
#  ('AANATs', 1),
#  ('acetyltransferases', 1),
#  ('arylalkylamine', 1),
#  ('insects', 1),
#  ('Cb', 1),
#  ('impeded', 1),
#  ('Linear', 1),
#  ('irgA', 1),
#  ('vasodilatation', 1),
#  ('Vasodilator', 1),
#  ('Block', 1),
#  ('Glut', 1),
#  ('facilitative', 1),
#  ('wit', 1),
#  ('parvovirus', 1),
#  ('Aplastic', 1),
#  ('Bg', 1),
#  ('pat', 1),
#  ('pCM2', 1),
#  ('combines', 1),
#  ('Piroximone', 1),
#  ('carboxypeptidase', 1),
#  ('Latexin', 1),
#  ('37kb', 1),
#  ('K159', 1),
#  ('Conformational', 1),
#  ('MEASURE', 1),
#  ('SECONDARY', 1),
#  ('3838', 1),
#  ('3829', 1),
#  ('minithoracotomy', 1),
#  ('Ligaclip', 1),
#  ('GRAIL', 1),
#  ('BLAST', 1),
#  ('0acteriuria', 1),
#  ('1RF', 1),
#  ('1SF2', 1),
#  ('1MN', 1),
#  ('1IIIB', 1),
#  ('LvUSF1', 1),
#  ('LvUSF2', 1),
#  ('MARTA2', 1),
#  ('MARTA1', 1),
#  ('hrpNEcc', 1),
#  ('ARP2', 1),
#  ('mu4', 1),
#  ('sigma4', 1),
#  ('beta4', 1),
#  ('untreatable', 1),
#  ('conservatively', 1),
#  ('operations', 1),
#  ('603', 1),
#  ('maturing', 1),
#  ('Acid', 1),
#  ('subtropical', 1),
#  ('boars', 1),
#  ('tones', 1),
#  ('disparity', 1),
#  ('relaxin', 1),
#  ('deltaEC', 1),
#  ('VAI', 1),
#  ('glaucomatous', 1),
#  ('echographic', 1),
#  ('cardiothoracic', 1),
#  ('Vo2', 1),
#  ('intramolecular', 1),
#  ('seldom', 1),
#  ('Amiodarone', 1),
#  ('nonfluorinated', 1),
#  ('fluoroquinolones', 1),
#  ('Reye', 1),
#  ('RACK1', 1),
#  ('presupplementary', 1),
#  ('corticosubthalamic', 1),
#  ('Corticostriatal', 1),
#  ('GHBP', 1),
#  ('SHRs', 1),
#  ('CDPK', 1),
#  ('nucleoplasmic', 1),
#  ('hIGF', 1),
#  ('aidB', 1),
#  ('accordingly', 1),
#  ('Exogenous', 1),
#  ('believers', 1),
#  ('Cytohesin', 1),
#  ('cryptococcal', 1),
#  ('mediastinum', 1),
#  ('Decreased', 1),
#  ('eucaryotic', 1),
#  ('PTR2', 1),
#  ('Vo2INDIR', 1),
#  ('Vo2DIR', 1),
#  ('cart', 1),
#  ('CSX1', 1),
#  ('380', 1),
#  ('Tyr181', 1),
#  ('Cys181', 1),
#  ('p51', 1),
#  ('Adverse', 1),
#  ('esterified', 1),
#  ('acetonides', 1),
#  ('Patch', 1),
#  ('velopharyngeal', 1),
#  ('NPF', 1),
#  ('Besides', 1),
#  ('pAW63', 1),
#  ('pSM19035', 1),
#  ('pIP501', 1),
#  (']),', 1),
#  ('Rep63A', 1),
#  ('dimerizes', 1),
#  ('DE', 1),
#  ('exercising', 1),
#  ('Per', 1),
#  ('ZN', 1),
#  ('Neelsen', 1),
#  ('Ziehl', 1),
#  ('supramaximal', 1),
#  ('electromyographic', 1),
#  ('AO2', 1),
#  ('Lagos', 1),
#  ('dermatology', 1),
#  ('Ini1', 1),
#  ('hSNF5', 1),
#  ('SWI', 1),
#  ('SNF', 1),
#  ('CRBPIIp', 1),
#  ('master', 1),
#  ('Hst6p', 1),
#  ('hyperheparinuria', 1),
#  ('Hoosier', 1),
#  ('DexRE', 1),
#  ('pharmacologic', 1),
#  ('VGS', 1),
#  ('HHCA', 1),
#  ('24K', 1),
#  ('VPg', 1),
#  ('58K', 1),
#  ('32K', 1),
#  ('CPSMV', 1),
#  ('mottle', 1),
#  ('CPMV', 1),
#  ('reactant', 1),
#  ('coagulant', 1),
#  ('CII', 1),
#  ('CIII', 1),
#  ('croup', 1),
#  ('south', 1),
#  ('towns', 1),
#  ('SOS2', 1),
#  ('sos2', 1),
#  ('metformin', 1),
#  ('glibenclamide', 1),
#  ('outwardly', 1),
#  ('NifL', 1),
#  ('vinelandii', 1),
#  ('304', 1),
#  ('conclusively', 1),
#  ('hexylsalicylic', 1),
#  ('bretylium', 1),
#  ('Nedd4', 1),
#  ('LNA', 1),
#  ('GALT', 1),
#  ('MPE', 1),
#  ('BKV', 1),
#  ('BK', 1),
#  ('Thromboelastography', 1),
#  ('dephosphorylates', 1),
#  ('SW', 1),
#  ('HEK293', 1),
#  ('p42', 1),
#  ('Ag35', 1),
#  ('discrepancy', 1),
#  ('muricidal', 1),
#  ('HSP81', 1),
#  ('citreoviridin', 1),
#  ('rrn26', 1),
#  ('oncogenicity', 1),
#  ('pSa', 1),
#  ('ESEM', 1),
#  ('morphofunctional', 1),
#  ('ensembles', 1),
#  ('VD', 1),
#  ('PAO2', 1),
#  ('fR', 1),
#  ('heifer', 1),
#  ('TBOH', 1),
#  ('cauliflower', 1),
#  ('multisynthetase', 1),
#  ('Than', 1),
#  ('significative', 1),
#  ('ABS', 1),
#  ('immunofluorescent', 1),
#  ('parkeri', 1),
#  ('turicatae', 1),
#  ('Posttranslational', 1),
#  ('terminals', 1),
#  ('plexus', 1),
#  ('distorted', 1),
#  ('porCa', 1),
#  ('porin', 1),
#  ('xenobiotics', 1),
#  ('justified', 1),
#  ('scanty', 1),
#  ('1628', 1),
#  ('nucleoplasm', 1),
#  ('DRS', 1),
#  ('MEMA', 1),
#  ('Signal', 1),
#  ('heterogeneously', 1),
#  ('painting', 1),
#  ('resections', 1),
#  ('leakage', 1),
#  ('Vivostat', 1),
#  ('OVAR', 1),
#  ('biogenic', 1),
#  ('adds', 1),
#  ('Prp42p', 1),
#  ('Duffy', 1),
#  ('LCGU', 1),
#  ('LCBF', 1),
#  ('hydroxyurea', 1),
#  ('MEC3', 1),
#  ('RAD24', 1),
#  ('RAD17', 1),
#  ('tetraphasic', 1),
#  ('infecting', 1),
#  ('EPVs', 1),
#  ('Smad1', 1),
#  ('xTAK1KN', 1),
#  ('negated', 1),
#  ('BAF1', 1),
#  ('entopeduncularis', 1),
#  ('lateralis', 1),
#  ('CATase', 1),
#  ('today', 1),
#  ('thirties', 1),
#  ('1940s', 1),
#  ('PBV', 1),
#  ('occipito', 1),
#  ('clival', 1),
#  ('sellar', 1),
#  ('directions', 1),
#  ('Vienna', 1),
#  ('Charite', 1),
#  ('gynecology', 1),
#  ('prospects', 1),
#  ('p105', 1),
#  ('NFKB1', 1),
#  ('CgA', 1),
#  ('DHE', 1),
#  ('pD2', 1),
#  ('Salaam', 1),
#  ('es', 1),
#  ('Dar', 1),
#  ('archives', 1),
#  ('Routinely', 1),
#  ('CCI', 1),
#  ('Gpt', 1),
#  ('increment', 1),
#  ('meshwork', 1),
#  ('damages', 1),
#  ('mucolytic', 1),
#  ('Fab1p', 1),
#  ('visited', 1),
#  ('FIV', 1),
#  ('GapB', 1),
#  ('GapA', 1),
#  ('occupies', 1),
#  ('ambient', 1),
#  ('ApoA', 1),
#  ('Bp50', 1),
#  ('Bp65', 1),
#  ('excessively', 1),
#  ('duty', 1),
#  ('Naval', 1),
#  ('SCH9', 1),
#  ('PBI', 1),
#  ('bounded', 1),
#  ('computing', 1),
#  ('RFSS', 1),
#  ('coronarogenic', 1),
#  ('HTF9A', 1),
#  ('DEDDDL', 1),
#  ('triangle', 1),
#  ('Ward', 1),
#  ('lat', 1),
#  ('NRAMP2', 1),
#  ('kDal', 1),
#  ('CORT', 1),
#  ('PND', 1),
#  ('Handling', 1),
#  ('midexpiratory', 1),
#  ('3923', 1),
#  ('Thbs3', 1),
#  ('Mtx', 1),
#  ('typing', 1),
#  ('dorsi', 1),
#  ('latissimus', 1),
#  ('Management', 1),
#  ('tartrate', 1),
#  ('unwind', 1),
#  ('equate', 1),
#  ('Neurons', 1),
#  ('medullo', 1),
#  ('RanGTP', 1),
#  ('NES', 1),
#  ('Crm1p', 1),
#  ('crm1', 1),
#  ('F10', 1),
#  ('F6', 1),
#  ('577', 1),
#  ('pANF', 1),
#  ('ANF', 1),
#  ('Hariana', 1),
#  ('calvings', 1),
#  ('prealbumin', 1),
#  ('lipocalin', 1),
#  ('arbutamine', 1),
#  ('Atromid', 1),
#  ('clofibrate', 1),
#  ('FNR', 1),
#  ('Location', 1),
#  ('integrates', 1),
#  ('pigmentary', 1),
#  ('Retinal', 1),
#  ('Breast', 1),
#  ('comparably', 1),
#  ('lipoamide', 1),
#  ('LPD1', 1),
#  ('Uzbekistan', 1),
#  ('ruler', 1),
#  ('political', 1),
#  ('strategist', 1),
#  ('him', 1),
#  ('lodges', 1),
#  ('masonic', 1),
#  ('4RE', 1),
#  ('supraphysiologic', 1),
#  ('pUTKAT1', 1),
#  ('Ren1d', 1),
#  ('SLT', 1),
#  ('hypogonadal', 1),
#  ('corroborated', 1),
#  ('pentose', 1),
#  ('xylitol', 1),
#  ('bottles', 1),
#  ('VNTR', 1),
#  ('Cosmid', 1),
#  ('quarters', 1),
#  ('FNF', 1),
#  ('drs2', 1),
#  ('Strains', 1),
#  ('Rainbow', 1),
#  ('KZM', 1),
#  ('D28K', 1),
#  ('calbindin', 1),
#  ('GAS', 1),
#  ('CD86', 1),
#  ('characterisation', 1),
#  ('maleate', 1),
#  ('methoxydextrane', 1),
#  ('xynB', 1),
#  ('patriciarum', 1),
#  ('Avicel', 1),
#  ('agonistic', 1),
#  ('analytically', 1),
#  ('SBBS', 1),
#  ('backscattering', 1),
#  ('Brillouin', 1),
#  ('brillouin', 1),
#  ('pisiformis', 1),
#  ('Cysticercus', 1),
#  ('evagination', 1),
#  ('bath', 1),
#  ('tensile', 1),
#  ('antisecretory', 1),
#  ('749', 1),
#  ('histalog', 1),
#  ('ANIMALS', 1),
#  ('transducin', 1),
#  ('Sternocleidomastoid', 1),
#  ('perspective', 1),
#  ('Epitope', 1),
#  ('odonate', 1),
#  ('nonresponsive', 1),
#  ('parasthesias', 1),
#  ('86Rb', 1),
#  ('equimolar', 1),
#  ('enucleation', 1),
#  ('favorably', 1),
#  ('navigation', 1),
#  ('VDBB', 1),
#  ('subcortical', 1),
#  ('impairments', 1),
#  ('sm', 1),
#  ('russelli', 1),
#  ('Transfer', 1),
#  ('A79V', 1),
#  ('tif1', 1),
#  ('phytochromes', 1),
#  ('DE1', 1),
#  ('nonbinding', 1),
#  ('immortalizing', 1),
#  ('HPV16', 1),
#  ('E7s', 1),
#  ('HPV8', 1),
#  ('HPV5', 1),
#  ('IRE', 1),
#  ('xylosus', 1),
#  ('ccpA', 1),
#  ('PVB', 1),
#  ('IJVB', 1),
#  ('NSE', 1),
#  ('OMeRNA', 1),
#  ('oligoribonucleotides', 1),
#  ('Essentially', 1),
#  ('methylglucose', 1),
#  ('mannitol', 1),
#  ('LHA2', 1),
#  ('LHA4', 1),
#  ('chlorpropamide', 1),
#  ('CPAF', 1),
#  ('dra', 1),
#  ('RPS30A', 1),
#  ('GenBankTM', 1),
#  ('mimicry', 1),
#  ('PAF1', 1),
#  ('paf1', 1),
#  ('abundances', 1),
#  ...]

# %%
RARE_KEYWORD = "_RARE_"
word_tag_pair_counts_r = word_tag_pair_counts.copy()
for wt, count in word_tag_pair_counts.items():
  word, tag = wt
  if word in d_rare:
    word_tag_pair_counts_r[(RARE_KEYWORD, tag)] = count
  #print(tag_counter[tag], tag, word, count)

# %%
for wt, count in word_tag_pair_counts_r.items():
  word, tag = wt
  p = count*  1.0 /tag_counter[tag]
  d[(word, tag)] = p
d
# Out:
# defaultdict(float,
#             {('Bacteriol', 'O'): 3.6101474023184367e-06,
#              ('In', 'O'): 0.0022274609472304756,
#              ('conclusion', 'O'): 5.054206363245811e-05,
#              (',', 'O'): 0.03509063275053521,
#              ('these', 'O'): 0.0014260082239157825,
#              ('studies', 'O'): 0.0006823178590381845,
#              ('indicate', 'O'): 0.0004223872460712571,
#              ('that', 'O'): 0.008285288288320812,
#              ('LiCl', 'O'): 7.220294804636873e-06,
#              ('(', 'O'): 0.01487380729755196,
#              ('1', 'O'): 0.0034115892951909225,
#              (')', 'O'): 0.009310570150579248,
#              ('decreases', 'O'): 6.137250583941343e-05,
#              ('histamine', 'O'): 2.8881179218547494e-05,
#              ('-', 'O'): 0.025242150637010508,
#              ('stimulated', 'O'): 0.00028159149738083805,
#              ('gastric', 'O'): 0.0001263551590811453,
#              ('acid', 'O'): 0.001025281862258436,
#              ('secretion', 'O'): 0.00015523633829969279,
#              ('and', 'O'): 0.028480452856890145,
#              ('2', 'O'): 0.002411578464748716,
#              ('diminishes', 'O'): 7.220294804636873e-06,
#              ('bile', 'O'): 3.9711621425502805e-05,
#              ('induced', 'O'): 0.001191348642765084,
#              ('disruption', 'O'): 4.693191623013968e-05,
#              ('of', 'O'): 0.04253475669411582,
#              ('the', 'O'): 0.04490662353743903,
#              ('mucosal', 'O'): 2.5271031816229057e-05,
#              ('barrier', 'O'): 2.8881179218547494e-05,
#              ('in', 'O'): 0.02341541605143738,
#              ('canine', 'O'): 3.249132662086593e-05,
#              ('Heidenhain', 'O'): 7.220294804636873e-06,
#              ('pouch', 'O'): 1.4440589609273747e-05,
#              ('.', 'O'): 0.04436149127968895,
#              ('Two', 'O'): 0.00023465958115069838,
#              ('new', 'O'): 0.0004801496045083521,
#              ('glucosidase', 'B'): 7.532389273877674e-05,
#              ('inhibitors', 'O'): 0.00014079574869041902,
#              ('BAY', 'O'): 7.220294804636873e-06,
#              ('m', 'O'): 9.747397986259779e-05,
#              ('1099', 'O'): 7.220294804636873e-06,
#              ('o', 'O'): 2.8881179218547494e-05,
#              ('1248', 'O'): 3.6101474023184367e-06,
#              ('were', 'O'): 0.005231103585959415,
#              ('studied', 'O'): 0.00040072636165734644,
#              ('volunteers', 'O'): 9.025368505796091e-05,
#              ('type', 'O'): 0.0009025368505796091,
#              ('II', 'O'): 0.0003862857720480727,
#              ('diabetics', 'O'): 7.220294804636873e-06,
#              ('under', 'O'): 0.0003646248876341621,
#              ('various', 'O'): 0.00025993061296692745,
#              ('conditions', 'O'): 0.0002743712025762012,
#              ('Therefore', 'O'): 0.00011913486427650841,
#              ('prevalences', 'O'): 3.6101474023184367e-06,
#              ('total', 'O'): 0.0004404379830828493,
#              ('diabetes', 'O'): 8.664353765564248e-05,
#              ('GDM', 'O'): 3.6101474023184367e-06,
#              ('19', 'O'): 0.00022382913894374308,
#              ('%', 'O'): 0.0018122939959638552,
#              ('0', 'O'): 0.002768983057578241,
#              ('56', 'O'): 9.747397986259779e-05,
#              ('%,', 'O'): 0.0003285234136109777,
#              ('respectively', 'O'): 0.0006498265324173186,
#              ('The', 'O'): 0.0073863615851435215,
#              ('relative', 'O'): 0.00023465958115069838,
#              ('toxicity', 'O'): 9.747397986259779e-05,
#              ('nickel', 'O'): 1.083044220695531e-05,
#              ('oxide', 'O'): 3.249132662086593e-05,
#              ('NiO', 'O'): 3.6101474023184367e-06,
#              ('),', 'O'): 0.002324934927093073,
#              ('sulfate', 'O'): 7.581309544868718e-05,
#              ('hexahydrate', 'O'): 3.6101474023184367e-06,
#              ('NiSO4', 'O'): 3.6101474023184367e-06,
#              ('6H2O', 'O'): 7.220294804636873e-06,
#              ('subsulfide', 'O'): 3.6101474023184367e-06,
#              ('Ni3S2', 'O'): 3.6101474023184367e-06,
#              ('was', 'O'): 0.0069820250760838564,
#              ('F344', 'O'): 7.220294804636873e-06,
#              ('/', 'O'): 0.004361058062000671,
#              ('N', 'O'): 0.0006101149109918158,
#              ('rats', 'O'): 0.0004945901941176258,
#              ('B6C3F1', 'O'): 3.6101474023184367e-06,
#              ('mice', 'O'): 0.00033574370841561464,
#              ('after', 'O'): 0.0013826864550879612,
#              ('inhalation', 'O'): 4.332176882782124e-05,
#              ('exposure', 'O'): 0.00017328707531128496,
#              ('for', 'O'): 0.007032567139716315,
#              ('6', 'O'): 0.001140806579132626,
#              ('hr', 'O'): 7.220294804636873e-05,
#              ('day', 'O'): 0.0004332176882782124,
#              ('5', 'O'): 0.0025415437712321795,
#              ('days', 'O'): 0.00037545532984111743,
#              ('week', 'O'): 0.00013357545388578216,
#              ('13', 'O'): 0.0003537944454272068,
#              ('weeks', 'O'): 0.0002491001707599721,
#              ('Each', 'O'): 6.498265324173186e-05,
#              ('patient', 'O'): 0.0003682350350364805,
#              ('had', 'O'): 0.0008700455239587432,
#              ('measurable', 'O'): 7.220294804636873e-06,
#              ('LH', 'B'): 0.0007532389273877674,
#              ('FSH', 'B'): 0.0010545344983428743,
#              ('levels', 'O'): 0.0012996530648346372,
#              ('with', 'O'): 0.00969685592262732,
#              ('pulsed', 'O'): 1.8050737011592182e-05,
#              ('nocturnal', 'O'): 7.220294804636873e-06,
#              ('pubertal', 'O'): 1.4440589609273747e-05,
#              ('responses', 'O'): 0.00029964223439243024,
#              ('to', 'O'): 0.014870197150149641,
#              ('LRH', 'B'): 7.532389273877674e-05,
#              ('Ophthalmosonographic', 'O'): 3.6101474023184367e-06,
#              ('evaluation', 'O'): 0.00012996530648346372,
#              ('blood', 'O'): 0.0009061469979819276,
#              ('flow', 'O'): 0.0003682350350364805,
#              ('velocity', 'O'): 3.249132662086593e-05,
#              ('arteriocavernous', 'O'): 3.6101474023184367e-06,
#              ('fistula', 'O'): 1.083044220695531e-05,
#              ('From', 'O'): 7.220294804636873e-05,
#              ('Pap', 'O'): 7.220294804636873e-06,
#              ('ApUp', 'O'): 3.6101474023184367e-06,
#              ('control', 'O'): 0.0008700455239587432,
#              ('patients', 'O'): 0.0025740350978530452,
#              ('baseline', 'O'): 8.664353765564248e-05,
#              ('images', 'O'): 4.332176882782124e-05,
#              ('presented', 'O'): 0.00016245663310432965,
#              ('Type', 'O'): 0.00011552471687418997,
#              ('I', 'O'): 0.00048736989931298896,
#              ('25', 'O'): 0.0002491001707599721,
#              ('7', 'O'): 0.0009350281772004751,
#              ('III', 'O'): 0.0001768972227136034,
#              ('&', 'O'): 5.415221103477655e-05,
#              ('IV', 'O'): 0.00013357545388578216,
#              ('loading', 'O'): 1.4440589609273747e-05,
#              ('same', 'O'): 0.0003429640032202515,
#              ('as', 'O'): 0.003646248876341621,
#              ('at', 'O'): 0.0029314396906825707,
#              ('major', 'O'): 0.000314082824001704,
#              ('findings', 'O'): 0.000256320465564609,
#              ('our', 'O'): 0.000256320465564609,
#              ('are', 'O'): 0.0029494904276941626,
#              ('follows', 'O'): 5.415221103477655e-05,
#              (':', 'O'): 0.00261013657187623,
#              ('There', 'O'): 0.00016967692790896652,
#              ('no', 'O'): 0.0006967584486474583,
#              ('detectable', 'O'): 8.664353765564248e-05,
#              ('signals', 'O'): 0.0001480160434950559,
#              ('around', 'O'): 6.137250583941343e-05,
#              ('GDF', 'B'): 7.532389273877674e-05,
#              ('-', 'I'): 0.180087327376117,
#              ('9', 'I'): 0.0003046303818034119,
#              ('deficient', 'O'): 0.00013357545388578216,
#              ('follicles', 'O'): 1.083044220695531e-05,
#              ('several', 'O'): 0.0004332176882782124,
#              ('theca', 'O'): 3.6101474023184367e-06,
#              ('cell', 'O'): 0.001909767975826453,
#              ('layer', 'O'): 6.137250583941343e-05,
#              ('markers', 'O'): 8.303339025332404e-05,
#              ('[', 'O'): 0.00039711621425502804,
#              ('i', 'O'): 0.0003862857720480727,
#              ('e', 'O'): 0.00024187987595533525,
#              ('Keck', 'O'): 3.6101474023184367e-06,
#              ('C', 'O'): 0.0009566890616143857,
#              ('J', 'O'): 0.00019494795972519558,
#              ('rbcL', 'B'): 7.532389273877674e-05,
#              ('rbcS', 'B'): 7.532389273877674e-05,
#              ('locus', 'O'): 0.0001371856012881006,
#              ('seems', 'O'): 7.581309544868718e-05,
#              ('be', 'O'): 0.002364646548518576,
#              ('barely', 'O'): 7.220294804636873e-06,
#              ('expressed', 'O'): 0.0008158933129239667,
#              ('a', 'O'): 0.015895479012408075,
#              ('standard', 'O'): 0.0001371856012881006,
#              ('condition', 'O'): 5.415221103477655e-05,
#              ('photoautotrophic', 'O'): 3.6101474023184367e-06,
#              ('growth', 'O'): 0.0005451322577500839,
#              ('properties', 'O'): 0.00020577840193215089,
#              ('phi', 'O'): 1.4440589609273747e-05,
#              ('29', 'O'): 0.0001263551590811453,
#              ('SSB', 'B'): 0.00030129557095510696,
#              ('ssDNA', 'I'): 5.077173030056864e-05,
#              ('complex', 'O'): 0.000595674321382542,
#              ('described', 'O'): 0.00022743928634606152,
#              ('Internal', 'O'): 1.4440589609273747e-05,
#              ('modes', 'O'): 1.8050737011592182e-05,
#              ('soliton', 'O'): 7.220294804636873e-06,
#              ('A', 'O'): 0.0022455116842420675,
#              ('281', 'O'): 7.220294804636873e-06,
#              ('divided', 'O'): 7.220294804636873e-05,
#              ('into', 'O'): 0.0008158933129239667,
#              ('groups', 'O'): 0.00036101474023184365,
#              ('according', 'O'): 9.386383246027936e-05,
#              ('their', 'O'): 0.0007653512492915086,
#              ('clinical', 'O'): 0.0004223872460712571,
#              ('diagnosis', 'O'): 0.00025993061296692745,
#              ('examined', 'O'): 0.0002888117921854749,
#              ('using', 'O'): 0.0009819600934306148,
#              ('capnography', 'O'): 3.6101474023184367e-06,
#              ('spirometry', 'O'): 1.4440589609273747e-05,
#              ('gas', 'O'): 9.747397986259779e-05,
#              ('analysis', 'O'): 0.0012274501167882684,
#              ('addition', 'O'): 0.00041516695126662023,
#              ('its', 'O'): 0.0010216717148561175,
#              ('effect', 'O'): 0.0008953165557749723,
#              ('augmenting', 'O'): 7.220294804636873e-06,
#              ('neutrophil', 'O'): 4.332176882782124e-05,
#              ('response', 'O'): 0.0008086730181193298,
#              ('eccentric', 'O'): 7.220294804636873e-06,
#              ('exercise', 'O'): 0.00015162619089737435,
#              ('vitamin', 'O'): 0.0001371856012881006,
#              ('E', 'O'): 0.0002888117921854749,
#              ('causes', 'O'): 0.0001371856012881006,
#              ('greater', 'O'): 0.00035740459282952524,
#              ('increase', 'O'): 0.0005018104889222627,
#              ('circulating', 'O'): 4.332176882782124e-05,
#              ('creatine', 'B'): 0.0006025911419102139,
#              ('kinase', 'I'): 0.017110073111291632,
#              ('activity', 'O'): 0.0023177146322884363,
#              ('perhaps', 'O'): 2.8881179218547494e-05,
#              ('indicating', 'O'): 0.00019855810712751402,
#              ('increased', 'O'): 0.000768961396693827,
#              ('skeletal', 'O'): 6.85928006440503e-05,
#              ('muscle', 'O'): 0.00037545532984111743,
#              ('repair', 'O'): 0.00010469427466723466,
#              ('Methods', 'O'): 1.083044220695531e-05,
#              ('included', 'O'): 0.0001263551590811453,
#              ('24', 'O'): 0.0003285234136109777,
#              ('hour', 'O'): 5.776235843709499e-05,
#              ('dietary', 'O'): 7.581309544868718e-05,
#              ('recall', 'O'): 1.083044220695531e-05,
#              ('menu', 'O'): 3.6101474023184367e-06,
#              ('weights', 'O'): 2.166088441391062e-05,
#              ('recipe', 'O'): 3.6101474023184367e-06,
#              ('this', 'O'): 0.0020216825452983246,
#              ('method', 'O'): 0.000371845182438799,
#              ('PLP', 'O'): 3.6101474023184367e-06,
#              ('plasma', 'O'): 0.00048736989931298896,
#              ('can', 'O'): 0.0008989267031772907,
#              ('determined', 'O'): 0.00043682783568053084,
#              ('high', 'O'): 0.0009169774401888829,
#              ('sensitivity', 'O'): 0.00020577840193215089,
#              ('derivatization', 'O'): 3.6101474023184367e-06,
#              ('sodium', 'O'): 0.00014079574869041902,
#              ('bisulfite', 'O'): 3.6101474023184367e-06,
#              ('mobile', 'O'): 2.5271031816229057e-05,
#              ('phase', 'O'): 0.00043682783568053084,
#              ('general', 'O'): 0.0001083044220695531,
#              ('recombination', 'O'): 0.00011552471687418997,
#              ('polarizing', 'O'): 3.6101474023184367e-06,
#              ('voltage', 'O'): 3.249132662086593e-05,
#              ('300', 'O'): 6.498265324173186e-05,
#              ('V', 'O'): 0.00014440589609273746,
#              ('is', 'O'): 0.00674375534753084,
#              ('less', 'O'): 0.000736470070072961,
#              ('than', 'O'): 0.0017075997212966205,
#              ('dose', 'O'): 0.00045126842528980457,
#              ('rates', 'O'): 0.0001660667805066481,
#              ('up', 'O'): 0.000314082824001704,
#              ('about', 'O'): 0.0002707610551738828,
#              ('100', 'O'): 0.00040794665646198337,
#              ('mGy', 'O'): 3.6101474023184367e-06,
#              ('min', 'O'): 0.0004909800467153074,
#              ('Use', 'O'): 2.5271031816229057e-05,
#              ('vena', 'O'): 1.083044220695531e-05,
#              ('cava', 'O'): 7.220294804636873e-06,
#              ('extend', 'O'): 2.8881179218547494e-05,
#              ('right', 'O'): 0.00020216825452983245,
#              ('renal', 'O'): 0.00025993061296692745,
#              ('vein', 'O'): 7.581309544868718e-05,
#              ('cadaver', 'O'): 7.220294804636873e-06,
#              ('transplantation', 'O'): 8.303339025332404e-05,
#              ('controversial', 'O'): 1.083044220695531e-05,
#              ('1992', 'O'): 5.776235843709499e-05,
#              ('Genomics', 'O'): 3.6101474023184367e-06,
#              ('12', 'O'): 0.0005379119629454471,
#              ('58', 'O'): 5.415221103477655e-05,
#              ('62', 'O'): 7.942324285100561e-05,
#              (').', 'O'): 0.0022382913894374305,
#              ('Spinal', 'O'): 3.6101474023184367e-06,
#              ('cord', 'O'): 6.137250583941343e-05,
#              ('representation', 'O'): 1.083044220695531e-05,
#              ('micturition', 'O'): 1.083044220695531e-05,
#              ('reflex', 'O'): 4.332176882782124e-05,
#              ('two', 'O'): 0.0018736665018032686,
#              ('hybrid', 'O'): 0.00012274501167882686,
#              ('assay', 'O'): 0.00023826972855301682,
#              ('then', 'O'): 0.00015884648570201122,
#              ('performed', 'O'): 0.00037906547724343584,
#              ('full', 'O'): 0.00018411751751824026,
#              ('length', 'O'): 0.0002527103181622906,
#              ('genes', 'O'): 0.0008664353765564247,
#              ('CI', 'B'): 7.532389273877674e-05,
#              ('HC', 'B'): 0.00022597167821633023,
#              ('Pro', 'I'): 5.077173030056864e-05,
#              ('P1', 'B'): 0.0003766194636938837,
#              ('P3', 'B'): 7.532389273877674e-05,
#              ('CP', 'B'): 0.00015064778547755348,
#              ('but', 'O'): 0.0016426170680548886,
#              ('heterologous', 'O'): 8.303339025332404e-05,
#              ('interactions', 'O'): 0.00020216825452983245,
#              ('detected', 'O'): 0.0003935060668527096,
#              ('High', 'O'): 6.498265324173186e-05,
#              ('concentrations', 'O'): 0.00040794665646198337,
#              ('soluble', 'O'): 6.85928006440503e-05,
#              ('E', 'B'): 0.0013558300692979813,
#              ('selectin', 'I'): 0.00020308692120227456,
#              ('closely', 'O'): 0.00013357545388578216,
#              ('associated', 'O'): 0.0006967584486474583,
#              ('multiple', 'O'): 0.00041516695126662023,
#              ('organ', 'O'): 6.137250583941343e-05,
#              ('dysfunction', 'O'): 3.6101474023184365e-05,
#              ('death', 'O'): 0.00015162619089737435,
#              ('limited', 'O'): 8.303339025332404e-05,
#              ('disease', 'O'): 0.0006426062376126817,
#              ('survival', 'O'): 0.00020938854933446932,
#              ('alternating', 'O'): 3.6101474023184367e-06,
#              ('arm', 'O'): 7.220294804636873e-05,
#              ('significantly', 'O'): 0.0007797918389007823,
#              ('superior', 'O'): 3.9711621425502805e-05,
#              ('CAV', 'O'): 3.6101474023184367e-06,
#              ('P', 'O'): 0.0006137250583941342,
#              ('=', 'O'): 0.0008122831655216483,
#              ('014', 'O'): 3.6101474023184367e-06,
#              ('or', 'O'): 0.0032707935465005034,
#              ('PE', 'O'): 7.220294804636873e-06,
#              ('023', 'O'): 3.6101474023184367e-06,
#              ('Mg', 'B'): 7.532389273877674e-05,
#              ('chelatase', 'I'): 5.077173030056864e-05,
#              ('tobacco', 'O'): 5.415221103477655e-05,
#              ('identification', 'O'): 0.00012996530648346372,
#              ('Chl', 'B'): 7.532389273877674e-05,
#              ('D', 'I'): 0.0013200649878147847,
#              ('cDNA', 'I'): 0.003147847278635256,
#              ('sequence', 'I'): 0.003554021121039805,
#              ('encoding', 'O'): 0.0005559626999570393,
#              ('third', 'O'): 0.00015884648570201122,
#              ('subunit', 'O'): 0.0002671509077715643,
#              ('interaction', 'O'): 0.00045848872009444144,
#              ('three', 'O'): 0.0007761816914984639,
#              ('subunits', 'O'): 0.00013357545388578216,
#              ('yeast', 'O'): 0.0004837597519106705,
#              ('system', 'O'): 0.000512640931129218,
#              ('reconstitution', 'O'): 1.083044220695531e-05,
#              ('enzyme', 'O'): 0.00029964223439243024,
#              ('by', 'O'): 0.006797907558565616,
#              ('co', 'O'): 0.00015884648570201122,
#              ('expression', 'O'): 0.0022527319790467044,
#              ('recombinant', 'B'): 0.0021090689966857487,
#              ('CHL', 'I'): 5.077173030056864e-05,
#              ('CHL', 'B'): 0.00015064778547755348,
#              ('H', 'I'): 0.001269293257514216,
#              ('I', 'I'): 0.006143379366368806,
#              ('This', 'O'): 0.0009097571453842461,
#              ('suggested', 'O'): 0.00022743928634606152,
#              ('delta', 'O'): 0.00012996530648346372,
#              ('desaturation', 'O'): 3.6101474023184367e-06,
#              ('activities', 'O'): 0.0002454900233576537,
#              ('normal', 'O'): 0.0007473005122799164,
#              ('C18', 'O'): 1.8050737011592182e-05,
#              ('2w6', 'O'): 3.6101474023184367e-06,
#              ('supply', 'O'): 2.8881179218547494e-05,
#              ('Gel', 'O'): 4.332176882782124e-05,
#              ('shift', 'O'): 0.00024187987595533525,
#              ('indicates', 'O'): 0.00016245663310432965,
#              ('full', 'B'): 0.0009792106056040976,
#              ('length', 'I'): 0.0007615759545085296,
#              ('ERM', 'I'): 5.077173030056864e-05,
#              ('protein', 'I'): 0.02878757108042242,
#              ('able', 'O'): 0.00015523633829969279,
#              ('bind', 'O'): 0.00028159149738083805,
#              ('specifically', 'O'): 0.00018772766492055872,
#              ('an', 'O'): 0.003075845586775308,
#              ('oligonucleotide', 'O'): 6.137250583941343e-05,
#              ('containing', 'O'): 0.0008231136077286035,
#              ('consensus', 'O'): 0.0002527103181622906,
#              ('nucleotide', 'O'): 0.00032130311880634085,
#              ('core', 'O'): 0.0001263551590811453,
#              ('sequence', 'O'): 0.001826734585573129,
#              ('GGAA', 'O'): 3.6101474023184367e-06,
#              ('recognized', 'O'): 7.220294804636873e-05,
#              ('Ets', 'B'): 0.0015064778547755348,
#              ('proteins', 'O'): 0.0009097571453842461,
#              ('test', 'O'): 0.00041155680386430177,
#              ('should', 'O'): 0.00019855810712751402,
#              ('provide', 'O'): 0.00014079574869041902,
#              ('another', 'O'): 0.00011191456947187154,
#              ('practical', 'O'): 1.4440589609273747e-05,
#              ('means', 'O'): 0.00011552471687418997,
#              ('study', 'O'): 0.0010866543680978493,
#              ('leprosy', 'O'): 1.083044220695531e-05,
#              ('CONCLUSIONS', 'O'): 0.00011913486427650841,
#              ('EBCT', 'O'): 3.6101474023184367e-06,
#              ('technology', 'O'): 2.166088441391062e-05,
#              ('allows', 'O'): 4.332176882782124e-05,
#              ('minimally', 'O'): 1.4440589609273747e-05,
#              ('invasive', 'O'): 6.498265324173186e-05,
#              ('intramyocardial', 'O'): 3.6101474023184367e-06,
#              ('microcirculatory', 'O'): 7.220294804636873e-06,
#              ('function', 'O'): 0.0008483846395448327,
#              ('permits', 'O'): 1.8050737011592182e-05,
#              ('assessment', 'O'): 7.942324285100561e-05,
#              ('microvascular', 'O'): 1.4440589609273747e-05,
#              ('BV', 'O'): 3.6101474023184367e-06,
#              ('distribution', 'O'): 0.0001660667805066481,
#              ('different', 'O'): 0.0006750975642335476,
#              ('functional', 'O'): 0.00042960754087589397,
#              ('components', 'O'): 0.00018050737011592182,
#              ('RT', 'O'): 5.415221103477655e-05,
#              ('PCR', 'O'): 0.0001660667805066481,
#              ('previously', 'O'): 0.0004620988674967599,
#              ('reported', 'O'): 0.0002671509077715643,
#              ('degenerate', 'O'): 1.4440589609273747e-05,
#              ('primers', 'O'): 4.332176882782124e-05,
#              ('ligand', 'O'): 0.00014440589609273746,
#              ('binding', 'O'): 0.0019061578284241345,
#              ('domain', 'O'): 0.0010180615674537992,
#              ('LBD', 'O'): 7.220294804636873e-06,
#              ('known', 'O'): 0.00033574370841561464,
#              ('beta', 'B'): 0.0067791503464899065,
#              ('integrin', 'I'): 0.0003046303818034119,
#              ('subunits', 'I'): 0.0009138911454102356,
#              ('Bge', 'B'): 7.532389273877674e-05,
#              ('effective', 'O'): 0.00022021899154142465,
#              ('low', 'O'): 0.00041155680386430177,
#              ('toxic', 'O'): 6.85928006440503e-05,
#              ('schedules', 'O'): 1.083044220695531e-05,
#              ('KW', 'O'): 3.6101474023184367e-06,
#              ('2083', 'O'): 3.6101474023184367e-06,
#              ('investigated', 'O'): 0.00022382913894374308,
#              ('further', 'O'): 0.00027798134997851964,
#              ('These', 'O'): 0.0009819600934306148,
#              ('results', 'O'): 0.001115535547316397,
#              ('suggest', 'O'): 0.0005595728473593576,
#              ('phenotype', 'O'): 0.00015884648570201122,
#              ('XLP', 'O'): 3.6101474023184367e-06,
#              ('may', 'O'): 0.0010974848103048047,
#              ('result', 'O'): 0.00022743928634606152,
#              ('from', 'O'): 0.004126398480849973,
#              ('perturbed', 'O'): 1.083044220695531e-05,
#              ('signaling', 'O'): 0.00028159149738083805,
#              ('not', 'O'): 0.002498222002404358,
#              ('only', 'O'): 0.0008231136077286035,
#              ('through', 'O'): 0.00037906547724343584,
#              ('SLAM', 'B'): 7.532389273877674e-05,
#              ('also', 'O'): 0.0014404488135250561,
#              ('other', 'O'): 0.0010144514200514808,
#              ('surface', 'O'): 0.00018050737011592182,
#              ('molecules', 'O'): 0.0001083044220695531,
#              ('utilize', 'O'): 7.220294804636873e-06,
#              ('SAP', 'B'): 0.00022597167821633023,
#              ('adaptor', 'O'): 4.693191623013968e-05,
#              ('protein', 'O'): 0.0020794449037354196,
#              ('randomized', 'O'): 7.942324285100561e-05,
#              ('prospective', 'O'): 5.054206363245811e-05,
#              ('conducted', 'O'): 6.498265324173186e-05,
#              ('compare', 'O'): 5.415221103477655e-05,
#              ('ovarian', 'O'): 6.85928006440503e-05,
#              ('stimulation', 'O'): 0.0002743712025762012,
#              ('human', 'B'): 0.017023199758963544,
#              ('menopausal', 'I'): 5.077173030056864e-05,
#              ('gonadotropin', 'I'): 0.0002538586515028432,
#              ('hMG', 'B'): 0.00015064778547755348,
#              ('follicle', 'I'): 5.077173030056864e-05,
#              ('stimulating', 'I'): 0.0008631194151096669,
#              ('hormone', 'I'): 0.002284727863525589,
#              ('hFSH', 'B'): 7.532389273877674e-05,
#              ('vitro', 'O'): 0.0006498265324173186,
#              ('fertilization', 'O'): 1.4440589609273747e-05,
#              ('embryo', 'O'): 7.581309544868718e-05,
#              ('transfer', 'O'): 9.025368505796091e-05,
#              ('IVF', 'O'): 1.083044220695531e-05,
#              ('ET', 'O'): 1.083044220695531e-05,
#              ('program', 'O'): 6.137250583941343e-05,
#              ('Tl', 'O'): 1.8050737011592182e-05,
#              ('201', 'O'): 5.054206363245811e-05,
#              ('uptake', 'O'): 0.00012274501167882686,
#              ('ratio', 'O'): 0.0002527103181622906,
#              ('ventricle', 'O'): 3.6101474023184365e-05,
#              ('which', 'O'): 0.0024512900861742184,
#              ('represents', 'O'): 0.0001083044220695531,
#              ('counts', 'O'): 7.220294804636873e-05,
#              ('administered', 'O'): 0.00019855810712751402,
#              ('higher', 'O'): 0.0005054206363245812,
#              ('COPD', 'O'): 2.166088441391062e-05,
#              ('especially', 'O'): 9.747397986259779e-05,
#              ('pulmonary', 'O'): 0.00015523633829969279,
#              ('emphysema', 'O'): 1.083044220695531e-05,
#              ('B', 'O'): 0.0006353859428080449,
#              ('Burrows', 'O'): 3.6101474023184367e-06,
#              ('classification', 'O'): 2.8881179218547494e-05,
#              ('controls', 'O'): 0.0002491001707599721,
#              ('yeast', 'B'): 0.002335040674902079,
#              ('SSS1', 'I'): 5.077173030056864e-05,
#              ('gene', 'I'): 0.03599715678310317,
#              ('essential', 'O'): 0.0003682350350364805,
#              ('secretory', 'O'): 3.9711621425502805e-05,
#              ('translocation', 'O'): 8.664353765564248e-05,
#              ('encodes', 'O'): 0.00040072636165734644,
#              ('conserved', 'O'): 0.0005090307837268996,
#              ('endoplasmic', 'O'): 3.9711621425502805e-05,
#              ('reticulum', 'O'): 4.693191623013968e-05,
#              ('some', 'O'): 0.00029964223439243024,
#              ('instances', 'O'): 1.4440589609273747e-05,
#              ('partly', 'O'): 2.8881179218547494e-05,
#              ('mediated', 'O'): 0.0004620988674967599,
#              ('virally', 'O'): 7.220294804636873e-06,
#              ('encoded', 'O'): 0.00031047267659938557,
#              ('proteases', 'O'): 1.8050737011592182e-05,
#              ('lead', 'O'): 8.664353765564248e-05,
#              ('cleavage', 'O'): 0.0001263551590811453,
#              ('initiation', 'B'): 7.532389273877674e-05,
#              ('factor', 'I'): 0.013606823720552396,
#              ('eIF4G', 'I'): 5.077173030056864e-05,
#              ('Structural', 'O'): 3.249132662086593e-05,
#              ('characteristics', 'O'): 0.00012274501167882686,
#              ('erythrocyte', 'O'): 3.249132662086593e-05,
#              ('membrane', 'O'): 0.000314082824001704,
#              ('peroxidation', 'O'): 1.8050737011592182e-05,
#              ('processes', 'O'): 8.303339025332404e-05,
#              ('antioxidant', 'O'): 2.166088441391062e-05,
#              ('children', 'O'): 0.0002888117921854749,
#              ('diffuse', 'O'): 2.166088441391062e-05,
#              ('glomerulonephritis', 'O'): 1.083044220695531e-05,
#              ('RPA190', 'B'): 7.532389273877674e-05,
#              ('polypeptide', 'O'): 0.00011552471687418997,
#              ('chain', 'O'): 0.00018050737011592182,
#              ('186', 'O'): 1.4440589609273747e-05,
#              ('270', 'O'): 1.8050737011592182e-05,
#              ('daltons', 'O'): 7.220294804636873e-06,
#              ('large', 'O'): 0.0002527103181622906,
#              ('uninterrupted', 'O'): 3.6101474023184367e-06,
#              ('reading', 'O'): 0.0002888117921854749,
#              ('frame', 'O'): 0.00023465958115069838,
#              ('paper', 'O'): 7.220294804636873e-05,
#              ('reviews', 'O'): 1.083044220695531e-05,
#              ('middleware', 'O'): 3.6101474023184367e-06,
#              ('based', 'O'): 0.00028159149738083805,
#              ('approach', 'O'): 9.747397986259779e-05,
#              ('adopted', 'O'): 1.8050737011592182e-05,
#              ('CEN', 'O'): 1.083044220695531e-05,
#              ('ENV', 'O'): 7.220294804636873e-06,
#              ('12967', 'O'): 3.6101474023184367e-06,
#              ('specialisation', 'O'): 3.6101474023184367e-06,
#              ('necessary', 'O'): 0.00018772766492055872,
#              ('healthcare', 'O'): 3.6101474023184367e-06,
#              ('record', 'O'): 1.8050737011592182e-05,
#              ('on', 'O'): 0.003263573251695867,
#              ('12265', 'O'): 3.6101474023184367e-06,
#              ("'", 'O'): 0.0016353967732502517,
#              ('Electronic', 'O'): 1.4440589609273747e-05,
#              ('Healthcare', 'O'): 3.6101474023184367e-06,
#              ('Record', 'O'): 3.6101474023184367e-06,
#              ('Architecture', 'O'): 3.6101474023184367e-06,
#              ("'.", 'O'): 1.8050737011592182e-05,
#              ('upstream', 'O'): 0.000512640931129218,
#              ('rhlA', 'B'): 7.532389273877674e-05,
#              ('promoter', 'I'): 0.013149878147847278,
#              ('contains', 'O'): 0.0005343018155431286,
#              ('inverted', 'O'): 4.693191623013968e-05,
#              ('repeats', 'O'): 0.0001263551590811453,
#              ('define', 'O'): 9.025368505796091e-05,
#              ('putative', 'O'): 0.00035018429802488837,
#              ('sites', 'O'): 0.0006642671220265924,
#              ('RhlR', 'B'): 7.532389273877674e-05,
#              ('regulator', 'I'): 0.0003554021121039805,
#              ('Ongoing', 'O'): 3.6101474023184367e-06,
#              ('future', 'O'): 5.054206363245811e-05,
#              ('investigations', 'O'): 3.249132662086593e-05,
#              ('better', 'O'): 0.00010469427466723466,
#              ('optimal', 'O'): 5.776235843709499e-05,
#              ('local', 'O'): 0.00010469427466723466,
#              ('duration', 'O'): 8.303339025332404e-05,
#              ('maintenance', 'O'): 6.85928006440503e-05,
#              ('chemotherapy', 'O'): 0.00012274501167882686,
#              ('possible', 'O'): 0.0002852016447831565,
#              ('role', 'O'): 0.0006642671220265924,
#              ('biologic', 'O'): 1.4440589609273747e-05,
#              ('modifiers', 'O'): 3.6101474023184367e-06,
#              ('factors', 'O'): 0.0006498265324173186,
#              ('improving', 'O'): 1.083044220695531e-05,
#              ('outcome', 'O'): 5.415221103477655e-05,
#              ('cloned', 'O'): 0.0003249132662086593,
#              ('alcR', 'B'): 0.00015064778547755348,
#              ('provided', 'O'): 0.00010469427466723466,
#              ('trans', 'O'): 0.00015884648570201122,
#              ('restored', 'O'): 5.776235843709499e-05,
#              ('siderophore', 'O'): 7.220294804636873e-06,
#              ('mutants', 'O'): 0.00023465958115069838,
#              ('Although', 'O'): 0.00022382913894374308,
#              ('4E', 'B'): 0.00015064778547755348,
#              ('BP1', 'I'): 0.00020308692120227456,
#              ('alone', 'O'): 0.00017328707531128496,
#              ('has', 'O'): 0.0014007371920995535,
#              ('yet', 'O'): 8.303339025332404e-05,
#              ('been', 'O'): 0.0012743820330184082,
#              ('accomplished', 'O'): 3.6101474023184367e-06,
#              ('gene', 'O'): 0.001660667805066481,
#              ('Escherichia', 'O'): 0.00015162619089737435,
#              ('coli', 'O'): 0.00023465958115069838,
#              ('BL21', 'O'): 7.220294804636873e-06,
#              ('DE3', 'O'): 7.220294804636873e-06,
#              (')]', 'O'): 2.5271031816229057e-05,
#              ('fusion', 'O'): 0.0002743712025762012,
#              ('glutathione', 'B'): 0.0012051822838204278,
#              ('S', 'I'): 0.001980097481722177,
#              ('transferase', 'I'): 0.0011169780666125102,
#              ('GST', 'B'): 0.0013558300692979813,
#              ('prokaryotic', 'O'): 1.8050737011592182e-05,
#              ('vector', 'O'): 0.00014440589609273746,
#              ('pGEX', 'O'): 1.083044220695531e-05,
#              ('4T', 'O'): 3.6101474023184367e-06,
#              ('coding', 'O'): 0.0002888117921854749,
#              ('site', 'O'): 0.0010469427466723467,
#              ('specific', 'O'): 0.001198568937569721,
#              ('protease', 'O'): 2.8881179218547494e-05,
#              ('alpha', 'B'): 0.0061765592045796925,
#              ('thrombin', 'I'): 5.077173030056864e-05,
#              ('An', 'O'): 0.0002924219395877934,
#              ('explanation', 'O'): 1.4440589609273747e-05,
#              ('explored', 'O'): 1.4440589609273747e-05,
#              ('lack', 'O'): 9.386383246027936e-05,
#              ('RAR', 'B'): 0.0009792106056040976,
#              ('alpha', 'I'): 0.011068237205523964,
#              ('PML', 'B'): 0.00022597167821633023,
#              ('might', 'O'): 0.00010108412726491623,
#              ('suppress', 'O'): 3.9711621425502805e-05,
#              ('APL', 'O'): 3.6101474023184367e-06,
#              ('holoenzyme', 'B'): 7.532389273877674e-05,
#              ('RNA', 'I'): 0.003147847278635256,
#              ('polymerases', 'I'): 0.00040617384240454913,
#              ('generated', 'O'): 0.00015884648570201122,
#              ('upon', 'O'): 0.0001480160434950559,
#              ('reconstituting', 'O'): 1.083044220695531e-05,
#              ('independently', 'O'): 7.581309544868718e-05,
#              ('core', 'B'): 0.0006025911419102139,
#              ('polymerase', 'I'): 0.003249390739236393,
#              ('alpha2beta', 'O'): 3.6101474023184367e-06,
#              ('beta', 'O'): 0.0003321335610132962,
#              ("')", 'O'): 1.8050737011592182e-05,
#              ('have', 'O'): 0.0017689722271360339,
#              ('shown', 'O'): 0.0005018104889222627,
#              ('reduced', 'O'): 0.0004729293097037152,
#              ('transcriptional', 'O'): 0.000685928006440503,
#              ('comparison', 'O'): 0.00022382913894374308,
#              ('wild', 'B'): 0.0027116601385959627,
#              ('type', 'I'): 0.004417140536149472,
#              ('sigma', 'I'): 0.0003046303818034119,
#              ('PAI', 'B'): 0.00045194335643266047,
#              ('2', 'I'): 0.015282290820471162,
#              ('one', 'O'): 0.0010361123044653913,
#              ('most', 'O'): 0.0003826756246457543,
#              ('TNF', 'B'): 0.002259716782163302,
#              ('responsive', 'I'): 0.000710804224207961,
#              ('genes', 'I'): 0.007717303005686434,
#              ('highly', 'O'): 0.00037545532984111743,
#              ('phorbol', 'O'): 0.00010469427466723466,
#              ('ester', 'O'): 4.693191623013968e-05,
#              ('myristate', 'O'): 2.8881179218547494e-05,
#              ('acetate', 'O'): 9.386383246027936e-05,
#              ('PMA', 'O'): 4.693191623013968e-05,
#              ('phosphatase', 'O'): 2.5271031816229057e-05,
#              ('inhibitor', 'O'): 0.0002454900233576537,
#              ('okadaic', 'O'): 1.4440589609273747e-05,
#              ('both', 'O'): 0.0016101257414340227,
#              ('HT', 'O'): 3.6101474023184365e-05,
#              ('1080', 'O'): 3.6101474023184367e-06,
#              ('fibrosarcoma', 'O'): 7.220294804636873e-06,
#              ('U', 'O'): 0.00011913486427650841,
#              ('937', 'O'): 3.6101474023184367e-06,
#              ('histiocytic', 'O'): 1.083044220695531e-05,
#              ('cells', 'O'): 0.002581255392657682,
#              ('Precipitating', 'O'): 3.6101474023184367e-06,
#              ('antibodies', 'O'): 0.0001480160434950559,
#              ('Thermophilic', 'O'): 3.6101474023184367e-06,
#              ('actinomycetes', 'O'): 3.6101474023184367e-06,
#              ('M', 'O'): 0.00022382913894374308,
#              ('f', 'O'): 1.4440589609273747e-05,
#              ('negative', 'O'): 0.00037906547724343584,
#              ('RESULTS', 'O'): 0.00018772766492055872,
#              ('cardiac', 'O'): 0.00020938854933446932,
#              ('index', 'O'): 0.0001263551590811453,
#              ('changed', 'O'): 5.054206363245811e-05,
#              ('varying', 'O'): 3.249132662086593e-05,
#              ('PaCO2', 'O'): 2.5271031816229057e-05,
#              ('hypocapnia', 'O'): 7.220294804636873e-06,
#              ('9', 'O'): 0.0006462163850150002,
#              ('%;', 'O'): 6.137250583941343e-05,
#              ('hypercapnia', 'O'): 1.083044220695531e-05,
#              ('%).', 'O'): 0.00011552471687418997,
#              ('sulfhydryl', 'O'): 7.220294804636873e-06,
#              ('group', 'O'): 0.0008844861135680169,
#              ('certain', 'O'): 9.386383246027936e-05,
#              ('angiotensin', 'B'): 0.0006779150346489907,
#              ('converting', 'I'): 0.0003046303818034119,
#              ('enzyme', 'I'): 0.0011677497969130788,
#              ('potentiate', 'O'): 1.4440589609273747e-05,
#              ('endogenous', 'O'): 0.00013357545388578216,
#              ('nitrovasodilator', 'O'): 3.6101474023184367e-06,
#              ('EDRF', 'B'): 7.532389273877674e-05,
#              ('PC12', 'O'): 2.8881179218547494e-05,
#              ('mutant', 'O'): 0.0003935060668527096,
#              ('protein', 'B'): 0.005046700813498042,
#              ('A', 'I'): 0.005483346872461413,
#              ('AB', 'O'): 7.220294804636873e-06,
#              ('11', 'O'): 0.0003682350350364805,
#              ('all', 'O'): 0.0007834019863031008,
#              ('differentiating', 'O'): 1.8050737011592182e-05,
#              ('agents', 'O'): 0.00018411751751824026,
#              ('unable', 'O'): 5.776235843709499e-05,
#              ('down', 'O'): 9.386383246027936e-05,
#              ('regulate', 'O'): 0.0001371856012881006,
#              ('nrg', 'B'): 7.532389273877674e-05,
#              ('1', 'I'): 0.03574329813160033,
#              ('mRNA', 'I'): 0.005686433793663688,
#              ('Anamnestic', 'O'): 3.6101474023184367e-06,
#              ('data', 'O'): 0.0006317757954057264,
#              ('obtained', 'O'): 0.00039711621425502804,
#              ('case', 'O'): 0.0002166088441391062,
#              ('history', 'O'): 0.00010469427466723466,
#              ('smoking', 'O'): 5.776235843709499e-05,
#              ('habits', 'O'): 7.220294804636873e-06,
#              ('collective', 'O'): 3.6101474023184367e-06,
#              ('evident', 'O'): 5.776235843709499e-05,
#              ('inciting', 'O'): 3.6101474023184367e-06,
#              ('agent', 'O'): 0.00012274501167882686,
#              ('Here', 'O'): 0.00022382913894374308,
#              ('we', 'O'): 0.0013826864550879612,
#              ('demonstrate', 'O'): 0.00031047267659938557,
#              ('Hh', 'B'): 7.532389273877674e-05,
#              ('Patched', 'B'): 7.532389273877674e-05,
#              ('Ptc', 'B'): 7.532389273877674e-05,
#              ('act', 'O'): 7.942324285100561e-05,
#              ('those', 'O'): 0.00046931916230139677,
#              ('Ci', 'B'): 0.00015064778547755348,
#              ('modulate', 'O'): 5.415221103477655e-05,
#              ('level', 'O'): 0.0006137250583941342,
#              ('dependent', 'O'): 0.000768961396693827,
#              ('activation', 'O'): 0.0011877384953627656,
#              ('S2', 'O'): 1.4440589609273747e-05,
#              ('coexpression', 'O'): 2.166088441391062e-05,
#              ('constructs', 'O'): 0.00014440589609273746,
#              ('DBP', 'B'): 0.00030129557095510696,
#              ('hepatic', 'B'): 0.00015064778547755348,
#              ('leukemia', 'I'): 0.0002538586515028432,
#              ('resulted', 'O'): 0.0002960320869901118,
#              ('dramatic', 'O'): 3.249132662086593e-05,
#              ('GAL4', 'B'): 0.0009038867128653209,
#              ('suggesting', 'O'): 0.00037906547724343584,
#              ('involvement', 'O'): 9.025368505796091e-05,
#              ('regulated', 'O'): 0.00037545532984111743,
#              ('coactivator', 'O'): 2.166088441391062e-05,
#              ('process', 'O'): 0.00012996530648346372,
#              ('Cox', 'O'): 1.4440589609273747e-05,
#              ('proportional', 'O'): 7.220294804636873e-06,
#              ('hazards', 'O'): 3.6101474023184367e-06,
#              ('model', 'O'): 0.00033935385581793304,
#              ('applied', 'O'): 4.693191623013968e-05,
#              ('order', 'O'): 0.00019855810712751402,
#              ('determine', 'O'): 0.0002454900233576537,
#              ('prognostic', 'O'): 1.8050737011592182e-05,
#              ('long', 'O'): 0.0003429640032202515,
#              ('term', 'O'): 0.00019494795972519558,
#              ('REM', 'O'): 1.083044220695531e-05,
#              ('sleep', 'O'): 3.9711621425502805e-05,
#              ('deprivation', 'O'): 2.166088441391062e-05,
#              ('platform', 'O'): 3.6101474023184367e-06,
#              ('technique', 'O'): 0.00020216825452983245,
#              ('How', 'O'): 1.4440589609273747e-05,
#              ('does', 'O'): 0.00026354076036924585,
#              ('nurse', 'O'): 2.166088441391062e-05,
#              ('go', 'O'): 3.6101474023184367e-06,
#              ('maintaining', 'O'): 4.332176882782124e-05,
#              ('her', 'O'): 1.4440589609273747e-05,
#              ('competence', 'O'): 1.083044220695531e-05,
#              ('when', 'O'): 0.0007220294804636873,
#              ('she', 'O'): 1.083044220695531e-05,
#              ('few', 'O'): 5.054206363245811e-05,
#              ('practitioners', 'O'): 3.6101474023184367e-06,
#              ('field', 'O'): 0.00014079574869041902,
#              ('?', 'O'): 7.581309544868718e-05,
#              ('Vancouver', 'O'): 3.6101474023184367e-06,
#              ('sex', 'O'): 8.303339025332404e-05,
#              ('therapist', 'O'): 3.6101474023184367e-06,
#              ('Bianca', 'O'): 3.6101474023184367e-06,
#              ('Rucker', 'O'): 3.6101474023184367e-06,
#              ('doing', 'O'): 3.6101474023184367e-06,
#              ('it', 'O'): 0.000736470070072961,
#              ('cultivating', 'O'): 3.6101474023184367e-06,
#              ('network', 'O'): 1.8050737011592182e-05,
#              ('colleagues', 'O'): 3.6101474023184367e-06,
#              ('mentors', 'O'): 3.6101474023184367e-06,
#              ('related', 'O'): 0.000570403289566313,
#              ('fields', 'O'): 2.5271031816229057e-05,
#              ('home', 'O'): 3.249132662086593e-05,
#              ('across', 'O'): 6.137250583941343e-05,
#              ('continent', 'O'): 3.6101474023184367e-06,
#              ('We', 'O'): 0.001422398076513464,
#              ('present', 'O'): 0.000570403289566313,
#              ('preliminary', 'O'): 2.5271031816229057e-05,
#              ('36', 'O'): 6.85928006440503e-05,
#              ('followed', 'O'): 0.00015523633829969279,
#              ('mean', 'O'): 0.00036101474023184365,
#              ('period', 'O'): 0.0002454900233576537,
#              ('months', 'O'): 0.00022743928634606152,
#              ('Biologically', 'O'): 3.6101474023184367e-06,
#              ('significant', 'O'): 0.0007148091856590505,
#              ('amounts', 'O'): 4.693191623013968e-05,
#              ('platelet', 'B'): 0.0005272672491714372,
#              ('activating', 'I'): 0.0011677497969130788,
#              ('eluted', 'O'): 1.083044220695531e-05,
#              ('sorbent', 'O'): 3.6101474023184367e-06,
#              ('during', 'O'): 0.0010866543680978493,
#              ('entire', 'O'): 0.00011191456947187154,
#              ('treatment', 'O'): 0.000942248472005112,
#              ('time', 'O'): 0.0005198612259338549,
#              ('287', 'O'): 7.220294804636873e-06,
#              ('advanced', 'O'): 6.85928006440503e-05,
#              ('non', 'O'): 0.00045126842528980457,
#              ('small', 'O'): 0.0002924219395877934,
#              ('lung', 'O'): 0.00023826972855301682,
#              ('cancer', 'O'): 0.0002743712025762012,
#              ('NSCLC', 'O'): 3.6101474023184367e-06,
#              ('stage', 'O'): 0.00019494795972519558,
#              ('IIIb', 'O'): 7.220294804636873e-06,
#              ('ECOG', 'O'): 3.6101474023184367e-06,
#              ('performance', 'O'): 0.00015162619089737435,
#              ('status', 'O'): 0.00014440589609273746,
#              ('PS', 'O'): 2.166088441391062e-05,
#              ('randomly', 'O'): 3.6101474023184365e-05,
#              ('assigned', 'O'): 2.5271031816229057e-05,
#              ('receive', 'O'): 2.8881179218547494e-05,
#              ('either', 'O'): 0.0004657090148990783,
#              ('best', 'O'): 6.137250583941343e-05,
#              ('supportive', 'O'): 1.4440589609273747e-05,
#              ('care', 'O'): 0.00010469427466723466,
#              ('BSC', 'O'): 3.6101474023184367e-06,
#              ('plus', 'O'): 0.00012274501167882686,
#              ('combination', 'O'): 0.0002454900233576537,
#              ('IEP', 'O'): 3.6101474023184367e-06,
#              ('regimen', 'O'): 8.664353765564248e-05,
#              ('ifosfamide', 'O'): 7.220294804636873e-06,
#              ('3', 'O'): 0.0022635624212536598,
#              ('gm', 'O'): 1.4440589609273747e-05,
#              ('m2', 'O'): 0.00015162619089737435,
#              ('mesna', 'O'): 3.6101474023184367e-06,
#              ('uroprotection', 'O'): 3.6101474023184367e-06,
#              ('epirubicin', 'O'): 3.6101474023184367e-06,
#              ('60', 'O'): 0.0002527103181622906,
#              ('mg', 'O'): 0.0009061469979819276,
#              ('cisplatin', 'O'): 4.693191623013968e-05,
#              (';', 'O'): 0.0015198720563760618,
#              ('MVP', 'O'): 3.6101474023184367e-06,
#              ('mitomycin', 'O'): 1.4440589609273747e-05,
#              ('8', 'O'): 0.0009278078823958383,
#              ('vinblastine', 'O'): 1.083044220695531e-05,
#              ('4', 'O'): 0.0012888226226276818,
#              ('15', 'O'): 0.00040072636165734644,
#              ('Sulphur', 'O'): 3.6101474023184367e-06,
#              ('amino', 'O'): 0.0011263659895233522,
#              ('acids', 'O'): 0.0004404379830828493,
#              ('g', 'O'): 0.00036101474023184365,
#              ('16', 'O'): 0.0003321335610132962,
#              ('isolates', 'O'): 6.85928006440503e-05,
#              ('flours', 'O'): 3.6101474023184367e-06,
#              ('Bacteriologic', 'O'): 3.6101474023184367e-06,
#              ('culture', 'O'): 6.85928006440503e-05,
#              ('pancreatic', 'O'): 7.942324285100561e-05,
#              ('tissue', 'O'): 0.00041155680386430177,
#              ('positive', 'O'): 0.0003935060668527096,
#              ('IB', 'O'): 3.6101474023184367e-06,
#              ('17', 'O'): 0.0002960320869901118,
#              ('NIB', 'O'): 3.6101474023184367e-06,
#              ('p', 'O'): 0.0006967584486474583,
#              ('01', 'O'): 0.00023465958115069838,
#              ('demonstrated', 'O'): 0.00041155680386430177,
#              ('reproductive', 'O'): 3.249132662086593e-05,
#              ('neuropeptide', 'O'): 3.6101474023184367e-06,
#              ('GnRH', 'B'): 0.0008285628201265442,
#              ('repressed', 'O'): 6.498265324173186e-05,
#              ('glutamate', 'O'): 1.083044220695531e-05,
#              ('NO', 'O'): 5.054206363245811e-05,
#              ('cyclic', 'O'): 6.137250583941343e-05,
#              ('GMP', 'O'): 1.083044220695531e-05,
#              ('cGMP', 'O'): 7.220294804636873e-06,
#              ('signal', 'O'): 0.00033574370841561464,
#              ('transduction', 'O'): 0.00011552471687418997,
#              ('pathway', 'O'): 0.0003682350350364805,
#              ('cGMP', 'B'): 0.00015064778547755348,
#              ('dependent', 'I'): 0.0026401299756295695,
#              ('hypothalamic', 'O'): 1.083044220695531e-05,
#              ('secreting', 'O'): 2.166088441391062e-05,
#              ('neuronal', 'O'): 8.303339025332404e-05,
#              ('line', 'O'): 0.0003285234136109777,
#              ('GT1', 'O'): 3.6101474023184367e-06,
#              ('Total', 'O'): 3.6101474023184365e-05,
#              ('cholesterol', 'O'): 9.025368505796091e-05,
#              ('20', 'O'): 0.00048736989931298896,
#              ('30', 'O'): 0.00043682783568053084,
#              ('52', 'O'): 6.85928006440503e-05,
#              ('(<', 'O'): 2.166088441391062e-05,
#              ('(>', 'O'): 2.166088441391062e-05,
#              ('Again', 'O'): 3.6101474023184367e-06,
#              ('residue', 'O'): 0.00018772766492055872,
#              ('Glu', 'O'): 1.4440589609273747e-05,
#              ('381', 'O'): 3.6101474023184367e-06,
#              ('notably', 'O'): 7.220294804636873e-06,
#              ('missing', 'O'): 3.249132662086593e-05,
#              ('epsilon', 'O'): 1.8050737011592182e-05,
#              ('peptide', 'O'): 0.00019133781232287715,
#              ('could', 'O'): 0.00043682783568053084,
#              ('identified', 'O'): 0.0008303339025332405,
#              ('choices', 'O'): 3.6101474023184367e-06,
#              ('Ser', 'O'): 0.00012274501167882686,
#              ('106', 'O'): 7.220294804636873e-06,
#              ('107', 'O'): 1.083044220695531e-05,
#              ('108', 'O'): 3.6101474023184367e-06,
#              ('4024', 'O'): 3.6101474023184367e-06,
#              ('base', 'O'): 0.0002852016447831565,
#              ('pair', 'O'): 0.00015884648570201122,
#              ('bp', 'O'): 0.0006570468272219554,
#              ('segment', 'O'): 0.00017328707531128496,
#              ('extends', 'O'): 1.083044220695531e-05,
#              ('149', 'O'): 1.083044220695531e-05,
#              ('cap', 'O'): 3.249132662086593e-05,
#              ('207', 'O'): 1.083044220695531e-05,
#              ('psi', 'B'): 0.00022597167821633023,
#              ('Self', 'O'): 1.083044220695531e-05,
#              ('emasculation', 'O'): 3.6101474023184367e-06,
#              ('end', 'O'): 0.0004259973934735755,
#              ('unusual', 'O'): 4.693191623013968e-05,
#              ('psychiatric', 'O'): 2.166088441391062e-05,
#              ('disorder', 'O'): 8.303339025332404e-05,
#              ('initially', 'O'): 6.498265324173186e-05,
#              ('requires', 'O'): 0.0001371856012881006,
#              ('surgical', 'O'): 8.303339025332404e-05,
#              ('Doxorubicin', 'O'): 3.6101474023184367e-06,
#              ('dacarbazine', 'O'): 3.6101474023184367e-06,
#              ('vincristine', 'O'): 1.4440589609273747e-05,
#              ('cyclophosphamide', 'O'): 5.054206363245811e-05,
#              ('gastrointestinal', 'O'): 3.9711621425502805e-05,
#              ('leiomyosarcoma', 'O'): 3.6101474023184367e-06,
#              ('inflation', 'O'): 7.220294804636873e-06,
#              ('hub', 'O'): 3.6101474023184367e-06,
#              ('probe', 'O'): 0.0001263551590811453,
#              ('recreated', 'O'): 3.6101474023184367e-06,
#              ('modifying', 'O'): 1.083044220695531e-05,
#              ('USCI', 'O'): 3.6101474023184367e-06,
#              ('Tuohy', 'O'): 3.6101474023184367e-06,
#              ('Borst', 'O'): 3.6101474023184367e-06,
#              ('Y', 'O'): 9.386383246027936e-05,
#              ('attaching', 'O'): 3.6101474023184367e-06,
#              ('transected', 'O'): 3.6101474023184367e-06,
#              ('hypotube', 'O'): 3.6101474023184367e-06,
#              ('indoramin', 'O'): 7.220294804636873e-06,
#              ('Class', 'O'): 5.054206363245811e-05,
#              ('antiarrhythmic', 'O'): 2.5271031816229057e-05,
#              ('desipramine', 'O'): 1.083044220695531e-05,
#              ('probably', 'O'): 8.303339025332404e-05,
#              ('inhibition', 'O'): 0.0002924219395877934,
#              ('amitriptyline', 'O'): 1.083044220695531e-05,
#              ('mianserin', 'O'): 3.6101474023184367e-06,
#              ('blockade', 'O'): 5.054206363245811e-05,
#              ('prejunctional', 'O'): 3.6101474023184367e-06,
#              ('adrenoreceptors', 'I'): 5.077173030056864e-05,
#              ('Data', 'O'): 1.8050737011592182e-05,
#              ('spread', 'O'): 5.415221103477655e-05,
#              ('LSF', 'O'): 3.6101474023184367e-06,
#              ('image', 'O'): 4.332176882782124e-05,
#              ('mm', 'O'): 0.00014440589609273746,
#              ('wide', 'O'): 4.693191623013968e-05,
#              ('slit', 'O'): 3.6101474023184367e-06,
#              ('between', 'O'): 0.0013826864550879612,
#              ('tungsten', 'O'): 3.6101474023184367e-06,
#              ('blocks', 'O'): 8.303339025332404e-05,
#              ('positioned', 'O'): 2.8881179218547494e-05,
#              ('isocentre', 'O'): 3.6101474023184367e-06,
#              ('front', 'O'): 1.8050737011592182e-05,
#              ('polystyrene', 'O'): 1.4440589609273747e-05,
#              ('phantom', 'O'): 7.220294804636873e-06,
#              ('Using', 'O'): 0.00018050737011592182,
#              ('series', 'O'): 0.00014440589609273746,
#              ('mutant', 'B'): 0.0013558300692979813,
#              ('T', 'I'): 0.0009138911454102356,
#              ('antigens', 'I'): 0.0002538586515028432,
#              ('recombinant', 'O'): 0.00017328707531128496,
#              ('baculoviruses', 'O'): 1.4440589609273747e-05,
#              ('Sf9', 'O'): 1.8050737011592182e-05,
#              ('find', 'O'): 3.249132662086593e-05,
#              ('origin', 'O'): 0.00013357545388578216,
#              ('unwinding', 'O'): 7.220294804636873e-06,
#              ('TS677', 'O'): 7.220294804636873e-06,
#              ('-->', 'O'): 3.9711621425502805e-05,
#              ('679', 'O'): 3.6101474023184367e-06,
#              ('inhibited', 'O'): 0.00021299869673678775,
#              ('T', 'B'): 0.002259716782163302,
#              ('antigen', 'I'): 0.002132412672623883,
#              ('Thus', 'O'): 0.0002707610551738828,
#              ('presence', 'O'): 0.00047653945710603363,
#              ('active', 'B'): 0.00022597167821633023,
#              ('CDKs', 'I'): 0.00010154346060113728,
#              ('Dbf4', 'B'): 7.532389273877674e-05,
#              ('Cdc7', 'B'): 7.532389273877674e-05,
#              ...})

# %% [markdown]
# ### Approch for RARE Words
# For each word that has a frequency of less than 5 i.e. the word occurs less than 5 times, the word is replaced with *_RARE_* . Thus, any word that is not in the vocabulary, the zero frequencies for new word appearing in the Test dataset is almost acocunted for.

# %%
def get_rare_word_counts(d):
  max_e = 0.0
  max_label = ""
  if (RARE_KEYWORD,'I') in d:
    if d[(RARE_KEYWORD, 'I')] > max_e:
      max_e = d[(RARE_KEYWORD,'I')]
      max_label = 'I'
  if (RARE_KEYWORD,'B') in d:
    if d[(RARE_KEYWORD, 'B')] > max_e:
      max_e = d[(RARE_KEYWORD,'B')]
      max_label = 'B'
  if (RARE_KEYWORD,'O') in d:
    if d[(RARE_KEYWORD, 'O')] > max_e:
      max_e = d[(RARE_KEYWORD,'O')]
      max_label = 'O'
  return max_e, max_label

# %%
import math
preds_new = []
full_preds = []
max_e_rare, max_label_rare = get_rare_word_counts(d)
for sent in test:
  this_sent = []
  counter = 1
  for wt in sent:

    w,_ = wt
    max_e = 0.0
    max_label = ""
    if (w,'I') in d:
      if d[(w, 'I')] > max_e:
        max_e = d[(w,'I')]
        max_label = 'I'
    if (w,'B') in d:
      if d[(w, 'B')] > max_e:
        max_e = d[(w,'B')]
        max_label = 'B'
    if (w,'O') in d:
      if d[(w, 'O')] > max_e:
        max_e = d[(w,'O')]
        max_label = 'O'

    if max_e == 0.0 and max_label == "":
      max_e = max_e_rare
      max_label = max_label_rare
    
    #print(max_e, max_e_rare, w, d)
    full_preds.append((w, max_label, math.log(max_e, 2)))
    this_sent.append('\t'.join([str(counter), w, max_label])+'\n' )
    counter += 1
  preds_new.append(this_sent)

# %%
full_preds[:5], preds_new[:10]
# Out:
# ([('The', 'O', -7.080920396025297),
#   ('main', 'O', -13.83158331232704),
#   ('aim', 'O', -14.379071107629533),
#   ('of', 'O', -4.555213988108001),
#   ('the', 'O', -4.476927937684343)],
#  [['1\tThe\tO\n',
#    '2\tmain\tO\n',
#    '3\taim\tO\n',
#    '4\tof\tO\n',
#    '5\tthe\tO\n',
#    '6\tcontribution\tO\n',
#    '7\t,\tO\n',
#    '8\twhich\tO\n',
#    '9\topens\tO\n',
#    '10\tan\tO\n',
#    '11\tarena\tO\n',
#    '12\tfor\tO\n',
#    '13\tdiscussion\tO\n',
#    '14\ton\tO\n',
#    '15\tthe\tO\n',
#    '16\tRivista\tO\n',
#    '17\tdell\tO\n',
#    "18\t'\tO\n",
#    '19\tInfermiere\tO\n',
#    '20\tis\tO\n',
#    '21\tto\tO\n',
#    '22\tcritically\tO\n',
#    '23\tappraise\tO\n',
#    '24\tpublished\tO\n',
#    '25\tresearch\tO\n',
#    '26\tworks\tO\n',
#    '27\tfocusing\tO\n',
#    '28\tboth\tO\n',
#    '29\ton\tO\n',
#    '30\tstrengths\tO\n',
#    '31\tand\tO\n',
#    '32\tnovelty\tO\n',
#    '33\tand\tO\n',
#    '34\tweaknesses\tO\n',
#    '35\tin\tO\n',
#    '36\tthe\tO\n',
#    '37\thypothesis\tO\n',
#    '38\tformulation\tO\n',
#    '39\t,\tO\n',
#    '40\tmethods\tO\n',
#    '41\tand\tO\n',
#    '42\tinstruments\tO\n',
#    '43\tused\tO\n',
#    '44\t,\tO\n',
#    '45\tdiscussion\tO\n',
#    '46\tof\tO\n',
#    '47\tresults\tO\n',
#    '48\t.\tO\n'],
#   ['1\tExamination\tO\n',
#    '2\tof\tO\n',
#    '3\tDNA\tI\n',
#    '4\t:\tO\n',
#    '5\tprotein\tI\n',
#    '6\tbinding\tI\n',
#    '7\tcomplexes\tI\n',
#    '8\tby\tO\n',
#    '9\tgel\tO\n',
#    '10\t-\tI\n',
#    '11\tshift\tO\n',
#    '12\tanalysis\tO\n',
#    '13\tindicated\tO\n',
#    '14\tthat\tO\n',
#    '15\tnuclear\tB\n',
#    '16\tfactors\tI\n',
#    '17\tfrom\tO\n',
#    '18\tboth\tO\n',
#    '19\tproliferative\tO\n',
#    '20\tand\tO\n',
#    '21\tgrowth\tI\n',
#    '22\t-\tI\n',
#    '23\tarrested\tO\n',
#    '24\tcells\tO\n',
#    '25\tbound\tO\n',
#    '26\tto\tO\n',
#    '27\tthe\tO\n',
#    '28\tDNA\tI\n',
#    '29\tfragment\tI\n',
#    '30\tspanning\tO\n',
#    '31\t-\tI\n',
#    '32\t949\tO\n',
#    '33\t-\tI\n',
#    '34\t-\tI\n',
#    '35\t722\tO\n',
#    '36\tbp\tO\n',
#    '37\t.\tO\n'],
#   ['1\tDemonstration\tO\n',
#    '2\tof\tO\n',
#    '3\tfine\tO\n',
#    '4\tstructure\tO\n',
#    '5\tof\tO\n',
#    '6\tthe\tO\n',
#    '7\tguinea\tB\n',
#    '8\tpig\tI\n',
#    '9\torgan\tO\n',
#    '10\tof\tO\n',
#    '11\tCorti\tO\n',
#    '12\tafter\tO\n',
#    '13\telectron\tO\n',
#    '14\tmicroscopic\tO\n',
#    '15\tsilver\tO\n',
#    '16\tstaining\tO\n'],
#   ['1\tEukaryotic\tB\n',
#    '2\ttranslation\tO\n',
#    '3\tinitiation\tI\n',
#    '4\tfactor\tI\n',
#    '5\t4GI\tO\n',
#    '6\tis\tO\n',
#    '7\ta\tO\n',
#    '8\tcellular\tB\n',
#    '9\ttarget\tO\n',
#    '10\tfor\tO\n',
#    '11\tNS1\tB\n',
#    '12\tprotein\tI\n',
#    '13\t,\tO\n',
#    '14\ta\tO\n',
#    '15\ttranslational\tO\n',
#    '16\tactivator\tI\n',
#    '17\tof\tO\n',
#    '18\tinfluenza\tI\n',
#    '19\tvirus\tI\n',
#    '20\t.\tO\n'],
#   ['1\tInsert2\tO\n',
#    '2\tcontains\tO\n',
#    '3\trepetitive\tI\n',
#    '4\tnon\tO\n',
#    '5\t-\tI\n',
#    '6\tIg\tB\n',
#    '7\t-\tI\n',
#    '8\trelated\tI\n',
#    '9\tsequences\tI\n',
#    '10\tand\tO\n',
#    '11\ta\tO\n',
#    '12\tsmall\tB\n',
#    '13\tIg\tB\n',
#    '14\t-\tI\n',
#    '15\trelated\tI\n',
#    '16\tsequence\tI\n',
#    '17\t.\tO\n'],
#   ['1\tIn\tO\n',
#    '2\tthe\tO\n',
#    '3\tOct\tB\n',
#    '4\t-\tI\n',
#    '5\t1\tI\n',
#    '6\tcrystal\tO\n',
#    '7\t,\tO\n',
#    '8\tthe\tO\n',
#    '9\tPOU\tB\n',
#    '10\t-\tI\n',
#    '11\tspecific\tI\n',
#    '12\tdomain\tI\n',
#    '13\trecognizes\tO\n',
#    '14\ta\tO\n',
#    '15\tGCAT\tO\n',
#    '16\thalf\tO\n',
#    '17\t-\tI\n',
#    '18\tsite\tI\n',
#    '19\t,\tO\n',
#    '20\twhile\tO\n',
#    '21\tthe\tO\n',
#    '22\tcorresponding\tO\n',
#    '23\tsequence\tI\n',
#    '24\trecognized\tO\n',
#    '25\tby\tO\n',
#    '26\tthe\tO\n',
#    '27\tPit\tB\n',
#    '28\t-\tI\n',
#    '29\t1\tI\n',
#    '30\tPOU\tB\n',
#    '31\t-\tI\n',
#    '32\tspecific\tI\n',
#    '33\tdomain\tI\n',
#    '34\t,\tO\n',
#    '35\tGTAT\tO\n',
#    '36\t,\tO\n',
#    '37\tis\tO\n',
#    '38\ton\tO\n',
#    '39\tthe\tO\n',
#    '40\topposing\tO\n',
#    '41\tstrand\tI\n',
#    '42\t.\tO\n'],
#   ['1\tConsistent\tO\n',
#    '2\twith\tO\n',
#    '3\tErbB\tB\n',
#    '4\t-\tI\n',
#    '5\t2\tI\n',
#    '6\tbeing\tO\n',
#    '7\ta\tO\n',
#    '8\tshared\tO\n',
#    '9\treceptor\tI\n',
#    '10\tsubunit\tI\n',
#    '11\t,\tO\n',
#    '12\tits\tO\n',
#    '13\ttyrosine\tI\n',
#    '14\tphosphorylation\tO\n',
#    '15\twas\tO\n',
#    '16\tincreased\tO\n',
#    '17\tby\tO\n',
#    '18\tboth\tO\n',
#    '19\theterologous\tO\n',
#    '20\tligands\tO\n',
#    '21\tand\tO\n',
#    '22\tit\tO\n',
#    '23\tmediated\tO\n',
#    '24\ta\tO\n',
#    '25\ttrans\tO\n',
#    '26\t-\tI\n',
#    '27\tinhibitory\tI\n',
#    '28\teffect\tO\n',
#    '29\tof\tO\n',
#    '30\tNDF\tO\n',
#    '31\ton\tO\n',
#    '32\tEGF\tB\n',
#    '33\tbinding\tI\n',
#    '34\t.\tO\n'],
#   ['1\tA\tI\n',
#    '2\tdecamer\tO\n',
#    '3\tsequence\tI\n',
#    '4\t,\tO\n',
#    '5\t5\tI\n',
#    "6\t'-\tI\n",
#    '7\tCGA\tO\n',
#    '8\t-\tI\n',
#    '9\tCCCCUCC\tO\n',
#    '10\t-\tI\n',
#    '11\t3\tI\n',
#    "12\t',\tI\n",
#    '13\tcomplementary\tO\n',
#    '14\tto\tO\n',
#    '15\ta\tO\n',
#    '16\tconserved\tO\n',
#    '17\tsequence\tI\n',
#    '18\tadjacent\tO\n',
#    '19\tto\tO\n',
#    '20\tthe\tO\n',
#    '21\tenzymatic\tO\n',
#    '22\tcleavage\tI\n',
#    '23\tsite\tI\n',
#    '24\ton\tO\n',
#    '25\tthe\tO\n',
#    '26\tmitochondrial\tI\n',
#    '27\tRNA\tB\n',
#    '28\tsubstrate\tI\n',
#    '29\t,\tO\n',
#    '30\tis\tO\n',
#    '31\tpresent\tO\n',
#    '32\tin\tO\n',
#    '33\tthe\tO\n',
#    '34\tRNAase\tO\n',
#    '35\tMRP\tI\n',
#    '36\tRNA\tB\n',
#    '37\t.\tO\n'],
#   ['1\tThese\tO\n',
#    '2\tdifferences\tO\n',
#    '3\tinvolve\tO\n',
#    '4\tspecific\tI\n',
#    '5\thydrogen\tO\n',
#    '6\t-\tI\n',
#    '7\tbonding\tO\n',
#    '8\tinteractions\tO\n',
#    '9\tbetween\tO\n',
#    '10\tthe\tO\n',
#    '11\tprotein\tI\n',
#    '12\tand\tO\n',
#    '13\tDNA\tI\n',
#    '14\t,\tO\n',
#    '15\tincluding\tO\n',
#    '16\tguanine\tB\n',
#    '17\tN7\tO\n',
#    '18\tsites\tI\n',
#    '19\tin\tO\n',
#    '20\tthe\tO\n',
#    '21\tmajor\tB\n',
#    '22\tgroove\tI\n',
#    '23\tof\tO\n',
#    '24\tDNA\tI\n',
#    '25\t,\tO\n',
#    '26\tand\tO\n',
#    '27\talterations\tO\n',
#    '28\tin\tO\n',
#    '29\tDNA\tI\n',
#    '30\tphosphodiester\tO\n',
#    '31\tconformation\tO\n',
#    '32\tinduced\tO\n',
#    '33\tby\tO\n',
#    '34\tprotein\tI\n',
#    '35\tbinding\tI\n',
#    '36\t.\tO\n'],
#   ['1\tAnti\tB\n',
#    '2\t-\tI\n',
#    '3\tCRK\tB\n',
#    '4\tantibodies\tI\n',
#    '5\tdetect\tO\n',
#    '6\ta\tO\n',
#    '7\t53kDa\tO\n',
#    '8\tprotein\tI\n',
#    '9\tin\tO\n',
#    '10\textracts\tO\n',
#    '11\tof\tO\n',
#    '12\tC\tI\n',
#    '13\t.\tO\n',
#    '14\tfasciculata\tO\n',
#    '15\tin\tO\n',
#    '16\tagreement\tO\n',
#    '17\twith\tO\n',
#    '18\tthe\tO\n',
#    '19\tsize\tO\n',
#    '20\tpredicted\tO\n',
#    '21\tfrom\tO\n',
#    '22\tthe\tO\n',
#    '23\tnucleotide\tI\n',
#    '24\tsequence\tI\n',
#    '25\tof\tO\n',
#    '26\tthe\tO\n',
#    '27\tcloned\tO\n',
#    '28\tgene\tI\n',
#    '29\t.\tO\n']])

# %%
len(preds_new) == len(test)
# Out:
# True

# %%
with open("preds_hmm.csv", 'w') as f:
  for s in preds_new:
    print("".join(s))
    f.write("".join(s))
f
# Out:
# 1	The	O
# 2	main	O
# 3	aim	O
# 4	of	O
# 5	the	O
# 6	contribution	O
# 7	,	O
# 8	which	O
# 9	opens	O
# 10	an	O
# 11	arena	O
# 12	for	O
# 13	discussion	O
# 14	on	O
# 15	the	O
# 16	Rivista	O
# 17	dell	O
# 18	'	O
# 19	Infermiere	O
# 20	is	O
# 21	to	O
# 22	critically	O
# 23	appraise	O
# 24	published	O
# 25	research	O
# 26	works	O
# 27	focusing	O
# 28	both	O
# 29	on	O
# 30	strengths	O
# 31	and	O
# 32	novelty	O
# 33	and	O
# 34	weaknesses	O
# 35	in	O
# 36	the	O
# 37	hypothesis	O
# 38	formulation	O
# 39	,	O
# 40	methods	O
# 41	and	O
# 42	instruments	O
# 43	used	O
# 44	,	O
# 45	discussion	O
# 46	of	O
# 47	results	O
# 48	.	O
#
# 1	Examination	O
# 2	of	O
# 3	DNA	I
# 4	:	O
# 5	protein	I
# 6	binding	I
# 7	complexes	I
# 8	by	O
# 9	gel	O
# 10	-	I
# 11	shift	O
# 12	analysis	O
# 13	indicated	O
# 14	that	O
# 15	nuclear	B
# 16	factors	I
# 17	from	O
# 18	both	O
# 19	proliferative	O
# 20	and	O
# 21	growth	I
# 22	-	I
# 23	arrested	O
# 24	cells	O
# 25	bound	O
# 26	to	O
# 27	the	O
# 28	DNA	I
# 29	fragment	I
# 30	spanning	O
# 31	-	I
# 32	949	O
# 33	-	I
# 34	-	I
# 35	722	O
# 36	bp	O
# 37	.	O
#
# 1	Demonstration	O
# 2	of	O
# 3	fine	O
# 4	structure	O
# 5	of	O
# 6	the	O
# 7	guinea	B
# 8	pig	I
# 9	organ	O
# 10	of	O
# 11	Corti	O
# 12	after	O
# 13	electron	O
# 14	microscopic	O
# 15	silver	O
# 16	staining	O
#
# 1	Eukaryotic	B
# 2	translation	O
# 3	initiation	I
# 4	factor	I
# 5	4GI	O
# 6	is	O
# 7	a	O
# 8	cellular	B
# 9	target	O
# 10	for	O
# 11	NS1	B
# 12	protein	I
# 13	,	O
# 14	a	O
# 15	translational	O
# 16	activator	I
# 17	of	O
# 18	influenza	I
# 19	virus	I
# 20	.	O
#
# 1	Insert2	O
# 2	contains	O
# 3	repetitive	I
# 4	non	O
# 5	-	I
# 6	Ig	B
# 7	-	I
# 8	related	I
# 9	sequences	I
# 10	and	O
# 11	a	O
# 12	small	B
# 13	Ig	B
# 14	-	I
# 15	related	I
# 16	sequence	I
# 17	.	O
#
# 1	In	O
# 2	the	O
# 3	Oct	B
# 4	-	I
# 5	1	I
# 6	crystal	O
# 7	,	O
# 8	the	O
# 9	POU	B
# 10	-	I
# 11	specific	I
# 12	domain	I
# 13	recognizes	O
# 14	a	O
# 15	GCAT	O
# 16	half	O
# 17	-	I
# 18	site	I
# 19	,	O
# 20	while	O
# 21	the	O
# 22	corresponding	O
# 23	sequence	I
# 24	recognized	O
# 25	by	O
# 26	the	O
# 27	Pit	B
# 28	-	I
# 29	1	I
# 30	POU	B
# 31	-	I
# 32	specific	I
# 33	domain	I
# 34	,	O
# 35	GTAT	O
# 36	,	O
# 37	is	O
# 38	on	O
# 39	the	O
# 40	opposing	O
# 41	strand	I
# 42	.	O
#
# 1	Consistent	O
# 2	with	O
# 3	ErbB	B
# 4	-	I
# 5	2	I
# 6	being	O
# 7	a	O
# 8	shared	O
# 9	receptor	I
# 10	subunit	I
# 11	,	O
# 12	its	O
# 13	tyrosine	I
# 14	phosphorylation	O
# 15	was	O
# 16	increased	O
# 17	by	O
# 18	both	O
# 19	heterologous	O
# 20	ligands	O
# 21	and	O
# 22	it	O
# 23	mediated	O
# 24	a	O
# 25	trans	O
# 26	-	I
# 27	inhibitory	I
# 28	effect	O
# 29	of	O
# 30	NDF	O
# 31	on	O
# 32	EGF	B
# 33	binding	I
# 34	.	O
#
# 1	A	I
# 2	decamer	O
# 3	sequence	I
# 4	,	O
# 5	5	I
# 6	'-	I
# 7	CGA	O
# 8	-	I
# 9	CCCCUCC	O
# 10	-	I
# 11	3	I
# 12	',	I
# 13	complementary	O
# 14	to	O
# 15	a	O
# 16	conserved	O
# 17	sequence	I
# 18	adjacent	O
# 19	to	O
# 20	the	O
# 21	enzymatic	O
# 22	cleavage	I
# 23	site	I
# 24	on	O
# 25	the	O
# 26	mitochondrial	I
# 27	RNA	B
# 28	substrate	I
# 29	,	O
# 30	is	O
# 31	present	O
# 32	in	O
# 33	the	O
# 34	RNAase	O
# 35	MRP	I
# 36	RNA	B
# 37	.	O
#
# 1	These	O
# 2	differences	O
# 3	involve	O
# 4	specific	I
# 5	hydrogen	O
# 6	-	I
# 7	bonding	O
# 8	interactions	O
# 9	between	O
# 10	the	O
# 11	protein	I
# 12	and	O
# 13	DNA	I
# 14	,	O
# 15	including	O
# 16	guanine	B
# 17	N7	O
# 18	sites	I
# 19	in	O
# 20	the	O
# 21	major	B
# 22	groove	I
# 23	of	O
# 24	DNA	I
# 25	,	O
# 26	and	O
# 27	alterations	O
# 28	in	O
# 29	DNA	I
# 30	phosphodiester	O
# 31	conformation	O
# 32	induced	O
# 33	by	O
# 34	protein	I
# 35	binding	I
# 36	.	O
#
# 1	Anti	B
# 2	-	I
# 3	CRK	B
# 4	antibodies	I
# 5	detect	O
# 6	a	O
# 7	53kDa	O
# 8	protein	I
# 9	in	O
# 10	extracts	O
# 11	of	O
# 12	C	I
# 13	.	O
# 14	fasciculata	O
# 15	in	O
# 16	agreement	O
# 17	with	O
# 18	the	O
# 19	size	O
# 20	predicted	O
# 21	from	O
# 22	the	O
# 23	nucleotide	I
# 24	sequence	I
# 25	of	O
# 26	the	O
# 27	cloned	O
# 28	gene	I
# 29	.	O
#
# 1	In	O
# 2	an	O
# 3	effort	O
# 4	to	O
# 5	separate	O
# 6	domains	I
# 7	of	O
# 8	FadR	O
# 9	required	O
# 10	for	O
# 11	DNA	I
# 12	binding	I
# 13	,	O
# 14	dimerization	I
# 15	,	O
# 16	and	O
# 17	ligand	O
# 18	binding	I
# 19	,	O
# 20	chimeric	B
# 21	protein	I
# 22	fusions	I
# 23	between	O
# 24	the	O
# 25	DNA	I
# 26	binding	I
# 27	domain	I
# 28	of	O
# 29	LexA	B
# 30	and	O
# 31	different	O
# 32	regions	O
# 33	of	O
# 34	FadR	O
# 35	were	O
# 36	constructed	O
# 37	.	O
#
# 1	Neither	O
# 2	model	O
# 3	,	O
# 4	as	O
# 5	applied	O
# 6	,	O
# 7	provided	O
# 8	a	O
# 9	satisfactory	O
# 10	account	O
# 11	of	O
# 12	the	O
# 13	effects	O
# 14	of	O
# 15	the	O
# 16	main	O
# 17	variables	O
# 18	of	O
# 19	number	O
# 20	of	O
# 21	tones	O
# 22	and	O
# 23	amount	O
# 24	of	O
# 25	perturbation	O
# 26	.(	O
# 27	ABSTRACT	O
# 28	TRUNCATED	O
# 29	AT	B
# 30	400	O
# 31	WORDS	O
# 32	)	O
#
# 1	A	I
# 2	herpesvirus	B
# 3	proteinase	I
# 4	activity	O
# 5	has	O
# 6	been	O
# 7	identified	O
# 8	and	O
# 9	partially	O
# 10	characterized	O
# 11	by	O
# 12	using	O
# 13	the	O
# 14	cloned	O
# 15	enzyme	I
# 16	and	O
# 17	substrate	I
# 18	genes	I
# 19	in	O
# 20	transient	O
# 21	transfection	O
# 22	assays	O
# 23	.	O
#
# 1	During	O
# 2	the	O
# 3	aftermath	O
# 4	of	O
# 5	excitation	O
# 6	of	O
# 7	the	O
# 8	skin	O
# 9	sympathetic	O
# 10	nerve	B
# 11	by	O
# 12	mental	O
# 13	arithmetics	O
# 14	,	O
# 15	3	I
# 16	/	I
# 17	12	O
# 18	A	I
# 19	delta	I
# 20	units	O
# 21	were	O
# 22	turned	O
# 23	to	O
# 24	the	O
# 25	active	O
# 26	state	O
# 27	with	O
# 28	decreased	O
# 29	mechanical	O
# 30	threshold	O
# 31	.	O
#
# 1	When	O
# 2	transfected	O
# 3	into	O
# 4	Drosophila	B
# 5	SL	O
# 6	-	I
# 7	2	I
# 8	cells	O
# 9	,	O
# 10	pCAT	B
# 11	plasmid	O
# 12	containing	O
# 13	2	I
# 14	,	O
# 15	090	O
# 16	bp	O
# 17	of	O
# 18	5	I
# 19	'-	I
# 20	flanking	I
# 21	region	I
# 22	shows	O
# 23	a	O
# 24	3	I
# 25	.	O
# 26	0	O
# 27	-	I
# 28	to	O
# 29	3	I
# 30	.	O
# 31	5	I
# 32	-	I
# 33	fold	O
# 34	increase	O
# 35	in	O
# 36	chloramphenicol	B
# 37	acetyltransferase	I
# 38	activity	O
# 39	after	O
# 40	induction	O
# 41	with	O
# 42	retinoic	B
# 43	acid	I
# 44	and	O
# 45	/	I
# 46	or	O
# 47	8	I
# 48	-	I
# 49	bromo	O
# 50	-	I
# 51	cAMP	B
# 52	.	O
#
# 1	G	B
# 2	.	O
#
# 1	The	O
# 2	effect	O
# 3	of	O
# 4	the	O
# 5	thromboxane	B
# 6	A2	I
# 7	(	O
# 8	TXA2	O
# 9	)/	I
# 10	prostaglandin	B
# 11	endoperoxide	I
# 12	receptor	I
# 13	antagonist	O
# 14	,	O
# 15	SQ	O
# 16	29	O
# 17	,	O
# 18	548	O
# 19	on	O
# 20	pacing	O
# 21	-	I
# 22	induced	O
# 23	ischemia	O
# 24	was	O
# 25	determined	O
# 26	in	O
# 27	anesthetized	O
# 28	open	O
# 29	-	I
# 30	chest	O
# 31	dogs	O
# 32	.	O
#
# 1	The	O
# 2	bHLH	B
# 3	proteins	I
# 4	function	O
# 5	as	O
# 6	potent	O
# 7	transcriptional	O
# 8	activators	I
# 9	of	O
# 10	tissue	B
# 11	-	I
# 12	specific	I
# 13	genes	I
# 14	by	O
# 15	forming	O
# 16	heterodimers	I
# 17	between	O
# 18	ubiquitous	O
# 19	and	O
# 20	cell	I
# 21	-	I
# 22	restricted	O
# 23	family	I
# 24	members	I
# 25	.	O
#
# 1	In	O
# 2	contrast	O
# 3	,	O
# 4	the	O
# 5	distribution	O
# 6	of	O
# 7	endocytic	O
# 8	markers	O
# 9	is	O
# 10	not	O
# 11	affected	O
# 12	.	O
#
# 1	Two	O
# 2	patients	O
# 3	had	O
# 4	immediate	B
# 5	adverse	O
# 6	effects	O
# 7	from	O
# 8	NMF	O
# 9	;	O
# 10	one	O
# 11	had	O
# 12	a	O
# 13	grand	O
# 14	mal	O
# 15	seizure	O
# 16	and	O
# 17	the	O
# 18	other	O
# 19	developed	O
# 20	severe	O
# 21	abdominal	O
# 22	pain	O
# 23	.	O
#
# 1	Two	O
# 2	polyadenylation	O
# 3	sites	I
# 4	were	O
# 5	used	O
# 6	,	O
# 7	one	O
# 8	at	O
# 9	the	O
# 10	end	O
# 11	of	O
# 12	the	O
# 13	early	I
# 14	(	O
# 15	E	B
# 16	)	O
# 17	region	I
# 18	of	O
# 19	the	O
# 20	viral	B
# 21	DNA	I
# 22	,	O
# 23	the	O
# 24	other	O
# 25	at	O
# 26	the	O
# 27	end	O
# 28	of	O
# 29	the	O
# 30	late	O
# 31	(	O
# 32	L	B
# 33	)	O
# 34	region	I
# 35	.	O
#
# 1	To	O
# 2	evaluate	O
# 3	the	O
# 4	gas	O
# 5	chromatographic	O
# 6	electron	O
# 7	capture	O
# 8	detection	O
# 9	method	O
# 10	described	O
# 11	earlier	O
# 12	,	O
# 13	23	O
# 14	plasma	B
# 15	samples	O
# 16	have	O
# 17	been	O
# 18	analysed	O
# 19	by	O
# 20	both	O
# 21	techniques	O
# 22	.	O
#
# 1	Production	O
# 2	costs	O
# 3	included	O
# 4	feed	O
# 5	,	O
# 6	non	O
# 7	-	I
# 8	feed	O
# 9	operating	O
# 10	,	O
# 11	fixed	O
# 12	,	O
# 13	and	O
# 14	replacement	O
# 15	stock	O
# 16	costs	O
# 17	.	O
#
# 1	Gastric	O
# 2	CO2	O
# 3	/	I
# 4	HCO3	O
# 5	was	O
# 6	determined	O
# 7	in	O
# 8	absence	O
# 9	of	O
# 10	simultaneous	O
# 11	inhibition	O
# 12	of	O
# 13	acid	I
# 14	secretion	O
# 15	by	O
# 16	intra	O
# 17	-	I
# 18	and	O
# 19	extragastric	O
# 20	pCO2	O
# 21	/	I
# 22	pH	O
# 23	measurements	O
# 24	in	O
# 25	23	O
# 26	persons	O
# 27	and	O
# 28	calculated	O
# 29	using	O
# 30	the	O
# 31	equation	O
# 32	of	O
# 33	Henderson	O
# 34	-	I
# 35	Hasselbalch	O
# 36	.	O
# 37	pCO2	O
# 38	was	O
# 39	measured	O
# 40	with	O
# 41	use	O
# 42	of	O
# 43	a	O
# 44	new	O
# 45	electrode	O
# 46	.	O
#
# 1	Since	O
# 2	proteins	I
# 3	containing	O
# 4	TPR	O
# 5	elements	I
# 6	are	O
# 7	typically	O
# 8	involved	O
# 9	in	O
# 10	multiple	O
# 11	protein	I
# 12	-	I
# 13	protein	I
# 14	interactions	O
# 15	,	O
# 16	we	O
# 17	suggest	O
# 18	that	O
# 19	the	O
# 20	102kD	O
# 21	protein	I
# 22	interacts	O
# 23	within	O
# 24	the	O
# 25	tri	O
# 26	-	I
# 27	snRNP	I
# 28	with	O
# 29	both	O
# 30	the	O
# 31	U5	B
# 32	and	O
# 33	U4	B
# 34	/	I
# 35	U6	B
# 36	snRNPs	O
# 37	,	O
# 38	thus	O
# 39	bridging	O
# 40	the	O
# 41	two	O
# 42	particles	I
# 43	.	O
#
# 1	The	O
# 2	region	I
# 3	that	O
# 4	imparts	O
# 5	inducibility	O
# 6	by	O
# 7	IL	B
# 8	-	I
# 9	1	I
# 10	or	O
# 11	TNF	B
# 12	(	O
# 13	positions	O
# 14	-	I
# 15	165	O
# 16	to	O
# 17	-	I
# 18	58	O
# 19	)	O
# 20	contains	O
# 21	potential	O
# 22	binding	I
# 23	sites	I
# 24	for	O
# 25	IRF	B
# 26	-	I
# 27	1	I
# 28	and	O
# 29	-	I
# 30	2	I
# 31	,	O
# 32	AP	B
# 33	-	I
# 34	1	I
# 35	,	O
# 36	and	O
# 37	NF	B
# 38	-	I
# 39	IL	B
# 40	-	I
# 41	6	I
# 42	.	O
#
# 1	One	O
# 2	of	O
# 3	these	O
# 4	is	O
# 5	surrounded	O
# 6	by	O
# 7	an	O
# 8	adenine	B
# 9	-	I
# 10	uridine	O
# 11	rich	I
# 12	region	I
# 13	that	O
# 14	can	O
# 15	form	O
# 16	an	O
# 17	11	I
# 18	-	I
# 19	base	O
# 20	pair	O
# 21	stem	O
# 22	structure	O
# 23	.	O
#
# 1	The	O
# 2	Saccharomyces	B
# 3	cerevisiae	I
# 4	RAD30	O
# 5	gene	I
# 6	,	O
# 7	a	O
# 8	homologue	I
# 9	of	O
# 10	Escherichia	B
# 11	coli	I
# 12	dinB	O
# 13	and	O
# 14	umuC	O
# 15	,	O
# 16	is	O
# 17	DNA	I
# 18	damage	O
# 19	inducible	I
# 20	and	O
# 21	functions	O
# 22	in	O
# 23	a	O
# 24	novel	O
# 25	error	O
# 26	-	I
# 27	free	O
# 28	postreplication	O
# 29	repair	I
# 30	mechanism	O
# 31	.	O
#
# 1	These	O
# 2	data	O
# 3	support	O
# 4	a	O
# 5	possible	O
# 6	biological	O
# 7	significance	O
# 8	of	O
# 9	the	O
# 10	frameshift	O
# 11	to	O
# 12	occur	O
# 13	at	O
# 14	this	O
# 15	position	O
# 16	of	O
# 17	the	O
# 18	large	O
# 19	overlap	O
# 20	by	O
# 21	including	O
# 22	the	O
# 23	putative	O
# 24	RNA	B
# 25	template	O
# 26	-	I
# 27	binding	I
# 28	site	I
# 29	of	O
# 30	the	O
# 31	PLRV	O
# 32	replicase	B
# 33	in	O
# 34	the	O
# 35	ORF2a	O
# 36	/	I
# 37	ORF2b	O
# 38	transframe	O
# 39	protein	I
# 40	.	O
#
# 1	Inhibition	O
# 2	of	O
# 3	RNA2	O
# 4	translation	O
# 5	was	O
# 6	selective	O
# 7	,	O
# 8	with	O
# 9	no	O
# 10	effect	O
# 11	on	O
# 12	general	B
# 13	cellular	B
# 14	translation	O
# 15	or	O
# 16	translation	O
# 17	of	O
# 18	BMV	O
# 19	RNA1	O
# 20	-	I
# 21	encoded	I
# 22	replication	O
# 23	factor	I
# 24	1a	I
# 25	,	O
# 26	and	O
# 27	was	O
# 28	independent	O
# 29	of	O
# 30	p20	B
# 31	,	O
# 32	a	O
# 33	cellular	B
# 34	antagonist	O
# 35	of	O
# 36	DED1	O
# 37	function	O
# 38	in	O
# 39	translation	O
# 40	.	O
#
# 1	We	O
# 2	could	O
# 3	demonstrate	O
# 4	the	O
# 5	involvement	O
# 6	of	O
# 7	cAMP	B
# 8	-	I
# 9	dependent	I
# 10	protein	I
# 11	kinase	I
# 12	(	O
# 13	PKA	B
# 14	)	O
# 15	in	O
# 16	the	O
# 17	phosphorylation	O
# 18	of	O
# 19	CDC25Mm	O
# 20	in	O
# 21	fibroblasts	O
# 22	overexpressing	O
# 23	this	O
# 24	RasGEF	O
# 25	as	O
# 26	well	O
# 27	as	O
# 28	in	O
# 29	mouse	B
# 30	brain	O
# 31	synaptosomal	O
# 32	membranes	O
# 33	.	O
#
# 1	The	O
# 2	effect	O
# 3	of	O
# 4	water	O
# 5	deprivation	O
# 6	for	O
# 7	19	O
# 8	h	O
# 9	on	O
# 10	renal	O
# 11	Na	B
# 12	excretion	O
# 13	of	O
# 14	conscious	O
# 15	adrenalectomized	O
# 16	(	O
# 17	ADX	O
# 18	)	O
# 19	sheep	O
# 20	maintained	O
# 21	on	O
# 22	a	O
# 23	constant	O
# 24	intravenous	O
# 25	infusion	O
# 26	of	O
# 27	aldosterone	O
# 28	and	O
# 29	cortisol	O
# 30	(	O
# 31	ADX	O
# 32	-	I
# 33	constant	O
# 34	steroid	B
# 35	sheep	O
# 36	)	O
# 37	was	O
# 38	investigated	O
# 39	.	O
#
# 1	Mothers	O
# 2	with	O
# 3	severe	O
# 4	anatomical	O
# 5	abnormalities	O
# 6	,	O
# 7	who	O
# 8	are	O
# 9	HIV	B
# 10	positive	O
# 11	,	O
# 12	have	O
# 13	active	O
# 14	TB	B
# 15	or	O
# 16	whose	O
# 17	children	O
# 18	have	O
# 19	inherited	O
# 20	mono	O
# 21	-	I
# 22	or	O
# 23	disaccharide	O
# 24	intolerances	O
# 25	should	O
# 26	not	O
# 27	breastfeed	O
# 28	.	O
#
# 1	The	O
# 2	sequence	I
# 3	of	O
# 4	the	O
# 5	HIR1	O
# 6	gene	I
# 7	predicts	O
# 8	an	O
# 9	88	O
# 10	-	I
# 11	kDa	I
# 12	protein	I
# 13	with	O
# 14	three	O
# 15	repeats	I
# 16	of	O
# 17	a	O
# 18	motif	I
# 19	found	O
# 20	in	O
# 21	the	O
# 22	G	B
# 23	beta	I
# 24	subunit	I
# 25	of	O
# 26	retinal	O
# 27	transducin	B
# 28	and	O
# 29	in	O
# 30	a	O
# 31	yeast	B
# 32	transcriptional	O
# 33	repressor	I
# 34	,	O
# 35	Tup1	O
# 36	.	O
#
# 1	This	O
# 2	gene	I
# 3	joins	O
# 4	the	O
# 5	group	O
# 6	of	O
# 7	genes	I
# 8	whose	O
# 9	members	I
# 10	are	O
# 11	rapidly	O
# 12	transcribed	O
# 13	in	O
# 14	response	I
# 15	to	O
# 16	insulin	B
# 17	and	O
# 18	other	O
# 19	mitogens	O
# 20	.	O
#
# 1	C	I
# 2	/	I
# 3	EBP	I
# 4	alpha	I
# 5	also	O
# 6	activates	O
# 7	the	O
# 8	promoter	I
# 9	of	O
# 10	the	O
# 11	rat	B
# 12	class	B
# 13	-	I
# 14	I	I
# 15	ADH	I
# 16	gene	I
# 17	in	O
# 18	a	O
# 19	sequence	I
# 20	-	I
# 21	specific	I
# 22	manner	O
# 23	[	O
# 24	Potter	O
# 25	et	O
# 26	al	O
# 27	.,	O
# 28	Arch	O
# 29	.	O
#
# 1	Expression	O
# 2	of	O
# 3	the	O
# 4	human	B
# 5	papillomavirus	I
# 6	type	I
# 7	11	I
# 8	E5A	O
# 9	protein	I
# 10	from	O
# 11	the	O
# 12	E1E4	O
# 13	,	O
# 14	E5	I
# 15	transcript	I
# 16	.	O
#
# 1	The	O
# 2	concentration	O
# 3	of	O
# 4	PGI2	O
# 5	on	O
# 6	the	O
# 7	newly	O
# 8	-	I
# 9	formed	O
# 10	luminal	O
# 11	surface	I
# 12	remained	O
# 13	low	O
# 14	.	O
#
# 1	The	O
# 2	mammalian	B
# 3	phosphoinositide	B
# 4	3	I
# 5	-	I
# 6	kinases	I
# 7	(	O
# 8	PI3Ks	O
# 9	)	O
# 10	p110alpha	O
# 11	,	O
# 12	beta	I
# 13	,	O
# 14	and	O
# 15	delta	I
# 16	form	O
# 17	heterodimers	I
# 18	with	O
# 19	Src	B
# 20	homology	I
# 21	2	I
# 22	(	O
# 23	SH2	B
# 24	)	O
# 25	domain	I
# 26	-	I
# 27	containing	O
# 28	adaptors	O
# 29	such	O
# 30	as	O
# 31	p85alpha	O
# 32	or	O
# 33	p55	B
# 34	(	O
# 35	PIK	O
# 36	).	O
#
# 1	In	O
# 2	vitro	O
# 3	expression	O
# 4	of	O
# 5	four	O
# 6	different	O
# 7	naturally	O
# 8	occurring	O
# 9	nonsense	O
# 10	and	O
# 11	missense	O
# 12	mutations	I
# 13	revealed	O
# 14	a	O
# 15	dramatically	O
# 16	altered	O
# 17	subcellular	O
# 18	location	O
# 19	of	O
# 20	the	O
# 21	protein	I
# 22	in	O
# 23	cultured	O
# 24	cells	O
# 25	.	O
#
# 1	Adjuvant	O
# 2	therapy	O
# 3	for	O
# 4	colon	O
# 5	cancer	O
# 6	]	I
# 7	Surgery	O
# 8	alone	O
# 9	may	O
# 10	fail	O
# 11	to	O
# 12	cure	O
# 13	a	O
# 14	considerable	O
# 15	number	O
# 16	of	O
# 17	locally	O
# 18	advanced	O
# 19	colon	O
# 20	cancers	O
# 21	.	O
#
# 1	Subjects	O
# 2	with	O
# 3	a	O
# 4	short	O
# 5	postexposure	O
# 6	time	O
# 7	and	O
# 8	a	O
# 9	dioxin	I
# 10	burden	O
# 11	>	O
# 12	0	O
# 13	.	O
# 14	6	I
# 15	pg	O
# 16	/	I
# 17	m3	O
# 18	had	O
# 19	a	O
# 20	significantly	O
# 21	higher	O
# 22	risk	O
# 23	of	O
# 24	hypoergy	O
# 25	than	O
# 26	unexposed	O
# 27	subjects	O
# 28	(	O
# 29	hypoergy	O
# 30	I	I
# 31	:	O
# 32	OR	O
# 33	=	O
# 34	9	O
# 35	.	O
# 36	51	I
# 37	,	O
# 38	95	O
# 39	%	O
# 40	CI	O
# 41	=	O
# 42	1	I
# 43	.	O
# 44	96	O
# 45	-	I
# 46	42	O
# 47	.	O
# 48	02	O
# 49	;	O
# 50	hypoergy	O
# 51	II	I
# 52	:	O
# 53	OR	O
# 54	=	O
# 55	2	I
# 56	.	O
# 57	92	O
# 58	,	O
# 59	95	O
# 60	%	O
# 61	CI	O
# 62	=	O
# 63	1	I
# 64	.	O
# 65	14	I
# 66	-	I
# 67	7	O
# 68	.	O
# 69	5	I
# 70	).	O
#
# 1	We	O
# 2	have	O
# 3	demonstrated	O
# 4	previously	O
# 5	that	O
# 6	two	O
# 7	binding	I
# 8	sites	I
# 9	in	O
# 10	the	O
# 11	-	I
# 12	184	O
# 13	HNF	B
# 14	-	I
# 15	3	I
# 16	beta	I
# 17	promoter	I
# 18	are	O
# 19	recognized	O
# 20	by	O
# 21	widely	O
# 22	distributed	O
# 23	factors	I
# 24	and	O
# 25	that	O
# 26	there	O
# 27	is	O
# 28	also	O
# 29	a	O
# 30	critical	O
# 31	autoregulatory	O
# 32	site	I
# 33	,	O
# 34	we	O
# 35	identified	O
# 36	a	O
# 37	binding	I
# 38	site	I
# 39	for	O
# 40	a	O
# 41	cell	I
# 42	-	I
# 43	specific	I
# 44	factor	I
# 45	,	O
# 46	LF	O
# 47	-	I
# 48	H3	I
# 49	beta	I
# 50	,	O
# 51	that	O
# 52	may	O
# 53	function	O
# 54	in	O
# 55	restricting	O
# 56	HNF	B
# 57	-	I
# 58	3	I
# 59	beta	I
# 60	gene	I
# 61	expression	O
# 62	to	O
# 63	hepatocytes	O
# 64	.	O
#
# 1	The	O
# 2	emerging	O
# 3	complexity	O
# 4	of	O
# 5	the	O
# 6	5	I
# 7	'	O
# 8	regulatory	I
# 9	region	I
# 10	of	O
# 11	the	O
# 12	GH	B
# 13	receptor	I
# 14	gene	I
# 15	was	O
# 16	emphasised	O
# 17	by	O
# 18	the	O
# 19	observation	O
# 20	that	O
# 21	probes	O
# 22	derived	I
# 23	from	O
# 24	exon	O
# 25	1B	I
# 26	and	O
# 27	the	O
# 28	distal	O
# 29	3	I
# 30	'	O
# 31	intron	O
# 32	boundary	O
# 33	do	O
# 34	not	O
# 35	hybridise	O
# 36	with	O
# 37	previously	O
# 38	cloned	O
# 39	genomic	O
# 40	sequences	I
# 41	that	O
# 42	span	O
# 43	the	O
# 44	liver	O
# 45	-	I
# 46	specific	I
# 47	P1	B
# 48	promoter	I
# 49	and	O
# 50	exon	O
# 51	2	I
# 52	.	O
#
# 1	For	O
# 2	this	O
# 3	,	O
# 4	cDNAs	I
# 5	containing	O
# 6	the	O
# 7	60K	O
# 8	,	O
# 9	87K	B
# 10	,	O
# 11	110K	O
# 12	and	O
# 13	170K	O
# 14	protein	I
# 15	coding	I
# 16	sequences	I
# 17	were	O
# 18	each	O
# 19	provided	O
# 20	with	O
# 21	an	O
# 22	ATG	O
# 23	start	O
# 24	codon	O
# 25	and	O
# 26	the	O
# 27	cDNA	I
# 28	containing	O
# 29	the	O
# 30	60K	O
# 31	coding	I
# 32	sequence	I
# 33	with	O
# 34	a	O
# 35	TAA	O
# 36	stop	O
# 37	codon	O
# 38	immediately	O
# 39	downstream	O
# 40	of	O
# 41	the	O
# 42	coding	I
# 43	sequence	I
# 44	.	O
#
# 1	Apart	O
# 2	from	O
# 3	iron	O
# 4	regulation	O
# 5	,	O
# 6	sodA	O
# 7	expression	O
# 8	was	O
# 9	affected	O
# 10	by	O
# 11	changes	O
# 12	in	O
# 13	DNA	I
# 14	topology	O
# 15	induced	O
# 16	by	O
# 17	coumermycin	O
# 18	A	I
# 19	but	O
# 20	not	O
# 21	by	O
# 22	the	O
# 23	global	O
# 24	virulence	I
# 25	regulatory	I
# 26	Bvg	O
# 27	system	O
# 28	.	O
#
# 1	In	O
# 2	addition	O
# 3	,	O
# 4	our	O
# 5	results	O
# 6	show	O
# 7	that	O
# 8	ERKs	B
# 9	and	O
# 10	PI3Ks	O
# 11	can	O
# 12	synergise	O
# 13	to	O
# 14	convert	O
# 15	ectoderm	B
# 16	into	O
# 17	mesoderm	O
# 18	.	O
#
# 1	We	O
# 2	have	O
# 3	now	O
# 4	identified	O
# 5	,	O
# 6	after	O
# 7	21	O
# 8	serial	O
# 9	undiluted	O
# 10	passages	O
# 11	of	O
# 12	MHV	O
# 13	,	O
# 14	a	O
# 15	small	B
# 16	DI	O
# 17	RNA	B
# 18	,	O
# 19	DIssF	O
# 20	,	O
# 21	which	O
# 22	is	O
# 23	efficiently	O
# 24	packaged	O
# 25	into	O
# 26	virions	O
# 27	.	O
#
# 1	All	O
# 2	radiologists	O
# 3	using	O
# 4	the	O
# 5	machine	O
# 6	found	O
# 7	that	O
# 8	the	O
# 9	reporting	O
# 10	terminal	I
# 11	was	O
# 12	simple	O
# 13	to	O
# 14	operate	O
# 15	,	O
# 16	but	O
# 17	found	O
# 18	that	O
# 19	reporting	O
# 20	abnormalities	O
# 21	caused	O
# 22	an	O
# 23	increased	O
# 24	effort	O
# 25	and	O
# 26	took	O
# 27	a	O
# 28	longer	O
# 29	time	O
# 30	.	O
#
# 1	Both	O
# 2	4	I
# 3	,	O
# 4	8	I
# 5	-	I
# 6	DiMeIQx	O
# 7	and	O
# 8	A	I
# 9	alpha	I
# 10	C	I
# 11	were	O
# 12	found	O
# 13	at	O
# 14	<	O
# 15	1	I
# 16	p	O
# 17	.	O
# 18	p	O
# 19	.	O
# 20	b	I
# 21	.	O
#
# 1	In	O
# 2	addition	O
# 3	to	O
# 4	its	O
# 5	elongation	B
# 6	activity	O
# 7	,	O
# 8	ELL	B
# 9	contains	O
# 10	a	O
# 11	novel	O
# 12	type	I
# 13	of	O
# 14	RNA	B
# 15	polymerase	I
# 16	II	I
# 17	interaction	O
# 18	domain	I
# 19	that	O
# 20	is	O
# 21	capable	O
# 22	of	O
# 23	repressing	O
# 24	polymerase	I
# 25	activity	O
# 26	in	O
# 27	promoter	I
# 28	-	I
# 29	specific	I
# 30	transcription	I
# 31	.	O
#
# 1	Almost	O
# 2	complete	O
# 3	sequence	I
# 4	identity	O
# 5	was	O
# 6	found	O
# 7	between	O
# 8	the	O
# 9	3	I
# 10	'	O
# 11	end	O
# 12	of	O
# 13	the	O
# 14	DXS6673E	O
# 15	gene	I
# 16	and	O
# 17	two	O
# 18	expressed	O
# 19	sequence	I
# 20	tags	O
# 21	(	O
# 22	ESTs	I
# 23	)	O
# 24	and	O
# 25	between	O
# 26	the	O
# 27	5	I
# 28	'	O
# 29	end	O
# 30	of	O
# 31	the	O
# 32	DXS6673E	O
# 33	gene	I
# 34	and	O
# 35	a	O
# 36	third	O
# 37	EST	B
# 38	.	O
#
# 1	Molecular	O
# 2	cloning	O
# 3	of	O
# 4	the	O
# 5	cDNA	I
# 6	for	O
# 7	the	O
# 8	human	B
# 9	U2	B
# 10	snRNA	I
# 11	-	I
# 12	specific	I
# 13	A	I
# 14	'	O
# 15	protein	I
# 16	.	O
#
# 1	86	I
# 2	:	O
# 3	3199	O
# 4	-	I
# 5	3203	O
# 6	)	O
# 7	or	O
# 8	G1	B
# 9	to	O
# 10	S	I
# 11	phase	O
# 12	(	O
# 13	Reilly	O
# 14	,	O
# 15	C	I
# 16	.	O
#
# 1	Static	O
# 2	and	O
# 3	dynamic	O
# 4	compliance	O
# 5	was	O
# 6	measured	O
# 7	after	O
# 8	induction	O
# 9	of	O
# 10	anesthesia	O
# 11	,	O
# 12	before	O
# 13	and	O
# 14	immediately	O
# 15	after	O
# 16	filtration	O
# 17	in	O
# 18	the	O
# 19	operating	O
# 20	theater	O
# 21	,	O
# 22	1	I
# 23	hour	O
# 24	after	O
# 25	return	O
# 26	to	O
# 27	the	O
# 28	pediatric	O
# 29	intensive	O
# 30	care	O
# 31	unit	I
# 32	,	O
# 33	and	O
# 34	24	O
# 35	hours	O
# 36	after	O
# 37	the	O
# 38	operation	O
# 39	.	O
#
# 1	Problems	O
# 2	remain	O
# 3	to	O
# 4	be	O
# 5	resolved	O
# 6	in	O
# 7	the	O
# 8	area	O
# 9	of	O
# 10	quantitative	O
# 11	risk	O
# 12	assessment	O
# 13	.	O
#
# 1	A	I
# 2	triple	O
# 3	-	I
# 4	mutant	I
# 5	TBP	B
# 6	(	O
# 7	R231E	O
# 8	+	I
# 9	R235E	O
# 10	+	I
# 11	R239S	O
# 12	)	O
# 13	had	O
# 14	greatly	O
# 15	reduced	O
# 16	activity	O
# 17	for	O
# 18	yeast	B
# 19	U6	B
# 20	snRNA	I
# 21	gene	I
# 22	transcription	I
# 23	while	O
# 24	remaining	O
# 25	active	O
# 26	for	O
# 27	Pol	B
# 28	II	I
# 29	basal	I
# 30	transcription	I
# 31	.	O
#
# 1	In	O
# 2	all	O
# 3	trials	O
# 4	,	O
# 5	antigen	I
# 6	challenge	O
# 7	followed	O
# 8	1	I
# 9	h	O
# 10	after	O
# 11	the	O
# 12	last	O
# 13	treatment	O
# 14	.	O
#
# 1	All	O
# 2	four	O
# 3	of	O
# 4	the	O
# 5	genes	I
# 6	have	O
# 7	a	O
# 8	similar	O
# 9	structure	O
# 10	,	O
# 11	with	O
# 12	the	O
# 13	receptor	I
# 14	protein	I
# 15	encoded	I
# 16	in	O
# 17	a	O
# 18	single	O
# 19	exon	O
# 20	.	O
#
# 1	The	O
# 2	development	O
# 3	and	O
# 4	distribution	O
# 5	of	O
# 6	Trypanosoma	O
# 7	congolense	O
# 8	,	O
# 9	T	B
# 10	vivax	O
# 11	and	O
# 12	T	B
# 13	brucei	O
# 14	in	O
# 15	the	O
# 16	skin	O
# 17	of	O
# 18	goats	O
# 19	was	O
# 20	examined	O
# 21	after	O
# 22	the	O
# 23	animals	O
# 24	were	O
# 25	bitten	O
# 26	by	O
# 27	infected	O
# 28	Glossina	O
# 29	morsitans	O
# 30	centralis	O
# 31	.	O
#
# 1	There	O
# 2	was	O
# 3	also	O
# 4	a	O
# 5	highly	O
# 6	significant	O
# 7	correlation	O
# 8	between	O
# 9	total	O
# 10	selenium	O
# 11	intake	O
# 12	and	O
# 13	liver	O
# 14	selenium	O
# 15	concentration	O
# 16	(	O
# 17	r	O
# 18	=	O
# 19	0	O
# 20	.	O
# 21	99	I
# 22	,	O
# 23	p	O
# 24	<	O
# 25	0	O
# 26	.	O
# 27	01	O
# 28	)	O
# 29	after	O
# 30	1	I
# 31	mo	O
# 32	of	O
# 33	treatment	O
# 34	,	O
# 35	but	O
# 36	this	O
# 37	time	O
# 38	liver	O
# 39	selenium	O
# 40	did	O
# 41	not	O
# 42	change	O
# 43	with	O
# 44	time	O
# 45	,	O
# 46	and	O
# 47	the	O
# 48	correlation	O
# 49	remained	O
# 50	highly	O
# 51	significant	O
# 52	throughout	O
# 53	the	O
# 54	investigation	O
# 55	.	O
#
# 1	When	O
# 2	two	O
# 3	determinations	O
# 4	were	O
# 5	performed	O
# 6	on	O
# 7	12	O
# 8	samples	O
# 9	of	O
# 10	plasma	B
# 11	taken	O
# 12	from	O
# 13	normal	O
# 14	adults	O
# 15	in	O
# 16	October	O
# 17	,	O
# 18	the	O
# 19	values	O
# 20	were	O
# 21	22	O
# 22	.	O
# 23	6	I
# 24	+/-	O
# 25	4	I
# 26	.	O
# 27	8	I
# 28	and	O
# 29	21	O
# 30	.	O
# 31	0	O
# 32	+/-	O
# 33	3	I
# 34	.	O
# 35	6	I
# 36	(	O
# 37	mean	O
# 38	+/-	O
# 39	SD	O
# 40	)	O
# 41	ng	B
# 42	/	I
# 43	ml	O
# 44	,	O
# 45	respectively	O
# 46	.	O
#
# 1	RESULTS	O
# 2	:	O
# 3	Prevalence	O
# 4	of	O
# 5	obesity	O
# 6	(	O
# 7	BMI	O
# 8	SDS	O
# 9	>	O
# 10	2	I
# 11	.	O
# 12	0	O
# 13	)	O
# 14	was	O
# 15	<	O
# 16	2	I
# 17	%	O
# 18	at	O
# 19	diagnosis	O
# 20	,	O
# 21	but	O
# 22	increased	O
# 23	to	O
# 24	16	O
# 25	%	O
# 26	at	O
# 27	3y	O
# 28	.	O
#
# 1	To	O
# 2	investigate	O
# 3	the	O
# 4	potential	O
# 5	role	O
# 6	of	O
# 7	SP1	B
# 8	,	O
# 9	we	O
# 10	examined	O
# 11	nuclear	B
# 12	extracts	O
# 13	from	O
# 14	HCMV	B
# 15	-	I
# 16	infected	O
# 17	cells	O
# 18	.	O
#
# 1	Allagille	O
# 2	'	O
# 3	s	O
# 4	syndrome	O
# 5	associated	I
# 6	with	O
# 7	antenatal	O
# 8	ascites	O
#
# 1	We	O
# 2	found	O
# 3	that	O
# 4	T3	B
# 5	(	O
# 6	10	O
# 7	(-	O
# 8	8	I
# 9	)	O
# 10	M	B
# 11	)	O
# 12	selectively	O
# 13	stimulates	O
# 14	transcription	I
# 15	from	O
# 16	rGH	B
# 17	-	I
# 18	TRE	B
# 19	-	I
# 20	and	O
# 21	TREpal	O
# 22	-,	I
# 23	but	O
# 24	not	O
# 25	ME	B
# 26	-	I
# 27	TRE	B
# 28	-	I
# 29	and	O
# 30	F2	O
# 31	-	I
# 32	TRE	B
# 33	-,	I
# 34	containing	O
# 35	templates	O
# 36	in	O
# 37	which	O
# 38	these	O
# 39	TREs	O
# 40	are	O
# 41	linked	O
# 42	in	O
# 43	front	O
# 44	of	O
# 45	the	O
# 46	rGH	B
# 47	minimal	I
# 48	promoter	I
# 49	containing	O
# 50	only	O
# 51	the	O
# 52	TATA	B
# 53	box	I
# 54	binding	I
# 55	protein	I
# 56	,	O
# 57	but	O
# 58	not	O
# 59	any	O
# 60	other	O
# 61	proximal	I
# 62	binding	I
# 63	protein	I
# 64	,	O
# 65	sequence	I
# 66	.	O
#
# 1	The	O
# 2	deduced	O
# 3	96	O
# 4	-	I
# 5	residue	O
# 6	amino	O
# 7	acid	I
# 8	coding	I
# 9	sequence	I
# 10	of	O
# 11	the	O
# 12	murine	B
# 13	HMG	B
# 14	-	I
# 15	I	I
# 16	(	O
# 17	Y	I
# 18	)	O
# 19	cDNA	I
# 20	is	O
# 21	very	O
# 22	similar	O
# 23	to	O
# 24	the	O
# 25	reported	O
# 26	amino	O
# 27	acid	I
# 28	sequence	I
# 29	of	O
# 30	human	B
# 31	HMG	B
# 32	-	I
# 33	I	I
# 34	,	O
# 35	except	O
# 36	that	O
# 37	it	O
# 38	lacks	O
# 39	11	I
# 40	internal	O
# 41	amino	O
# 42	acids	O
# 43	reported	O
# 44	in	O
# 45	the	O
# 46	human	B
# 47	protein	I
# 48	.	O
#
# 1	SETTING	O
# 2	:	O
# 3	A	I
# 4	division	O
# 5	of	O
# 6	a	O
# 7	large	O
# 8	tea	O
# 9	plantation	O
# 10	in	O
# 11	Kandy	O
# 12	.	O
#
# 1	ZK7	O
# 2	and	O
# 3	HZF16	O
# 4	genes	I
# 5	appear	O
# 6	to	O
# 7	be	O
# 8	the	O
# 9	splice	O
# 10	variants	I
# 11	transcribed	O
# 12	from	O
# 13	the	O
# 14	same	O
# 15	gene	I
# 16	.	O
#
# 1	The	O
# 2	results	O
# 3	confirm	O
# 4	and	O
# 5	extend	O
# 6	previous	O
# 7	work	O
# 8	by	O
# 9	other	O
# 10	researchers	O
# 11	.	O
#
# 1	11	I
# 2	-	I
# 3	Aminoundecanoyl	O
# 4	-	I
# 5	SK	O
# 6	-	I
# 7	NH2	I
# 8	and	O
# 9	11	I
# 10	-	I
# 11	aminoundecanoyl	O
# 12	-	I
# 13	SH	B
# 14	-	I
# 15	NH2	I
# 16	establish	O
# 17	that	O
# 18	a	O
# 19	simple	O
# 20	alkyl	O
# 21	backbone	O
# 22	can	O
# 23	maintain	O
# 24	an	O
# 25	appropriate	O
# 26	distance	O
# 27	between	O
# 28	three	O
# 29	elements	I
# 30	critical	O
# 31	for	O
# 32	recognition	I
# 33	by	O
# 34	the	O
# 35	fungal	B
# 36	enzyme	I
# 37	'	O
# 38	s	O
# 39	peptide	I
# 40	-	I
# 41	binding	I
# 42	site	I
# 43	:	O
# 44	a	O
# 45	simple	O
# 46	omega	I
# 47	-	I
# 48	terminal	I
# 49	amino	O
# 50	group	O
# 51	,	O
# 52	a	O
# 53	beta	I
# 54	-	I
# 55	hydroxyl	O
# 56	,	O
# 57	and	O
# 58	an	O
# 59	epsilon	I
# 60	-	I
# 61	amino	O
# 62	group	O
# 63	or	O
# 64	an	O
# 65	imidazole	O
# 66	.	O
#
# 1	We	O
# 2	characterized	O
# 3	three	O
# 4	Arabidopsis	B
# 5	thaliana	O
# 6	cDNA	I
# 7	clones	O
# 8	that	O
# 9	could	O
# 10	rescue	O
# 11	the	O
# 12	sterile	O
# 13	phenotype	O
# 14	of	O
# 15	the	O
# 16	Schizosaccharomyces	B
# 17	pombe	I
# 18	pde1	O
# 19	mutant	I
# 20	,	O
# 21	which	O
# 22	is	O
# 23	defective	O
# 24	in	O
# 25	cAMP	B
# 26	phosphodiesterase	I
# 27	.	O
#
# 1	The	O
# 2	opioid	B
# 3	antagonist	O
# 4	naltrexone	O
# 5	(	O
# 6	0	O
# 7	.	O
# 8	01	O
# 9	-	I
# 10	1	I
# 11	.	O
# 12	0	O
# 13	mg	O
# 14	/	I
# 15	kg	O
# 16	)	O
# 17	antagonized	O
# 18	the	O
# 19	discriminative	O
# 20	stimulus	O
# 21	effects	O
# 22	of	O
# 23	heroin	O
# 24	,	O
# 25	but	O
# 26	naltrexone	O
# 27	at	O
# 28	doses	O
# 29	up	O
# 30	to	O
# 31	10	O
# 32	mg	O
# 33	/	I
# 34	kg	O
# 35	had	O
# 36	no	O
# 37	effect	O
# 38	on	O
# 39	the	O
# 40	discriminative	O
# 41	stimulus	O
# 42	effects	O
# 43	of	O
# 44	cocaine	O
# 45	.	O
#
# 1	The	O
# 2	inhibitory	I
# 3	response	I
# 4	to	O
# 5	taps	O
# 6	is	O
# 7	essentially	O
# 8	a	O
# 9	protective	O
# 10	reflex	O
# 11	which	O
# 12	probably	O
# 13	serves	O
# 14	to	O
# 15	reduce	O
# 16	the	O
# 17	activity	O
# 18	of	O
# 19	the	O
# 20	jaw	O
# 21	-	I
# 22	closing	O
# 23	muscles	O
# 24	when	O
# 25	one	O
# 26	bites	O
# 27	unexpectedly	O
# 28	on	O
# 29	hard	O
# 30	objects	O
# 31	.	O
#
# 1	This	O
# 2	would	O
# 3	have	O
# 4	had	O
# 5	the	O
# 6	effect	O
# 7	of	O
# 8	positioning	O
# 9	the	O
# 10	genes	I
# 11	currently	O
# 12	on	O
# 13	the	O
# 14	long	I
# 15	arm	O
# 16	adjacent	O
# 17	to	O
# 18	the	O
# 19	centromeric	O
# 20	heterochromatin	O
# 21	,	O
# 22	perhaps	O
# 23	resulting	O
# 24	in	O
# 25	a	O
# 26	"	O
# 27	position	O
# 28	effect	O
# 29	"	O
# 30	on	O
# 31	transcription	I
# 32	of	O
# 33	these	O
# 34	genes	I
# 35	.	O
#
# 1	The	O
# 2	encoded	I
# 3	protein	I
# 4	has	O
# 5	a	O
# 6	leader	O
# 7	sequence	I
# 8	of	O
# 9	27	O
# 10	amino	O
# 11	acids	O
# 12	.	O
#
# 1	The	O
# 2	initial	O
# 3	inpatient	O
# 4	experience	O
# 5	for	O
# 6	individuals	O
# 7	with	O
# 8	HIV	B
# 9	-	I
# 10	related	I
# 11	TB	B
# 12	may	O
# 13	be	O
# 14	pivotal	O
# 15	to	O
# 16	the	O
# 17	acceptance	O
# 18	of	O
# 19	and	O
# 20	participation	O
# 21	in	O
# 22	ongoing	O
# 23	TB	B
# 24	care	O
# 25	.	O
#
# 1	Pathogenetic	O
# 2	relationships	O
# 3	between	O
# 4	renal	O
# 5	tubular	O
# 6	acidosis	O
# 7	and	O
# 8	sodium	O
# 9	metabolism	O
# 10	alterations	O
# 11	in	O
# 12	liver	O
# 13	cirrhosis	O
# 14	.	O
#
# 1	Our	O
# 2	laboratory	O
# 3	and	O
# 4	others	O
# 5	have	O
# 6	shown	O
# 7	alternative	O
# 8	splicing	O
# 9	of	O
# 10	up	O
# 11	to	O
# 12	ten	O
# 13	exons	O
# 14	at	O
# 15	a	O
# 16	discrete	O
# 17	extracellular	B
# 18	site	I
# 19	to	O
# 20	be	O
# 21	primarily	O
# 22	responsible	O
# 23	for	O
# 24	the	O
# 25	generation	O
# 26	of	O
# 27	CD44	B
# 28	variant	I
# 29	(	O
# 30	CD44v	O
# 31	)	O
# 32	isoforms	I
# 33	.	O
#
# 1	Risk	O
# 2	of	O
# 3	infection	O
# 4	in	O
# 5	the	O
# 6	treatment	O
# 7	of	O
# 8	fractures	O
#
# 1	Icterus	O
# 2	and	O
# 3	beta	I
# 4	-	I
# 5	thalassemia	O
# 6	in	O
# 7	Congolese	O
# 8	children	O
# 9	in	O
# 10	Brazzaville	O
#
# 1	Proteasomes	O
# 2	are	O
# 3	the	O
# 4	multisubunit	B
# 5	protease	I
# 6	involved	O
# 7	in	O
# 8	the	O
# 9	generation	O
# 10	of	O
# 11	peptides	I
# 12	presented	O
# 13	by	O
# 14	MHC	B
# 15	class	B
# 16	I	I
# 17	molecules	I
# 18	.	O
#
# 1	This	O
# 2	regulation	O
# 3	could	O
# 4	not	O
# 5	be	O
# 6	appreciably	O
# 7	modified	O
# 8	by	O
# 9	enhanced	O
# 10	expression	O
# 11	of	O
# 12	STAT	B
# 13	proteins	I
# 14	.	O
#
# 1	To	O
# 2	define	O
# 3	the	O
# 4	minimal	I
# 5	VDRE	I
# 6	binding	I
# 7	domain	I
# 8	for	O
# 9	human	B
# 10	VDR	B
# 11	(	O
# 12	hVDR	O
# 13	),	O
# 14	a	O
# 15	series	O
# 16	of	O
# 17	C	I
# 18	-	I
# 19	terminally	I
# 20	truncated	B
# 21	hVDR	O
# 22	mutants	I
# 23	(	O
# 24	Delta134	O
# 25	,	O
# 26	Delta113	O
# 27	,	O
# 28	Delta102	O
# 29	,	O
# 30	Delta90	O
# 31	,	O
# 32	Delta84	O
# 33	,	O
# 34	Delta80	O
# 35	,	O
# 36	and	O
# 37	Delta60	O
# 38	)	O
# 39	was	O
# 40	generated	O
# 41	and	O
# 42	expressed	O
# 43	in	O
# 44	bacteria	O
# 45	.	O
#
# 1	The	O
# 2	rCBF	O
# 3	and	O
# 4	vasomotion	O
# 5	were	O
# 6	recorded	O
# 7	by	O
# 8	laser	O
# 9	-	I
# 10	doppler	O
# 11	fluxmetry	O
# 12	.	O
#
# 1	CO2	O
# 2	assimilation	O
# 3	by	O
# 4	chloroplasts	O
# 5	illuminated	O
# 6	on	O
# 7	filter	O
# 8	paper	O
# 9	.	O
#
# 1	UGA	O
# 2	codon	O
# 3	position	O
# 4	affects	O
# 5	the	O
# 6	efficiency	O
# 7	of	O
# 8	selenocysteine	B
# 9	incorporation	O
# 10	into	O
# 11	glutathione	B
# 12	peroxidase	I
# 13	-	I
# 14	1	I
# 15	.	O
#
# 1	We	O
# 2	analysed	O
# 3	two	O
# 4	regions	O
# 5	involved	O
# 6	in	O
# 7	preS2	O
# 8	/	I
# 9	S	I
# 10	gene	I
# 11	transcription	I
# 12	of	O
# 13	the	O
# 14	HBV	B
# 15	adw	O
# 16	subtype	I
# 17	:	O
# 18	the	O
# 19	diverged	O
# 20	TATA	B
# 21	box	I
# 22	and	O
# 23	a	O
# 24	putative	O
# 25	initiator	I
# 26	element	I
# 27	.	O
#
# 1	In	O
# 2	most	O
# 3	subjects	O
# 4	,	O
# 5	markers	O
# 6	of	O
# 7	bone	B
# 8	formation	O
# 9	and	O
# 10	resorption	O
# 11	were	O
# 12	normal	O
# 13	.	O
#
# 1	Possible	O
# 2	roles	O
# 3	of	O
# 4	RAD5	O
# 5	putative	O
# 6	ATPase	I
# 7	/	I
# 8	DNA	I
# 9	helicase	B
# 10	activity	O
# 11	in	O
# 12	DNA	I
# 13	repair	I
# 14	and	O
# 15	in	O
# 16	the	O
# 17	maintenance	O
# 18	of	O
# 19	wild	B
# 20	-	I
# 21	type	I
# 22	rates	O
# 23	of	O
# 24	instability	O
# 25	of	O
# 26	simple	O
# 27	repetitive	I
# 28	sequences	I
# 29	are	O
# 30	discussed	O
# 31	.	O
#
# 1	Oligonucleotide	O
# 2	-	I
# 3	directed	O
# 4	mutagenesis	O
# 5	was	O
# 6	used	O
# 7	to	O
# 8	create	O
# 9	an	O
# 10	NdeI	O
# 11	restriction	O
# 12	site	I
# 13	at	O
# 14	the	O
# 15	natural	O
# 16	ATG	O
# 17	of	O
# 18	the	O
# 19	yeast	B
# 20	R	I
# 21	.	O
#
# 1	Lens	O
# 2	aldose	B
# 3	reductase	I
# 4	in	O
# 5	diabetic	O
# 6	and	O
# 7	galactosemic	O
# 8	cataracts	O
# 9	.	O
#
# 1	Nipponbare	O
# 2	as	O
# 3	well	O
# 4	as	O
# 5	O	I
# 6	.	O
# 7	australiensis	O
# 8	.	O
#
# 1	In	O
# 2	infected	O
# 3	mammalian	B
# 4	cells	O
# 5	,	O
# 6	the	O
# 7	ARV	O
# 8	G	B
# 9	and	O
# 10	GNS	O
# 11	genes	I
# 12	are	O
# 13	transcribed	O
# 14	primarily	O
# 15	as	O
# 16	a	O
# 17	polycistronic	O
# 18	mRNA	I
# 19	which	O
# 20	appears	O
# 21	to	O
# 22	extend	O
# 23	from	O
# 24	the	O
# 25	consensus	I
# 26	sequence	I
# 27	(	O
# 28	AACAG	O
# 29	)	O
# 30	at	O
# 31	the	O
# 32	start	O
# 33	of	O
# 34	the	O
# 35	G	B
# 36	gene	I
# 37	to	O
# 38	the	O
# 39	next	O
# 40	recognized	O
# 41	polyadenylation	O
# 42	signal	I
# 43	(	O
# 44	CATG	O
# 45	[	O
# 46	A	I
# 47	]	I
# 48	7	O
# 49	)	O
# 50	located	O
# 51	697	O
# 52	nucleotides	O
# 53	downstream	O
# 54	of	O
# 55	the	O
# 56	GNS	O
# 57	protein	I
# 58	termination	I
# 59	codon	O
# 60	.	O
#
# 1	The	O
# 2	novel	O
# 3	protein	I
# 4	kinases	I
# 5	,	O
# 6	c	B
# 7	-	I
# 8	Jun	I
# 9	NH2	I
# 10	-	I
# 11	terminal	I
# 12	kinases	I
# 13	(	O
# 14	JNKs	O
# 15	)/	I
# 16	stress	B
# 17	-	I
# 18	activated	I
# 19	protein	I
# 20	kinases	I
# 21	,	O
# 22	are	O
# 23	also	O
# 24	activated	I
# 25	by	O
# 26	TNF	B
# 27	-	I
# 28	alpha	I
# 29	,	O
# 30	IL	B
# 31	-	I
# 32	1	I
# 33	,	O
# 34	and	O
# 35	CD28	O
# 36	costimulation	O
# 37	.	O
#
# 1	Multivariate	O
# 2	logistic	O
# 3	regression	O
# 4	analysis	O
# 5	indicated	O
# 6	that	O
# 7	seropositivity	O
# 8	was	O
# 9	strongly	O
# 10	associated	I
# 11	with	O
# 12	the	O
# 13	prevalence	O
# 14	of	O
# 15	hepatitis	B
# 16	B	I
# 17	in	O
# 18	an	O
# 19	employee	O
# 20	'	O
# 21	s	O
# 22	country	O
# 23	of	O
# 24	birth	O
# 25	and	O
# 26	with	O
# 27	age	O
# 28	.	O
#
# 1	As	O
# 2	predicted	O
# 3	by	O
# 4	the	O
# 5	Wing	O
# 6	and	O
# 7	Kristofferson	O
# 8	model	O
# 9	,	O
# 10	the	O
# 11	durations	O
# 12	of	O
# 13	successive	O
# 14	ISIs	O
# 15	tended	O
# 16	to	O
# 17	be	O
# 18	negatively	O
# 19	correlated	O
# 20	.	O
#
# 1	Tristetraprolin	O
# 2	(	O
# 3	TTP	O
# 4	)	O
# 5	is	O
# 6	the	O
# 7	prototype	O
# 8	of	O
# 9	a	O
# 10	group	O
# 11	of	O
# 12	potential	O
# 13	transcription	I
# 14	factors	I
# 15	that	O
# 16	contain	O
# 17	two	O
# 18	or	O
# 19	more	O
# 20	unusual	O
# 21	CCCH	O
# 22	zinc	B
# 23	fingers	I
# 24	.	O
#
# 1	Interestingly	O
# 2	,	O
# 3	the	O
# 4	RNA	B
# 5	sequences	I
# 6	selected	O
# 7	by	O
# 8	the	O
# 9	mutated	B
# 10	zinc	B
# 11	knuckle	O
# 12	9G8	O
# 13	variant	I
# 14	are	O
# 15	efficiently	O
# 16	recognized	O
# 17	by	O
# 18	SRp20	O
# 19	,	O
# 20	in	O
# 21	agreement	O
# 22	with	O
# 23	the	O
# 24	fact	O
# 25	that	O
# 26	the	O
# 27	RBD	O
# 28	of	O
# 29	9G8	O
# 30	and	O
# 31	SRp20	O
# 32	are	O
# 33	similar	O
# 34	.	O
#
# 1	These	O
# 2	modifications	O
# 3	may	O
# 4	improve	O
# 5	the	O
# 6	interlaboratory	O
# 7	reproducibility	O
# 8	of	O
# 9	CD34	B
# 10	determinations	O
# 11	due	O
# 12	to	O
# 13	the	O
# 14	reduction	O
# 15	in	O
# 16	sample	O
# 17	handling	O
# 18	and	O
# 19	calculation	O
# 20	of	O
# 21	results	O
# 22	.	O
#
# 1	In	O
# 2	support	O
# 3	of	O
# 4	a	O
# 5	role	O
# 6	at	O
# 7	the	O
# 8	spindle	O
# 9	,	O
# 10	two	O
# 11	-	I
# 12	hybrid	O
# 13	library	O
# 14	screening	O
# 15	with	O
# 16	HEF1	B
# 17	identifies	O
# 18	the	O
# 19	human	B
# 20	homolog	I
# 21	of	O
# 22	the	O
# 23	G2	B
# 24	/	I
# 25	M	B
# 26	spindle	O
# 27	-	I
# 28	regulatory	I
# 29	protein	I
# 30	Dim1p	O
# 31	as	O
# 32	a	O
# 33	specific	I
# 34	interactor	O
# 35	with	O
# 36	a	O
# 37	region	I
# 38	of	O
# 39	HEF1	B
# 40	encompassed	O
# 41	in	O
# 42	p55	B
# 43	(	O
# 44	HEF1	B
# 45	).	O
#
# 1	A	I
# 2	-	I
# 3	tracts	O
# 4	functioned	O
# 5	best	O
# 6	when	O
# 7	positioned	O
# 8	close	O
# 9	to	O
# 10	the	O
# 11	-	I
# 12	35	O
# 13	hexamer	O
# 14	rather	O
# 15	than	O
# 16	one	O
# 17	helical	O
# 18	turn	I
# 19	farther	O
# 20	upstream	O
# 21	,	O
# 22	similar	O
# 23	to	O
# 24	the	O
# 25	positioning	O
# 26	optimal	O
# 27	for	O
# 28	UP	I
# 29	element	I
# 30	function	O
# 31	.	O
#
# 1	Nucleoprotein	O
# 2	(	O
# 3	N	I
# 4	)	O
# 5	expressed	O
# 6	by	O
# 7	both	O
# 8	recombinant	B
# 9	vaccinia	I
# 10	virus	I
# 11	and	O
# 12	TGEV	O
# 13	had	O
# 14	a	O
# 15	relative	O
# 16	molecular	O
# 17	mass	O
# 18	(	O
# 19	Mr	O
# 20	)	O
# 21	of	O
# 22	47	B
# 23	,	O
# 24	000	O
# 25	and	O
# 26	was	O
# 27	susceptible	O
# 28	to	O
# 29	degradation	O
# 30	at	O
# 31	the	O
# 32	C	I
# 33	-	I
# 34	terminus	I
# 35	yielding	O
# 36	discrete	O
# 37	breakdown	O
# 38	products	I
# 39	.	O
#
# 1	A	I
# 2	similar	O
# 3	phenomenon	O
# 4	has	O
# 5	been	O
# 6	reported	O
# 7	in	O
# 8	a	O
# 9	few	O
# 10	humans	O
# 11	.	O
#
# 1	The	O
# 2	5	I
# 3	'	O
# 4	untranslated	O
# 5	and	O
# 6	coding	I
# 7	regions	O
# 8	are	O
# 9	contained	O
# 10	within	O
# 11	12	O
# 12	exons	O
# 13	,	O
# 14	with	O
# 15	the	O
# 16	translation	O
# 17	start	O
# 18	site	I
# 19	located	O
# 20	within	O
# 21	the	O
# 22	first	O
# 23	exon	O
# 24	.	O
#
# 1	This	O
# 2	element	I
# 3	was	O
# 4	used	O
# 5	to	O
# 6	screen	O
# 7	an	O
# 8	EMBL3	O
# 9	mouse	B
# 10	genomic	O
# 11	library	O
# 12	.	O
#
# 1	Sequential	O
# 2	cleavage	I
# 3	by	O
# 4	metallopeptidases	O
# 5	and	O
# 6	proteasomes	I
# 7	is	O
# 8	involved	O
# 9	in	O
# 10	processing	O
# 11	HIV	B
# 12	-	I
# 13	1	I
# 14	ENV	B
# 15	epitope	I
# 16	for	O
# 17	endogenous	B
# 18	MHC	B
# 19	class	B
# 20	I	I
# 21	antigen	I
# 22	presentation	O
# 23	.	O
#
# 1	In	O
# 2	this	O
# 3	study	O
# 4	,	O
# 5	to	O
# 6	characterize	O
# 7	the	O
# 8	gene	I
# 9	for	O
# 10	protein	I
# 11	Z	B
# 12	,	O
# 13	its	O
# 14	organization	O
# 15	and	O
# 16	structure	O
# 17	were	O
# 18	determined	O
# 19	by	O
# 20	a	O
# 21	combination	O
# 22	of	O
# 23	PCR	O
# 24	amplification	O
# 25	of	O
# 26	leukocyte	B
# 27	DNA	I
# 28	and	O
# 29	isolation	O
# 30	of	O
# 31	phage	B
# 32	clones	O
# 33	from	O
# 34	a	O
# 35	human	B
# 36	genomic	O
# 37	library	O
# 38	.	O
#
# 1	Furthermore	O
# 2	,	O
# 3	freezing	O
# 4	in	O
# 5	the	O
# 6	presence	O
# 7	of	O
# 8	bovine	B
# 9	lactalbumin	O
# 10	resulted	O
# 11	in	O
# 12	a	O
# 13	good	O
# 14	maintenance	O
# 15	of	O
# 16	the	O
# 17	cellular	B
# 18	viability	O
# 19	and	O
# 20	of	O
# 21	the	O
# 22	CCCD	O
# 23	heterogeneity	O
# 24	in	O
# 25	respect	O
# 26	to	O
# 27	fresh	O
# 28	cells	O
# 29	.	O
#
# 1	Prognostic	O
# 2	value	O
# 3	of	O
# 4	a	O
# 5	treadmill	O
# 6	exercise	O
# 7	score	O
# 8	in	O
# 9	symptomatic	O
# 10	patients	O
# 11	with	O
# 12	nonspecific	O
# 13	ST	O
# 14	-	I
# 15	T	B
# 16	abnormalities	O
# 17	on	O
# 18	resting	O
# 19	ECG	O
# 20	.	O
#
# 1	Structure	O
# 2	and	O
# 3	regulation	O
# 4	of	O
# 5	the	O
# 6	gene	I
# 7	encoding	I
# 8	the	O
# 9	neuron	B
# 10	-	I
# 11	specific	I
# 12	protein	I
# 13	kinase	I
# 14	C	I
# 15	substrate	I
# 16	neurogranin	B
# 17	(	O
# 18	RC3	B
# 19	protein	I
# 20	).	O
#
# 1	Using	O
# 2	autoantibodies	O
# 3	from	O
# 4	a	O
# 5	Sjogren	O
# 6	'	O
# 7	s	O
# 8	syndrome	O
# 9	patient	O
# 10	,	O
# 11	we	O
# 12	have	O
# 13	previously	O
# 14	identified	O
# 15	a	O
# 16	230	O
# 17	-	I
# 18	kDa	I
# 19	peripheral	O
# 20	membrane	I
# 21	protein	I
# 22	associated	I
# 23	with	O
# 24	the	O
# 25	cytosolic	B
# 26	face	O
# 27	of	O
# 28	the	O
# 29	trans	O
# 30	-	I
# 31	Golgi	B
# 32	(	O
# 33	Kooy	O
# 34	,	O
# 35	J	O
# 36	.,	O
# 37	Toh	O
# 38	,	O
# 39	B	I
# 40	.	O
#
# 1	A	I
# 2	complementary	O
# 3	DNA	I
# 4	was	O
# 5	isolated	O
# 6	from	O
# 7	Caenorhabditis	B
# 8	elegans	I
# 9	that	O
# 10	encoded	I
# 11	a	O
# 12	polypeptide	I
# 13	of	O
# 14	1438	O
# 15	amino	O
# 16	acid	I
# 17	residues	O
# 18	,	O
# 19	CeGAP	O
# 20	,	O
# 21	which	O
# 22	contains	O
# 23	a	O
# 24	domain	I
# 25	with	O
# 26	sequence	I
# 27	similarity	O
# 28	to	O
# 29	the	O
# 30	COOH	O
# 31	-	I
# 32	terminal	I
# 33	segment	O
# 34	(	O
# 35	GTPase	B
# 36	-	I
# 37	activating	I
# 38	protein	I
# 39	region	I
# 40	)	O
# 41	of	O
# 42	Bcr	B
# 43	and	O
# 44	other	O
# 45	known	O
# 46	GTPase	B
# 47	-	I
# 48	activating	I
# 49	proteins	I
# 50	of	O
# 51	the	O
# 52	Rho	B
# 53	subfamily	I
# 54	.	O
#
# 1	Plasma	B
# 2	concentrations	O
# 3	of	O
# 4	atracurium	O
# 5	and	O
# 6	laudanosine	O
# 7	were	O
# 8	0	O
# 9	.	O
# 10	73	O
# 11	-	I
# 12	3	I
# 13	.	O
# 14	11	I
# 15	micrograms	O
# 16	ml	O
# 17	-	I
# 18	1	I
# 19	and	O
# 20	0	O
# 21	.	O
# 22	48	O
# 23	-	I
# 24	8	I
# 25	.	O
# 26	65	O
# 27	micrograms	O
# 28	ml	O
# 29	-	I
# 30	1	I
# 31	,	O
# 32	respectively	O
# 33	;	O
# 34	CSF	I
# 35	concentration	O
# 36	of	O
# 37	laudanosine	O
# 38	was	O
# 39	70	I
# 40	-	I
# 41	440	O
# 42	ng	B
# 43	ml	O
# 44	-	I
# 45	1	I
# 46	.	O
#
# 1	These	O
# 2	results	O
# 3	suggest	O
# 4	that	O
# 5	gluconeogenic	O
# 6	genes	I
# 7	are	O
# 8	derepressed	O
# 9	upon	O
# 10	binding	I
# 11	of	O
# 12	Cat8p	O
# 13	,	O
# 14	whose	O
# 15	synthesis	O
# 16	depends	O
# 17	on	O
# 18	the	O
# 19	release	O
# 20	of	O
# 21	Cat4p	O
# 22	(	O
# 23	Mig1p	I
# 24	)	O
# 25	from	O
# 26	the	O
# 27	CAT8	O
# 28	promoter	I
# 29	.	O
#
# 1	Examples	O
# 2	are	O
# 3	using	O
# 4	more	O
# 5	subjects	O
# 6	or	O
# 7	an	O
# 8	improved	O
# 9	research	O
# 10	design	O
# 11	,	O
# 12	developing	O
# 13	consensus	I
# 14	statements	O
# 15	or	O
# 16	using	O
# 17	meta	O
# 18	-	I
# 19	analysis	O
# 20	.	O
#
# 1	Therefore	O
# 2	,	O
# 3	mechanisms	O
# 4	that	O
# 5	control	O
# 6	activation	O
# 7	of	O
# 8	the	O
# 9	MAP	B
# 10	kinase	I
# 11	cascade	O
# 12	temporally	O
# 13	and	O
# 14	spatially	O
# 15	may	O
# 16	be	O
# 17	important	O
# 18	for	O
# 19	specification	O
# 20	of	O
# 21	cellular	B
# 22	responses	O
# 23	.	O
#
# 1	The	O
# 2	mean	O
# 3	transfer	B
# 4	ratios	O
# 5	of	O
# 6	the	O
# 7	drug	O
# 8	into	O
# 9	the	O
# 10	genital	B
# 11	tissues	O
# 12	to	O
# 13	the	O
# 14	concentration	O
# 15	in	O
# 16	the	O
# 17	uterine	O
# 18	arterial	O
# 19	blood	O
# 20	were	O
# 21	such	O
# 22	that	O
# 23	the	O
# 24	transfer	B
# 25	ratio	O
# 26	into	O
# 27	the	O
# 28	portio	O
# 29	vaginalis	O
# 30	was	O
# 31	the	O
# 32	highest	O
# 33	,	O
# 34	followed	O
# 35	by	O
# 36	the	O
# 37	uterine	O
# 38	cervix	O
# 39	and	O
# 40	the	O
# 41	myometrium	O
# 42	,	O
# 43	and	O
# 44	that	O
# 45	into	O
# 46	the	O
# 47	oviduct	O
# 48	was	O
# 49	the	O
# 50	lowest	O
# 51	with	O
# 52	about	O
# 53	1	I
# 54	/	I
# 55	2	I
# 56	that	O
# 57	into	O
# 58	the	O
# 59	portio	O
# 60	vaginalis	O
# 61	.	O
#
# 1	Workers	O
# 2	with	O
# 3	"	O
# 4	sensitivity	O
# 5	"	O
# 6	to	O
# 7	toluene	O
# 8	diisocyanate	O
# 9	(	O
# 10	TDI	O
# 11	)	O
# 12	studied	O
# 13	in	O
# 14	depth	O
# 15	in	O
# 16	an	O
# 17	attempt	O
# 18	to	O
# 19	determine	O
# 20	mechanisms	O
# 21	of	O
# 22	bronchial	O
# 23	hyperreactivity	O
# 24	.	O
#
# 1	We	O
# 2	examined	O
# 3	behavioral	O
# 4	alterations	O
# 5	in	O
# 6	the	O
# 7	brown	O
# 8	cockroach	O
# 9	,	O
# 10	Periplaneta	O
# 11	brunnea	O
# 12	,	O
# 13	infected	O
# 14	with	O
# 15	the	O
# 16	acanthocephalan	O
# 17	,	O
# 18	Moniliformis	O
# 19	moniliformis	O
# 20	.	O
#
# 1	The	O
# 2	subunit	I
# 3	protein	I
# 4	of	O
# 5	curli	O
# 6	was	O
# 7	highly	O
# 8	homologous	I
# 9	at	O
# 10	its	O
# 11	amino	O
# 12	terminus	I
# 13	to	O
# 14	SEF	O
# 15	-	I
# 16	17	O
# 17	,	O
# 18	the	O
# 19	subunit	I
# 20	protein	I
# 21	of	O
# 22	thin	O
# 23	,	O
# 24	aggregative	O
# 25	fimbriae	O
# 26	of	O
# 27	Salmonella	B
# 28	enteritidis	O
# 29	27655	O
# 30	strain	O
# 31	3b	O
# 32	,	O
# 33	suggesting	O
# 34	that	O
# 35	these	O
# 36	fibres	O
# 37	form	O
# 38	a	O
# 39	novel	O
# 40	class	B
# 41	of	O
# 42	surface	I
# 43	organelles	O
# 44	on	O
# 45	enterobacteria	O
# 46	.	O
#
# 1	Furthermore	O
# 2	,	O
# 3	expression	O
# 4	of	O
# 5	the	O
# 6	promoter	I
# 7	in	O
# 8	embryonic	O
# 9	Drosophila	B
# 10	melanogaster	I
# 11	cells	O
# 12	that	O
# 13	lack	O
# 14	MyoD1	O
# 15	and	O
# 16	Sp1	B
# 17	is	O
# 18	strictly	O
# 19	dependent	I
# 20	on	O
# 21	all	O
# 22	three	O
# 23	sites	I
# 24	remaining	O
# 25	intact	O
# 26	and	O
# 27	on	O
# 28	the	O
# 29	presence	O
# 30	of	O
# 31	exogenously	O
# 32	supplied	O
# 33	Sp1	B
# 34	and	O
# 35	MyoD1	O
# 36	.	O
#
# 1	LY290181	O
# 2	appears	O
# 3	to	O
# 4	inhibit	O
# 5	uPA	B
# 6	promoter	I
# 7	activation	O
# 8	by	O
# 9	blocking	O
# 10	phorbol	O
# 11	ester	O
# 12	-	I
# 13	stimulated	O
# 14	binding	I
# 15	of	O
# 16	nuclear	B
# 17	proteins	I
# 18	to	O
# 19	the	O
# 20	uPA	B
# 21	PEA3	B
# 22	/	I
# 23	12	O
# 24	-	I
# 25	0	O
# 26	-	I
# 27	tetradecanoylphorbol	O
# 28	13	O
# 29	-	I
# 30	acetate	O
# 31	responsive	I
# 32	element	I
# 33	(	O
# 34	TRE	B
# 35	).	O
#
# 1	Thalamotomy	O
# 2	aiming	O
# 3	at	O
# 4	the	O
# 5	CM	B
# 6	-	I
# 7	Pf	O
# 8	complex	I
# 9	and	O
# 10	using	O
# 11	stereotactic	O
# 12	gamma	I
# 13	irradiation	O
# 14	has	O
# 15	been	O
# 16	performed	O
# 17	in	O
# 18	a	O
# 19	series	O
# 20	of	O
# 21	52	O
# 22	patients	O
# 23	with	O
# 24	severe	O
# 25	pain	O
# 26	due	O
# 27	to	O
# 28	malignancy	O
# 29	.	O
#
# 1	The	O
# 2	IE13	O
# 3	.	O
# 4	1	I
# 5	cell	I
# 6	line	O
# 7	was	O
# 8	able	O
# 9	to	O
# 10	complement	B
# 11	a	O
# 12	recombinant	B
# 13	virus	I
# 14	in	O
# 15	which	O
# 16	both	O
# 17	copies	O
# 18	of	O
# 19	the	O
# 20	IE	B
# 21	gene	I
# 22	were	O
# 23	replaced	O
# 24	by	O
# 25	insertion	O
# 26	of	O
# 27	the	O
# 28	Escherichia	B
# 29	coli	I
# 30	lacZ	B
# 31	gene	I
# 32	.	O
#
# 1	Effects	O
# 2	of	O
# 3	prostaglandin	B
# 4	inhibitors	O
# 5	on	O
# 6	the	O
# 7	onset	O
# 8	of	O
# 9	proteinuria	O
# 10	and	O
# 11	stroke	O
# 12	in	O
# 13	stroke	O
# 14	-	I
# 15	prone	O
# 16	spontaneously	O
# 17	hypertensive	O
# 18	rats	O
# 19	.	O
#
# 1	Collectively	O
# 2	,	O
# 3	these	O
# 4	data	O
# 5	indicate	O
# 6	that	O
# 7	HIP	O
# 8	is	O
# 9	a	O
# 10	membrane	I
# 11	-	I
# 12	associated	I
# 13	HP	O
# 14	-	I
# 15	binding	I
# 16	protein	I
# 17	expressed	O
# 18	on	O
# 19	the	O
# 20	surface	I
# 21	of	O
# 22	normal	O
# 23	human	B
# 24	uterine	O
# 25	epithelia	O
# 26	and	O
# 27	uterine	O
# 28	epithelial	B
# 29	cell	I
# 30	lines	O
# 31	.	O
#
# 1	In	O
# 2	Schizosaccharomyces	B
# 3	pombe	I
# 4	,	O
# 5	the	O
# 6	activity	O
# 7	of	O
# 8	the	O
# 9	M	B
# 10	-	I
# 11	phase	O
# 12	-	I
# 13	inducing	O
# 14	Cdc2	B
# 15	/	I
# 16	Cdc13	O
# 17	cyclin	B
# 18	-	I
# 19	dependent	I
# 20	kinase	I
# 21	is	O
# 22	inhibited	O
# 23	by	O
# 24	Wee1	B
# 25	and	O
# 26	Mik1	O
# 27	tyrosine	I
# 28	kinases	I
# 29	,	O
# 30	and	O
# 31	activated	I
# 32	by	O
# 33	Cdc25	B
# 34	and	O
# 35	Pyp3	O
# 36	tyrosine	I
# 37	phosphatases	I
# 38	.	O
#
# 1	However	O
# 2	,	O
# 3	parallax	O
# 4	measurements	O
# 5	showed	O
# 6	that	O
# 7	at	O
# 8	150K	O
# 9	,	O
# 10	collapse	O
# 11	of	O
# 12	Epon	O
# 13	sections	O
# 14	does	O
# 15	not	O
# 16	take	O
# 17	place	O
# 18	.	O
#
# 1	Three	O
# 2	group	O
# 3	1	I
# 4	patients	O
# 5	developed	O
# 6	CMV	I
# 7	disease	O
# 8	;	O
# 9	1	I
# 10	group	O
# 11	2	I
# 12	patient	O
# 13	developed	O
# 14	CMV	I
# 15	hepatitis	B
# 16	.	O
#
# 1	It	O
# 2	applies	O
# 3	Udry	O
# 4	'	O
# 5	s	O
# 6	biosocial	O
# 7	perspective	O
# 8	,	O
# 9	which	O
# 10	attempts	O
# 11	to	O
# 12	reconcile	O
# 13	the	O
# 14	biological	O
# 15	and	O
# 16	sociological	O
# 17	models	O
# 18	of	O
# 19	premarital	O
# 20	sexual	O
# 21	and	O
# 22	reproductive	O
# 23	behaviour	O
# 24	.	O
#
# 1	In	O
# 2	addition	O
# 3	,	O
# 4	carp	O
# 5	JAK1	B
# 6	shows	O
# 7	higher	O
# 8	sequence	I
# 9	homology	I
# 10	to	O
# 11	mammalian	B
# 12	JAK1	B
# 13	in	O
# 14	both	O
# 15	the	O
# 16	kinase	I
# 17	-	I
# 18	like	I
# 19	(	O
# 20	JH2	O
# 21	)	O
# 22	and	O
# 23	kinase	I
# 24	(	O
# 25	JH1	O
# 26	)	O
# 27	domains	I
# 28	(	O
# 29	approximately	O
# 30	70	I
# 31	%	O
# 32	identity	O
# 33	).	O
#
# 1	Following	O
# 2	the	O
# 3	patients	O
# 4	during	O
# 5	a	O
# 6	course	O
# 7	of	O
# 8	therapy	O
# 9	with	O
# 10	a	O
# 11	selective	O
# 12	vasodilator	O
# 13	calcium	O
# 14	antagonist	O
# 15	,	O
# 16	the	O
# 17	beta	I
# 18	-	I
# 19	adrenergic	I
# 20	reflex	O
# 21	vasodilation	O
# 22	became	O
# 23	substantially	O
# 24	attenuated	O
# 25	but	O
# 26	was	O
# 27	preserved	O
# 28	during	O
# 29	a	O
# 30	placebo	O
# 31	course	O
# 32	of	O
# 33	therapy	O
# 34	.	O
#
# 1	On	O
# 2	the	O
# 3	basis	O
# 4	of	O
# 5	this	O
# 6	anatomic	O
# 7	concept	O
# 8	,	O
# 9	the	O
# 10	brachioplasty	O
# 11	procedure	O
# 12	was	O
# 13	modified	O
# 14	to	O
# 15	provide	O
# 16	secure	O
# 17	anchoring	O
# 18	of	O
# 19	the	O
# 20	arm	O
# 21	flap	O
# 22	to	O
# 23	the	O
# 24	axillary	O
# 25	fascia	O
# 26	along	O
# 27	with	O
# 28	strong	O
# 29	superficial	O
# 30	fascial	O
# 31	system	O
# 32	repair	I
# 33	of	O
# 34	incisions	O
# 35	,	O
# 36	reducing	O
# 37	the	O
# 38	risk	O
# 39	of	O
# 40	widening	O
# 41	or	O
# 42	migration	O
# 43	of	O
# 44	scars	O
# 45	and	O
# 46	unnatural	O
# 47	contours	O
# 48	.	O
#
# 1	GH	B
# 2	failed	O
# 3	to	O
# 4	stimulate	O
# 5	phosphorylation	O
# 6	or	O
# 7	activation	O
# 8	of	O
# 9	Jun	I
# 10	N	I
# 11	-	I
# 12	terminal	I
# 13	kinase	I
# 14	under	O
# 15	the	O
# 16	conditions	O
# 17	used	O
# 18	.	O
#
# 1	Accumulated	O
# 2	evidence	O
# 3	indicates	O
# 4	that	O
# 5	,	O
# 6	upon	O
# 7	stimulation	O
# 8	with	O
# 9	interferon	B
# 10	-	I
# 11	gamma	I
# 12	(	O
# 13	IFN	B
# 14	-	I
# 15	gamma	I
# 16	),	O
# 17	three	O
# 18	beta	I
# 19	-	I
# 20	type	I
# 21	subunits	I
# 22	,	O
# 23	designated	O
# 24	LMP2	O
# 25	,	O
# 26	LMP7	O
# 27	,	O
# 28	and	O
# 29	PSMB10	O
# 30	,	O
# 31	are	O
# 32	incorporated	O
# 33	into	O
# 34	the	O
# 35	20S	B
# 36	proteasome	I
# 37	by	O
# 38	displacing	O
# 39	the	O
# 40	housekeeping	O
# 41	beta	I
# 42	-	I
# 43	type	I
# 44	subunits	I
# 45	designated	O
# 46	PSMB6	O
# 47	,	O
# 48	PSMB5	O
# 49	,	O
# 50	and	O
# 51	PSMB7	O
# 52	,	O
# 53	respectively	O
# 54	.	O
#
# 1	The	O
# 2	nerve	B
# 3	growth	I
# 4	factor	I
# 5	beta	I
# 6	gene	I
# 7	(	O
# 8	NGFB	O
# 9	)	O
# 10	belongs	O
# 11	to	O
# 12	a	O
# 13	conserved	O
# 14	syntenic	O
# 15	group	O
# 16	on	O
# 17	human	B
# 18	chromosome	O
# 19	1	I
# 20	and	O
# 21	mouse	B
# 22	Chromosome	O
# 23	3	I
# 24	.	O
#
# 1	Antibodies	O
# 2	specific	I
# 3	to	O
# 4	rE12	O
# 5	and	O
# 6	rNFIL	O
# 7	-	I
# 8	6	I
# 9	disrupt	O
# 10	nucleoprotein	I
# 11	complexes	I
# 12	with	O
# 13	these	O
# 14	DNA	I
# 15	-	I
# 16	binding	I
# 17	sites	I
# 18	,	O
# 19	confirming	O
# 20	the	O
# 21	interaction	O
# 22	of	O
# 23	native	B
# 24	in	O
# 25	vivo	O
# 26	factors	I
# 27	.	O
#
# 1	These	O
# 2	results	O
# 3	indicate	O
# 4	that	O
# 5	during	O
# 6	pregnancy	O
# 7	there	O
# 8	are	O
# 9	increases	O
# 10	in	O
# 11	bone	B
# 12	formation	O
# 13	rates	O
# 14	contributing	O
# 15	to	O
# 16	the	O
# 17	increases	O
# 18	in	O
# 19	skeletal	B
# 20	mass	O
# 21	.	O
#
# 1	In	O
# 2	one	O
# 3	mechanism	O
# 4	,	O
# 5	a	O
# 6	specialized	O
# 7	ubiquitin	B
# 8	-	I
# 9	dependent	I
# 10	proteolytic	I
# 11	system	O
# 12	(	O
# 13	called	O
# 14	the	O
# 15	APC	B
# 16	-	I
# 17	dependent	I
# 18	proteolysis	O
# 19	machinery	O
# 20	)	O
# 21	degrades	O
# 22	the	O
# 23	mitotic	O
# 24	(	O
# 25	Clb	B
# 26	)	O
# 27	cyclin	B
# 28	subunit	I
# 29	.	O
#
# 1	Serum	B
# 2	creatine	B
# 3	kinase	I
# 4	(	O
# 5	SCK	O
# 6	)	O
# 7	was	O
# 8	measured	O
# 9	in	O
# 10	ten	O
# 11	subjects	O
# 12	in	O
# 13	the	O
# 14	laboratory	O
# 15	before	O
# 16	and	O
# 17	after	O
# 18	the	O
# 19	performance	O
# 20	of	O
# 21	bicycle	O
# 22	ergometry	O
# 23	and	O
# 24	a	O
# 25	lifting	O
# 26	task	O
# 27	.	O
#
# 1	This	O
# 2	sequence	I
# 3	is	O
# 4	almost	O
# 5	identical	O
# 6	with	O
# 7	that	O
# 8	of	O
# 9	human	B
# 10	luteinizing	B
# 11	hormone	I
# 12	(	O
# 13	Sairam	O
# 14	,	O
# 15	M	B
# 16	.	O
#
# 1	A	I
# 2	clinical	O
# 3	,	O
# 4	serological	O
# 5	and	O
# 6	prognostic	O
# 7	study	O
#
# 1	In	O
# 2	similar	O
# 3	transient	O
# 4	transfection	O
# 5	experiments	O
# 6	in	O
# 7	HeLa	O
# 8	cells	O
# 9	,	O
# 10	overexpression	O
# 11	of	O
# 12	the	O
# 13	wt	B
# 14	human	B
# 15	retinoblastoma	B
# 16	susceptibility	O
# 17	gene	I
# 18	product	I
# 19	,	O
# 20	RB	B
# 21	,	O
# 22	was	O
# 23	found	O
# 24	to	O
# 25	repress	O
# 26	the	O
# 27	serum	B
# 28	-	I
# 29	induced	O
# 30	IL	B
# 31	-	I
# 32	6	I
# 33	(-	O
# 34	225	O
# 35	to	O
# 36	+	I
# 37	13	O
# 38	),	O
# 39	c	B
# 40	-	I
# 41	fos	I
# 42	(-	O
# 43	711	O
# 44	to	O
# 45	+	I
# 46	42	O
# 47	),	O
# 48	and	O
# 49	beta	I
# 50	-	I
# 51	actin	B
# 52	(-	O
# 53	3400	O
# 54	to	O
# 55	+	I
# 56	912	O
# 57	)	O
# 58	promoters	I
# 59	but	O
# 60	not	O
# 61	the	O
# 62	PRV	O
# 63	-	I
# 64	induced	O
# 65	IL	B
# 66	-	I
# 67	6	I
# 68	(-	O
# 69	110	I
# 70	to	O
# 71	+	I
# 72	13	O
# 73	)	O
# 74	or	O
# 75	the	O
# 76	serum	B
# 77	-	I
# 78	induced	O
# 79	MHC	B
# 80	(-	O
# 81	528	O
# 82	to	O
# 83	-	I
# 84	38	O
# 85	)	O
# 86	promoters	I
# 87	.	O
#
# 1	Cotransfection	O
# 2	analyses	O
# 3	of	O
# 4	the	O
# 5	T	B
# 6	/	I
# 7	EBP	I
# 8	promoter	I
# 9	-	I
# 10	reporter	I
# 11	constructs	I
# 12	with	O
# 13	a	O
# 14	T	B
# 15	/	I
# 16	EBP	I
# 17	expression	O
# 18	vector	O
# 19	into	O
# 20	human	B
# 21	HepG2	I
# 22	cells	O
# 23	,	O
# 24	which	O
# 25	do	O
# 26	not	O
# 27	express	O
# 28	T	B
# 29	/	I
# 30	EBP	I
# 31	,	O
# 32	suggested	O
# 33	that	O
# 34	autoregulation	O
# 35	may	O
# 36	be	O
# 37	involved	O
# 38	in	O
# 39	controlling	O
# 40	both	O
# 41	rat	B
# 42	and	O
# 43	human	B
# 44	T	B
# 45	/	I
# 46	EBP	I
# 47	gene	I
# 48	expression	O
# 49	.	O
#
# 1	In	O
# 2	Malmo	O
# 3	,	O
# 4	Sweden	O
# 5	,	O
# 6	17	O
# 7	,	O
# 8	181	O
# 9	school	O
# 10	children	O
# 11	born	O
# 12	in	O
# 13	the	O
# 14	years	O
# 15	1961	O
# 16	-	I
# 17	1965	O
# 18	were	O
# 19	screened	O
# 20	for	O
# 21	scoliosis	O
# 22	once	O
# 23	a	O
# 24	year	O
# 25	between	O
# 26	the	O
# 27	ages	O
# 28	of	O
# 29	7	O
# 30	and	O
# 31	16	O
# 32	years	O
# 33	,	O
# 34	during	O
# 35	1971	O
# 36	-	I
# 37	1980	O
# 38	.	O
#
# 1	In	O
# 2	contrast	O
# 3	,	O
# 4	the	O
# 5	neu	B
# 6	proto	I
# 7	-	I
# 8	oncogene	I
# 9	did	O
# 10	not	O
# 11	show	O
# 12	kinase	I
# 13	activity	O
# 14	or	O
# 15	transforming	B
# 16	properties	O
# 17	when	O
# 18	expressed	O
# 19	at	O
# 20	similar	O
# 21	levels	O
# 22	in	O
# 23	NIH	I
# 24	3T3	O
# 25	cells	O
# 26	.(	O
# 27	ABSTRACT	O
# 28	TRUNCATED	O
# 29	AT	B
# 30	250	O
# 31	WORDS	O
# 32	)	O
#
# 1	One	O
# 2	of	O
# 3	these	O
# 4	factors	I
# 5	,	O
# 6	HRF	O
# 7	-	I
# 8	1	I
# 9	,	O
# 10	recognizes	O
# 11	a	O
# 12	cis	I
# 13	element	I
# 14	consisting	O
# 15	of	O
# 16	an	O
# 17	inverted	O
# 18	palindromic	O
# 19	motif	I
# 20	.	O
#
# 1	Since	O
# 2	1968	O
# 3	,	O
# 4	a	O
# 5	steep	O
# 6	decrease	O
# 7	in	O
# 8	the	O
# 9	number	O
# 10	of	O
# 11	strains	O
# 12	resistant	O
# 13	to	O
# 14	three	O
# 15	or	O
# 16	more	O
# 17	antibiotics	O
# 18	(	O
# 19	multiple	O
# 20	-	I
# 21	resistant	O
# 22	)	O
# 23	and	O
# 24	in	O
# 25	strains	O
# 26	of	O
# 27	the	O
# 28	83A	O
# 29	complex	I
# 30	was	O
# 31	noticed	O
# 32	.	O
#
# 1	The	O
# 2	ubiquitously	O
# 3	expressed	O
# 4	hypoxia	B
# 5	-	I
# 6	inducible	I
# 7	factor	I
# 8	-	I
# 9	1	I
# 10	(	O
# 11	HIF	B
# 12	-	I
# 13	1	I
# 14	)	O
# 15	is	O
# 16	involved	O
# 17	in	O
# 18	expression	O
# 19	of	O
# 20	a	O
# 21	large	O
# 22	number	O
# 23	of	O
# 24	oxygen	O
# 25	-	I
# 26	regulated	I
# 27	genes	I
# 28	.	O
#
# 1	Characterization	O
# 2	of	O
# 3	the	O
# 4	promoter	I
# 5	for	O
# 6	the	O
# 7	human	B
# 8	85	I
# 9	kDa	I
# 10	cytosolic	B
# 11	phospholipase	B
# 12	A2	I
# 13	gene	I
# 14	.	O
#
# 1	Hematocrit	O
# 2	and	O
# 3	PaO2	O
# 4	did	O
# 5	not	O
# 6	change	O
# 7	.	O
#
# 1	A	I
# 2	pharmacokinetic	O
# 3	study	O
# 4	of	O
# 5	apalcillin	O
# 6	was	O
# 7	performed	O
# 8	in	O
# 9	12	O
# 10	patients	O
# 11	in	O
# 12	an	O
# 13	intensive	O
# 14	-	I
# 15	care	O
# 16	unit	I
# 17	.	O
#
# 1	This	O
# 2	study	O
# 3	allows	O
# 4	us	O
# 5	to	O
# 6	draw	O
# 7	conclusions	O
# 8	about	O
# 9	the	O
# 10	identity	O
# 11	of	O
# 12	proteins	I
# 13	required	O
# 14	for	O
# 15	the	O
# 16	development	O
# 17	of	O
# 18	the	O
# 19	nervous	O
# 20	system	O
# 21	in	O
# 22	Drosophila	B
# 23	and	O
# 24	provides	O
# 25	an	O
# 26	example	O
# 27	of	O
# 28	a	O
# 29	molecular	O
# 30	approach	O
# 31	to	O
# 32	characterize	O
# 33	en	B
# 34	masse	O
# 35	transposon	I
# 36	-	I
# 37	tagged	I
# 38	mutations	I
# 39	identified	O
# 40	in	O
# 41	genetic	O
# 42	screens	O
# 43	.	O
#
# 1	DESIGN	O
# 2	AND	B
# 3	METHODS	O
# 4	:	O
# 5	Case	O
# 6	study	O
# 7	.	O
#
# 1	Effect	O
# 2	of	O
# 3	Azadirachta	O
# 4	indica	O
# 5	hydroalcoholic	O
# 6	leaf	O
# 7	extract	O
# 8	on	O
# 9	the	O
# 10	cardiovascular	O
# 11	system	O
# 12	.	O
#
# 1	Three	O
# 2	mog	O
# 3	-	I
# 4	1	I
# 5	alleles	I
# 6	possess	O
# 7	premature	O
# 8	stop	O
# 9	codons	O
# 10	and	O
# 11	are	O
# 12	likely	O
# 13	to	O
# 14	be	O
# 15	null	I
# 16	alleles	I
# 17	,	O
# 18	and	O
# 19	one	O
# 20	is	O
# 21	a	O
# 22	missense	O
# 23	mutation	I
# 24	and	O
# 25	is	O
# 26	likely	O
# 27	to	O
# 28	retain	O
# 29	residual	O
# 30	activity	O
# 31	.	O
# 32	mog	O
# 33	-	I
# 34	1	I
# 35	mRNA	I
# 36	is	O
# 37	expressed	O
# 38	in	O
# 39	both	O
# 40	germ	B
# 41	line	O
# 42	and	O
# 43	somatic	O
# 44	tissues	O
# 45	and	O
# 46	appears	O
# 47	to	O
# 48	be	O
# 49	ubiquitous	O
# 50	.	O
#
# 1	Anti	B
# 2	-	I
# 3	anxiety	O
# 4	action	O
# 5	of	O
# 6	diazepam	B
# 7	after	O
# 8	intra	O
# 9	-	I
# 10	amygdaloid	O
# 11	application	O
# 12	in	O
# 13	the	O
# 14	rat	B
# 15	.	O
#
# 1	202	O
# 2	-	I
# 3	8	I
# 4	.	O
#
# 1	Magnetic	O
# 2	trapping	O
# 3	of	O
# 4	spin	O
# 5	-	I
# 6	polarized	O
# 7	atomic	O
# 8	hydrogen	O
# 9	.	O
#
# 1	We	O
# 2	have	O
# 3	improved	O
# 4	our	O
# 5	system	O
# 6	for	O
# 7	nuclear	B
# 8	contour	O
# 9	digitization	O
# 10	and	O
# 11	determined	O
# 12	its	O
# 13	theoretical	O
# 14	limitations	O
# 15	by	O
# 16	digitizing	O
# 17	standardized	O
# 18	objects	O
# 19	.	O
#
# 1	CREB	B
# 2	was	O
# 3	identified	O
# ...
# 24	pyrimidine	O
# 25	-	I
# 26	rich	I
# 27	DNA	I
# 28	.	O
#
# 1	Based	O
# 2	on	O
# 3	213	O
# 4	determinations	O
# 5	,	O
# 6	the	O
# 7	control	O
# 8	mean	O
# 9	serum	B
# 10	CPK	B
# 11	activity	O
# 12	was	O
# 13	262	O
# 14	+/-	O
# 15	113	I
# 16	I	I
# 17	.	O
# 18	U	B
# 19	./	O
# 20	liter	O
# 21	.	O
#
# 1	The	O
# 2	NR2	O
# 3	hybrid	O
# 4	is	O
# 5	a	O
# 6	powerful	O
# 7	tool	O
# 8	for	O
# 9	the	O
# 10	mapping	O
# 11	of	O
# 12	new	O
# 13	probes	O
# 14	of	O
# 15	this	O
# 16	region	I
# 17	,	O
# 18	as	O
# 19	well	O
# 20	as	O
# 21	for	O
# 22	obtaining	O
# 23	new	O
# 24	informative	O
# 25	probes	O
# 26	specific	I
# 27	for	O
# 28	the	O
# 29	deletion	I
# 30	by	O
# 31	subtractive	O
# 32	cloning	O
# 33	of	O
# 34	the	O
# 35	region	I
# 36	.	O
#
# 1	In	O
# 2	addition	O
# 3	,	O
# 4	mutation	I
# 5	of	O
# 6	the	O
# 7	Sp1	B
# 8	site	I
# 9	also	O
# 10	significantly	O
# 11	reduced	O
# 12	promoter	I
# 13	activity	O
# 14	.	O
#
# 1	The	O
# 2	aim	O
# 3	of	O
# 4	our	O
# 5	study	O
# 6	was	O
# 7	to	O
# 8	evaluate	O
# 9	the	O
# 10	level	O
# 11	of	O
# 12	oxidative	O
# 13	stress	B
# 14	in	O
# 15	healthy	O
# 16	controls	O
# 17	(	O
# 18	CTL	O
# 19	)	O
# 20	compared	O
# 21	with	O
# 22	CRF	B
# 23	and	O
# 24	HD	B
# 25	patients	O
# 26	before	O
# 27	(	O
# 28	pre	I
# 29	-	I
# 30	HD	B
# 31	)	O
# 32	and	O
# 33	after	O
# 34	(	O
# 35	post	O
# 36	-	I
# 37	HD	B
# 38	)	O
# 39	the	O
# 40	dialysis	O
# 41	session	O
# 42	,	O
# 43	carried	O
# 44	out	O
# 45	on	O
# 46	a	O
# 47	high	O
# 48	biocompatible	O
# 49	polyacrylonitrile	O
# 50	membrane	I
# 51	AN69	O
# 52	.	O
#
# 1	The	O
# 2	p36	B
# 3	gene	I
# 4	is	O
# 5	at	O
# 6	least	O
# 7	22	O
# 8	kb	O
# 9	in	O
# 10	length	I
# 11	and	O
# 12	has	O
# 13	a	O
# 14	coding	I
# 15	sequence	I
# 16	of	O
# 17	approximately	O
# 18	1	I
# 19	kb	O
# 20	,	O
# 21	representing	O
# 22	only	O
# 23	4	I
# 24	.	O
# 25	5	I
# 26	%	O
# 27	of	O
# 28	the	O
# 29	gene	I
# 30	.(	O
# 31	ABSTRACT	O
# 32	TRUNCATED	O
# 33	AT	B
# 34	250	O
# 35	WORDS	O
# 36	)	O
#
# 1	A	I
# 2	catalytic	I
# 3	domain	I
# 4	of	O
# 5	eukaryotic	B
# 6	DNA	I
# 7	topoisomerase	I
# 8	I	I
# 9	.	O
#
# 1	Detection	O
# 2	of	O
# 3	exercise	O
# 4	-	I
# 5	induced	O
# 6	asynergy	O
# 7	by	O
# 8	M	B
# 9	-	I
# 10	mode	O
# 11	echocardiography	O
# 12	.	O
#
# 1	Tumor	B
# 2	necrosis	I
# 3	factor	I
# 4	-	I
# 5	alpha	I
# 6	(	O
# 7	TNF	B
# 8	alpha	I
# 9	),	O
# 10	a	O
# 11	proinflammatory	O
# 12	cytokine	O
# 13	,	O
# 14	inhibits	O
# 15	cAMP	B
# 16	-	I
# 17	stimulated	O
# 18	testosterone	O
# 19	production	O
# 20	in	O
# 21	mouse	B
# 22	Leydig	O
# 23	cells	O
# 24	.	O
#
# 1	A	I
# 2	correlation	O
# 3	coefficient	O
# 4	was	O
# 5	used	O
# 6	for	O
# 7	assessing	O
# 8	the	O
# 9	similarity	O
# 10	of	O
# 11	each	O
# 12	map	O
# 13	pattern	O
# 14	with	O
# 15	the	O
# 16	normal	O
# 17	mean	O
# 18	IQRST	O
# 19	map	O
# 20	.	O
#
# 1	In	O
# 2	the	O
# 3	studies	O
# 4	reported	O
# 5	here	O
# 6	,	O
# 7	the	O
# 8	5	I
# 9	'-	I
# 10	flanking	I
# 11	region	I
# 12	of	O
# 13	the	O
# 14	human	B
# 15	gp130	I
# 16	gene	I
# 17	was	O
# 18	isolated	O
# 19	and	O
# 20	the	O
# 21	transcription	I
# 22	initiation	I
# 23	sites	I
# 24	were	O
# 25	mapped	O
# 26	.	O
#
# 1	Derivatives	O
# 2	of	O
# 3	fluorene	O
# 4	.	O
#
# 1	Coronary	O
# 2	vasoconstriction	O
# 3	caused	O
# 4	by	O
# 5	endothelin	B
# 6	-	I
# 7	1	I
# 8	is	O
# 9	enhanced	O
# 10	by	O
# 11	ischemia	O
# 12	-	I
# 13	reperfusion	O
# 14	and	O
# 15	by	O
# 16	norepinephrine	O
# 17	present	O
# 18	in	O
# 19	concentrations	O
# 20	typically	O
# 21	observed	O
# 22	after	O
# 23	neonatal	O
# 24	cardiopulmonary	O
# 25	bypass	O
# 26	.	O
#
# 1	Erythema	O
# 2	exsudativum	O
# 3	multiforme	O
# 4	induced	O
# 5	by	O
# 6	granulocyte	B
# 7	colony	I
# 8	-	I
# 9	stimulating	I
# 10	factor	I
# 11	in	O
# 12	an	O
# 13	allogeneic	O
# 14	peripheral	O
# 15	blood	O
# 16	stem	O
# 17	cell	I
# 18	donor	O
# 19	.	O
#
# 1	The	O
# 2	cDNAs	I
# 3	cross	O
# 4	-	I
# 5	hybridize	O
# 6	with	O
# 7	genomic	O
# 8	sequences	I
# 9	in	O
# 10	rat	B
# 11	,	O
# 12	human	B
# 13	,	O
# 14	and	O
# 15	chicken	B
# 16	DNA	I
# 17	,	O
# 18	but	O
# 19	not	O
# 20	with	O
# 21	DNA	I
# 22	from	O
# 23	frog	O
# 24	,	O
# 25	Drosophila	B
# 26	,	O
# 27	or	O
# 28	sea	B
# 29	urchin	I
# 30	.	O
#
# 1	Neural	O
# 2	blockade	O
# 3	in	O
# 4	chronic	O
# 5	and	O
# 6	cancer	O
# 7	pain	O
# 8	.	O
#
# 1	Immunofluoresence	O
# 2	data	O
# 3	indicated	O
# 4	that	O
# 5	once	O
# 6	bound	O
# 7	to	O
# 8	the	O
# 9	mutant	I
# 10	receptor	I
# 11	,	O
# 12	fluorescent	I
# 13	-	I
# 14	labeled	O
# 15	RAP	O
# 16	co	O
# 17	-	I
# 18	localized	O
# 19	with	O
# 20	markers	O
# 21	of	O
# 22	the	O
# 23	endosomal	O
# 24	pathway	O
# 25	,	O
# 26	whereas	O
# 27	,	O
# 28	in	O
# 29	cells	O
# 30	expressing	O
# 31	the	O
# 32	wild	B
# 33	-	I
# 34	type	I
# 35	receptor	I
# 36	,	O
# 37	RAP	O
# 38	fluorescence	O
# 39	co	O
# 40	-	I
# 41	localized	O
# 42	with	O
# 43	lysosomal	B
# 44	markers	O
# 45	.	O
#
# 1	A	I
# 2	case	O
# 3	observed	O
# 4	in	O
# 5	Saigon	O
#
# 1	In	O
# 2	the	O
# 3	first	O
# 4	series	O
# 5	of	O
# 6	experiments	O
# 7	,	O
# 8	Sprague	O
# 9	-	I
# 10	Dawley	O
# 11	male	O
# 12	rats	O
# 13	were	O
# 14	implanted	O
# 15	unilaterally	O
# 16	with	O
# 17	guide	O
# 18	cannulas	O
# 19	aimed	O
# 20	at	O
# 21	the	O
# 22	lateral	O
# 23	ventricle	O
# 24	.	O
#
# 1	The	O
# 2	authors	O
# 3	proposed	O
# 4	that	O
# 5	the	O
# 6	highly	O
# 7	convergent	O
# 8	inputs	O
# 9	to	O
# 10	the	O
# 11	entorhinal	O
# 12	cortex	O
# 13	indicate	O
# 14	this	O
# 15	region	I
# 16	may	O
# 17	be	O
# 18	particularly	O
# 19	important	O
# 20	for	O
# 21	selecting	O
# 22	or	O
# 23	compressing	O
# 24	information	O
# 25	.	O
#
# 1	This	O
# 2	article	O
# 3	reviews	O
# 4	recent	O
# 5	information	O
# 6	on	O
# 7	the	O
# 8	frequency	O
# 9	,	O
# 10	characteristics	O
# 11	,	O
# 12	and	O
# 13	possible	O
# 14	pathogenic	O
# 15	mechanisms	O
# 16	of	O
# 17	the	O
# 18	vasculitides	O
# 19	occurring	O
# 20	in	O
# 21	patients	O
# 22	with	O
# 23	the	O
# 24	main	O
# 25	connective	B
# 26	tissue	B
# 27	diseases	O
# 28	.	O
#
# 1	Genomic	O
# 2	organization	O
# 3	of	O
# 4	the	O
# 5	human	B
# 6	phosphodiesterase	I
# 7	PDE11A	O
# 8	gene	I
# 9	.	O
#
# 1	Cloning	O
# 2	and	O
# 3	expression	O
# 4	of	O
# 5	a	O
# 6	specific	I
# 7	human	B
# 8	alpha	I
# 9	1	I
# 10	,	O
# 11	2	I
# 12	-	I
# 13	mannosidase	B
# 14	that	O
# 15	trims	O
# 16	Man9GlcNAc2	O
# 17	to	O
# 18	Man8GlcNAc2	O
# 19	isomer	O
# 20	B	I
# 21	during	O
# 22	N	I
# 23	-	I
# 24	glycan	O
# 25	biosynthesis	O
# 26	.	O
#
# 1	It	O
# 2	is	O
# 3	concluded	O
# 4	that	O
# 5	stereotypy	O
# 6	can	O
# 7	be	O
# 8	evoked	O
# 9	also	O
# 10	in	O
# 11	the	O
# 12	case	O
# 13	when	O
# 14	the	O
# 15	striatal	O
# 16	dopaminergic	O
# 17	tone	O
# 18	is	O
# 19	normal	O
# 20	or	O
# 21	even	O
# 22	below	O
# 23	normal	O
# 24	:	O
# 25	it	O
# 26	is	O
# 27	the	O
# 28	equilibrium	O
# 29	of	O
# 30	the	O
# 31	striatal	O
# 32	cholinergic	O
# 33	-	I
# 34	dopaminergic	O
# 35	systems	O
# 36	which	O
# 37	must	O
# 38	be	O
# 39	shifted	O
# 40	towards	O
# 41	dopamine	B
# 42	,	O
# 43	which	O
# 44	is	O
# 45	necessary	O
# 46	for	O
# 47	the	O
# 48	development	O
# 49	of	O
# 50	this	O
# 51	behavioral	O
# 52	manifestation	O
# 53	.	O
#
# 1	Cardiovascular	O
# 2	risk	O
# 3	factors	I
# 4	were	O
# 5	measured	O
# 6	by	O
# 7	standardized	O
# 8	techniques	O
# 9	.	O
#
# 1	The	O
# 2	enhancer	I
# 3	region	I
# 4	of	O
# 5	Akv	O
# 6	murine	B
# 7	leukemia	I
# 8	virus	I
# 9	contains	O
# 10	the	O
# 11	sequence	I
# 12	motif	I
# 13	ACAGATGG	O
# 14	.	O
#
# 1	A	I
# 2	2	I
# 3	.	O
# 4	4	I
# 5	-	I
# 6	kb	O
# 7	MAPKAPK	I
# 8	-	I
# 9	2	I
# 10	message	I
# 11	is	O
# 12	expressed	O
# 13	throughout	O
# 14	development	O
# 15	,	O
# 16	while	O
# 17	two	O
# 18	shorter	O
# 19	transcripts	I
# 20	of	O
# 21	2	I
# 22	.	O
# 23	3	I
# 24	and	O
# 25	1	I
# 26	.	O
# 27	8	I
# 28	kb	O
# 29	appear	O
# 30	to	O
# 31	be	O
# 32	specifically	O
# 33	expressed	O
# 34	in	O
# 35	the	O
# 36	germline	I
# 37	.	O
#
# 1	At	O
# 2	rest	O
# 3	AFF	O
# 4	was	O
# 5	significantly	O
# 6	higher	O
# 7	in	O
# 8	UT	O
# 9	(	O
# 10	29	O
# 11	%)	O
# 12	as	O
# 13	compared	O
# 14	to	O
# 15	AT	B
# 16	(	O
# 17	25	O
# 18	%)	O
# 19	and	O
# 20	UEA	O
# 21	(	O
# 22	25	O
# 23	%).	O
#
# 1	The	O
# 2	use	O
# 3	of	O
# 4	specific	I
# 5	antibodies	I
# 6	allowed	O
# 7	the	O
# 8	identification	O
# 9	of	O
# 10	at	O
# 11	least	O
# 12	RAR	B
# 13	beta	I
# 14	in	O
# 15	some	O
# 16	of	O
# 17	the	O
# 18	DNA	I
# 19	-	I
# 20	protein	I
# 21	complexes	I
# 22	,	O
# 23	although	O
# 24	the	O
# 25	four	O
# 26	sequences	I
# 27	bind	O
# 28	single	O
# 29	RARs	O
# 30	transfected	O
# 31	in	O
# 32	COS	O
# 33	cells	O
# 34	much	O
# 35	less	O
# 36	efficiently	O
# 37	,	O
# 38	or	O
# 39	not	O
# 40	at	O
# 41	all	O
# 42	,	O
# 43	when	O
# 44	compared	O
# 45	to	O
# 46	a	O
# 47	canonical	O
# 48	RAR	B
# 49	responsive	I
# 50	element	I
# 51	.	O
#
# 1	The	O
# 2	patients	O
# 3	were	O
# 4	divided	O
# 5	into	O
# 6	ischaemia	O
# 7	and	O
# 8	non	O
# 9	-	I
# 10	ischaemia	O
# 11	groups	O
# 12	on	O
# 13	the	O
# 14	basis	O
# 15	of	O
# 16	the	O
# 17	change	O
# 18	in	O
# 19	lactate	B
# 20	extraction	O
# 21	ratio	O
# 22	during	O
# 23	balloon	O
# 24	inflation	O
# 25	.	O
#
# 1	Clinical	O
# 2	applications	O
# 3	of	O
# 4	inhibition	O
# 5	of	O
# 6	beta	I
# 7	-	I
# 8	adrenergic	I
# 9	receptors	I
# 10	with	O
# 11	propranolol	O
# 12	.	O
#
# 1	Spontaneous	O
# 2	sensitization	O
# 3	to	O
# 4	cross	O
# 5	-	I
# 6	reacting	O
# 7	chemicals	O
# 8	in	O
# 9	a	O
# 10	proportion	O
# 11	of	O
# 12	control	O
# 13	animals	O
# 14	is	O
# 15	strongly	O
# 16	suggested	O
# 17	,	O
# 18	somewhat	O
# 19	akin	O
# 20	to	O
# 21	spontaneous	O
# 22	sensitization	O
# 23	in	O
# 24	patients	O
# 25	with	O
# 26	anaphylactoid	O
# 27	reactions	O
# 28	to	O
# 29	neuromuscular	O
# 30	blockers	O
# 31	on	O
# 32	first	O
# 33	exposure	O
# 34	,	O
# 35	and	O
# 36	in	O
# 37	whom	O
# 38	IgE	B
# 39	antibodies	I
# 40	are	O
# 41	detected	O
# 42	.	O
#
# 1	In	O
# 2	contrast	O
# 3	,	O
# 4	similar	O
# 5	rates	O
# 6	of	O
# 7	B	I
# 8	.	O
# 9	sphaericus	O
# 10	products	I
# 11	,	O
# 12	ABG	O
# 13	-	I
# 14	6184	O
# 15	technical	O
# 16	powder	O
# 17	and	O
# 18	BSP	B
# 19	-	I
# 20	2	I
# 21	flowable	O
# 22	concentrate	O
# 23	,	O
# 24	produced	O
# 25	no	O
# 26	significant	O
# 27	reduction	O
# 28	.	O
#
# 1	OKA	O
# 2	and	O
# 3	calyculin	O
# 4	A	I
# 5	do	O
# 6	not	O
# 7	decrease	O
# 8	OCFRE	O
# 9	DNA	I
# 10	-	I
# 11	protein	I
# 12	interactions	O
# 13	,	O
# 14	suggesting	O
# 15	that	O
# 16	important	O
# 17	protein	I
# 18	-	I
# 19	protein	I
# 20	interactions	O
# 21	are	O
# 22	phosphatase	I
# 23	regulated	I
# 24	.	O
#
# 1	Interestingly	O
# 2	,	O
# 3	following	O
# 4	induction	O
# 5	of	O
# 6	stress	B
# 7	by	O
# 8	heat	I
# 9	shock	I
# 10	,	O
# 11	high	O
# 12	salt	O
# 13	,	O
# 14	or	O
# 15	ethanol	O
# 16	,	O
# 17	conditions	O
# 18	under	O
# 19	which	O
# 20	most	O
# 21	mRNA	I
# 22	export	O
# 23	is	O
# 24	blocked	O
# 25	,	O
# 26	Npl3p	O
# 27	is	O
# 28	still	O
# 29	exported	O
# 30	from	O
# 31	the	O
# 32	nucleus	O
# 33	.	O
#
# 1	Two	O
# 2	predominant	O
# 3	effects	O
# 4	were	O
# 5	noted	O
# 6	:	O
# 7	(	O
# 8	i	O
# 9	)	O
# 10	the	O
# 11	Xaa	O
# 12	residue	O
# 13	in	O
# 14	the	O
# 15	dual	O
# 16	phosphorylation	O
# 17	motif	I
# 18	Thr	O
# 19	-	I
# 20	Xaa	O
# 21	-	I
# 22	Tyr	B
# 23	as	O
# 24	well	O
# 25	as	O
# 26	the	O
# 27	length	I
# 28	of	O
# 29	L12	I
# 30	influence	O
# 31	p38	B
# 32	substrate	I
# 33	specificity	O
# 34	,	O
# 35	and	O
# 36	(	O
# 37	ii	O
# 38	)	O
# 39	the	O
# 40	length	I
# 41	of	O
# 42	L12	I
# 43	plays	O
# 44	a	O
# 45	major	B
# 46	role	O
# 47	in	O
# 48	controlling	O
# 49	autophosphorylation	O
# 50	.	O
#
# 1	Therefore	O
# 2	,	O
# 3	we	O
# 4	studied	O
# 5	ninety	O
# 6	coagulopathic	O
# 7	patients	O
# 8	with	O
# 9	the	O
# 10	aim	O
# 11	of	O
# 12	determining	O
# 13	the	O
# 14	prevalence	O
# 15	of	O
# 16	hepatitis	B
# 17	C	I
# 18	virus	I
# 19	(	O
# 20	HCV	I
# 21	)	O
# 22	antibodies	I
# 23	using	O
# 24	the	O
# 25	ELISA	O
# 26	and	O
# 27	RIBA	O
# 28	methods	O
# 29	.	O
#
# 1	Transfection	O
# 2	with	O
# 3	a	O
# 4	CSF	I
# 5	-	I
# 6	1R	I
# 7	expression	O
# 8	plasmid	O
# 9	permitted	O
# 10	CSF	I
# 11	-	I
# 12	1	I
# 13	-	I
# 14	dependent	I
# 15	activation	O
# 16	of	O
# 17	the	O
# 18	signalling	O
# 19	pathway	O
# 20	targeting	O
# 21	an	O
# 22	Ets	B
# 23	/	I
# 24	AP1	B
# 25	(	O
# 26	activator	I
# 27	protein	I
# 28	1	I
# 29	)	O
# 30	element	I
# 31	in	O
# 32	the	O
# 33	uPA	B
# 34	promoter	I
# 35	that	O
# 36	has	O
# 37	been	O
# 38	shown	O
# 39	previously	O
# 40	to	O
# 41	be	O
# 42	a	O
# 43	target	O
# 44	of	O
# 45	oncogenic	B
# 46	ras	B
# 47	and	O
# 48	protein	I
# 49	kinase	I
# 50	C	I
# 51	pathways	O
# 52	.	O
#
# 1	LON	O
# 2	-	I
# 3	72	O
# 4	(	O
# 5	34	I
# 6	isolates	O
# 7	),	O
# 8	LON	O
# 9	-	I
# 10	73	O
# 11	(	O
# 12	1	I
# 13	),	O
# 14	LON	O
# 15	-	I
# 16	71	I
# 17	(	O
# 18	2	I
# 19	)	O
# 20	and	O
# 21	LON	O
# 22	-	I
# 23	10	O
# 24	(	O
# 25	2	I
# 26	)	O
# 27	were	O
# 28	found	O
# 29	at	O
# 30	altitudes	O
# 31	around	O
# 32	2000	O
# 33	m	B
# 34	,	O
# 35	3	I
# 36	of	O
# 37	them	O
# 38	in	O
# 39	a	O
# 40	single	O
# 41	village	O
# 42	.	O
#
# 1	Forty	O
# 2	-	I
# 3	five	O
# 4	cases	O
# 5	were	O
# 6	surgically	O
# 7	by	O
# 8	direct	O
# 9	approach	O
# 10	to	O
# 11	the	O
# 12	tumour	I
# 13	,	O
# 14	while	O
# 15	two	O
# 16	cases	O
# 17	were	O
# 18	treated	O
# 19	only	O
# 20	with	O
# 21	a	O
# 22	shunt	O
# 23	.	O
#
# 1	They	O
# 2	also	O
# 3	reported	O
# 4	that	O
# 5	E	B
# 6	mu	B
# 7	pim	I
# 8	-	I
# 9	1	I
# 10	transgenic	O
# 11	mice	O
# 12	show	O
# 13	greatly	O
# 14	accelerated	O
# 15	lymphoma	O
# 16	development	O
# 17	when	O
# 18	infected	O
# 19	with	O
# 20	wild	B
# 21	-	I
# 22	type	I
# 23	M	B
# 24	-	I
# 25	MuLV	O
# 26	at	O
# 27	birth	O
# 28	.	O
#
# 1	To	O
# 2	study	O
# 3	the	O
# 4	structure	O
# 5	-	I
# 6	function	O
# 7	of	O
# 8	the	O
# 9	gene	I
# 10	5	I
# 11	product	I
# 12	,	O
# 13	wild	B
# 14	-	I
# 15	type	I
# 16	and	O
# 17	mutant	I
# 18	forms	O
# 19	of	O
# 20	NS53	O
# 21	were	O
# 22	produced	O
# 23	by	O
# 24	using	O
# 25	a	O
# 26	recombinant	B
# 27	baculovirus	B
# 28	expression	O
# 29	system	O
# 30	and	O
# 31	a	O
# 32	recombinant	B
# 33	vaccinia	I
# 34	virus	I
# 35	/	I
# 36	T7	B
# 37	(	O
# 38	vTF7	O
# 39	-	I
# 40	3	I
# 41	)	O
# 42	expression	O
# 43	system	O
# 44	.	O
#
# 1	The	O
# 2	N	I
# 3	-	I
# 4	syndecan	O
# 5	-	I
# 6	dependent	I
# 7	neurite	O
# 8	outgrowth	O
# 9	is	O
# 10	inhibited	O
# 11	by	O
# 12	the	O
# 13	tyrosine	I
# 14	kinase	I
# 15	inhibitors	O
# 16	herbimycin	O
# 17	A	I
# 18	and	O
# 19	PP1	B
# 20	.	O
#
# 1	These	O
# 2	data	O
# 3	suggest	O
# 4	that	O
# 5	RPF	O
# 6	-	I
# 7	1	I
# 8	is	O
# 9	likely	O
# 10	to	O
# 11	be	O
# 12	involved	O
# 13	in	O
# 14	early	I
# 15	steps	O
# 16	in	O
# 17	the	O
# 18	differentiation	O
# 19	of	O
# 20	amacrine	O
# 21	and	O
# 22	ganglion	O
# 23	cells	O
# 24	.	O
#
# 1	Effects	O
# 2	of	O
# 3	a	O
# 4	new	O
# 5	antihypertensive	O
# 6	agent	O
# 7	,	O
# 8	SGB	O
# 9	-	I
# 10	1534	O
# 11	,	O
# 12	on	O
# 13	rat	B
# 14	platelet	B
# 15	aggregation	I
# 16	.	O
#
# 1	In	O
# 2	this	O
# 3	study	O
# 4	,	O
# 5	we	O
# 6	investigated	O
# 7	the	O
# 8	molecular	O
# 9	mechanisms	O
# 10	underlying	O
# 11	the	O
# 12	inducible	I
# 13	expression	O
# 14	of	O
# 15	the	O
# 16	flt	O
# 17	-	I
# 18	1	I
# 19	gene	I
# 20	during	O
# 21	the	O
# 22	activation	O
# 23	of	O
# 24	THP	O
# 25	-	I
# 26	1	I
# 27	cells	O
# 28	.	O
#
# 1	Allergy	O
# 2	and	O
# 3	Tourette	O
# 4	'	O
# 5	s	O
# 6	syndrome	O
# 7	.	O
#
# 1	The	O
# 2	limits	O
# 3	of	O
# 4	agreement	O
# 5	between	O
# 6	DBS	O
# 7	and	O
# 8	TOF	O
# 9	responses	O
# 10	were	O
# 11	so	O
# 12	wide	O
# 13	that	O
# 14	they	O
# 15	cannot	O
# 16	be	O
# 17	used	O
# 18	interchangeably	O
# 19	.	O
#
# 1	Arterial	O
# 2	radioactivity	O
# 3	content	O
# 4	after	O
# 5	the	O
# 6	intravenous	O
# 7	administration	O
# 8	of	O
# 9	HMPAO	O
# 10	in	O
# 11	seven	O
# 12	human	B
# 13	subjects	O
# 14	was	O
# 15	analyzed	O
# 16	.	O
#
# 1	The	O
# 2	effect	O
# 3	of	O
# 4	emotional	O
# 5	-	I
# 6	painful	O
# 7	stress	B
# 8	(	O
# 9	EPS	O
# 10	)	O
# 11	on	O
# 12	myocardial	O
# 13	extensibility	O
# 14	and	O
# 15	contractility	O
# 16	was	O
# 17	studied	O
# 18	on	O
# 19	an	O
# 20	isolated	O
# 21	rat	B
# 22	atrium	O
# 23	.	O
#
# 1	For	O
# 2	SMX	O
# 3	at	O
# 4	pH	O
# 5	7	O
# 6	.	O
# 7	0	O
# 8	,	O
# 9	a	O
# 10	1	I
# 11	:	O
# 12	1	I
# 13	complex	I
# 14	is	O
# 15	formed	O
# 16	,	O
# 17	but	O
# 18	at	O
# 19	pH	O
# 20	7	O
# 21	.	O
# 22	5	I
# 23	HPCD	O
# 24	has	O
# 25	little	O
# 26	effect	O
# 27	on	O
# 28	the	O
# 29	solubility	O
# 30	of	O
# 31	the	O
# 32	highly	O
# 33	ionized	O
# 34	SMX	O
# 35	,	O
# 36	presumably	O
# 37	since	O
# 38	only	O
# 39	un	O
# 40	-	I
# 41	ionized	O
# 42	molecules	I
# 43	can	O
# 44	form	O
# 45	inclusion	O
# 46	complexes	I
# 47	with	O
# 48	the	O
# 49	HPCD	O
# 50	.	O
#
# 1	Testosterone	O
# 2	,	O
# 3	free	O
# 4	testosterone	O
# 5	,	O
# 6	non	O
# 7	-	I
# 8	sex	B
# 9	hormone	I
# 10	-	I
# 11	binding	I
# 12	globulin	I
# 13	-	I
# 14	bound	O
# 15	testosterone	O
# 16	,	O
# 17	and	O
# 18	free	O
# 19	androgen	B
# 20	index	O
# 21	:	O
# 22	which	O
# 23	testosterone	O
# 24	measurement	O
# 25	is	O
# 26	most	O
# 27	relevant	O
# 28	to	O
# 29	reproductive	O
# 30	and	O
# 31	sexual	O
# 32	function	O
# 33	in	O
# 34	men	O
# 35	with	O
# 36	epilepsy	O
# 37	?	O
#
# 1	The	O
# 2	C	I
# 3	-	I
# 4	terminal	I
# 5	mutants	I
# 6	were	O
# 7	strongly	O
# 8	dominant	B
# 9	over	O
# 10	TraR	B
# 11	,	O
# 12	suggesting	O
# 13	that	O
# 14	they	O
# 15	can	O
# 16	form	O
# 17	heteromultimers	O
# 18	with	O
# 19	the	O
# 20	wild	B
# 21	-	I
# 22	type	I
# 23	activator	I
# 24	.	O
#
# 1	Large	O
# 2	T	B
# 3	antigen	I
# 4	was	O
# 5	coimmunoprecipitated	O
# 6	by	O
# 7	antibodies	I
# 8	to	O
# 9	epitope	I
# 10	-	I
# 11	tagged	I
# 12	TBP	B
# 13	,	O
# 14	endogenous	B
# 15	TBP	B
# 16	,	O
# 17	hTAF	O
# 18	(	O
# 19	II	I
# 20	)	O
# 21	100	O
# 22	,	O
# 23	hTAF	O
# 24	(	O
# 25	II	I
# 26	)	O
# 27	130	I
# 28	,	O
# 29	and	O
# 30	hTAF	O
# 31	(	O
# 32	II	I
# 33	)	O
# 34	250	O
# 35	,	O
# 36	under	O
# 37	conditions	O
# 38	where	O
# 39	holo	O
# 40	-	I
# 41	TFIID	B
# 42	would	O
# 43	be	O
# 44	precipitated	O
# 45	.	O
#
# 1	Isolation	O
# 2	of	O
# 3	Aeromonas	O
# 4	from	O
# 5	faeces	O
# 6	.	O
#
# 1	Holger	O
# 2	v	B
# 3	.	O
#
# 1	The	O
# 2	combination	O
# 3	PIP	B
# 4	64	O
# 5	micrograms	O
# 6	-	I
# 7	PEF	O
# 8	4	I
# 9	micrograms	O
# 10	prevents	O
# 11	the	O
# 12	frequent	O
# 13	secondary	O
# 14	regrowth	O
# 15	seen	O
# 16	after	O
# 17	6	I
# 18	hours	O
# 19	with	O
# 20	the	O
# 21	antibiotics	O
# 22	used	O
# 23	alone	O
# 24	.	O
#
# 1	Altogether	O
# 2	,	O
# 3	these	O
# 4	data	O
# 5	suggest	O
# 6	that	O
# 7	Ypt51p	O
# 8	,	O
# 9	Ypt52p	O
# 10	,	O
# 11	and	O
# 12	Ypt53p	O
# 13	are	O
# 14	required	O
# 15	for	O
# 16	transport	I
# 17	in	O
# 18	the	O
# 19	endocytic	O
# 20	pathway	O
# 21	and	O
# 22	for	O
# 23	correct	O
# 24	sorting	I
# 25	of	O
# 26	vacuolar	B
# 27	hydrolases	I
# 28	suggesting	O
# 29	a	O
# 30	possible	O
# 31	intersection	O
# 32	of	O
# 33	the	O
# 34	endocytic	O
# 35	with	O
# 36	the	O
# 37	vacuolar	B
# 38	sorting	I
# 39	pathway	O
# 40	.	O
#
# 1	Displacement	O
# 2	thresholds	O
# 3	of	O
# 4	peripheral	O
# 5	sites	I
# 6	in	O
# 7	monocular	O
# 8	human	B
# 9	vision	O
# 10	were	O
# 11	obtained	O
# 12	.	O
#
# 1	The	O
# 2	COP	B
# 3	-	I
# 4	PAWP	O
# 5	gradient	O
# 6	was	O
# 7	markedly	O
# 8	decreased	O
# 9	in	O
# 10	both	O
# 11	shock	I
# 12	and	O
# 13	non	O
# 14	-	I
# 15	shock	I
# 16	patients	O
# 17	with	O
# 18	pulmonary	O
# 19	edema	O
# 20	.	O
# <_io.TextIOWrapper name='preds_hmm.csv' mode='w' encoding='UTF-8'>

# %% [markdown]
# #### The results and analysis
# The results are not as satisfactory which further compelled to attempt other approaches towards the problem to NER task.
