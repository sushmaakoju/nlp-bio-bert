# %% [markdown]
# ### Named Entity Recognition with BioBERT over biomedical journal corpus

# %% [markdown]
# ##### Homework 3, Fall, 2021
# ##### Prof. James H. Martin
# ###### author: Sushma Akoju

# %% [markdown]
# Notebook to train/fine-tune a BioBERT model to perform named entity recognition (NER).
#
# Required features:
#   - Sentence id
#   - Word
#   - POS
#   - Tag
#
# For this task, POS tag for this dataset was not available, POS tag generation was done using NLTK library. [Using a NLTK Tagger](https://www.nltk.org/book/ch05.html)
#
# Steps:
# * Getting Data
# * Training and validating the Model
# * Model Inference over Test data

# %% [markdown]
# #### Inuition, background:
# A special case to consider, for example, the least common words in dataset provided for this homework, 'K713','hypercholesterolemic','lutein','P69','conference','Talk','Tele','cruciform','TE105'. They are not only least common, they need special domain specific knowledge for subword tokenization, which is very different as well as difficult from that of other common English word tokens. Thus BioBERT makes for a special case and seems more reasonable to explore. This also complies with the fact that domain specific expertise adds additional information required to understand the Named Entity tags and vice versa. The reverse case is : to represent knowledge and “reason” as understood from a given context in a medical journal text corpus, Named entity recognition also serves as a pre-requisite for knowledge mining. To rephrase the reverse case, for domain specific knowledge mining, we need Named Entity recognition as a prerequisite.

# %% [markdown]
# #### Task Description
#
# > Named entity recognition (NER) is the task of tagging entities in text with their corresponding type. Approaches typically use BIO notation, which differentiates the beginning (B) and the inside (I) of entities. O is used for non-entity tokens.

# %% [markdown]
# #### Install Dependencies and Restart Runtime

# %%
# !pip install -q transformers
# !pip install -q simpletransformers
# Out:
#      |████████████████████████████████| 3.1 MB 7.4 MB/s
#      |████████████████████████████████| 596 kB 42.3 MB/s
#      |████████████████████████████████| 3.3 MB 42.1 MB/s
#      |████████████████████████████████| 59 kB 5.4 MB/s
#      |████████████████████████████████| 895 kB 51.9 MB/s
#      |████████████████████████████████| 247 kB 8.0 MB/s
#      |████████████████████████████████| 9.1 MB 47.6 MB/s
#      |████████████████████████████████| 1.2 MB 38.7 MB/s
#      |████████████████████████████████| 1.7 MB 51.4 MB/s
#      |████████████████████████████████| 290 kB 62.0 MB/s
#      |████████████████████████████████| 43 kB 1.9 MB/s
#      |████████████████████████████████| 140 kB 57.3 MB/s
#      |████████████████████████████████| 180 kB 61.2 MB/s
#      |████████████████████████████████| 97 kB 6.6 MB/s
#      |████████████████████████████████| 63 kB 1.6 MB/s
#      |████████████████████████████████| 132 kB 55.4 MB/s
#      |████████████████████████████████| 1.1 MB 34.5 MB/s
#      |████████████████████████████████| 243 kB 59.1 MB/s
#      |████████████████████████████████| 271 kB 62.0 MB/s
#      |████████████████████████████████| 160 kB 60.9 MB/s
#      |████████████████████████████████| 192 kB 61.4 MB/s
#      |████████████████████████████████| 4.3 MB 48.7 MB/s
#      |████████████████████████████████| 111 kB 56.7 MB/s
#      |████████████████████████████████| 76 kB 4.8 MB/s
#      |████████████████████████████████| 178 kB 67.4 MB/s
#      |████████████████████████████████| 125 kB 60.5 MB/s
#      |████████████████████████████████| 790 kB 54.5 MB/s
#      |████████████████████████████████| 374 kB 61.6 MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
#   Building wheel for pympler (setup.py) ... done
#   Building wheel for blinker (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.22 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.5.1 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.29.0 which is incompatible.

# %% [markdown]
# ### Getting Data

# %% [markdown]
# #### Loading the data from Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
d = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/bio_ner.csv")
n =  d.to_numpy().tolist()
new_list = []
counter = 0
for l in n:
  #print(l)
  if l[2] == 1:
    counter += 1
  l[1] = counter
  new_list.append(l)

# %% [markdown]
# ##### The data was converted to a csv file with Sentence ID, Line, Word, POS tag and the IOB Tag

# %%
d = pd.DataFrame.from_records(new_list, columns = ['ind', 'Sentence #','Line','Word', 'POS', 'Tag'])
d.head(30)
# Out:
#     ind  Sentence #  Line                Word  POS Tag
# 0     1           1     1          Comparison  NNP   O
# 1     2           1     2                with   IN   O
# 2     3           1     3            alkaline   JJ   B
# 3     4           1     4        phosphatases  NNS   I
# 4     5           1     5                 and   CC   O
# 5     6           1     6                   5   CD   B
# 6     7           1     7                   -    :   I
# 7     8           1     8        nucleotidase   NN   I
# 8     9           1     9                   .    .   O
# 9    10           2     1       Pharmacologic  NNP   O
# 10   11           2     2             aspects  NNS   O
# 11   12           2     3                  of   IN   O
# 12   13           2     4            neonatal   JJ   O
# 13   14           2     5  hyperbilirubinemia   NN   O
# 14   15           2     6                   .    .   O
# 15   16           3     1                When  WRB   O
# 16   17           3     2                 CSF  NNP   O
# 17   18           3     3                   [  NNP   O
# 18   19           3     4                HCO3  NNP   O
# 19   20           3     5                  -]  NaN   O
# 20   21           3     6                  is  VBZ   O
# 21   22           3     7               shown  VBN   O
# 22   23           3     8                  as   IN   O
# 23   24           3     9                   a   DT   O
# 24   25           3    10            function   NN   O
# 25   26           3    11                  of   IN   O
# 26   27           3    12                 CSF  NNP   O
# 27   28           3    13                PCO2  NNP   O
# 28   29           3    14                 the   DT   O
# 29   30           3    15                data   NN   O

# %%
d = d.drop('ind', axis=1)
df = d[['Sentence #','Word', 'POS', 'Tag']]
start = df[df['Sentence #']==6897].index.values.astype(int)[0]
second_start = df[df['Sentence #']==10347].index.values.astype(int)[0]
end = df[df['Sentence #']==13794].index.values.astype(int)[0]
train = df.iloc[0:start]
train_dev = df.iloc[start:second_start]
test = df.iloc[second_start:end]

# %%
df.head(13)
# Out:
#     Sentence #           Word  POS Tag
# 0            1     Comparison  NNP   O
# 1            1           with   IN   O
# 2            1       alkaline   JJ   B
# 3            1   phosphatases  NNS   I
# 4            1            and   CC   O
# 5            1              5   CD   B
# 6            1              -    :   I
# 7            1   nucleotidase   NN   I
# 8            1              .    .   O
# 9            2  Pharmacologic  NNP   O
# 10           2        aspects  NNS   O
# 11           2             of   IN   O
# 12           2       neonatal   JJ   O

# %%
train.to_csv('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/train.tsv', sep="\t", header=False, index = False)
test.to_csv('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/test.tsv', sep="\t", header=False, index = False)
train_dev.to_csv('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/train_dev.tsv', sep="\t", header=False, index = False)

# %%
import pandas as pd
def read_conll(filename):
    df = pd.read_csv(filename,
                    sep = '\t', header = None, keep_default_na = False,
                    names = ['sentence_id','words', 'pos', 'labels'],
                    quoting = 3, skip_blank_lines = False)
    df = df[~df['words'].astype(str).str.startswith('-DOCSTART- ')] 
    return df[df.words != '']

# %% [markdown]
# #### For this task, Data is split inot Train, Test and Dev datasets.
# - Train # : 6896 sentences
# - Test # : 3448 sentences.
# - Dev # : 3450 sentences.

# %%
train_df = read_conll('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw//train.tsv')
test_df = read_conll('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/test.tsv')
dev_df = read_conll('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/train_dev.tsv')
test_df.head(20)
# Out:
#     sentence_id        words  pos labels
# 0         10347           In   IN      O
# 1         10347         some   DT      O
# 2         10347        cases  NNS      O
# 3         10347            ,    ,      O
# 4         10347          the   DT      O
# 5         10347     aberrant   JJ      O
# 6         10347  methylation   NN      O
# 7         10347           of   IN      O
# 8         10347         CpGs  NNP      O
# 9         10347       within   IN      O
# 10        10347            5   CD      O
# 11        10347            '  POS      O
# 12        10347   regulatory   JJ      O
# 13        10347      regions  NNS      O
# 14        10347          has  VBZ      O
# 15        10347          led  VBN      O
# 16        10347           to   TO      O
# 17        10347  suppression   NN      O
# 18        10347           of   IN      O
# 19        10347         gene   NN      O

# %% [markdown]
# We now print out the statistics (number of sentences) of the train, dev and test sets.

# %%
data = [[train_df['sentence_id'].nunique(), test_df['sentence_id'].nunique(), dev_df['sentence_id'].nunique()]]

# Prints out the dataset sizes of train and test sets per label.
pd.DataFrame(data, columns=["Train", "Test", "Dev"])
# Out:
#    Train  Test   Dev
# 0   6896  3447  3450

# %% [markdown]
# # Training and Testing the Model

# %% [markdown]
# #### Set up the Training Arguments
#
# We set up the training arguments. Here we train to 10 epochs to get accuracy close to the SOTA. The train, test and dev sets are relatively small so we don't have to wait too long. We set a sliding window as NER sequences can be quite long and because we have limited GPU memory we can't increase the `max_seq_length` too long.

# %%
train_args = {
    'reprocess_input_data': True,
    'overwrite_output_dir': True,
    'sliding_window': True,
    'max_seq_length': 64,
    'num_train_epochs': 10,
    'train_batch_size': 32,
    'fp16': True,
    'output_dir': '/outputs/',
    'best_model_dir': '/outputs/best_model/',
    'evaluate_during_training': True,
}

# %% [markdown]
# The following line of code saves (to the variable `custom_labels`) a set of all the NER tags/labels in the dataset.

# %%
custom_labels = ['I', 'B', 'O'] #list(train_df['labels'].unique())
print(custom_labels)
# Out:
# ['I', 'B', 'O']

# %% [markdown]
# #### Train the Model
#
# ###### The pre-trained BioBERT model (by [DMIS Lab, Korea University](https://huggingface.co/dmis-lab)) from the [Hugging Face Transformers](https://github.com/huggingface/transformers) library as the base and use the [Simple Transformers library](https://simpletransformers.ai/docs/classification-models/) on top of it to train the NER (sequence tagging) model with just a few lines of code.

# %%
from simpletransformers.ner import NERModel
from transformers import AutoTokenizer
import pandas as pd
import logging

logging.basicConfig(level=logging.DEBUG)
transformers_logger = logging.getLogger('transformers')
transformers_logger.setLevel(logging.WARNING)

# We use the bio BERT pre-trained model.
model = NERModel('bert', 'dmis-lab/biobert-v1.1', labels=custom_labels, args=train_args)

# Train the model
# https://simpletransformers.ai/docs/tips-and-tricks/#using-early-stopping
model.train_model(train_df, eval_data=dev_df)

# Evaluate the model in terms of accuracy score
result, model_outputs, preds_list = model.eval_model(test_df)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at dmis-lab/biobert-v1.1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /api/models/dmis-lab/biobert-v1.1 HTTP/1.1" 200 646
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/vocab.txt HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/special_tokens_map.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/tokenizer_config.json HTTP/1.1" 200 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/tokenizer.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /dmis-lab/biobert-v1.1/resolve/main/config.json HTTP/1.1" 200 0
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/4 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/10 [00:00<?, ?it/s]
# Running Epoch 0 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 1 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 2 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 3 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 4 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 5 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 6 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 7 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 8 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# Running Epoch 9 of 10:   0%|          | 0/216 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/432 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model: Training of bert model complete. Saved to /outputs/.
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Evaluation:   0%|          | 0/431 [00:00<?, ?it/s]
# INFO:simpletransformers.ner.ner_model:{'eval_loss': 0.14850225066391373, 'precision': 0.830317147464612, 'recall': 0.8575129533678757, 'f1_score': 0.8436959490213929}

# %% [markdown]
# The F1-score for the model is **84.3%** ('f1_score': 0.8436959490213929).

# %% [markdown]
# # Using the Model (Running Inference)
#
# Running the model to do some predictions/inference is as simple as calling `model.predict(samples)`. First we get a sentence from the test set and conduct the prediction of each of the sentence.

# %%
ids = test_df.sentence_id.unique().tolist()
len(ids)
# Out:
# 3447

# %%
preds = []
counter = 1
for id in ids:
  sample = test_df[test_df.sentence_id == id].words.str.cat(sep=' ')
  samples.append(sample)

predictions, _ = model.predict(samples)
print(predictions, samples)
for idx, sample in enumerate(samples):
  counter = 1
  print('{}: '.format(idx))
  for word in predictions[idx]:
    w = list(word.keys())[0]
    tag = list(word.values())[0]
    preds.append([counter, w,tag ])
    print('{}'.format(word), type(word), word)
    counter += 1
# Out:
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/5 [00:00<?, ?it/s]
# Running Prediction:   0%|          | 0/1725 [00:00<?, ?it/s]
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Streaming output truncated to the last 5000 lines.
# {'activity': 'O'} <class 'dict'> {'activity': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13628:
# {'Effects': 'O'} <class 'dict'> {'Effects': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'spatial': 'O'} <class 'dict'> {'spatial': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'temporal': 'O'} <class 'dict'> {'temporal': 'O'}
# {'smoothing': 'O'} <class 'dict'> {'smoothing': 'O'}
# {'on': 'O'} <class 'dict'> {'on': 'O'}
# {'stimulated': 'O'} <class 'dict'> {'stimulated': 'O'}
# {'brillouin': 'O'} <class 'dict'> {'brillouin': 'O'}
# {'scattering': 'O'} <class 'dict'> {'scattering': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'independent': 'O'} <class 'dict'> {'independent': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'hot': 'O'} <class 'dict'> {'hot': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'spot': 'O'} <class 'dict'> {'spot': 'O'}
# {'model': 'O'} <class 'dict'> {'model': 'O'}
# {'limit': 'O'} <class 'dict'> {'limit': 'O'}
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'influence': 'O'} <class 'dict'> {'influence': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'laser': 'O'} <class 'dict'> {'laser': 'O'}
# {'beam': 'O'} <class 'dict'> {'beam': 'O'}
# {'smoothing': 'O'} <class 'dict'> {'smoothing': 'O'}
# {'on': 'O'} <class 'dict'> {'on': 'O'}
# {'stimulated': 'O'} <class 'dict'> {'stimulated': 'O'}
# {'Brillouin': 'O'} <class 'dict'> {'Brillouin': 'O'}
# {'backscattering': 'O'} <class 'dict'> {'backscattering': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'SBBS': 'O'} <class 'dict'> {'SBBS': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'studied': 'O'} <class 'dict'> {'studied': 'O'}
# {'analytically': 'O'} <class 'dict'> {'analytically': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'limit': 'O'} <class 'dict'> {'limit': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'independent': 'O'} <class 'dict'> {'independent': 'O'}
# {'hot': 'O'} <class 'dict'> {'hot': 'O'}
# {'spot': 'O'} <class 'dict'> {'spot': 'O'}
# {'model': 'O'} <class 'dict'> {'model': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13629:
# {'Simultaneous': 'O'} <class 'dict'> {'Simultaneous': 'O'}
# {'determination': 'O'} <class 'dict'> {'determination': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'theophylline': 'O'} <class 'dict'> {'theophylline': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'its': 'O'} <class 'dict'> {'its': 'O'}
# {'metabolites': 'O'} <class 'dict'> {'metabolites': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'HPLC': 'O'} <class 'dict'> {'HPLC': 'O'}
# {']': 'O'} <class 'dict'> {']': 'O'}
# {'A': 'O'} <class 'dict'> {'A': 'O'}
# {'high': 'O'} <class 'dict'> {'high': 'O'}
# {'performance': 'O'} <class 'dict'> {'performance': 'O'}
# {'liquid': 'O'} <class 'dict'> {'liquid': 'O'}
# {'chromatography': 'O'} <class 'dict'> {'chromatography': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'HPLC': 'O'} <class 'dict'> {'HPLC': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'method': 'O'} <class 'dict'> {'method': 'O'}
# {'has': 'O'} <class 'dict'> {'has': 'O'}
# {'been': 'O'} <class 'dict'> {'been': 'O'}
# {'developed': 'O'} <class 'dict'> {'developed': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'simultaneous': 'O'} <class 'dict'> {'simultaneous': 'O'}
# {'determination': 'O'} <class 'dict'> {'determination': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'theophylline': 'O'} <class 'dict'> {'theophylline': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'its': 'O'} <class 'dict'> {'its': 'O'}
# {'metabolites': 'O'} <class 'dict'> {'metabolites': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'caffeine': 'O'} <class 'dict'> {'caffeine': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'its': 'O'} <class 'dict'> {'its': 'O'}
# {'metabolites': 'O'} <class 'dict'> {'metabolites': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13630:
# {'Ten': 'O'} <class 'dict'> {'Ten': 'O'}
# {'males': 'O'} <class 'dict'> {'males': 'O'}
# {'performed': 'O'} <class 'dict'> {'performed': 'O'}
# {'both': 'O'} <class 'dict'> {'both': 'O'}
# {'test': 'O'} <class 'dict'> {'test': 'O'}
# {'conditions': 'O'} <class 'dict'> {'conditions': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'oxygen': 'O'} <class 'dict'> {'oxygen': 'O'}
# {'uptake': 'O'} <class 'dict'> {'uptake': 'O'}
# {'VO2': 'O'} <class 'dict'> {'VO2': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'heart': 'O'} <class 'dict'> {'heart': 'O'}
# {'rate': 'O'} <class 'dict'> {'rate': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'minute': 'O'} <class 'dict'> {'minute': 'O'}
# {'ventilation': 'O'} <class 'dict'> {'ventilation': 'O'}
# {'VE': 'O'} <class 'dict'> {'VE': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'perceived': 'O'} <class 'dict'> {'perceived': 'O'}
# {'exertion': 'O'} <class 'dict'> {'exertion': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'spinal': 'O'} <class 'dict'> {'spinal': 'O'}
# {'shrinkage': 'O'} <class 'dict'> {'shrinkage': 'O'}
# {'were': 'O'} <class 'dict'> {'were': 'O'}
# {'recorded': 'O'} <class 'dict'> {'recorded': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13631:
# {'CONCLUSION': 'O'} <class 'dict'> {'CONCLUSION': 'O'}
# {':': 'O'} <class 'dict'> {':': 'O'}
# {'SPT': 'O'} <class 'dict'> {'SPT': 'O'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'more': 'O'} <class 'dict'> {'more': 'O'}
# {'useful': 'O'} <class 'dict'> {'useful': 'O'}
# {'than': 'O'} <class 'dict'> {'than': 'O'}
# {'WST': 'O'} <class 'dict'> {'WST': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'differentiating': 'O'} <class 'dict'> {'differentiating': 'O'}
# {'patients': 'O'} <class 'dict'> {'patients': 'O'}
# {'predisposed': 'O'} <class 'dict'> {'predisposed': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'aspiration': 'O'} <class 'dict'> {'aspiration': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13632:
# {'Studied': 'O'} <class 'dict'> {'Studied': 'O'}
# {'groups': 'O'} <class 'dict'> {'groups': 'O'}
# {'were': 'O'} <class 'dict'> {'were': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'1': 'O'} <class 'dict'> {'1': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'untreated': 'O'} <class 'dict'> {'untreated': 'O'}
# {'control': 'O'} <class 'dict'> {'control': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'n': 'O'} <class 'dict'> {'n': 'O'}
# {'=': 'O'} <class 'dict'> {'=': 'O'}
# {'12': 'O'} <class 'dict'> {'12': 'O'}
# {';': 'O'} <class 'dict'> {';': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'2': 'O'} <class 'dict'> {'2': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'FK': 'O'} <class 'dict'> {'FK': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'1': 'O'} <class 'dict'> {'1': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'n': 'O'} <class 'dict'> {'n': 'O'}
# {'=': 'O'} <class 'dict'> {'=': 'O'}
# {'8': 'O'} <class 'dict'> {'8': 'O'}
# {';': 'O'} <class 'dict'> {';': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'3': 'O'} <class 'dict'> {'3': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'FK': 'O'} <class 'dict'> {'FK': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'3': 'O'} <class 'dict'> {'3': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'n': 'O'} <class 'dict'> {'n': 'O'}
# {'=': 'O'} <class 'dict'> {'=': 'O'}
# {'8': 'O'} <class 'dict'> {'8': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13633:
# {'DNA': 'O'} <class 'dict'> {'DNA': 'O'}
# {'binding': 'O'} <class 'dict'> {'binding': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'glutathione': 'B'} <class 'dict'> {'glutathione': 'B'}
# {'S': 'I'} <class 'dict'> {'S': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'transferase': 'I'} <class 'dict'> {'transferase': 'I'}
# {'pull': 'O'} <class 'dict'> {'pull': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'down': 'O'} <class 'dict'> {'down': 'O'}
# {'assays': 'O'} <class 'dict'> {'assays': 'O'}
# {'demonstrate': 'O'} <class 'dict'> {'demonstrate': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'binding': 'O'} <class 'dict'> {'binding': 'O'}
# {'requires': 'O'} <class 'dict'> {'requires': 'O'}
# {'Elk': 'B'} <class 'dict'> {'Elk': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'1': 'I'} <class 'dict'> {'1': 'I'}
# {'(': 'I'} <class 'dict'> {'(': 'I'}
# {'1': 'I'} <class 'dict'> {'1': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'212': 'I'} <class 'dict'> {'212': 'I'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'but': 'O'} <class 'dict'> {'but': 'O'}
# {'not': 'O'} <class 'dict'> {'not': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'C': 'O'} <class 'dict'> {'C': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'terminal': 'O'} <class 'dict'> {'terminal': 'O'}
# {'transactivation': 'O'} <class 'dict'> {'transactivation': 'O'}
# {'domain': 'O'} <class 'dict'> {'domain': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13634:
# {'Unexpectedly': 'O'} <class 'dict'> {'Unexpectedly': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'ALK7': 'B'} <class 'dict'> {'ALK7': 'B'}
# {'signaling': 'O'} <class 'dict'> {'signaling': 'O'}
# {'produced': 'O'} <class 'dict'> {'produced': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'remarkable': 'O'} <class 'dict'> {'remarkable': 'O'}
# {'change': 'O'} <class 'dict'> {'change': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'cell': 'O'} <class 'dict'> {'cell': 'O'}
# {'morphology': 'O'} <class 'dict'> {'morphology': 'O'}
# {'characterized': 'O'} <class 'dict'> {'characterized': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'cell': 'O'} <class 'dict'> {'cell': 'O'}
# {'flattening': 'O'} <class 'dict'> {'flattening': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'elaboration': 'O'} <class 'dict'> {'elaboration': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'blunt': 'O'} <class 'dict'> {'blunt': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'short': 'O'} <class 'dict'> {'short': 'O'}
# {'cell': 'O'} <class 'dict'> {'cell': 'O'}
# {'processes': 'O'} <class 'dict'> {'processes': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13635:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'swa2': 'B'} <class 'dict'> {'swa2': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'1': 'I'} <class 'dict'> {'1': 'I'}
# {'allele': 'I'} <class 'dict'> {'allele': 'I'}
# {'recovered': 'O'} <class 'dict'> {'recovered': 'O'}
# {'from': 'O'} <class 'dict'> {'from': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'original': 'O'} <class 'dict'> {'original': 'O'}
# {'screen': 'O'} <class 'dict'> {'screen': 'O'}
# {'carries': 'O'} <class 'dict'> {'carries': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'point': 'O'} <class 'dict'> {'point': 'O'}
# {'mutation': 'O'} <class 'dict'> {'mutation': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'its': 'O'} <class 'dict'> {'its': 'O'}
# {'tetratricopeptide': 'O'} <class 'dict'> {'tetratricopeptide': 'O'}
# {'repeat': 'O'} <class 'dict'> {'repeat': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'TPR': 'O'} <class 'dict'> {'TPR': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'domain': 'O'} <class 'dict'> {'domain': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'motif': 'O'} <class 'dict'> {'motif': 'O'}
# {'not': 'O'} <class 'dict'> {'not': 'O'}
# {'found': 'O'} <class 'dict'> {'found': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'auxilin': 'B'} <class 'dict'> {'auxilin': 'B'}
# {'but': 'O'} <class 'dict'> {'but': 'O'}
# {'known': 'O'} <class 'dict'> {'known': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'other': 'O'} <class 'dict'> {'other': 'O'}
# {'proteins': 'O'} <class 'dict'> {'proteins': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'mediate': 'O'} <class 'dict'> {'mediate': 'O'}
# {'interaction': 'O'} <class 'dict'> {'interaction': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'heat': 'B'} <class 'dict'> {'heat': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'shock': 'I'} <class 'dict'> {'shock': 'I'}
# {'proteins': 'I'} <class 'dict'> {'proteins': 'I'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13636:
# {'Association': 'O'} <class 'dict'> {'Association': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'stress': 'O'} <class 'dict'> {'stress': 'O'}
# {'during': 'O'} <class 'dict'> {'during': 'O'}
# {'delivery': 'O'} <class 'dict'> {'delivery': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'increased': 'O'} <class 'dict'> {'increased': 'O'}
# {'numbers': 'O'} <class 'dict'> {'numbers': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'nucleated': 'O'} <class 'dict'> {'nucleated': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'hematopoietic': 'O'} <class 'dict'> {'hematopoietic': 'O'}
# {'progenitor': 'O'} <class 'dict'> {'progenitor': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'umbilical': 'O'} <class 'dict'> {'umbilical': 'O'}
# {'cord': 'O'} <class 'dict'> {'cord': 'O'}
# {'blood': 'O'} <class 'dict'> {'blood': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13637:
# {'In': 'O'} <class 'dict'> {'In': 'O'}
# {'slightly': 'O'} <class 'dict'> {'slightly': 'O'}
# {'older': 'O'} <class 'dict'> {'older': 'O'}
# {'embryos': 'O'} <class 'dict'> {'embryos': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'expression': 'O'} <class 'dict'> {'expression': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'skewed': 'O'} <class 'dict'> {'skewed': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'one': 'O'} <class 'dict'> {'one': 'O'}
# {'side': 'O'} <class 'dict'> {'side': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'embryo': 'O'} <class 'dict'> {'embryo': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'E6': 'O'} <class 'dict'> {'E6': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# {'5': 'O'} <class 'dict'> {'5': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'at': 'O'} <class 'dict'> {'at': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'onset': 'O'} <class 'dict'> {'onset': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'gastrulation': 'O'} <class 'dict'> {'gastrulation': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'expression': 'O'} <class 'dict'> {'expression': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'seen': 'O'} <class 'dict'> {'seen': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'epiblast': 'O'} <class 'dict'> {'epiblast': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'visceral': 'O'} <class 'dict'> {'visceral': 'O'}
# {'endoderm': 'O'} <class 'dict'> {'endoderm': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'nascent': 'O'} <class 'dict'> {'nascent': 'O'}
# {'mesoderm': 'O'} <class 'dict'> {'mesoderm': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# 13638:
# {'Transformation': 'O'} <class 'dict'> {'Transformation': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'sconC3': 'B'} <class 'dict'> {'sconC3': 'B'}
# {'mutant': 'I'} <class 'dict'> {'mutant': 'I'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'sconB': 'B'} <class 'dict'> {'sconB': 'B'}
# {'+': 'I'} <class 'dict'> {'+': 'I'}
# {'restores': 'O'} <class 'dict'> {'restores': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'wild': 'O'} <class 'dict'> {'wild': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'type': 'O'} <class 'dict'> {'type': 'O'}
# {'phenotype': 'O'} <class 'dict'> {'phenotype': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13639:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'authors': 'O'} <class 'dict'> {'authors': 'O'}
# {'proposed': 'O'} <class 'dict'> {'proposed': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'highly': 'O'} <class 'dict'> {'highly': 'O'}
# {'convergent': 'O'} <class 'dict'> {'convergent': 'O'}
# {'inputs': 'O'} <class 'dict'> {'inputs': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'entorhinal': 'O'} <class 'dict'> {'entorhinal': 'O'}
# {'cortex': 'O'} <class 'dict'> {'cortex': 'O'}
# {'indicate': 'O'} <class 'dict'> {'indicate': 'O'}
# {'this': 'O'} <class 'dict'> {'this': 'O'}
# {'region': 'O'} <class 'dict'> {'region': 'O'}
# {'may': 'O'} <class 'dict'> {'may': 'O'}
# {'be': 'O'} <class 'dict'> {'be': 'O'}
# {'particularly': 'O'} <class 'dict'> {'particularly': 'O'}
# {'important': 'O'} <class 'dict'> {'important': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'selecting': 'O'} <class 'dict'> {'selecting': 'O'}
# {'or': 'O'} <class 'dict'> {'or': 'O'}
# {'compressing': 'O'} <class 'dict'> {'compressing': 'O'}
# {'information': 'O'} <class 'dict'> {'information': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13640:
# {'Influence': 'O'} <class 'dict'> {'Influence': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'oil': 'O'} <class 'dict'> {'oil': 'O'}
# {'emulsions': 'O'} <class 'dict'> {'emulsions': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'diphenyl': 'O'} <class 'dict'> {'diphenyl': 'O'}
# {'on': 'O'} <class 'dict'> {'on': 'O'}
# {'post': 'O'} <class 'dict'> {'post': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'harvest': 'O'} <class 'dict'> {'harvest': 'O'}
# {'physiconutritional': 'O'} <class 'dict'> {'physiconutritional': 'O'}
# {'changes': 'O'} <class 'dict'> {'changes': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'Kagzi': 'O'} <class 'dict'> {'Kagzi': 'O'}
# {'limes': 'O'} <class 'dict'> {'limes': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'Citrus': 'O'} <class 'dict'> {'Citrus': 'O'}
# {'aurantifolia': 'O'} <class 'dict'> {'aurantifolia': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'studied': 'O'} <class 'dict'> {'studied': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13641:
# {'Detailed': 'O'} <class 'dict'> {'Detailed': 'O'}
# {'analysis': 'O'} <class 'dict'> {'analysis': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'alpha1': 'B'} <class 'dict'> {'alpha1': 'B'}
# {',': 'I'} <class 'dict'> {',': 'I'}
# {'3GT': 'I'} <class 'dict'> {'3GT': 'I'}
# {'transcripts': 'I'} <class 'dict'> {'transcripts': 'I'}
# {'revealed': 'O'} <class 'dict'> {'revealed': 'O'}
# {'two': 'O'} <class 'dict'> {'two': 'O'}
# {'major': 'O'} <class 'dict'> {'major': 'O'}
# {'alternative': 'O'} <class 'dict'> {'alternative': 'O'}
# {'splicing': 'O'} <class 'dict'> {'splicing': 'O'}
# {'patterns': 'O'} <class 'dict'> {'patterns': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'5': 'O'} <class 'dict'> {'5': 'O'}
# {"'-": 'O'} <class 'dict'> {"'-": 'O'}
# {'untranslated': 'O'} <class 'dict'> {'untranslated': 'O'}
# {'region': 'O'} <class 'dict'> {'region': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'5': 'O'} <class 'dict'> {'5': 'O'}
# {"'-": 'O'} <class 'dict'> {"'-": 'O'}
# {'UTR': 'O'} <class 'dict'> {'UTR': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'evidence': 'O'} <class 'dict'> {'evidence': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'minor': 'O'} <class 'dict'> {'minor': 'O'}
# {'splicing': 'O'} <class 'dict'> {'splicing': 'O'}
# {'activity': 'O'} <class 'dict'> {'activity': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'occurs': 'O'} <class 'dict'> {'occurs': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'tissue': 'O'} <class 'dict'> {'tissue': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'specific': 'O'} <class 'dict'> {'specific': 'O'}
# {'manner': 'O'} <class 'dict'> {'manner': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13642:
# {'A': 'O'} <class 'dict'> {'A': 'O'}
# {'thermal': 'O'} <class 'dict'> {'thermal': 'O'}
# {'Kubo': 'O'} <class 'dict'> {'Kubo': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'Martin': 'O'} <class 'dict'> {'Martin': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'Schwinger': 'O'} <class 'dict'> {'Schwinger': 'O'}
# {'condition': 'O'} <class 'dict'> {'condition': 'O'}
# {'arises': 'O'} <class 'dict'> {'arises': 'O'}
# {'due': 'O'} <class 'dict'> {'due': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'coupling': 'O'} <class 'dict'> {'coupling': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'computer': 'O'} <class 'dict'> {'computer': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'strong': 'O'} <class 'dict'> {'strong': 'O'}
# {'periodic': 'O'} <class 'dict'> {'periodic': 'O'}
# {'source': 'O'} <class 'dict'> {'source': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'namely': 'O'} <class 'dict'> {'namely': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'daily': 'O'} <class 'dict'> {'daily': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'weekly': 'O'} <class 'dict'> {'weekly': 'O'}
# {'usage': 'O'} <class 'dict'> {'usage': 'O'}
# {'patterns': 'O'} <class 'dict'> {'patterns': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'system': 'O'} <class 'dict'> {'system': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13643:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'non': 'O'} <class 'dict'> {'non': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'homologous': 'O'} <class 'dict'> {'homologous': 'O'}
# {'sequences': 'O'} <class 'dict'> {'sequences': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'5': 'O'} <class 'dict'> {'5': 'O'}
# {"'": 'O'} <class 'dict'> {"'": 'O'}
# {'untranslated': 'O'} <class 'dict'> {'untranslated': 'O'}
# {'regions': 'O'} <class 'dict'> {'regions': 'O'}
# {'might': 'O'} <class 'dict'> {'might': 'O'}
# {'be': 'O'} <class 'dict'> {'be': 'O'}
# {'acquired': 'O'} <class 'dict'> {'acquired': 'O'}
# {'at': 'O'} <class 'dict'> {'at': 'O'}
# {'or': 'O'} <class 'dict'> {'or': 'O'}
# {'after': 'O'} <class 'dict'> {'after': 'O'}
# {'transcription': 'O'} <class 'dict'> {'transcription': 'O'}
# {'during': 'O'} <class 'dict'> {'during': 'O'}
# {'retrotransposition': 'O'} <class 'dict'> {'retrotransposition': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'ATLN': 'B'} <class 'dict'> {'ATLN': 'B'}
# {'elements': 'O'} <class 'dict'> {'elements': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13644:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'time': 'O'} <class 'dict'> {'time': 'O'}
# {'course': 'O'} <class 'dict'> {'course': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'RNA1': 'B'} <class 'dict'> {'RNA1': 'B'}
# {'replication': 'O'} <class 'dict'> {'replication': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'RNA3': 'B'} <class 'dict'> {'RNA3': 'B'}
# {'synthesis': 'O'} <class 'dict'> {'synthesis': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'induced': 'O'} <class 'dict'> {'induced': 'O'}
# {'yeast': 'O'} <class 'dict'> {'yeast': 'O'}
# {'paralleled': 'O'} <class 'dict'> {'paralleled': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'yeast': 'O'} <class 'dict'> {'yeast': 'O'}
# {'transfected': 'O'} <class 'dict'> {'transfected': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'natural': 'O'} <class 'dict'> {'natural': 'O'}
# {'FHV': 'O'} <class 'dict'> {'FHV': 'O'}
# {'virion': 'O'} <class 'dict'> {'virion': 'O'}
# {'RNA': 'O'} <class 'dict'> {'RNA': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13645:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'transcription': 'O'} <class 'dict'> {'transcription': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'alternative': 'O'} <class 'dict'> {'alternative': 'O'}
# {'splicing': 'O'} <class 'dict'> {'splicing': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'human': 'B'} <class 'dict'> {'human': 'B'}
# {'ORL1': 'I'} <class 'dict'> {'ORL1': 'I'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'GAIP': 'B'} <class 'dict'> {'GAIP': 'B'}
# {'are': 'O'} <class 'dict'> {'are': 'O'}
# {'cell': 'O'} <class 'dict'> {'cell': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'type': 'O'} <class 'dict'> {'type': 'O'}
# {'specific': 'O'} <class 'dict'> {'specific': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13646:
# {'RESULTS': 'O'} <class 'dict'> {'RESULTS': 'O'}
# {':': 'O'} <class 'dict'> {':': 'O'}
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'main': 'O'} <class 'dict'> {'main': 'O'}
# {'effect': 'O'} <class 'dict'> {'effect': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'muscle': 'O'} <class 'dict'> {'muscle': 'O'}
# {'pain': 'O'} <class 'dict'> {'pain': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'compared': 'O'} <class 'dict'> {'compared': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'non': 'O'} <class 'dict'> {'non': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'painful': 'O'} <class 'dict'> {'painful': 'O'}
# {'stimulation': 'O'} <class 'dict'> {'stimulation': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'significant': 'O'} <class 'dict'> {'significant': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'long': 'O'} <class 'dict'> {'long': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'lasting': 'O'} <class 'dict'> {'lasting': 'O'}
# {'increase': 'O'} <class 'dict'> {'increase': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'delta': 'O'} <class 'dict'> {'delta': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'1': 'O'} <class 'dict'> {'1': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'3': 'O'} <class 'dict'> {'3': 'O'}
# {'Hz': 'O'} <class 'dict'> {'Hz': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'power': 'O'} <class 'dict'> {'power': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'an': 'O'} <class 'dict'> {'an': 'O'}
# {'alpha': 'O'} <class 'dict'> {'alpha': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'1': 'O'} <class 'dict'> {'1': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'9': 'O'} <class 'dict'> {'9': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'11': 'O'} <class 'dict'> {'11': 'O'}
# {'Hz': 'O'} <class 'dict'> {'Hz': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'power': 'O'} <class 'dict'> {'power': 'O'}
# {'increase': 'O'} <class 'dict'> {'increase': 'O'}
# {'over': 'O'} <class 'dict'> {'over': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'contralateral': 'O'} <class 'dict'> {'contralateral': 'O'}
# {'parietal': 'O'} <class 'dict'> {'parietal': 'O'}
# {'locus': 'O'} <class 'dict'> {'locus': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13647:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'extraction': 'O'} <class 'dict'> {'extraction': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'subsequently': 'O'} <class 'dict'> {'subsequently': 'O'}
# {'rated': 'O'} <class 'dict'> {'rated': 'O'}
# {'as': 'O'} <class 'dict'> {'as': 'O'}
# {"'": 'O'} <class 'dict'> {"'": 'O'}
# {'easy': 'O'} <class 'dict'> {'easy': 'O'}
# {"'": 'O'} <class 'dict'> {"'": 'O'}
# {'or': 'O'} <class 'dict'> {'or': 'O'}
# {"'": 'O'} <class 'dict'> {"'": 'O'}
# {'difficult': 'O'} <class 'dict'> {'difficult': 'O'}
# {"'.": 'O'} <class 'dict'> {"'.": 'O'}
# {'Taking': 'O'} <class 'dict'> {'Taking': 'O'}
# {'Pell': 'O'} <class 'dict'> {'Pell': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'Gregory': 'O'} <class 'dict'> {'Gregory': 'O'}
# {'class': 'O'} <class 'dict'> {'class': 'O'}
# {'C': 'O'} <class 'dict'> {'C': 'O'}
# {'as': 'O'} <class 'dict'> {'as': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'predictor': 'O'} <class 'dict'> {'predictor': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {"'": 'O'} <class 'dict'> {"'": 'O'}
# {'difficult': 'O'} <class 'dict'> {'difficult': 'O'}
# {"'": 'O'} <class 'dict'> {"'": 'O'}
# {'extraction': 'O'} <class 'dict'> {'extraction': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'specificity': 'O'} <class 'dict'> {'specificity': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'88': 'O'} <class 'dict'> {'88': 'O'}
# {'%': 'O'} <class 'dict'> {'%': 'O'}
# {'but': 'O'} <class 'dict'> {'but': 'O'}
# {'sensitivity': 'O'} <class 'dict'> {'sensitivity': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'low': 'O'} <class 'dict'> {'low': 'O'}
# {'at': 'O'} <class 'dict'> {'at': 'O'}
# {'15': 'O'} <class 'dict'> {'15': 'O'}
# {'%.': 'O'} <class 'dict'> {'%.': 'O'}
# 13648:
# {'In': 'O'} <class 'dict'> {'In': 'O'}
# {'addition': 'O'} <class 'dict'> {'addition': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'our': 'O'} <class 'dict'> {'our': 'O'}
# {'results': 'O'} <class 'dict'> {'results': 'O'}
# {'show': 'O'} <class 'dict'> {'show': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'ERKs': 'B'} <class 'dict'> {'ERKs': 'B'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'PI3Ks': 'B'} <class 'dict'> {'PI3Ks': 'B'}
# {'can': 'O'} <class 'dict'> {'can': 'O'}
# {'synergise': 'O'} <class 'dict'> {'synergise': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'convert': 'O'} <class 'dict'> {'convert': 'O'}
# {'ectoderm': 'O'} <class 'dict'> {'ectoderm': 'O'}
# {'into': 'O'} <class 'dict'> {'into': 'O'}
# {'mesoderm': 'O'} <class 'dict'> {'mesoderm': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13649:
# {'Based': 'O'} <class 'dict'> {'Based': 'O'}
# {'on': 'O'} <class 'dict'> {'on': 'O'}
# {'16S': 'B'} <class 'dict'> {'16S': 'B'}
# {'rRNA': 'I'} <class 'dict'> {'rRNA': 'I'}
# {'gene': 'I'} <class 'dict'> {'gene': 'I'}
# {'sequence': 'O'} <class 'dict'> {'sequence': 'O'}
# {'analysis': 'O'} <class 'dict'> {'analysis': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'11': 'O'} <class 'dict'> {'11': 'O'}
# {'species': 'O'} <class 'dict'> {'species': 'O'}
# {'having': 'O'} <class 'dict'> {'having': 'O'}
# {'two': 'O'} <class 'dict'> {'two': 'O'}
# {'tuf': 'B'} <class 'dict'> {'tuf': 'B'}
# {'genes': 'I'} <class 'dict'> {'genes': 'I'}
# {'all': 'O'} <class 'dict'> {'all': 'O'}
# {'have': 'O'} <class 'dict'> {'have': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'common': 'O'} <class 'dict'> {'common': 'O'}
# {'ancestor': 'O'} <class 'dict'> {'ancestor': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'while': 'O'} <class 'dict'> {'while': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'six': 'O'} <class 'dict'> {'six': 'O'}
# {'species': 'O'} <class 'dict'> {'species': 'O'}
# {'having': 'O'} <class 'dict'> {'having': 'O'}
# {'only': 'O'} <class 'dict'> {'only': 'O'}
# {'one': 'O'} <class 'dict'> {'one': 'O'}
# {'copy': 'O'} <class 'dict'> {'copy': 'O'}
# {'diverged': 'O'} <class 'dict'> {'diverged': 'O'}
# {'from': 'O'} <class 'dict'> {'from': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'enterococcal': 'O'} <class 'dict'> {'enterococcal': 'O'}
# {'lineage': 'O'} <class 'dict'> {'lineage': 'O'}
# {'before': 'O'} <class 'dict'> {'before': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'common': 'O'} <class 'dict'> {'common': 'O'}
# {'ancestor': 'O'} <class 'dict'> {'ancestor': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13650:
# {'Nevertheless': 'O'} <class 'dict'> {'Nevertheless': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'protein': 'B'} <class 'dict'> {'protein': 'B'}
# {'kinase': 'I'} <class 'dict'> {'kinase': 'I'}
# {'A': 'I'} <class 'dict'> {'A': 'I'}
# {'stimulation': 'O'} <class 'dict'> {'stimulation': 'O'}
# {'induces': 'O'} <class 'dict'> {'induces': 'O'}
# {'CREMalpha': 'B'} <class 'dict'> {'CREMalpha': 'B'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'activate': 'O'} <class 'dict'> {'activate': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'complex': 'O'} <class 'dict'> {'complex': 'O'}
# {'native': 'O'} <class 'dict'> {'native': 'O'}
# {'promoter': 'O'} <class 'dict'> {'promoter': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'phosphoenolpyruvate': 'B'} <class 'dict'> {'phosphoenolpyruvate': 'B'}
# {'carboxykinase': 'I'} <class 'dict'> {'carboxykinase': 'I'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'PEPCK': 'B'} <class 'dict'> {'PEPCK': 'B'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'gene': 'O'} <class 'dict'> {'gene': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13651:
# {'Another': 'O'} <class 'dict'> {'Another': 'O'}
# {'putative': 'O'} <class 'dict'> {'putative': 'O'}
# {'HNF3': 'B'} <class 'dict'> {'HNF3': 'B'}
# {'site': 'I'} <class 'dict'> {'site': 'I'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'close': 'O'} <class 'dict'> {'close': 'O'}
# {'apposition': 'O'} <class 'dict'> {'apposition': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'NF1': 'B'} <class 'dict'> {'NF1': 'B'}
# {'/': 'I'} <class 'dict'> {'/': 'I'}
# {'CTF': 'I'} <class 'dict'> {'CTF': 'I'}
# {'site': 'I'} <class 'dict'> {'site': 'I'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'localized': 'O'} <class 'dict'> {'localized': 'O'}
# {'upstream': 'O'} <class 'dict'> {'upstream': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'silencer': 'O'} <class 'dict'> {'silencer': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'like': 'O'} <class 'dict'> {'like': 'O'}
# {'element': 'O'} <class 'dict'> {'element': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13652:
# {'This': 'O'} <class 'dict'> {'This': 'O'}
# {'transcriptional': 'O'} <class 'dict'> {'transcriptional': 'O'}
# {'regulation': 'O'} <class 'dict'> {'regulation': 'O'}
# {'occurs': 'O'} <class 'dict'> {'occurs': 'O'}
# {'through': 'O'} <class 'dict'> {'through': 'O'}
# {'modulation': 'O'} <class 'dict'> {'modulation': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'forkhead': 'B'} <class 'dict'> {'forkhead': 'B'}
# {'transcription': 'I'} <class 'dict'> {'transcription': 'I'}
# {'factor': 'I'} <class 'dict'> {'factor': 'I'}
# {'FKHR': 'I'} <class 'dict'> {'FKHR': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'L1': 'I'} <class 'dict'> {'L1': 'I'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'IL': 'B'} <class 'dict'> {'IL': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'3': 'I'} <class 'dict'> {'3': 'I'}
# {'inhibited': 'O'} <class 'dict'> {'inhibited': 'O'}
# {'FKHR': 'B'} <class 'dict'> {'FKHR': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'L1': 'I'} <class 'dict'> {'L1': 'I'}
# {'activity': 'O'} <class 'dict'> {'activity': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'PI3K': 'O'} <class 'dict'> {'PI3K': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'dependent': 'O'} <class 'dict'> {'dependent': 'O'}
# {'manner': 'O'} <class 'dict'> {'manner': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13653:
# {'Taken': 'O'} <class 'dict'> {'Taken': 'O'}
# {'together': 'O'} <class 'dict'> {'together': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'these': 'O'} <class 'dict'> {'these': 'O'}
# {'observations': 'O'} <class 'dict'> {'observations': 'O'}
# {'indicate': 'O'} <class 'dict'> {'indicate': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'inhibition': 'O'} <class 'dict'> {'inhibition': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'p27': 'B'} <class 'dict'> {'p27': 'B'}
# {'(': 'I'} <class 'dict'> {'(': 'I'}
# {'KIP1': 'I'} <class 'dict'> {'KIP1': 'I'}
# {')': 'I'} <class 'dict'> {')': 'I'}
# {'transcription': 'O'} <class 'dict'> {'transcription': 'O'}
# {'through': 'O'} <class 'dict'> {'through': 'O'}
# {'PI3K': 'B'} <class 'dict'> {'PI3K': 'B'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'induced': 'O'} <class 'dict'> {'induced': 'O'}
# {'FKHR': 'B'} <class 'dict'> {'FKHR': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'L1': 'I'} <class 'dict'> {'L1': 'I'}
# {'phosphorylation': 'O'} <class 'dict'> {'phosphorylation': 'O'}
# {'provides': 'O'} <class 'dict'> {'provides': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'novel': 'O'} <class 'dict'> {'novel': 'O'}
# {'mechanism': 'O'} <class 'dict'> {'mechanism': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'regulating': 'O'} <class 'dict'> {'regulating': 'O'}
# {'cytokine': 'O'} <class 'dict'> {'cytokine': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'mediated': 'O'} <class 'dict'> {'mediated': 'O'}
# {'survival': 'O'} <class 'dict'> {'survival': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'proliferation': 'O'} <class 'dict'> {'proliferation': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13654:
# {'DNase': 'B'} <class 'dict'> {'DNase': 'B'}
# {'I': 'I'} <class 'dict'> {'I': 'I'}
# {'genomic': 'O'} <class 'dict'> {'genomic': 'O'}
# {'footprinting': 'O'} <class 'dict'> {'footprinting': 'O'}
# {'revealed': 'O'} <class 'dict'> {'revealed': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'c': 'B'} <class 'dict'> {'c': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'Myb': 'I'} <class 'dict'> {'Myb': 'I'}
# {'site': 'I'} <class 'dict'> {'site': 'I'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'occupied': 'O'} <class 'dict'> {'occupied': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'tissue': 'O'} <class 'dict'> {'tissue': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'specific': 'O'} <class 'dict'> {'specific': 'O'}
# {'fashion': 'O'} <class 'dict'> {'fashion': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'vivo': 'O'} <class 'dict'> {'vivo': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13655:
# {'We': 'O'} <class 'dict'> {'We': 'O'}
# {'conclude': 'O'} <class 'dict'> {'conclude': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'c': 'B'} <class 'dict'> {'c': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'Myb': 'I'} <class 'dict'> {'Myb': 'I'}
# {'regulates': 'O'} <class 'dict'> {'regulates': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'RAG': 'B'} <class 'dict'> {'RAG': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'2': 'I'} <class 'dict'> {'2': 'I'}
# {'promoter': 'I'} <class 'dict'> {'promoter': 'I'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'T': 'O'} <class 'dict'> {'T': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'binding': 'O'} <class 'dict'> {'binding': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'this': 'O'} <class 'dict'> {'this': 'O'}
# {'consensus': 'O'} <class 'dict'> {'consensus': 'O'}
# {'c': 'B'} <class 'dict'> {'c': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'Myb': 'I'} <class 'dict'> {'Myb': 'I'}
# {'binding': 'I'} <class 'dict'> {'binding': 'I'}
# {'site': 'I'} <class 'dict'> {'site': 'I'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13656:
# {'A': 'O'} <class 'dict'> {'A': 'O'}
# {'recently': 'O'} <class 'dict'> {'recently': 'O'}
# {'reported': 'O'} <class 'dict'> {'reported': 'O'}
# {'new': 'O'} <class 'dict'> {'new': 'O'}
# {'member': 'O'} <class 'dict'> {'member': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'Vav': 'B'} <class 'dict'> {'Vav': 'B'}
# {'family': 'I'} <class 'dict'> {'family': 'I'}
# {'proteins': 'I'} <class 'dict'> {'proteins': 'I'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'Vav3': 'B'} <class 'dict'> {'Vav3': 'B'}
# {'has': 'O'} <class 'dict'> {'has': 'O'}
# {'been': 'O'} <class 'dict'> {'been': 'O'}
# {'identified': 'O'} <class 'dict'> {'identified': 'O'}
# {'as': 'O'} <class 'dict'> {'as': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'Ros': 'B'} <class 'dict'> {'Ros': 'B'}
# {'receptor': 'I'} <class 'dict'> {'receptor': 'I'}
# {'protein': 'I'} <class 'dict'> {'protein': 'I'}
# {'tyrosine': 'I'} <class 'dict'> {'tyrosine': 'I'}
# {'kinase': 'I'} <class 'dict'> {'kinase': 'I'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'RPTK': 'B'} <class 'dict'> {'RPTK': 'B'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'interacting': 'O'} <class 'dict'> {'interacting': 'O'}
# {'protein': 'O'} <class 'dict'> {'protein': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'yeast': 'O'} <class 'dict'> {'yeast': 'O'}
# {'two': 'O'} <class 'dict'> {'two': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'hybrid': 'O'} <class 'dict'> {'hybrid': 'O'}
# {'screening': 'O'} <class 'dict'> {'screening': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13657:
# {'Subsequently': 'O'} <class 'dict'> {'Subsequently': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'we': 'O'} <class 'dict'> {'we': 'O'}
# {'show': 'O'} <class 'dict'> {'show': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'reexpression': 'O'} <class 'dict'> {'reexpression': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'r': 'B'} <class 'dict'> {'r': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'PTPeta': 'I'} <class 'dict'> {'PTPeta': 'I'}
# {'gene': 'I'} <class 'dict'> {'gene': 'I'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'highly': 'O'} <class 'dict'> {'highly': 'O'}
# {'malignant': 'O'} <class 'dict'> {'malignant': 'O'}
# {'rat': 'O'} <class 'dict'> {'rat': 'O'}
# {'thyroid': 'O'} <class 'dict'> {'thyroid': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'transformed': 'O'} <class 'dict'> {'transformed': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'retroviruses': 'O'} <class 'dict'> {'retroviruses': 'O'}
# {'carrying': 'O'} <class 'dict'> {'carrying': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'v': 'B'} <class 'dict'> {'v': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'mos': 'I'} <class 'dict'> {'mos': 'I'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'v': 'B'} <class 'dict'> {'v': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'ras': 'I'} <class 'dict'> {'ras': 'I'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'Ki': 'B'} <class 'dict'> {'Ki': 'B'}
# {'oncogenes': 'O'} <class 'dict'> {'oncogenes': 'O'}
# {'suppresses': 'O'} <class 'dict'> {'suppresses': 'O'}
# {'their': 'O'} <class 'dict'> {'their': 'O'}
# {'malignant': 'O'} <class 'dict'> {'malignant': 'O'}
# {'phenotype': 'O'} <class 'dict'> {'phenotype': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13658:
# {'Induced': 'O'} <class 'dict'> {'Induced': 'O'}
# {'expression': 'O'} <class 'dict'> {'expression': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'Rnd3': 'B'} <class 'dict'> {'Rnd3': 'B'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'associated': 'O'} <class 'dict'> {'associated': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'transformation': 'O'} <class 'dict'> {'transformation': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'polarized': 'O'} <class 'dict'> {'polarized': 'O'}
# {'epithelial': 'O'} <class 'dict'> {'epithelial': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'Raf': 'B'} <class 'dict'> {'Raf': 'B'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'MEK': 'B'} <class 'dict'> {'MEK': 'B'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'extracellular': 'B'} <class 'dict'> {'extracellular': 'B'}
# {'signal': 'I'} <class 'dict'> {'signal': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'regulated': 'I'} <class 'dict'> {'regulated': 'I'}
# {'kinase': 'I'} <class 'dict'> {'kinase': 'I'}
# {'pathway': 'O'} <class 'dict'> {'pathway': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13659:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'activity': 'O'} <class 'dict'> {'activity': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'transcription': 'O'} <class 'dict'> {'transcription': 'O'}
# {'factor': 'O'} <class 'dict'> {'factor': 'O'}
# {'CREB': 'B'} <class 'dict'> {'CREB': 'B'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'regulated': 'O'} <class 'dict'> {'regulated': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'extracellular': 'O'} <class 'dict'> {'extracellular': 'O'}
# {'stimuli': 'O'} <class 'dict'> {'stimuli': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'result': 'O'} <class 'dict'> {'result': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'its': 'O'} <class 'dict'> {'its': 'O'}
# {'phosphorylation': 'O'} <class 'dict'> {'phosphorylation': 'O'}
# {'at': 'O'} <class 'dict'> {'at': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'critical': 'O'} <class 'dict'> {'critical': 'O'}
# {'serine': 'O'} <class 'dict'> {'serine': 'O'}
# {'residue': 'O'} <class 'dict'> {'residue': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'Ser133': 'O'} <class 'dict'> {'Ser133': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13660:
# {'RESULTS': 'O'} <class 'dict'> {'RESULTS': 'O'}
# {':': 'O'} <class 'dict'> {':': 'O'}
# {'Average': 'O'} <class 'dict'> {'Average': 'O'}
# {'age': 'O'} <class 'dict'> {'age': 'O'}
# {'at': 'O'} <class 'dict'> {'at': 'O'}
# {'symptom': 'O'} <class 'dict'> {'symptom': 'O'}
# {'onset': 'O'} <class 'dict'> {'onset': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'41': 'O'} <class 'dict'> {'41': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# {'2': 'O'} <class 'dict'> {'2': 'O'}
# {'years': 'O'} <class 'dict'> {'years': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13661:
# {'When': 'O'} <class 'dict'> {'When': 'O'}
# {'10': 'O'} <class 'dict'> {'10': 'O'}
# {'fields': 'O'} <class 'dict'> {'fields': 'O'}
# {'were': 'O'} <class 'dict'> {'were': 'O'}
# {'analysed': 'O'} <class 'dict'> {'analysed': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'strong': 'O'} <class 'dict'> {'strong': 'O'}
# {'relationship': 'O'} <class 'dict'> {'relationship': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'found': 'O'} <class 'dict'> {'found': 'O'}
# {'between': 'O'} <class 'dict'> {'between': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'presence': 'O'} <class 'dict'> {'presence': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'bacteria': 'O'} <class 'dict'> {'bacteria': 'O'}
# {'on': 'O'} <class 'dict'> {'on': 'O'}
# {'Gram': 'O'} <class 'dict'> {'Gram': 'O'}
# {'staining': 'O'} <class 'dict'> {'staining': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'final': 'O'} <class 'dict'> {'final': 'O'}
# {'diagnosis': 'O'} <class 'dict'> {'diagnosis': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'VAP': 'O'} <class 'dict'> {'VAP': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'PSB': 'O'} <class 'dict'> {'PSB': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'PTC': 'O'} <class 'dict'> {'PTC': 'O'}
# {'respectively': 'O'} <class 'dict'> {'respectively': 'O'}
# {':': 'O'} <class 'dict'> {':': 'O'}
# {'sensitivity': 'O'} <class 'dict'> {'sensitivity': 'O'}
# {'74': 'O'} <class 'dict'> {'74': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'81': 'O'} <class 'dict'> {'81': 'O'}
# {'%,': 'O'} <class 'dict'> {'%,': 'O'}
# {'specificity': 'O'} <class 'dict'> {'specificity': 'O'}
# {'94': 'O'} <class 'dict'> {'94': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'100': 'O'} <class 'dict'> {'100': 'O'}
# {'%,': 'O'} <class 'dict'> {'%,': 'O'}
# {'positive': 'O'} <class 'dict'> {'positive': 'O'}
# {'predictive': 'O'} <class 'dict'> {'predictive': 'O'}
# {'value': 'O'} <class 'dict'> {'value': 'O'}
# {'91': 'O'} <class 'dict'> {'91': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'100': 'O'} <class 'dict'> {'100': 'O'}
# {'%,': 'O'} <class 'dict'> {'%,': 'O'}
# {'negative': 'O'} <class 'dict'> {'negative': 'O'}
# {'predictive': 'O'} <class 'dict'> {'predictive': 'O'}
# 13662:
# {'Unlike': 'O'} <class 'dict'> {'Unlike': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'mammalian': 'O'} <class 'dict'> {'mammalian': 'O'}
# {'proteins': 'O'} <class 'dict'> {'proteins': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'XFGF3': 'B'} <class 'dict'> {'XFGF3': 'B'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'efficiently': 'O'} <class 'dict'> {'efficiently': 'O'}
# {'secreted': 'O'} <class 'dict'> {'secreted': 'O'}
# {'as': 'O'} <class 'dict'> {'as': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'Mr': 'O'} <class 'dict'> {'Mr': 'O'}
# {'31': 'O'} <class 'dict'> {'31': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'000': 'O'} <class 'dict'> {'000': 'O'}
# {'glycoprotein': 'O'} <class 'dict'> {'glycoprotein': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'gp31': 'B'} <class 'dict'> {'gp31': 'B'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'which': 'O'} <class 'dict'> {'which': 'O'}
# {'undergoes': 'O'} <class 'dict'> {'undergoes': 'O'}
# {'proteolytic': 'O'} <class 'dict'> {'proteolytic': 'O'}
# {'cleavage': 'O'} <class 'dict'> {'cleavage': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'produce': 'O'} <class 'dict'> {'produce': 'O'}
# {'an': 'O'} <class 'dict'> {'an': 'O'}
# {'NH2': 'O'} <class 'dict'> {'NH2': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'terminally': 'O'} <class 'dict'> {'terminally': 'O'}
# {'truncated': 'O'} <class 'dict'> {'truncated': 'O'}
# {'product': 'O'} <class 'dict'> {'product': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'gp27': 'B'} <class 'dict'> {'gp27': 'B'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13663:
# {'NH2': 'O'} <class 'dict'> {'NH2': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'terminal': 'O'} <class 'dict'> {'terminal': 'O'}
# {'trimming': 'O'} <class 'dict'> {'trimming': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'Xenopus': 'B'} <class 'dict'> {'Xenopus': 'B'}
# {'and': 'I'} <class 'dict'> {'and': 'I'}
# {'mammalian': 'I'} <class 'dict'> {'mammalian': 'I'}
# {'FGF3s': 'I'} <class 'dict'> {'FGF3s': 'I'}
# {'may': 'O'} <class 'dict'> {'may': 'O'}
# {'therefore': 'O'} <class 'dict'> {'therefore': 'O'}
# {'be': 'O'} <class 'dict'> {'be': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# ...
# {'or': 'O'} <class 'dict'> {'or': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'G': 'B'} <class 'dict'> {'G': 'B'}
# {'protein': 'I'} <class 'dict'> {'protein': 'I'}
# {'beta': 'I'} <class 'dict'> {'beta': 'I'}
# {'gamma': 'I'} <class 'dict'> {'gamma': 'I'}
# {'subunits': 'I'} <class 'dict'> {'subunits': 'I'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13785:
# {'Deletion': 'O'} <class 'dict'> {'Deletion': 'O'}
# {'analysis': 'O'} <class 'dict'> {'analysis': 'O'}
# {'showed': 'O'} <class 'dict'> {'showed': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'321': 'O'} <class 'dict'> {'321': 'O'}
# {'/+': 'O'} <class 'dict'> {'/+': 'O'}
# {'41': 'O'} <class 'dict'> {'41': 'O'}
# {'sequence': 'O'} <class 'dict'> {'sequence': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'sufficient': 'O'} <class 'dict'> {'sufficient': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'both': 'O'} <class 'dict'> {'both': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'constitutive': 'O'} <class 'dict'> {'constitutive': 'O'}
# {'promoter': 'O'} <class 'dict'> {'promoter': 'O'}
# {'activity': 'O'} <class 'dict'> {'activity': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'auto': 'O'} <class 'dict'> {'auto': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'activation': 'O'} <class 'dict'> {'activation': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'electrophoretic': 'O'} <class 'dict'> {'electrophoretic': 'O'}
# {'mobility': 'O'} <class 'dict'> {'mobility': 'O'}
# {'shift': 'O'} <class 'dict'> {'shift': 'O'}
# {'assays': 'O'} <class 'dict'> {'assays': 'O'}
# {'identified': 'O'} <class 'dict'> {'identified': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'interaction': 'O'} <class 'dict'> {'interaction': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'C': 'B'} <class 'dict'> {'C': 'B'}
# {'/': 'I'} <class 'dict'> {'/': 'I'}
# {'EBPs': 'I'} <class 'dict'> {'EBPs': 'I'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'Sp1': 'B'} <class 'dict'> {'Sp1': 'B'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'this': 'O'} <class 'dict'> {'this': 'O'}
# {'region': 'O'} <class 'dict'> {'region': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13786:
# {'Termination': 'O'} <class 'dict'> {'Termination': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'induced': 'O'} <class 'dict'> {'induced': 'O'}
# {'VT': 'O'} <class 'dict'> {'VT': 'O'}
# {'on': 'O'} <class 'dict'> {'on': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'first': 'O'} <class 'dict'> {'first': 'O'}
# {'attempt': 'O'} <class 'dict'> {'attempt': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'comparable': 'O'} <class 'dict'> {'comparable': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'BV': 'O'} <class 'dict'> {'BV': 'O'}
# {'pacing': 'O'} <class 'dict'> {'pacing': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'87': 'O'} <class 'dict'> {'87': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# {'4': 'O'} <class 'dict'> {'4': 'O'}
# {'%)': 'O'} <class 'dict'> {'%)': 'O'}
# {'versus': 'O'} <class 'dict'> {'versus': 'O'}
# {'RV': 'O'} <class 'dict'> {'RV': 'O'}
# {'pacing': 'O'} <class 'dict'> {'pacing': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'89': 'O'} <class 'dict'> {'89': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# {'6': 'O'} <class 'dict'> {'6': 'O'}
# {'%).': 'O'} <class 'dict'> {'%).': 'O'}
# 13787:
# {'We': 'O'} <class 'dict'> {'We': 'O'}
# {'compare': 'O'} <class 'dict'> {'compare': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'results': 'O'} <class 'dict'> {'results': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'this': 'O'} <class 'dict'> {'this': 'O'}
# {'algorithm': 'O'} <class 'dict'> {'algorithm': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'results': 'O'} <class 'dict'> {'results': 'O'}
# {'obtained': 'O'} <class 'dict'> {'obtained': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'two': 'O'} <class 'dict'> {'two': 'O'}
# {'other': 'O'} <class 'dict'> {'other': 'O'}
# {'algorithms': 'O'} <class 'dict'> {'algorithms': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'optimal': 'O'} <class 'dict'> {'optimal': 'O'}
# {'algorithm': 'O'} <class 'dict'> {'algorithm': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'monochannel': 'O'} <class 'dict'> {'monochannel': 'O'}
# {'nonoverlapping': 'O'} <class 'dict'> {'nonoverlapping': 'O'}
# {'noise': 'O'} <class 'dict'> {'noise': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'optimal': 'O'} <class 'dict'> {'optimal': 'O'}
# {'algorithm': 'O'} <class 'dict'> {'algorithm': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'multichannel': 'O'} <class 'dict'> {'multichannel': 'O'}
# {'additive': 'O'} <class 'dict'> {'additive': 'O'}
# {'noise': 'O'} <class 'dict'> {'noise': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'we': 'O'} <class 'dict'> {'we': 'O'}
# {'show': 'O'} <class 'dict'> {'show': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'both': 'O'} <class 'dict'> {'both': 'O'}
# {'cases': 'O'} <class 'dict'> {'cases': 'O'}
# {'improvement': 'O'} <class 'dict'> {'improvement': 'O'}
# {'can': 'O'} <class 'dict'> {'can': 'O'}
# {'be': 'O'} <class 'dict'> {'be': 'O'}
# {'obtained': 'O'} <class 'dict'> {'obtained': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13788:
# {'Changes': 'O'} <class 'dict'> {'Changes': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'stimulation': 'O'} <class 'dict'> {'stimulation': 'O'}
# {'levels': 'O'} <class 'dict'> {'levels': 'O'}
# {'over': 'O'} <class 'dict'> {'over': 'O'}
# {'time': 'O'} <class 'dict'> {'time': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'nucleus': 'O'} <class 'dict'> {'nucleus': 'O'}
# {'22': 'O'} <class 'dict'> {'22': 'O'}
# {'cochlear': 'O'} <class 'dict'> {'cochlear': 'O'}
# {'implant': 'O'} <class 'dict'> {'implant': 'O'}
# {'users': 'O'} <class 'dict'> {'users': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13789:
# {'Nuclease': 'O'} <class 'dict'> {'Nuclease': 'O'}
# {'probing': 'O'} <class 'dict'> {'probing': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'structure': 'O'} <class 'dict'> {'structure': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'directed': 'O'} <class 'dict'> {'directed': 'O'}
# {'mutagenesis': 'O'} <class 'dict'> {'mutagenesis': 'O'}
# {'revealed': 'O'} <class 'dict'> {'revealed': 'O'}
# {'that': 'O'} <class 'dict'> {'that': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'105': 'O'} <class 'dict'> {'105': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'nt': 'O'} <class 'dict'> {'nt': 'O'}
# {'TE': 'O'} <class 'dict'> {'TE': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'TE105': 'O'} <class 'dict'> {'TE105': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'forms': 'O'} <class 'dict'> {'forms': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'cruciform': 'O'} <class 'dict'> {'cruciform': 'O'}
# {'secondary': 'O'} <class 'dict'> {'secondary': 'O'}
# {'structure': 'O'} <class 'dict'> {'structure': 'O'}
# {'containing': 'O'} <class 'dict'> {'containing': 'O'}
# {'four': 'O'} <class 'dict'> {'four': 'O'}
# {'helices': 'O'} <class 'dict'> {'helices': 'O'}
# {'connected': 'O'} <class 'dict'> {'connected': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'single': 'O'} <class 'dict'> {'single': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'stranded': 'O'} <class 'dict'> {'stranded': 'O'}
# {'regions': 'O'} <class 'dict'> {'regions': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13790:
# {'Tele': 'O'} <class 'dict'> {'Tele': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'Talk': 'O'} <class 'dict'> {'Talk': 'O'}
# {'has': 'O'} <class 'dict'> {'has': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'extra': 'O'} <class 'dict'> {'extra': 'O'}
# {'capability': 'O'} <class 'dict'> {'capability': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'operating': 'O'} <class 'dict'> {'operating': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'live': 'O'} <class 'dict'> {'live': 'O'}
# {'conference': 'O'} <class 'dict'> {'conference': 'O'}
# {'situations': 'O'} <class 'dict'> {'situations': 'O'}
# {'using': 'O'} <class 'dict'> {'using': 'O'}
# {'microphone': 'O'} <class 'dict'> {'microphone': 'O'}
# {'input': 'O'} <class 'dict'> {'input': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13791:
# {'A': 'O'} <class 'dict'> {'A': 'O'}
# {'marked': 'O'} <class 'dict'> {'marked': 'O'}
# {'decrease': 'O'} <class 'dict'> {'decrease': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'type': 'B'} <class 'dict'> {'type': 'B'}
# {'1': 'I'} <class 'dict'> {'1': 'I'}
# {'insulin': 'I'} <class 'dict'> {'insulin': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'like': 'I'} <class 'dict'> {'like': 'I'}
# {'growth': 'I'} <class 'dict'> {'growth': 'I'}
# {'factor': 'I'} <class 'dict'> {'factor': 'I'}
# {'(': 'I'} <class 'dict'> {'(': 'I'}
# {'IGF': 'I'} <class 'dict'> {'IGF': 'I'}
# {')': 'I'} <class 'dict'> {')': 'I'}
# {'receptor': 'I'} <class 'dict'> {'receptor': 'I'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'IGF': 'B'} <class 'dict'> {'IGF': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'IR': 'I'} <class 'dict'> {'IR': 'I'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'occurs': 'O'} <class 'dict'> {'occurs': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'prostate': 'O'} <class 'dict'> {'prostate': 'O'}
# {'epithelial': 'O'} <class 'dict'> {'epithelial': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'during': 'O'} <class 'dict'> {'during': 'O'}
# {'transformation': 'O'} <class 'dict'> {'transformation': 'O'}
# {'from': 'O'} <class 'dict'> {'from': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'benign': 'O'} <class 'dict'> {'benign': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'metastatic': 'O'} <class 'dict'> {'metastatic': 'O'}
# {'state': 'O'} <class 'dict'> {'state': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13792:
# {'The': 'O'} <class 'dict'> {'The': 'O'}
# {'P69': 'O'} <class 'dict'> {'P69': 'O'}
# {'cell': 'O'} <class 'dict'> {'cell': 'O'}
# {'line': 'O'} <class 'dict'> {'line': 'O'}
# {'was': 'O'} <class 'dict'> {'was': 'O'}
# {'derived': 'O'} <class 'dict'> {'derived': 'O'}
# {'by': 'O'} <class 'dict'> {'by': 'O'}
# {'immortalization': 'O'} <class 'dict'> {'immortalization': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'human': 'O'} <class 'dict'> {'human': 'O'}
# {'primary': 'O'} <class 'dict'> {'primary': 'O'}
# {'prostate': 'O'} <class 'dict'> {'prostate': 'O'}
# {'epithelial': 'O'} <class 'dict'> {'epithelial': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'with': 'O'} <class 'dict'> {'with': 'O'}
# {'simian': 'B'} <class 'dict'> {'simian': 'B'}
# {'virus': 'I'} <class 'dict'> {'virus': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'40': 'I'} <class 'dict'> {'40': 'I'}
# {'T': 'I'} <class 'dict'> {'T': 'I'}
# {'antigen': 'I'} <class 'dict'> {'antigen': 'I'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'rarely': 'O'} <class 'dict'> {'rarely': 'O'}
# {'tumorigenic': 'O'} <class 'dict'> {'tumorigenic': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13793:
# {'We': 'O'} <class 'dict'> {'We': 'O'}
# {'determined': 'O'} <class 'dict'> {'determined': 'O'}
# {'whether': 'O'} <class 'dict'> {'whether': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'human': 'B'} <class 'dict'> {'human': 'B'}
# {'StAR': 'I'} <class 'dict'> {'StAR': 'I'}
# {'promoter': 'I'} <class 'dict'> {'promoter': 'I'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'responsive': 'O'} <class 'dict'> {'responsive': 'O'}
# {'to': 'O'} <class 'dict'> {'to': 'O'}
# {'sterol': 'B'} <class 'dict'> {'sterol': 'B'}
# {'regulatory': 'I'} <class 'dict'> {'regulatory': 'I'}
# {'element': 'I'} <class 'dict'> {'element': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'binding': 'I'} <class 'dict'> {'binding': 'I'}
# {'proteins': 'I'} <class 'dict'> {'proteins': 'I'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'SREBPs': 'B'} <class 'dict'> {'SREBPs': 'B'}
# {').': 'O'} <class 'dict'> {').': 'O'}
# 13794:
# {'Expression': 'O'} <class 'dict'> {'Expression': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'SREBP': 'B'} <class 'dict'> {'SREBP': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'1a': 'I'} <class 'dict'> {'1a': 'I'}
# {'stimulated': 'O'} <class 'dict'> {'stimulated': 'O'}
# {'StAR': 'B'} <class 'dict'> {'StAR': 'B'}
# {'promoter': 'I'} <class 'dict'> {'promoter': 'I'}
# {'activity': 'O'} <class 'dict'> {'activity': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'context': 'O'} <class 'dict'> {'context': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'COS': 'O'} <class 'dict'> {'COS': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'1': 'O'} <class 'dict'> {'1': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'human': 'O'} <class 'dict'> {'human': 'O'}
# {'granulosa': 'O'} <class 'dict'> {'granulosa': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'lutein': 'O'} <class 'dict'> {'lutein': 'O'}
# {'cells': 'O'} <class 'dict'> {'cells': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13795:
# {'Because': 'O'} <class 'dict'> {'Because': 'O'}
# {'the': 'O'} <class 'dict'> {'the': 'O'}
# {'high': 'B'} <class 'dict'> {'high': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'density': 'I'} <class 'dict'> {'density': 'I'}
# {'lipoprotein': 'I'} <class 'dict'> {'lipoprotein': 'I'}
# {'receptor': 'I'} <class 'dict'> {'receptor': 'I'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'HDL': 'B'} <class 'dict'> {'HDL': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'R': 'I'} <class 'dict'> {'R': 'I'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'key': 'O'} <class 'dict'> {'key': 'O'}
# {'element': 'O'} <class 'dict'> {'element': 'O'}
# {'in': 'O'} <class 'dict'> {'in': 'O'}
# {'cholesterol': 'O'} <class 'dict'> {'cholesterol': 'O'}
# {'homeostasis': 'O'} <class 'dict'> {'homeostasis': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'a': 'O'} <class 'dict'> {'a': 'O'}
# {'potential': 'O'} <class 'dict'> {'potential': 'O'}
# {'therapeutic': 'O'} <class 'dict'> {'therapeutic': 'O'}
# {'target': 'O'} <class 'dict'> {'target': 'O'}
# {'for': 'O'} <class 'dict'> {'for': 'O'}
# {'hypercholesterolemic': 'O'} <class 'dict'> {'hypercholesterolemic': 'O'}
# {'drugs': 'O'} <class 'dict'> {'drugs': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'an': 'O'} <class 'dict'> {'an': 'O'}
# {'understanding': 'O'} <class 'dict'> {'understanding': 'O'}
# {'of': 'O'} <class 'dict'> {'of': 'O'}
# {'HDL': 'B'} <class 'dict'> {'HDL': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'R': 'I'} <class 'dict'> {'R': 'I'}
# {'regulation': 'O'} <class 'dict'> {'regulation': 'O'}
# {'is': 'O'} <class 'dict'> {'is': 'O'}
# {'essential': 'O'} <class 'dict'> {'essential': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}
# 13796:
# {'IFN': 'B'} <class 'dict'> {'IFN': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'stimulated': 'I'} <class 'dict'> {'stimulated': 'I'}
# {'gene': 'I'} <class 'dict'> {'gene': 'I'}
# {'factor': 'I'} <class 'dict'> {'factor': 'I'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'3': 'I'} <class 'dict'> {'3': 'I'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'STAT1': 'B'} <class 'dict'> {'STAT1': 'B'}
# {'homodimers': 'I'} <class 'dict'> {'homodimers': 'I'}
# {'formed': 'O'} <class 'dict'> {'formed': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'bound': 'O'} <class 'dict'> {'bound': 'O'}
# {'an': 'O'} <class 'dict'> {'an': 'O'}
# {'IFN': 'B'} <class 'dict'> {'IFN': 'B'}
# {'-': 'I'} <class 'dict'> {'-': 'I'}
# {'stimulated': 'I'} <class 'dict'> {'stimulated': 'I'}
# {'response': 'I'} <class 'dict'> {'response': 'I'}
# {'element': 'I'} <class 'dict'> {'element': 'I'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'ISRE': 'O'} <class 'dict'> {'ISRE': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'and': 'O'} <class 'dict'> {'and': 'O'}
# {'gamma': 'O'} <class 'dict'> {'gamma': 'O'}
# {'-': 'O'} <class 'dict'> {'-': 'O'}
# {'activated': 'O'} <class 'dict'> {'activated': 'O'}
# {'sequence': 'O'} <class 'dict'> {'sequence': 'O'}
# {'(': 'O'} <class 'dict'> {'(': 'O'}
# {'GAS': 'O'} <class 'dict'> {'GAS': 'O'}
# {')': 'O'} <class 'dict'> {')': 'O'}
# {'element': 'O'} <class 'dict'> {'element': 'O'}
# {',': 'O'} <class 'dict'> {',': 'O'}
# {'respectively': 'O'} <class 'dict'> {'respectively': 'O'}
# {'.': 'O'} <class 'dict'> {'.': 'O'}

# %%
df_preds = pd.DataFrame.from_records(preds)
df_preds.head(30)
# Out:
#      0            1  2
# 0    1          The  O
# 1    2      genomic  O
# 2    3    fragments  O
# 3    4         were  O
# 4    5        fused  O
# 5    6     upstream  O
# 6    7           of  O
# 7    8          the  O
# 8    9   luciferase  B
# 9   10     reporter  I
# 10  11         gene  I
# 11  12            .  O
# 12   1           In  O
# 13   2         some  O
# 14   3        cases  O
# 15   4            ,  O
# 16   5          the  O
# 17   6     aberrant  O
# 18   7  methylation  O
# 19   8           of  O
# 20   9         CpGs  O
# 21  10       within  O
# 22  11            5  O
# 23  12            '  O
# 24  13   regulatory  O
# 25  14      regions  O
# 26  15          has  O
# 27  16          led  O
# 28  17           to  O
# 29  18  suppression  O

# %%
df_preds.to_csv('/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/preds_biobert.csv', sep="\t", header=False, index = False)

# %%
samples = [sample]
predictions, _ = model.predict(samples)
print(predictions, samples)
for idx, sample in enumerate(samples):
  print('{}: '.format(idx))
  for word in predictions[idx]:
    print('{}'.format(word))
# Out:
# INFO:simpletransformers.ner.ner_model: Converting to features started.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [[{'Deletion': 'O'}, {'of': 'O'}, {'the': 'O'}, {'last': 'O'}, {'two': 'O'}, {'Ser': 'O'}, {'residues': 'O'}, {',': 'O'}, {'including': 'O'}, {'one': 'O'}, {'PKC': 'B'}, {'consensus': 'I'}, {'site': 'I'}, {'in': 'O'}, {'the': 'O'}, {'receptor': 'O'}, {'tail': 'O'}, {',': 'O'}, {'prevented': 'O'}, {'only': 'O'}, {'phorbol': 'O'}, {'12': 'O'}, {'-': 'O'}, {'myristate': 'O'}, {'13': 'O'}, {'-': 'O'}, {'acetate': 'O'}, {'-': 'O'}, {'induced': 'O'}, {'desensitization': 'O'}, {'by': 'O'}, {'30': 'O'}, {'%.': 'O'}]] ['Deletion of the last two Ser residues , including one PKC consensus site in the receptor tail , prevented only phorbol 12 - myristate 13 - acetate - induced desensitization by 30 %.']
# 0:
# {'Deletion': 'O'}
# {'of': 'O'}
# {'the': 'O'}
# {'last': 'O'}
# {'two': 'O'}
# {'Ser': 'O'}
# {'residues': 'O'}
# {',': 'O'}
# {'including': 'O'}
# {'one': 'O'}
# {'PKC': 'B'}
# {'consensus': 'I'}
# {'site': 'I'}
# {'in': 'O'}
# {'the': 'O'}
# {'receptor': 'O'}
# {'tail': 'O'}
# {',': 'O'}
# {'prevented': 'O'}
# {'only': 'O'}
# {'phorbol': 'O'}
# {'12': 'O'}
# {'-': 'O'}
# {'myristate': 'O'}
# {'13': 'O'}
# {'-': 'O'}
# {'acetate': 'O'}
# {'-': 'O'}
# {'induced': 'O'}
# {'desensitization': 'O'}
# {'by': 'O'}
# {'30': 'O'}
# {'%.': 'O'}

# %% [markdown]
# You can move the model checkpount files which are saved in the `/outputs/` directory to your Google Drive.

# %%
import shutil
shutil.move('/outputs/', "/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/outputs/")
# Out:
# '/content/drive/MyDrive/Colab Notebooks/entity-extraction/hw3/data_ner_hw/outputs/'

# %% [markdown]
# #### The results and analysis
# For comparative purpose, the results and analysis are conducted along with various other approaches implemented for this homework. Additionally, although results from validation do seem impressive, the performance is far apart from expected and/or reasonable f1-scores. The results are covered in detail in final report.
